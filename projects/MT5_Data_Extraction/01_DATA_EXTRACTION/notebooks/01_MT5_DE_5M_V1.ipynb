# %%
# ============================ Celda 01 — Bootstrap y Control de Ejecución ============================
# Esta celda NO crea carpetas ni archivos y NO se conecta a MT5.
# Objetivo:
#   1) Iniciar contexto de ejecución con RUN_ID único (YYYYMMDD_HHMMSS).
#   2) Fijar explícitamente la zona horaria objetivo IANA: America/Guayaquil (GYE).
#      - Imprimir SIEMPRE hora en UTC y en GYE (para trazabilidad) y además la TZ local detectada.
#   3) Verificar espacio en disco mínimo (umbral configurable; por defecto 3 GiB).
#   4) Detectar e imprimir versión de Python, S.O., usuario (si aplica).
#   5) Definir flags de control de ejecución (solo inicialización):
#         - FORCE_REDOWNLOAD_BULK_M5 = False
#         - FORCE_REWRITE_DAY        = False
#         - TICKS_RECENT_DAYS        = 30
#         - DATA_VERSION             = "v1"
#         - WRITE_MODE               = "append"
#   6) Preparar variables simples para celdas siguientes (en memoria).
#
# Formato de salida (impresiones obligatorias, en este orden):
#   1) RUN_ID
#   2) Hora GYE (ISO 8601), hora UTC (ISO 8601), TZ objetivo (IANA) y TZ local detectada
#   3) Versión de Python y S.O. (y usuario si aplica)
#   4) Espacio en disco libre (GiB) y umbral requerido
#   5) Valores iniciales de los flags
#   6) Mensaje final:
#        - "✅ Bootstrap listo: OK para continuar con Celda 02"  (si pasa todo)
#        - Excepción con mensaje claro si NO hay espacio suficiente o si no se puede fijar la TZ IANA
# =====================================================================================================

from datetime import datetime, timezone
from pathlib import Path
import shutil
import platform
import getpass
import sys

# -------------------------------- 0) Zona horaria objetivo --------------------------------
# Intentamos cargar la zona IANA 'America/Guayaquil' desde la base de datos del sistema.
# En Windows o entornos sin base IANA, asegúrate de tener instalado 'tzdata' (pip install tzdata).
TIMEZONE_IANA: str = "America/Guayaquil"
try:
    from zoneinfo import ZoneInfo  # Python 3.9+
    GYE_TZ = ZoneInfo(TIMEZONE_IANA)
except Exception as e:
    raise RuntimeError(
        f"No se pudo fijar la zona horaria IANA '{TIMEZONE_IANA}'. "
        f"Detalle: {e}. Sugerencia: instala el paquete 'tzdata' e inténtalo de nuevo."
    )

# ----------------------------- 1) RUN_ID único -----------------------------
RUN_ID: str = datetime.now().strftime("%Y%m%d_%H%M%S")

# ------------------ 2) Tiempos y zonas horarias (UTC, GYE, local) ---------
_now_utc = datetime.now(timezone.utc)
UTC_TIME_ISO: str = _now_utc.isoformat()

_now_gye = _now_utc.astimezone(GYE_TZ)
GYE_TIME_ISO: str = _now_gye.isoformat()

_local_dt = datetime.now().astimezone()
LOCAL_TZ_NAME: str = _local_dt.tzname() or "LOCAL_TZ"
LOCAL_TIME_ISO: str = _local_dt.isoformat()

# ------------------------- 3) Python, S.O. y usuario -----------------------
PYTHON_VERSION: str = sys.version.split()[0]
OS_NAME: str = platform.system()
OS_RELEASE: str = platform.release()
OS_VERSION: str = platform.version()
try:
    USER_NAME: str = getpass.getuser()
except Exception:
    USER_NAME = "N/A"

# --------------- 4) Flags de control (solo inicialización) ----------------
FORCE_REDOWNLOAD_BULK_M5: bool = False
FORCE_REWRITE_DAY: bool = False
TICKS_RECENT_DAYS: int = 30
DATA_VERSION: str = "v1"
WRITE_MODE: str = "append"   # posibles valores futuros: "overwrite_part"

# ---------- 5) Verificación de espacio en disco (sin escribir nada) -------
# Usamos el directorio de trabajo actual como referencia de disco.
DISK_CHECK_PATH = Path.cwd()
_total_b, _used_b, _free_b = shutil.disk_usage(DISK_CHECK_PATH)

def _to_gib(bytes_val: int) -> float:
    return round(bytes_val / (1024**3), 2)

FREE_GIB: float = _to_gib(_free_b)
DISK_MIN_GIB_REQUIRED: float = 3.00  # Umbral configurable

# --------------------------------- IMPRESIONES ---------------------------------
print("================================================================================")
print(f"RUN_ID: {RUN_ID}")
print("--------------------------------------------------------------------------------")
print(f"TZ objetivo (IANA): {TIMEZONE_IANA}")
print(f"Hora GYE (ISO 8601): {GYE_TIME_ISO}")
print(f"Hora UTC (ISO 8601): {UTC_TIME_ISO}")
print(f"TZ local detectada : {LOCAL_TZ_NAME}")
print(f"Hora local (ISO)   : {LOCAL_TIME_ISO}")
print("--------------------------------------------------------------------------------")
print(f"Python: {PYTHON_VERSION} | S.O.: {OS_NAME} {OS_RELEASE}")
print(f"S.O. versión detallada: {OS_VERSION}")
print(f"Usuario: {USER_NAME}")
print("--------------------------------------------------------------------------------")
print(f"Espacio libre en disco: {FREE_GIB:.2f} GiB | Umbral requerido: {DISK_MIN_GIB_REQUIRED:.2f} GiB")
print(f"Directorio base de verificación de disco: {DISK_CHECK_PATH}")
print("--------------------------------------------------------------------------------")
print("FLAGS de control iniciales:")
print(f"  - FORCE_REDOWNLOAD_BULK_M5 = {FORCE_REDOWNLOAD_BULK_M5}")
print(f"  - FORCE_REWRITE_DAY        = {FORCE_REWRITE_DAY}")
print(f"  - TICKS_RECENT_DAYS        = {TICKS_RECENT_DAYS}")
print(f"  - DATA_VERSION             = {DATA_VERSION}")
print(f"  - WRITE_MODE               = {WRITE_MODE}")
print("================================================================================")

# ---------------------------------- VALIDACIONES ----------------------------------
if FREE_GIB < DISK_MIN_GIB_REQUIRED:
    raise RuntimeError(
        f"Espacio insuficiente en disco: {FREE_GIB:.2f} GiB libres < {DISK_MIN_GIB_REQUIRED:.2f} GiB requeridos. "
        f"Libera espacio o ajusta el umbral antes de continuar con la Celda 02."
    )

# Nota: dejamos variables listas para celdas siguientes (no se persisten aún):
#   RUN_ID, TIMEZONE_IANA, GYE_TZ, GYE_TIME_ISO, UTC_TIME_ISO, LOCAL_TZ_NAME, LOCAL_TIME_ISO,
#   PYTHON_VERSION, OS_NAME, OS_RELEASE, OS_VERSION, USER_NAME,
#   FORCE_REDOWNLOAD_BULK_M5, FORCE_REWRITE_DAY, TICKS_RECENT_DAYS,
#   DATA_VERSION, WRITE_MODE, DISK_CHECK_PATH, FREE_GIB, DISK_MIN_GIB_REQUIRED

print("✅ Bootstrap listo: OK para continuar con Celda 02")
# =====================================================================================================
# Out:
# ================================================================================
# RUN_ID: 20251202_232253
# --------------------------------------------------------------------------------
# TZ objetivo (IANA): America/Guayaquil
# Hora GYE (ISO 8601): 2025-12-02T23:22:53.165378-05:00
# Hora UTC (ISO 8601): 2025-12-03T04:22:53.165378+00:00
# TZ local detectada : Hora est. Pacífico, Sudamérica
# Hora local (ISO)   : 2025-12-02T23:22:53.165378-05:00
# --------------------------------------------------------------------------------
# Python: 3.11.9 | S.O.: Windows 10
# S.O. versión detallada: 10.0.26200
# Usuario: PC
# --------------------------------------------------------------------------------
# Espacio libre en disco: 257.97 GiB | Umbral requerido: 3.00 GiB
# Directorio base de verificación de disco: c:\Quant\MT5_Data_Extraction
# --------------------------------------------------------------------------------
# FLAGS de control iniciales:
#   - FORCE_REDOWNLOAD_BULK_M5 = False
#   - FORCE_REWRITE_DAY        = False
#   - TICKS_RECENT_DAYS        = 30
#   - DATA_VERSION             = v1
#   - WRITE_MODE               = append
# ================================================================================
# ✅ Bootstrap listo: OK para continuar con Celda 02

# %%
# ============================ Celda 02 — Configuración y Rutas base ============================
# Esta celda crea/valida las rutas base del pipeline y persiste un "snapshot" de configuración.
# Reglas:
#   - NO se conecta a MT5.
#   - NO descarga datos.
#   - Crea directorios de forma idempotente (no falla si ya existen).
#   - Escribe metadata/config_snapshot.json con rutas, flags, parámetros globales y QA/GOLD.
#   - Imprime TZ objetivo, configuración Parquet, árbol de rutas y la ubicación del snapshot.
# ------------------------------------------------------------------------------------------------

from pathlib import Path
from datetime import datetime, timezone
import os
import json
import platform
import sys
import getpass

# --- Unified path contract (single source of truth) ---
import sys as _sys
from pathlib import Path as _Path
for _p in [_Path.cwd().resolve()] + list(_Path.cwd().resolve().parents):
    _contract = _p / "shared" / "contracts" / "path_contract.py"
    if _contract.exists():
        if str(_contract.parent) not in _sys.path:
            _sys.path.insert(0, str(_contract.parent))
        break
import path_contract

# -------------------------- 0) Dependencias del Bootstrap (guardas) --------------------------
# Requiere que la Celda 01 (Bootstrap) haya definido estas variables. Si faltan, se proveen valores seguros.
if 'RUN_ID' not in globals():
    RUN_ID = datetime.now().strftime("%Y%m%d_%H%M%S")
    print(f"⚠️  Aviso: RUN_ID no estaba definido. Se generó temporalmente: {RUN_ID}")

if 'TIMEZONE_IANA' not in globals() or not isinstance(TIMEZONE_IANA, str) or not TIMEZONE_IANA:
    TIMEZONE_IANA = "America/Guayaquil"
    print(f"⚠️  Aviso: TIMEZONE_IANA no estaba definido. Se fijó a: {TIMEZONE_IANA}")

if 'FORCE_REDOWNLOAD_BULK_M5' not in globals():
    FORCE_REDOWNLOAD_BULK_M5 = True
if 'FORCE_REWRITE_DAY' not in globals():
    FORCE_REWRITE_DAY = True
if 'TICKS_RECENT_DAYS' not in globals():
    TICKS_RECENT_DAYS = 30
if 'DATA_VERSION' not in globals():
    DATA_VERSION = "v1"
if 'WRITE_MODE' not in globals():
    WRITE_MODE = "append"

# -------------------------- 1) Parámetros generales del dataset --------------------------
TIMEFRAME_LABEL: str = "M5"               # Foco intradía 5 minutos (estricto)
PERSISTENCE_TIMEZONE: str = "UTC"         # Persistencia SIEMPRE en UTC
PARQUET_COMPRESSION: str = "zstd"         # Compresión recomendada (ratio/velocidad)
PARQUET_WRITE_STATISTICS: bool = True     # Escribir estadísticas en parquet

# -------------------------- 2) PROJECT_ROOT & DATA_ROOT (via path_contract) --------------------------
# Prioridad:
#   1) Variable de entorno MT5_DE_DATA_ROOT (si existe).
#   2) path_contract.data_root() (resolución unificada del proyecto).
PROJECT_ROOT = path_contract.detect_project_root()
_env_data = os.environ.get("MT5_DE_DATA_ROOT")
if _env_data:
    DATA_ROOT = Path(_env_data).expanduser().resolve()
else:
    DATA_ROOT = path_contract.data_root(PROJECT_ROOT)

# -------------------------- 3) Definición de rutas del pipeline --------------------------
# Mantiene la nomenclatura existente del proyecto, derivando TODO desde DATA_ROOT (ROOT único).
BULK_DATA_DIR            = DATA_ROOT / "bulk_data"
M5_RAW_DIR               = BULK_DATA_DIR / "m5_raw"           # M5 histórico bruto (particionado símbolo/año/mes)
TICKS_RECENT_DIR         = BULK_DATA_DIR / "ticks_recent"     # Ticks recientes para QA (30–90 días)

HISTORICAL_DATA_DIR      = DATA_ROOT / "historical_data"
M5_CLEAN_DIR             = HISTORICAL_DATA_DIR / "m5_clean"   # Capa gold M5 normalizado (UTC, esquema fijo)

PROCESSED_DATA_DIR       = DATA_ROOT / "processed_data"
M5_WINDOWS_DIR           = PROCESSED_DATA_DIR / "m5_windows"  # Ventanas listas (last_30d/90d/180d)

METADATA_DIR             = DATA_ROOT / "metadata"
LOGS_DIR                 = DATA_ROOT / "logs"
REPORTS_DIR              = DATA_ROOT / "reports"
BACKUPS_DIR              = DATA_ROOT / "backups"

# Archivos de metadata clave (se crean/escriben en celdas específicas más adelante)
CONFIG_SNAPSHOT_PATH     = METADATA_DIR / "config_snapshot.json"
SCHEMA_M5_PATH           = METADATA_DIR / "schema_m5.json"            # se escribirá más adelante
SYMBOLS_BROKER_PATH      = METADATA_DIR / "symbols_broker.parquet"    # se escribirá más adelante
SERVER_TIME_INFO_PATH    = METADATA_DIR / "server_time_info.json"     # se escribirá más adelante
DATASET_CATALOG_PATH     = METADATA_DIR / "dataset_catalog.parquet"   # se validará/escribirá más adelante
QA_M5_BULK_PATH          = METADATA_DIR / "qa_m5_bulk.parquet"        # se escribirá más adelante
RUN_LOG_JSONL_PATH       = METADATA_DIR / "run_log.jsonl"             # se actualizará en ingestiones/QA
MANIFEST_PATH            = METADATA_DIR / "manifest.json"             # se generará en cierre
CHECKSUMS_JSONL_PATH     = METADATA_DIR / "checksums.jsonl"           # se generará en cierre

# -------------------------- 4) Creación idempotente de carpetas --------------------------
dirs_to_create = [
    DATA_ROOT,
    BULK_DATA_DIR,
    M5_RAW_DIR,
    TICKS_RECENT_DIR,
    HISTORICAL_DATA_DIR,
    M5_CLEAN_DIR,
    PROCESSED_DATA_DIR,
    M5_WINDOWS_DIR,
    METADATA_DIR,
    LOGS_DIR,
    REPORTS_DIR,
    BACKUPS_DIR,
]
for d in dirs_to_create:
    d.mkdir(parents=True, exist_ok=True)

# -------------------------- 5) Parámetros de QA & GOLD --------------------------
# Estos parámetros controlan la QA operativa M5 (Celda 10) y los filtros hacia la capa GOLD (Celda 12C).
# Pueden sobre-escribirse ANTES de ejecutar esta celda, vía globals(), por ejemplo:
#   QA_OK_MIN_OK_RATIO = 0.85
#   QA_GOLD_KEEP_STATUSES = ["OK", "WARN"]

# QA operativa M5 por símbolo (qa_operativa_summary.parquet)
QA_OK_MIN_OK_RATIO       = float(globals().get("QA_OK_MIN_OK_RATIO", 0.90))    # ≥ 90% días OK
QA_OK_MAX_FAIL_RATIO     = float(globals().get("QA_OK_MAX_FAIL_RATIO", 0.05))  # ≤ 5% días FAIL
QA_OK_MIN_REJILLA_MEAN   = float(globals().get("QA_OK_MIN_REJILLA_MEAN", 80.0))# rejilla media ≥ 80%

QA_BAD_MIN_FAIL_RATIO    = float(globals().get("QA_BAD_MIN_FAIL_RATIO", 0.20)) # ≥ 20% FAIL → BAD
QA_BAD_MAX_REJILLA_MEAN  = float(globals().get("QA_BAD_MAX_REJILLA_MEAN", 60.0))# rejilla media < 60% → BAD
QA_BAD_MAX_EMPTY_RATIO   = float(globals().get("QA_BAD_MAX_EMPTY_RATIO", 0.20)) # > 20% EMPTY → BAD

# Sanity-check global de cobertura M5 (Celda 10)
MIN_MEAN_REJILLA_HARD    = float(globals().get("MIN_MEAN_REJILLA_HARD", 5.0))  # % rejilla media mínima aceptable

# Para n_bars_mean usamos un default relativo a la rejilla M5 teórica (288 barras/día).
# Si se desea otro valor, puede sobre-escribirse antes de ejecutar esta celda.
EXPECTED_BARS_M5         = 288
MIN_MEAN_NBARS_HARD      = float(
    globals().get("MIN_MEAN_NBARS_HARD", EXPECTED_BARS_M5 * 0.20)
)  # 20% de las barras esperadas por día

# Estados que el GOLD va a aceptar por defecto (si nadie los sobreescribe antes).
# OK   = día totalmente sano.
# WARN = día estructuralmente sano pero con avisos (rejilla 24h, gaps pequeños, etc.).
QA_GOLD_KEEP_STATUSES    = list(globals().get("QA_GOLD_KEEP_STATUSES", ["OK", "WARN"]))

# Sólo para métricas/reporting en 12C, NO se usa como veto de días.
MIN_REJILLA_FOR_GOLD     = float(globals().get("MIN_REJILLA_FOR_GOLD", 80.0))

# -------------------------- 6) Snapshot de configuración --------------------------
def _safe_get_user():
    try:
        return getpass.getuser()
    except Exception:
        return "N/A"

config_snapshot = {
    "run": {
        "RUN_ID": RUN_ID,
        "created_ts_utc": datetime.now(timezone.utc).isoformat(),
    },
    "environment": {
        "python_version": sys.version.split()[0],
        "os_name": platform.system(),
        "os_release": platform.release(),
        "os_version": platform.version(),
        "user": _safe_get_user(),
    },
    "dataset": {
        "TIMEFRAME_LABEL": TIMEFRAME_LABEL,
        "PERSISTENCE_TIMEZONE": PERSISTENCE_TIMEZONE,
        "TIMEZONE_IANA": TIMEZONE_IANA,                 # <- TZ objetivo incluida en snapshot
        "DATA_VERSION": DATA_VERSION,
        "WRITE_MODE": WRITE_MODE,
        "TICKS_RECENT_DAYS": TICKS_RECENT_DAYS,
        "FORCE_REDOWNLOAD_BULK_M5": bool(FORCE_REDOWNLOAD_BULK_M5),
        "FORCE_REWRITE_DAY": bool(FORCE_REWRITE_DAY),
        "parquet": {
            "compression": PARQUET_COMPRESSION,
            "write_statistics": PARQUET_WRITE_STATISTICS,
        },
    },
    "paths": {
        "DATA_ROOT": str(DATA_ROOT),
        "BULK_DATA_DIR": str(BULK_DATA_DIR),
        "M5_RAW_DIR": str(M5_RAW_DIR),
        "TICKS_RECENT_DIR": str(TICKS_RECENT_DIR),
        "HISTORICAL_DATA_DIR": str(HISTORICAL_DATA_DIR),
        "M5_CLEAN_DIR": str(M5_CLEAN_DIR),
        "PROCESSED_DATA_DIR": str(PROCESSED_DATA_DIR),
        "M5_WINDOWS_DIR": str(M5_WINDOWS_DIR),
        "METADATA_DIR": str(METADATA_DIR),
        "LOGS_DIR": str(LOGS_DIR),
        "REPORTS_DIR": str(REPORTS_DIR),
        "BACKUPS_DIR": str(BACKUPS_DIR),
        # Archivos clave:
        "CONFIG_SNAPSHOT_PATH": str(CONFIG_SNAPSHOT_PATH),
        "SCHEMA_M5_PATH": str(SCHEMA_M5_PATH),
        "SYMBOLS_BROKER_PATH": str(SYMBOLS_BROKER_PATH),
        "SERVER_TIME_INFO_PATH": str(SERVER_TIME_INFO_PATH),
        "DATASET_CATALOG_PATH": str(DATASET_CATALOG_PATH),
        "QA_M5_BULK_PATH": str(QA_M5_BULK_PATH),
        "RUN_LOG_JSONL_PATH": str(RUN_LOG_JSONL_PATH),
        "MANIFEST_PATH": str(MANIFEST_PATH),
        "CHECKSUMS_JSONL_PATH": str(CHECKSUMS_JSONL_PATH),
    },
    "qa": {
        "operativa_m5": {
            "QA_OK_MIN_OK_RATIO": QA_OK_MIN_OK_RATIO,
            "QA_OK_MAX_FAIL_RATIO": QA_OK_MAX_FAIL_RATIO,
            "QA_OK_MIN_REJILLA_MEAN": QA_OK_MIN_REJILLA_MEAN,
            "QA_BAD_MIN_FAIL_RATIO": QA_BAD_MIN_FAIL_RATIO,
            "QA_BAD_MAX_REJILLA_MEAN": QA_BAD_MAX_REJILLA_MEAN,
            "QA_BAD_MAX_EMPTY_RATIO": QA_BAD_MAX_EMPTY_RATIO,
        },
        "sanity_m5": {
            "MIN_MEAN_REJILLA_HARD": MIN_MEAN_REJILLA_HARD,
            "EXPECTED_BARS_M5": EXPECTED_BARS_M5,
            "MIN_MEAN_NBARS_HARD": MIN_MEAN_NBARS_HARD,
        },
        "gold_m5": {
            "QA_GOLD_KEEP_STATUSES": QA_GOLD_KEEP_STATUSES,
            "MIN_REJILLA_FOR_GOLD": MIN_REJILLA_FOR_GOLD,
        },
    },
}

# Persistimos el snapshot (idempotente; se sobreescribe en cada corrida)
CONFIG_SNAPSHOT_PATH.parent.mkdir(parents=True, exist_ok=True)
with open(CONFIG_SNAPSHOT_PATH, "w", encoding="utf-8") as f:
    json.dump(config_snapshot, f, ensure_ascii=False, indent=2)

# -------------------------- 7) Impresiones obligatorias --------------------------
print("================================================================================")
print(f"TZ objetivo (IANA): {TIMEZONE_IANA}")
print(f"DATA_ROOT         : {DATA_ROOT}")
print("--------------------------------------------------------------------------------")
print("Rutas creadas/validadas (idempotente):")
for d in dirs_to_create:
    print(f"OK  {d}")
print("--------------------------------------------------------------------------------")
print(f"Parquet -> compression: {PARQUET_COMPRESSION} | write_statistics: {PARQUET_WRITE_STATISTICS}")
print("--------------------------------------------------------------------------------")
print(f"Snapshot de configuración escrito en:\n  {CONFIG_SNAPSHOT_PATH}")
print("================================================================================")
print("✅ Config & Rutas listas: OK para continuar con Celda 03")

# =====================================================================================================
# Variables disponibles para celdas siguientes:
#   DATA_ROOT, BULK_DATA_DIR, M5_RAW_DIR, TICKS_RECENT_DIR,
#   HISTORICAL_DATA_DIR, M5_CLEAN_DIR, PROCESSED_DATA_DIR, M5_WINDOWS_DIR,
#   METADATA_DIR, LOGS_DIR, REPORTS_DIR, BACKUPS_DIR,
#   CONFIG_SNAPSHOT_PATH, SCHEMA_M5_PATH, SYMBOLS_BROKER_PATH, SERVER_TIME_INFO_PATH,
#   DATASET_CATALOG_PATH, QA_M5_BULK_PATH, RUN_LOG_JSONL_PATH, MANIFEST_PATH, CHECKSUMS_JSONL_PATH,
#   TIMEFRAME_LABEL, PERSISTENCE_TIMEZONE, TIMEZONE_IANA, PARQUET_COMPRESSION, PARQUET_WRITE_STATISTICS,
#   RUN_ID, DATA_VERSION, WRITE_MODE, TICKS_RECENT_DAYS, FORCE_REDOWNLOAD_BULK_M5, FORCE_REWRITE_DAY,
#   # QA & GOLD:
#   QA_OK_MIN_OK_RATIO, QA_OK_MAX_FAIL_RATIO, QA_OK_MIN_REJILLA_MEAN,
#   QA_BAD_MIN_FAIL_RATIO, QA_BAD_MAX_REJILLA_MEAN, QA_BAD_MAX_EMPTY_RATIO,
#   MIN_MEAN_REJILLA_HARD, EXPECTED_BARS_M5, MIN_MEAN_NBARS_HARD,
#   QA_GOLD_KEEP_STATUSES, MIN_REJILLA_FOR_GOLD
# =====================================================================================================
# Out:
# ================================================================================
# TZ objetivo (IANA): America/Guayaquil
# DATA_ROOT         : C:\Quant\MT5_Data_Extraction\data
# --------------------------------------------------------------------------------
# Rutas creadas/validadas (idempotente):
# OK  C:\Quant\MT5_Data_Extraction\data
# OK  C:\Quant\MT5_Data_Extraction\data\bulk_data
# OK  C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# OK  C:\Quant\MT5_Data_Extraction\data\bulk_data\ticks_recent
# OK  C:\Quant\MT5_Data_Extraction\data\historical_data
# OK  C:\Quant\MT5_Data_Extraction\data\historical_data\m5_clean
# OK  C:\Quant\MT5_Data_Extraction\data\processed_data
# OK  C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows
# OK  C:\Quant\MT5_Data_Extraction\data\metadata
# OK  C:\Quant\MT5_Data_Extraction\data\logs
# OK  C:\Quant\MT5_Data_Extraction\data\reports
# OK  C:\Quant\MT5_Data_Extraction\data\backups
# --------------------------------------------------------------------------------
# Parquet -> compression: zstd | write_statistics: True
# --------------------------------------------------------------------------------
# Snapshot de configuración escrito en:
#   C:\Quant\MT5_Data_Extraction\data\metadata\config_snapshot.json
# ================================================================================
# ✅ Config & Rutas listas: OK para continuar con Celda 03

# %%
# =============================== Celda 03 — Logging y auditoría ===============================
# Objetivo:
#   - Configurar un logger rotativo (archivo + consola) en logs/mt5_de_5m_<RUN_ID>.log.
#   - Formato: [YYYY-MM-DD HH:MM:SS] [RUN_ID] [LEVEL] [CELDA] Mensaje
#   - Banner inicial con: Python/OS, versiones de Polars/PyArrow (sin pandas), RUN_ID,
#     y TZ objetivo IANA (America/Guayaquil) + horas de referencia (UTC y GYE).
#   - Proveer helper get_logger(celda) y log_msg(celda, level, message).
# Reglas:
#   - NO conecta a MT5.
#   - NO usa pandas ni “fallbacks” a pandas.
#   - No bloquea si alguna librería no está instalada (reporta “no disponible”).
#   - Imprime al final: ruta exacta del log, primera línea efectivamente escrita y mensaje final.
# =================================================================================================

import logging
from logging.handlers import RotatingFileHandler
from datetime import datetime, timezone
from pathlib import Path
import sys, platform, importlib
from typing import Optional

# ----------------------- 0) Dependencias de celdas previas (guardas) -----------------------
# Se espera que la Celda 02 haya definido LOGS_DIR y que la Celda 01 haya definido RUN_ID y TIMEZONE_IANA.
# Si faltan, se proveen valores seguros para no interrumpir la sesión.
if 'RUN_ID' not in globals():
    RUN_ID = datetime.now().strftime("%Y%m%d_%H%M%S")
    print(f"⚠️  Aviso: RUN_ID no estaba definido. Se generó temporalmente: {RUN_ID}")

if 'LOGS_DIR' not in globals():
    LOGS_DIR = (Path.cwd() / "data" / "logs").resolve()
    LOGS_DIR.mkdir(parents=True, exist_ok=True)
    print(f"⚠️  Aviso: LOGS_DIR no estaba definido. Usando: {LOGS_DIR}")

if 'TIMEZONE_IANA' not in globals() or not isinstance(TIMEZONE_IANA, str) or not TIMEZONE_IANA:
    TIMEZONE_IANA = "America/Guayaquil"
    print(f"⚠️  Aviso: TIMEZONE_IANA no estaba definido. Se fijó a: {TIMEZONE_IANA}")

# Intentar cargar ZoneInfo para GYE
GYE_TZ = None
try:
    from zoneinfo import ZoneInfo  # Python 3.9+
    GYE_TZ = ZoneInfo(TIMEZONE_IANA)
except Exception:
    # Si falla, continuamos; el logger usará la TZ local del sistema.
    pass

# ------------------------------ 1) Archivo de log objetivo ------------------------------
LOG_FILE_PATH = LOGS_DIR / f"mt5_de_5m_{RUN_ID}.log"

# ------------------------------ 2) Formato y formateador con TZ GYE ------------------------------
LOG_DATEFMT = "%Y-%m-%d %H:%M:%S"
LOG_FORMAT  = "[%(asctime)s] [%(run_id)s] [%(levelname)s] [%(celda)s] %(message)s"

class _RunContextFilter(logging.Filter):
    """Inyecta 'run_id' y un 'celda' por defecto para asegurar el formato."""
    def filter(self, record: logging.LogRecord) -> bool:
        if not hasattr(record, "run_id"):
            record.run_id = RUN_ID
        if not hasattr(record, "celda"):
            record.celda = "NA"
        return True

class _TzFormatter(logging.Formatter):
    """Formatter que imprime las fechas en la TZ indicada (por defecto, local)."""
    def __init__(self, fmt: Optional[str] = None, datefmt: Optional[str] = None, tz=None):
        super().__init__(fmt=fmt, datefmt=datefmt)
        self._tz = tz  # ZoneInfo o None

    def formatTime(self, record, datefmt=None):
        dt = datetime.fromtimestamp(record.created, tz=self._tz) if self._tz else datetime.fromtimestamp(record.created)
        if datefmt:
            return dt.strftime(datefmt)
        return dt.isoformat(timespec="seconds")

# ------------------------------ 3) Construcción del logger ------------------------------
LOGGER_NAME = "mt5_de_5m"
LOGGER = logging.getLogger(LOGGER_NAME)
LOGGER.setLevel(logging.DEBUG)
LOGGER.propagate = False

# Evitar duplicados si se re-ejecuta la celda
for h in list(LOGGER.handlers):
    LOGGER.removeHandler(h)

file_handler = RotatingFileHandler(
    LOG_FILE_PATH,
    mode="a",
    maxBytes=10 * 1024 * 1024,  # ~10 MiB
    backupCount=5,
    encoding="utf-8",
    delay=False
)
console_handler = logging.StreamHandler(stream=sys.stdout)

# Formateadores (timestamps en GYE si está disponible)
formatter_gye = _TzFormatter(LOG_FORMAT, datefmt=LOG_DATEFMT, tz=GYE_TZ)
file_handler.setFormatter(formatter_gye)
console_handler.setFormatter(formatter_gye)

# Niveles de handlers (ajustables)
file_handler.setLevel(logging.INFO)
console_handler.setLevel(logging.INFO)

# Filtro para inyectar run_id/celda
ctx_filter = _RunContextFilter()
file_handler.addFilter(ctx_filter)
console_handler.addFilter(ctx_filter)

# Registrar handlers
LOGGER.addHandler(file_handler)
LOGGER.addHandler(console_handler)

# ------------------------------ 4) Utilitarios de logging ------------------------------
def get_logger(celda: str = "NA") -> logging.LoggerAdapter:
    """
    Devuelve un LoggerAdapter con los campos extra ('run_id', 'celda') inyectados.
    Uso:
        log = get_logger("03-Logging")
        log.info("Mensaje")
    """
    return logging.LoggerAdapter(LOGGER, {"run_id": RUN_ID, "celda": celda})

def log_msg(celda: str, level: str, message: str):
    """
    Helper para loguear con prefijo de celda y nivel textual.
    Niveles válidos: DEBUG, INFO, WARNING, ERROR, CRITICAL
    """
    adapter = get_logger(celda)
    lvl = (level or "INFO").upper()
    if   lvl == "DEBUG":    adapter.debug(message)
    elif lvl == "INFO":     adapter.info(message)
    elif lvl == "WARNING":  adapter.warning(message)
    elif lvl == "ERROR":    adapter.error(message)
    elif lvl == "CRITICAL": adapter.critical(message)
    else:                   adapter.info(message + f"  (nivel desconocido: {level})")

# ------------------------------ 5) Detección de versiones necesarias ------------------------------
def _detect_version(modname: str) -> str:
    try:
        mod = importlib.import_module(modname)
        return getattr(mod, "__version__", "desconocida")
    except Exception:
        return "no disponible"

PYTHON_VERSION = sys.version.split()[0]
OS_NAME        = platform.system()
OS_RELEASE     = platform.release()
OS_VERSION     = platform.version()

VERS_POLARS  = _detect_version("polars")
VERS_PYARROW = _detect_version("pyarrow")

# ------------------------------ 6) Banner inicial al log ------------------------------
_log = get_logger("03-Logging")

# Registro de una primera línea para asegurar contenido inmediato
_log.info("Logger inicializado (demostración de formato).")

# Horas de referencia y TZ
_now_utc = datetime.now(timezone.utc)
utc_iso  = _now_utc.isoformat(timespec="seconds")
gye_iso  = (_now_utc.astimezone(GYE_TZ).isoformat(timespec="seconds")) if GYE_TZ else "(GYE no disponible; usando TZ local)"

_log.info("=== INICIO DE SESIÓN DE LOG ===")
_log.info(f"RUN_ID: {RUN_ID} | TIMEFRAME_LABEL: {globals().get('TIMEFRAME_LABEL', 'M5')} | DATA_VERSION: {globals().get('DATA_VERSION', 'v1')}")
_log.info(f"Python: {PYTHON_VERSION} | SO: {OS_NAME} {OS_RELEASE} ({OS_VERSION})")
_log.info(f"polars: {VERS_POLARS} | pyarrow: {VERS_PYARROW}")
_log.info(f"TZ objetivo (IANA): {TIMEZONE_IANA} | Hora GYE: {gye_iso} | Hora UTC: {utc_iso}")
_log.info("========================================================================")

# Flush explícito a archivo antes de leer
for h in LOGGER.handlers:
    try:
        h.flush()
    except Exception:
        pass

# ------------------------------ 7) Impresiones obligatorias ------------------------------
print("================================================================================")
print(f"Archivo de log activo: {LOG_FILE_PATH}")

first_line = ""
try:
    with open(LOG_FILE_PATH, "r", encoding="utf-8") as f:
        first_line = f.readline().rstrip("\n")
except Exception as e:
    first_line = f"ERROR al leer primera línea del log: {e}"

print("Primera línea efectivamente escrita (formato de ejemplo):")
print(first_line if first_line else "(vacío)")
print("--------------------------------------------------------------------------------")
print("✅ Logging y auditoría listos: OK para continuar con Celda 04")

# ========================= Utilitarios disponibles a partir de aquí =========================
#   - LOGGER (logger base)
#   - LOG_FILE_PATH (path del archivo de log)
#   - get_logger(celda: str) -> LoggerAdapter
#   - log_msg(celda: str, level: str, message: str)
#   - Formato garantizado: [YYYY-MM-DD HH:MM:SS] [RUN_ID] [LEVEL] [CELDA] Mensaje
# ===========================================================================================
# Out:
# [2025-12-02 23:22:53] [20251202_232253] [INFO] [03-Logging] Logger inicializado (demostración de formato).
# [2025-12-02 23:22:53] [20251202_232253] [INFO] [03-Logging] === INICIO DE SESIÓN DE LOG ===
# [2025-12-02 23:22:53] [20251202_232253] [INFO] [03-Logging] RUN_ID: 20251202_232253 | TIMEFRAME_LABEL: M5 | DATA_VERSION: v1
# [2025-12-02 23:22:53] [20251202_232253] [INFO] [03-Logging] Python: 3.11.9 | SO: Windows 10 (10.0.26200)
# [2025-12-02 23:22:53] [20251202_232253] [INFO] [03-Logging] polars: 1.35.1 | pyarrow: 22.0.0
# [2025-12-02 23:22:53] [20251202_232253] [INFO] [03-Logging] TZ objetivo (IANA): America/Guayaquil | Hora GYE: 2025-12-02T23:22:53-05:00 | Hora UTC: 2025-12-03T04:22:53+00:00
# [2025-12-02 23:22:53] [20251202_232253] [INFO] [03-Logging] ========================================================================
# ================================================================================
# Archivo de log activo: C:\Quant\MT5_Data_Extraction\data\logs\mt5_de_5m_20251202_232253.log
# Primera línea efectivamente escrita (formato de ejemplo):
# [2025-12-02 23:22:53] [20251202_232253] [INFO] [03-Logging] Logger inicializado (demostración de formato).
# --------------------------------------------------------------------------------
# ✅ Logging y auditoría listos: OK para continuar con Celda 04

# %%
# ========================== Celda 04 — Inventario de símbolos del bróker (snapshot) ==========================
# Objetivos (UNA sola función):
#   1) Conectar a MT5 con reintentos exponenciales e imprimir diagnóstico.
#   2) Capturar info básica de cuenta/terminal y estimar hora del servidor (aprox) vs. UTC.
#   3) Descargar la lista COMPLETA de símbolos (sin filtrar) y normalizar campos clave.
#   4) (Opcional) Añadir tick actual por símbolo (bid/ask/last/time) si está disponible.
#   5) Escribir Parquet: metadata/symbols_broker.parquet (Polars-only).
#   6) Escribir JSON: metadata/server_time_info.json.
#   7) Imprimir: ruta escrita, conteos, esquema/dtypes, min/max y percentiles (point/contract_size), % nulos.
#
# Validaciones y prints:
#   - Inicio/fin (UTC y GYE) + TZ objetivo (IANA).
#   - Estado de conexión MT5 y detalles de cuenta/terminal (si existen).
#   - Ruta exacta del Parquet y JSON escritos.
#   - #símbolos total, visibles y proxy "tradeable" por trade_mode>=0.
#   - Esquema/dtypes Polars.
#   - min/max y p50/p90/p95/p99 de point y contract_size.
#   - % de nulos en columnas críticas (point, contract_size, digits, trade_mode).
#   - Top-5 símbolos (symbol, path).
#
# Reglas:
#   - NO usa pandas ni loops de transformación (solo loops de extracción MT5).
#   - Conexión a MT5 se cierra siempre.
#   - Si no hay símbolos -> error claro. Si MT5 no está disponible -> error claro.
# ============================================================================================================

from __future__ import annotations

import time
import json
from datetime import datetime, timezone
from pathlib import Path
from typing import List, Dict, Any, Optional

import polars as pl
import sys, platform

# ------------------------------------ 0) Dependencias previas / guardas ------------------------------------
if 'METADATA_DIR' not in globals():
    METADATA_DIR = (Path.cwd() / "data" / "metadata").resolve()
    METADATA_DIR.mkdir(parents=True, exist_ok=True)

if 'SYMBOLS_BROKER_PATH' not in globals():
    SYMBOLS_BROKER_PATH = METADATA_DIR / "symbols_broker.parquet"

if 'SERVER_TIME_INFO_PATH' not in globals():
    SERVER_TIME_INFO_PATH = METADATA_DIR / "server_time_info.json"

if 'TIMEFRAME_LABEL' not in globals():
    TIMEFRAME_LABEL = "M5"
if 'DATA_VERSION' not in globals():
    DATA_VERSION = "v1"
if 'RUN_ID' not in globals():
    RUN_ID = datetime.now().strftime("%Y%m%d_%H%M%S")

if 'PARQUET_COMPRESSION' not in globals():
    PARQUET_COMPRESSION = "zstd"
if 'PARQUET_WRITE_STATISTICS' not in globals():
    PARQUET_WRITE_STATISTICS = True

if 'TIMEZONE_IANA' not in globals() or not isinstance(TIMEZONE_IANA, str) or not TIMEZONE_IANA:
    TIMEZONE_IANA = "America/Guayaquil"

# TZ objetivo (GYE) para impresiones
try:
    from zoneinfo import ZoneInfo
    GYE_TZ = ZoneInfo(TIMEZONE_IANA)
except Exception:
    GYE_TZ = None  # seguimos sin bloquear, pero avisamos en los prints

def _now_iso_utc() -> str:
    return datetime.now(timezone.utc).isoformat(timespec="seconds")

def _now_iso_gye() -> str:
    if GYE_TZ is None:
        return "(GYE no disponible; instala 'tzdata')"
    return datetime.now(timezone.utc).astimezone(GYE_TZ).isoformat(timespec="seconds")

# ----------------------------------------- 1) Conexión a MT5 -----------------------------------------
print("================================================================================")
print(f"Inicio Celda 04 — Inventario de símbolos | TZ objetivo: {TIMEZONE_IANA}")
print(f"Hora GYE: {_now_iso_gye()} | Hora UTC: {_now_iso_utc()}")
print("--------------------------------------------------------------------------------")

try:
    import MetaTrader5 as mt5
except Exception as e:
    raise ImportError(
        "No se pudo importar 'MetaTrader5'. Instala el paquete y asegúrate de tener el terminal MT5 operativo."
    ) from e

def connect_mt5_with_retries(max_tries: int = 5, base_sleep: float = 1.0) -> bool:
    for i in range(max_tries):
        if mt5.initialize():
            return True
        sleep_s = base_sleep * (2 ** i)
        print(f"⚠️  Conexión MT5 fallida #{i+1}/{max_tries}. Reintentando en {sleep_s:.1f}s...")
        time.sleep(sleep_s)
    return False

connected = connect_mt5_with_retries(max_tries=5, base_sleep=1.0)
if not connected:
    last_error = mt5.last_error()
    raise RuntimeError(
        f"No fue posible conectar a MT5 tras varios intentos. last_error={last_error}. "
        f"Verifica terminal, cuenta, permisos y red."
    )
print("✅ Conexión MT5 establecida.")

# ----------------------------------- 2) Info de cuenta y hora servidor -----------------------------------
account_info = mt5.account_info()
terminal_info = mt5.terminal_info()

server_name  = getattr(account_info, "server", None) if account_info else None
company_name = getattr(account_info, "company", None) if account_info else None
login_id     = getattr(account_info, "login", None) if account_info else None

# Estimación de hora de servidor
probe_symbol = "EURUSD"
use_alt_symbol = False
si = mt5.symbol_info(probe_symbol)
if si is None or (not getattr(si, "visible", True)):
    all_syms_for_pick = mt5.symbols_get()
    if all_syms_for_pick and len(all_syms_for_pick) > 0:
        probe_symbol = getattr(all_syms_for_pick[0], "name", "EURUSD")
        use_alt_symbol = True
    else:
        mt5.shutdown()
        raise RuntimeError("La lista de símbolos está vacía; no es posible continuar con el inventario.")

server_time_epoch = None
server_time_iso_utc = None
server_time_source = None
try:
    tick = mt5.symbol_info_tick(probe_symbol)
    if tick is not None and getattr(tick, "time", None):
        server_time_epoch = int(getattr(tick, "time"))
        server_time_iso_utc = datetime.fromtimestamp(server_time_epoch, tz=timezone.utc).isoformat(timespec="seconds")
        server_time_source = "last_tick_time"
    else:
        rates = mt5.copy_rates_from_pos(probe_symbol, mt5.TIMEFRAME_M1, 0, 1)
        if rates is not None and len(rates) > 0 and "time" in rates.dtype.names:
            server_time_epoch = int(rates["time"][0])
            server_time_iso_utc = datetime.fromtimestamp(server_time_epoch, tz=timezone.utc).isoformat(timespec="seconds")
            server_time_source = "last_rate_time"
except Exception as e:
    print(f"⚠️  No se pudo estimar hora de servidor: {e}")

offset_seconds_estimate = None
if server_time_epoch is not None:
    offset_seconds_estimate = int(server_time_epoch - int(datetime.now(timezone.utc).timestamp()))

server_time_info = {
    "collected_at_utc": _now_iso_utc(),
    "server_name": server_name,
    "company_name": company_name,
    "login_id": login_id,
    "terminal_info": {
        "name": getattr(terminal_info, "name", None),
        "community": getattr(terminal_info, "community", None),
        "path": getattr(terminal_info, "path", None),
        "data_path": getattr(terminal_info, "data_path", None),
        "build": getattr(terminal_info, "build", None),
    },
    "time_probe": {
        "symbol_used": probe_symbol,
        "used_alternative_symbol": use_alt_symbol,
        "server_time_source": server_time_source,
        "server_time_epoch": server_time_epoch,
        "server_time_iso_utc": server_time_iso_utc,
        "local_now_iso_utc": _now_iso_utc(),
        "offset_seconds_estimate": offset_seconds_estimate,
        "note": "Estimación aproximada (no TZ oficial del servidor).",
    },
}

# Persistimos JSON auxiliar (no bloqueante si falla)
try:
    SERVER_TIME_INFO_PATH.parent.mkdir(parents=True, exist_ok=True)
    with open(SERVER_TIME_INFO_PATH, "w", encoding="utf-8") as f:
        json.dump(server_time_info, f, ensure_ascii=False, indent=2)
    print(f"📝 server_time_info.json escrito en: {SERVER_TIME_INFO_PATH}")
except Exception as e:
    print(f"⚠️  No se pudo escribir server_time_info.json: {e}")

# ------------------------------------ 3) Descarga y normalización ------------------------------------
print("Descargando lista completa de símbolos del bróker...")
syms = mt5.symbols_get()
if syms is None:
    err = mt5.last_error()
    mt5.shutdown()
    raise RuntimeError(f"symbols_get() devolvió None. last_error={err}. Verifica conexión/permisos.")

if len(syms) == 0:
    mt5.shutdown()
    raise RuntimeError("La lista de símbolos está vacía. ¿Cuenta sin permisos o instrumentos ocultos?")

FIELDS = [
    ("name", "symbol"),
    ("path", "path"),
    ("visible", "visible"),
    ("select", "selected"),
    ("digits", "digits"),
    ("point", "point"),
    ("trade_mode", "trade_mode"),
    ("trade_contract_size", "contract_size"),
    ("trade_stops_level", "stops_level"),
    ("trade_freeze_level", "freeze_level"),
    ("spread", "spread"),
    ("spread_float", "spread_float"),
    ("margin_initial", "margin_initial"),
    ("margin_maintenance", "margin_maintenance"),
    ("swap_mode", "swap_mode"),
    ("swap_long", "swap_long"),
    ("swap_short", "swap_short"),
    ("currency_base", "currency_base"),
    ("currency_profit", "currency_profit"),
    ("currency_margin", "currency_margin"),
    ("description", "description"),
]

rows: List[Dict[str, Any]] = []
for s in syms:
    row = {dst: getattr(s, src, None) for src, dst in FIELDS}
    rows.append(row)

# (Opcional) Tick actual por símbolo (best-effort). Puede tardar según #símbolos.
GET_TICKS = True
if GET_TICKS:
    for i, r in enumerate(rows):
        sym = r.get("symbol")
        if not sym:
            continue
        try:
            t = mt5.symbol_info_tick(sym)
            if t is not None:
                r["bid"] = float(getattr(t, "bid", None)) if getattr(t, "bid", None) is not None else None
                r["ask"] = float(getattr(t, "ask", None)) if getattr(t, "ask", None) is not None else None
                r["last"] = float(getattr(t, "last", None)) if getattr(t, "last", None) is not None else None
                te = getattr(t, "time", None)
                r["tick_time_utc"] = (
                    datetime.fromtimestamp(int(te), tz=timezone.utc).isoformat(timespec="seconds")
                    if te is not None else None
                )
            if (i + 1) % 500 == 0:
                print(f"  • Ticks consultados para {i+1} símbolos...")
        except Exception:
            r["bid"] = r["ask"] = r["last"] = None
            r["tick_time_utc"] = None

# ------------------------------ 4) DataFrame Polars con tipos explícitos ------------------------------
columns_order = [
    "symbol","path","visible","selected","digits","point","trade_mode","contract_size",
    "stops_level","freeze_level","spread","spread_float","margin_initial","margin_maintenance",
    "swap_mode","swap_long","swap_short","currency_base","currency_profit","currency_margin",
    "description","bid","ask","last","tick_time_utc"
]

df = pl.DataFrame(rows, strict=False)

# Aseguramos columnas faltantes como null
for c in columns_order:
    if c not in df.columns:
        df = df.with_columns(pl.lit(None).alias(c))

# Casteos explícitos y metadatos
df = df.select(columns_order).with_columns([
    pl.col("symbol", "path", "currency_base", "currency_profit", "currency_margin", "description").cast(pl.Utf8),
    pl.col("visible", "selected", "spread_float").cast(pl.Boolean),
    pl.col("digits", "stops_level", "freeze_level", "trade_mode", "spread", "swap_mode").cast(pl.Int32),
    pl.col("point", "contract_size", "margin_initial", "margin_maintenance", "swap_long", "swap_short",
           "bid", "ask", "last").cast(pl.Float64),

    # tick_time_utc -> Datetime con TZ UTC (corrección: usar 'format' en lugar de 'fmt' y sin 'time_unit')
    pl.when(pl.col("tick_time_utc").is_not_null())
      .then(pl.col("tick_time_utc").str.strptime(pl.Datetime(time_zone="UTC"), strict=False, format=None))
      .otherwise(pl.lit(None))
      .alias("tick_time_utc"),

    # snapshot_ts_utc -> Datetime con TZ UTC (parseando desde ISO)
    pl.lit(_now_iso_utc()).str.strptime(pl.Datetime(time_zone="UTC"), strict=False, format=None).alias("snapshot_ts_utc"),

    pl.lit(TIMEFRAME_LABEL).alias("timeframe_label"),
    pl.lit(DATA_VERSION).alias("data_version"),
    pl.lit(RUN_ID).alias("run_id"),
    pl.lit(server_name).alias("broker_server"),
    pl.lit(company_name).alias("company"),
])

# Reorden final (metadatos primero)
meta_cols = ["snapshot_ts_utc","broker_server","company","timeframe_label","data_version","run_id"]
df = df.select(meta_cols + [c for c in df.columns if c not in meta_cols])

# ------------------------------ 5) Métricas (percentiles, nulls, esquema) ------------------------------
def _pct_null(col: str) -> float:
    if col not in df.columns:
        return 100.0
    n = df.height
    if n == 0:
        return 0.0
    return float(df.select(pl.col(col).is_null().sum()).item()) * 100.0 / n

def _percentiles_summary(col: str) -> Optional[pl.DataFrame]:
    if col not in df.columns:
        return None
    sub = df.select(pl.col(col).drop_nans().drop_nulls())
    if sub.height == 0:
        return None
    return sub.select([
        pl.col(col).min().alias("min"),
        pl.col(col).quantile(0.50, "nearest").alias("p50"),
        pl.col(col).quantile(0.90, "nearest").alias("p90"),
        pl.col(col).quantile(0.95, "nearest").alias("p95"),
        pl.col(col).quantile(0.99, "nearest").alias("p99"),
        pl.col(col).max().alias("max"),
        pl.count().alias("n"),
    ])

total_symbols = df.height
visible_count = df.select(pl.col("visible").fill_null(False).sum()).item() if "visible" in df.columns else None
tradeable_proxy = df.select((pl.col("trade_mode").fill_null(-1) >= 0).sum()).item() if "trade_mode" in df.columns else None

point_stats = _percentiles_summary("point")
cs_stats    = _percentiles_summary("contract_size")

# ------------------------------ 6) Escritura Parquet (Polars) ------------------------------
SYMBOLS_BROKER_PATH.parent.mkdir(parents=True, exist_ok=True)
df.write_parquet(
    SYMBOLS_BROKER_PATH,
    compression=PARQUET_COMPRESSION,
    statistics=bool(PARQUET_WRITE_STATISTICS)
)

# ------------------------------ 7) Cierre de MT5 (siempre) ------------------------------
try:
    mt5.shutdown()
except Exception:
    pass

# ------------------------------ 8) Impresiones obligatorias ------------------------------
print("--------------------------------------------------------------------------------")
print(f"Inventario de símbolos escrito en: {SYMBOLS_BROKER_PATH}")
print(f"Total de símbolos: {total_symbols}", end="")
if visible_count is not None:
    print(f" | visibles: {visible_count}", end="")
if tradeable_proxy is not None:
    print(f" | 'tradeable'(proxy trade_mode>=0): {tradeable_proxy}", end="")
print()

print("Esquema/dtypes (Polars):")
for c, t in df.schema.items():
    print(f"  - {c}: {t}")

crit_cols = ["point","contract_size","digits","trade_mode"]
print("Nulos en columnas críticas (%):")
for c in crit_cols:
    print(f"  - {c}: {_pct_null(c):.2f}%")

def _print_stats(label: str, stats_df: Optional[pl.DataFrame]):
    print(f"{label}:")
    if stats_df is None:
        print("  (sin datos válidos)")
        return
    s = stats_df.row(0)
    keys = ["min","p50","p90","p95","p99","max","n"]
    for k, v in zip(keys, s):
        val = "None" if v is None else (f"{v:.10f}" if isinstance(v, float) else str(v))
        print(f"  - {k}: {val}")

_print_stats("point (min/p50/p90/p95/p99/max, n)", point_stats)
_print_stats("contract_size (min/p50/p90/p95/p99/max, n)", cs_stats)

print("--------------------------------------------------------------------------------")
print("Top-5 símbolos (symbol, path):")
for r in df.select(["symbol","path"]).head(5).iter_rows():
    print(f"  - {r[0]} | {r[1]}")

print(f"server_time_info.json escrito en: {SERVER_TIME_INFO_PATH}")
print("--------------------------------------------------------------------------------")
print(f"Hora GYE fin: {_now_iso_gye()} | Hora UTC fin: {_now_iso_utc()}")
print("✅ Inventario de símbolos completado: OK para continuar con Celda 05")
# ============================================================================================================
# Out:
# ================================================================================
# Inicio Celda 04 — Inventario de símbolos | TZ objetivo: America/Guayaquil
# Hora GYE: 2025-12-02T23:22:53-05:00 | Hora UTC: 2025-12-03T04:22:53+00:00
# --------------------------------------------------------------------------------
# ✅ Conexión MT5 establecida.
# 📝 server_time_info.json escrito en: C:\Quant\MT5_Data_Extraction\data\metadata\server_time_info.json
# Descargando lista completa de símbolos del bróker...
# --------------------------------------------------------------------------------
# Inventario de símbolos escrito en: C:\Quant\MT5_Data_Extraction\data\metadata\symbols_broker.parquet
# Total de símbolos: 131 | visibles: 131 | 'tradeable'(proxy trade_mode>=0): 131
# Esquema/dtypes (Polars):
#   - snapshot_ts_utc: Datetime(time_unit='us', time_zone='UTC')
#   - broker_server: String
#   - company: String
#   - timeframe_label: String
#   - data_version: String
#   - run_id: String
#   - symbol: String
#   - path: String
#   - visible: Boolean
#   - selected: Boolean
#   - digits: Int32
#   - point: Float64
#   - trade_mode: Int32
#   - contract_size: Float64
#   - stops_level: Int32
#   - freeze_level: Int32
#   - spread: Int32
#   - spread_float: Boolean
#   - margin_initial: Float64
#   - margin_maintenance: Float64
#   - swap_mode: Int32
#   - swap_long: Float64
#   - swap_short: Float64
#   - currency_base: String
#   - currency_profit: String
#   - currency_margin: String
#   - description: String
#   - bid: Float64
#   - ask: Float64
#   - last: Float64
#   - tick_time_utc: Datetime(time_unit='us', time_zone='UTC')
# Nulos en columnas críticas (%):
#   - point: 0.00%
#   - contract_size: 0.00%
#   - digits: 0.00%
#   - trade_mode: 0.00%
# point (min/p50/p90/p95/p99/max, n):
#   - min: 0.0000100000
#   - p50: 0.0010000000
#   - p90: 0.0100000000
#   - p95: 0.0100000000
#   - p99: 0.0100000000
#   - max: 0.1000000000
#   - n: 131
# contract_size (min/p50/p90/p95/p99/max, n):
#   - min: 1.0000000000
#   - p50: 1000.0000000000
#   - p90: 100000.0000000000
#   - p95: 100000.0000000000
#   - p99: 1000000.0000000000
#   - max: 1000000.0000000000
#   - n: 131
# --------------------------------------------------------------------------------
# Top-5 símbolos (symbol, path):
#   - EURUSD | Forex\EURUSD
#   - GBPUSD | Forex\GBPUSD
#   - USDCHF | Forex\USDCHF
#   - USDJPY | Forex\USDJPY
#   - USDCAD | Forex\USDCAD
# server_time_info.json escrito en: C:\Quant\MT5_Data_Extraction\data\metadata\server_time_info.json
# --------------------------------------------------------------------------------
# Hora GYE fin: 2025-12-02T23:22:57-05:00 | Hora UTC fin: 2025-12-03T04:22:57+00:00
# ✅ Inventario de símbolos completado: OK para continuar con Celda 05
# C:\Users\PC\AppData\Local\Temp\ipykernel_5380\4057496962.py:316: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   pl.count().alias("n"),

# %%
# ====================== Celda 05 — Filtro de costes (spread + comisiones) [“3B”] ======================
# Propósito:
#   - Estimar el coste round-trip en bps por símbolo: cost_bps = spread_bps + commission_bps + slippage_bps.
#   - Filtrar el universo elegible según umbrales por clase de activo.
# Entradas:
#   - metadata/symbols_broker.parquet  (de Celda 04; debe incluir: symbol, path, bid, ask, contract_size, point, trade_mode, visible, description)
#   - metadata/fees/commissions.json   (opcional; comisiones por clase/símbolo; USD por round-trip o por lado)
#   - metadata/filters/cost_filter_config.json (opcional; umbrales por clase, slippage_bps, require_valid_tick)
# Salidas:
#   - metadata/filters/eligible_symbols_by_cost.parquet  (símbolos elegibles con columnas clave)
#   - metadata/filters/eligible_symbols_by_cost.txt      (lista de símbolos elegibles, uno por línea)
#   - metadata/filters/cost_filter_report.json           (reporte con métricas y conteos)
#   - metadata/costs_summary.parquet                     (resumen de costes por símbolo, 1 fila por símbolo)
#
# Impresiones obligatorias:
#   - Input path, parámetros (slippage_bps, require_valid_tick), thresholds por clase.
#   - p50/p90/p95/p99 para spread_bps, commission_bps y cost_bps (ignorando nulls).
#   - Σ total / elegibles / no elegibles; faltantes por métrica.
#   - Top-10 mayor coste y Top-10 elegibles con menor coste.
#   - Rutas exactas de salidas (parquet/txt/json) con número de filas.
#
# Reglas:
#   - Polars-only para cálculo/transformaciones (sin pandas).
#   - NO re-conecta a MT5; usa el snapshot de Celda 04 (bid/ask).
#   - Una celda = una función.
# Nota importante (costes actuales vs histórico):
#   - Este filtro 3B utiliza symbols_broker.parquet + commissions.json ACTUALES.
#   - En los backtests sobre 4 años de histórico, el coste aplicado es una aproximación
#     "con condiciones actuales" (NO reproduce las condiciones históricas exactas).
#   - Interpretación: PnL backtest ≈ PnL con spreads/comisiones de hoy.

# ======================================================================================================

from __future__ import annotations

import json
import re
from pathlib import Path
from datetime import datetime, timezone
from typing import Dict, Any, Optional

import polars as pl

# --------------------------- Logger (reutiliza Celda 03 si existe) ---------------------------
def _log(level: str, msg: str):
    """
    Wrapper ligero sobre log_msg() de la Celda 03.
    Si no existe log_msg en globals(), no hace nada (no rompe la ejecución).
    """
    if "log_msg" in globals():
        try:
            log_msg("05-Costs", level, msg)
        except Exception:
            # Fallback silencioso si hubiera cualquier problema con el logger
            pass

# --------------------------- Guardas y rutas base (alineadas a celdas previas) ---------------------------
if 'METADATA_DIR' not in globals():
    METADATA_DIR = (Path.cwd() / "data" / "metadata").resolve()
    METADATA_DIR.mkdir(parents=True, exist_ok=True)

SYMBOLS_BROKER_PATH   = METADATA_DIR / "symbols_broker.parquet"
FILTERS_DIR           = METADATA_DIR / "filters"
FEES_DIR              = METADATA_DIR / "fees"
FILTERS_DIR.mkdir(parents=True, exist_ok=True)
FEES_DIR.mkdir(parents=True, exist_ok=True)

ELIGIBLE_PARQUET      = FILTERS_DIR / "eligible_symbols_by_cost.parquet"
ELIGIBLE_TXT          = FILTERS_DIR / "eligible_symbols_by_cost.txt"
REPORT_JSON           = FILTERS_DIR / "cost_filter_report.json"
COMMISSIONS_PATH      = FEES_DIR / "commissions.json"
COST_CFG_PATH         = FILTERS_DIR / "cost_filter_config.json"

# 🔹 Nuevo: resumen de costes por símbolo en metadata/
COSTS_SUMMARY_PATH    = METADATA_DIR / "costs_summary.parquet"

RUN_ID                = globals().get("RUN_ID", datetime.now().strftime("%Y%m%d_%H%M%S"))
TIMEFRAME_LABEL       = globals().get("TIMEFRAME_LABEL", "M5")
DATA_VERSION          = globals().get("DATA_VERSION", "v1")

# --------------------------- Config por defecto (se puede sobreescribir con cost_filter_config.json) ---------------------------
DEFAULT_CFG = {
    "slippage_bps": 0.0,
    "require_valid_tick": True,
    "threshold_bps": {
        "FX_MAJOR": 3.0,
        "FX_MINOR": 6.0,
        "METAL": 10.0,
        "INDEX": 8.0,
        "CRYPTO": 50.0,
        "ENERGY": 12.0,
        "EQUITY": 12.0,
        "OTHER": 12.0
    },
    "classify": {
        "fx_majors_suffix": ["USD","EUR","JPY","GBP","AUD","NZD","CAD","CHF"],
        "metals_prefix": ["XAU","XAG","XPT","XPD"],
        "indices_keywords": ["US500","US100","US30","GER40","FRA40","UK100","EU50","JP225",".CASH"],
        "crypto_prefix": ["BTC","ETH","SOL","BNB","ADA","XRP","DOGE","LTC","DOT","AVAX","UNI","LINK","XLM","ATOM","ETC","FIL","AAVE","ALGO","NEAR","SUI","ARB","OP","APT","MATIC","TON","PEPE","SHIB"],
        "energy_keywords": ["WTI","BRENT","UKOIL","USOIL","NGAS","NATGAS"],
        "crypto_path_markers": ["CRYPTO", "CRYPTOCURRENCY"]
    }
}

# Cargar overrides del usuario (si existen)
cfg = DEFAULT_CFG.copy()
if COST_CFG_PATH.exists():
    try:
        with open(COST_CFG_PATH, "r", encoding="utf-8") as f:
            user_cfg = json.load(f)
        for k, v in user_cfg.items():
            if isinstance(v, dict) and k in cfg:
                cfg[k].update(v)
            else:
                cfg[k] = v
        print(f"⚙️  cost_filter_config.json cargado: {COST_CFG_PATH}")
        _log("INFO", f"cost_filter_config.json cargado desde {COST_CFG_PATH}")
    except Exception as e:
        msg = f"No se pudo leer cost_filter_config.json: {e}. Se usan valores por defecto."
        print(f"⚠️  {msg}")
        _log("WARNING", msg)

# Comisiones (USD)
COMMISSIONS: Dict[str, Any] = {
    "default": {"unit": "per_lot", "round_trip": True, "value_usd": 0.0},
    "SYMBOL_OVERRIDES": {}
}
if COMMISSIONS_PATH.exists():
    try:
        with open(COMMISSIONS_PATH, "r", encoding="utf-8") as f:
            COMMISSIONS.update(json.load(f))
        print(f"💲 commissions.json cargado: {COMMISSIONS_PATH}")
        _log("INFO", f"commissions.json cargado desde {COMMISSIONS_PATH}")
    except Exception as e:
        msg = f"No se pudo leer commissions.json: {e}. Se asume comisión 0.0 USD (round-trip)."
        print(f"⚠️  {msg}")
        _log("WARNING", msg)
else:
    msg = "commissions.json no encontrado. Se asume comisión 0.0 USD (round-trip)."
    print(f"⚠️  {msg}")
    _log("WARNING", msg)

slippage_bps: float             = float(cfg.get("slippage_bps", 0.0))
require_valid_tick: bool        = bool(cfg.get("require_valid_tick", True))
thresholds_map: Dict[str,float] = {**DEFAULT_CFG["threshold_bps"], **cfg.get("threshold_bps", {})}

# --------------------------- Lectura del snapshot de símbolos ---------------------------
if not SYMBOLS_BROKER_PATH.exists():
    msg = f"Falta entrada requerida: {SYMBOLS_BROKER_PATH}"
    _log("ERROR", msg)
    raise RuntimeError(msg)

sb = pl.read_parquet(SYMBOLS_BROKER_PATH)
if sb.height == 0:
    msg = "symbols_broker.parquet está vacío; no hay símbolos para evaluar."
    _log("ERROR", msg)
    raise RuntimeError(msg)

_log("INFO", f"Snapshot de símbolos cargado: {SYMBOLS_BROKER_PATH} ({sb.height} filas)")

# Asegurar columnas necesarias (si alguna falta, crear como null)
need_cols = [
    "symbol","path","visible","trade_mode","digits","point","contract_size",
    "currency_profit","description","spread","spread_float","bid","ask"
]
for c in need_cols:
    if c not in sb.columns:
        sb = sb.with_columns(pl.lit(None).alias(c))

# Uppercase auxiliares para clasificación
sb = sb.with_columns([
    pl.col("symbol").cast(pl.Utf8).alias("symbol"),
    pl.col("path").cast(pl.Utf8).alias("path"),
    pl.col("description").cast(pl.Utf8).alias("description"),
    pl.col("symbol").cast(pl.Utf8).str.to_uppercase().alias("_SYM"),
    pl.col("path").cast(pl.Utf8).str.to_uppercase().alias("_PATH"),
    pl.col("description").cast(pl.Utf8).str.to_uppercase().alias("_DESC"),
])

# --------------------------- Clasificación de activo (expresiones Polars) ---------------------------
maj = cfg["classify"]["fx_majors_suffix"]
met_pat = r"^(XAU|XAG|XPT|XPD)"
idx_pat = r"(US500|US100|US30|GER40|FRA40|UK100|EU50|JP225|\.CASH)"
ene_pat = r"(WTI|BRENT|UKOIL|USOIL|NGAS|NATGAS)"
cry_pre_pat = r"^(%s)" % "|".join([re.escape(s) for s in cfg["classify"]["crypto_prefix"]])

is_index  = pl.col("_SYM").str.contains(idx_pat) | pl.col("_PATH").str.contains(idx_pat)
is_metal  = pl.col("_SYM").str.contains(met_pat)
is_energy = pl.col("_SYM").str.contains(ene_pat) | pl.col("_PATH").str.contains(ene_pat)
is_crypto_path = pl.col("_PATH").str.contains("CRYPTO") | pl.col("_DESC").str.contains("CRYPTO")
is_crypto_pref = pl.col("_SYM").str.contains(cry_pre_pat)

sym_len   = pl.col("_SYM").str.len_chars()
base3     = pl.col("_SYM").str.slice(0, 3)
quote3    = pl.col("_SYM").str.slice(-3)
is_len_ok = (sym_len >= 6) & (sym_len <= 10)
is_fx     = is_len_ok & quote3.is_in(maj)
is_fx_maj = is_fx & base3.is_in(maj)
is_equity = pl.col("_PATH").str.contains("STOCK|SHARE|EQUITY") | pl.col("_DESC").str.contains("STOCK|SHARE|EQUITY")

asset_class_expr = (
    pl.when(is_index).then(pl.lit("INDEX"))
      .when(is_metal).then(pl.lit("METAL"))
      .when(is_energy).then(pl.lit("ENERGY"))
      .when(is_crypto_path | is_crypto_pref).then(pl.lit("CRYPTO"))
      .when(is_fx).then(pl.when(is_fx_maj).then(pl.lit("FX_MAJOR")).otherwise(pl.lit("FX_MINOR")))
      .when(is_equity).then(pl.lit("EQUITY"))
      .otherwise(pl.lit("OTHER"))
)
sb = sb.with_columns(asset_class_expr.alias("asset_class"))

# --------------------------- Umbral por clase (join de referencia, sin UDF) ---------------------------
th_df = pl.DataFrame({
    "asset_class": list(thresholds_map.keys()),
    "threshold_bps": list(thresholds_map.values())
}).with_columns(pl.col("asset_class").cast(pl.Utf8))

sb = sb.join(th_df, on="asset_class", how="left")

# --------------------------- Comisión USD round-trip (override→clase→default) ---------------------------
def _extract_comm_value(entry: Dict[str, Any]) -> float:
    if not isinstance(entry, dict):
        return 0.0
    val = float(entry.get("value_usd", 0.0))
    rt  = bool(entry.get("round_trip", True))
    return val if rt else (2.0 * val)

sym_over = COMMISSIONS.get("SYMBOL_OVERRIDES", {}) or {}

def _commission_usd_rt(symbol: Optional[str], asset_class: Optional[str]) -> float:
    s = (symbol or "").upper()
    if s in sym_over:
        return _extract_comm_value(sym_over[s])
    cls = COMMISSIONS.get(asset_class or "", None)
    if cls is not None:
        return _extract_comm_value(cls)
    return _extract_comm_value(COMMISSIONS.get("default", {}))

sb = sb.with_columns(
    pl.struct(["symbol","asset_class"]).map_elements(lambda r: _commission_usd_rt(r["symbol"], r["asset_class"])).alias("commission_usd_rt")
)

# --------------------------- Cálculo de métricas en bps (expresiones Polars) ---------------------------
valid_tick = pl.col("bid").is_not_null() & pl.col("ask").is_not_null() & (pl.col("bid") > 0) & (pl.col("ask") > 0)
mid       = pl.when(valid_tick).then((pl.col("bid") + pl.col("ask")) * 0.5).otherwise(None)

spread_bps = (
    pl.when(valid_tick & (pl.col("ask") > pl.col("bid")))
      .then(((pl.col("ask") - pl.col("bid")) / mid) * 10000.0)
      .otherwise(None)
)

commission_bps = (
    pl.when((mid.is_not_null()) & (pl.col("contract_size").is_not_null()) & (pl.col("contract_size") > 0))
      .then((pl.col("commission_usd_rt") / (mid * pl.col("contract_size"))) * 10000.0)
      .otherwise(
          pl.when(pl.col("commission_usd_rt") == 0.0).then(0.0).otherwise(None)
      )
)

sb = sb.with_columns([
    spread_bps.alias("spread_bps"),
    commission_bps.alias("commission_bps"),
    pl.lit(float(slippage_bps)).alias("slippage_bps"),
])

cost_bps = (
    pl.when((~valid_tick) & pl.lit(require_valid_tick))
      .then(None)
      .otherwise(pl.col("spread_bps").fill_null(0.0) + pl.col("commission_bps").fill_null(0.0) + pl.col("slippage_bps").fill_null(0.0))
)
sb = sb.with_columns(cost_bps.alias("cost_bps"))

visible_ok    = pl.when(pl.col("visible").is_null()).then(True).otherwise(pl.col("visible"))
trade_mode_ok = pl.when(pl.col("trade_mode").is_null()).then(True).otherwise(pl.col("trade_mode") >= 0)
within_th     = pl.col("cost_bps").is_not_null() & (pl.col("cost_bps") <= pl.col("threshold_bps"))

eligible = (
    pl.when(pl.lit(require_valid_tick) & (~valid_tick)).then(False).otherwise(True)
    & within_th & visible_ok & trade_mode_ok
)
sb = sb.with_columns(eligible.alias("eligible"))

reason_no_tick   = pl.when(pl.lit(require_valid_tick) & (~valid_tick)).then(pl.lit("NO_TICK")).otherwise(pl.lit(""))
reason_spread_na = pl.when(pl.col("spread_bps").is_null()).then(pl.lit("SPREAD_BPS_MISSING")).otherwise(pl.lit(""))
reason_comm_na   = pl.when(pl.col("commission_bps").is_null()).then(pl.lit("COMMISSION_BPS_MISSING")).otherwise(pl.lit(""))
reason_cost_gt   = pl.when(pl.col("cost_bps").is_not_null() & (pl.col("cost_bps") > pl.col("threshold_bps"))) \
                    .then(pl.concat_str([pl.lit("COST>"), pl.col("threshold_bps").round(2).cast(pl.Utf8), pl.lit("bps")], separator="")) \
                    .otherwise(pl.lit(""))
reason_not_vis   = pl.when(pl.col("visible").is_not_null() & (pl.col("visible") == False)).then(pl.lit("NOT_VISIBLE")).otherwise(pl.lit(""))
reason_tm_neg    = pl.when(pl.col("trade_mode").is_not_null() & (pl.col("trade_mode") < 0)).then(pl.lit("TRADE_MODE<0")).otherwise(pl.lit(""))

sb = sb.with_columns(
    pl.concat_list([reason_no_tick, reason_spread_na, reason_comm_na, reason_cost_gt, reason_not_vis, reason_tm_neg])
      .list.eval(pl.element().filter(pl.element() != ""))
      .list.join(";")
      .alias("reason")
)

# --------------------------- Resúmenes de percentiles ---------------------------
def pct_summary(df: pl.DataFrame, col: str) -> Optional[dict]:
    if col not in df.columns:
        return None
    sub = df.select(pl.col(col).drop_nulls())
    if sub.height == 0:
        return None
    return sub.select([
        pl.col(col).quantile(0.50, "nearest").alias("p50"),
        pl.col(col).quantile(0.90, "nearest").alias("p90"),
        pl.col(col).quantile(0.95, "nearest").alias("p95"),
        pl.col(col).quantile(0.99, "nearest").alias("p99"),
        pl.len().alias("n"),
    ]).to_dicts()[0]

spread_stats = pct_summary(sb, "spread_bps")
comm_stats   = pct_summary(sb, "commission_bps")
cost_stats   = pct_summary(sb, "cost_bps")

# --------------------------- Salidas (parquet/txt/json) existentes ---------------------------
eligible_out = sb.filter(pl.col("eligible")).select([
    "symbol","asset_class","spread_bps","commission_bps","slippage_bps","cost_bps","threshold_bps","reason"
])

eligible_out.write_parquet(ELIGIBLE_PARQUET, compression="zstd", statistics=True)

with open(ELIGIBLE_TXT, "w", encoding="utf-8") as f:
    for s in eligible_out.select("symbol").to_series().to_list():
        f.write(f"{s}\n")

report = {
    "run_id": RUN_ID,
    "timeframe": TIMEFRAME_LABEL,
    "data_version": DATA_VERSION,
    "generated_at_utc": datetime.now(timezone.utc).isoformat(timespec="seconds"),
    "inputs": {
        "symbols_broker": str(SYMBOLS_BROKER_PATH),
        "commissions_json": str(COMMISSIONS_PATH),
        "cost_filter_config": str(COST_CFG_PATH),
    },
    "params": {
        "slippage_bps": slippage_bps,
        "require_valid_tick": require_valid_tick,
        "threshold_bps": thresholds_map,
    },
    "counts": {
        "total_symbols": int(sb.height),
        "eligible": int(eligible_out.height),
        "not_eligible": int(sb.height - eligible_out.height),
        "missing_spread_bps": int(sb.select(pl.col("spread_bps").is_null().sum()).item()),
        "missing_commission_bps": int(sb.select(pl.col("commission_bps").is_null().sum()).item()),
        "cost_undefined": int(sb.select(pl.col("cost_bps").is_null().sum()).item()),
    },
    "percentiles": {
        "spread_bps": spread_stats,
        "commission_bps": comm_stats,
        "cost_bps": cost_stats,
    },
    "notes": [
        "spread_bps = ((ask - bid) / mid) * 10000, con mid=(bid+ask)/2 y guardas.",
        "commission_bps = (commission_usd_rt / (mid * contract_size)) * 10000. Si commission_usd_rt=0 → 0 bps.",
        "slippage_bps es constante desde config.",
        "Elegible requiere (por defecto): tick válido, cost_bps ≤ threshold_bps, visible!=False y trade_mode>=0 si viene informado."
    ],
}
with open(REPORT_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)

_log("INFO", f"eligible_symbols_by_cost.parquet escrito ({eligible_out.height} filas)")

# --------------------------- NUEVO: costs_summary.parquet (resumen por símbolo) ---------------------------
# Estructura recomendada:
#   - symbol, asset_class
#   - spread_bps, commission_bps, slippage_bps, cost_bps, threshold_bps
#   - eligible, reason
#   - cost_flag: OK / CARO / PROHIBITIVO / UNKNOWN

# Definición de cost_flag por tramos relativos al threshold_bps:
cost_flag_expr = (
    pl.when(pl.col("cost_bps").is_null() | pl.col("threshold_bps").is_null())
      .then(pl.lit("UNKNOWN"))
      .when(pl.col("cost_bps") <= pl.col("threshold_bps") * 0.5)
      .then(pl.lit("OK"))                  # coste claramente barato vs umbral 3B
      .when(pl.col("cost_bps") <= pl.col("threshold_bps"))
      .then(pl.lit("CARO"))                # coste alto pero todavía dentro de 3B
      .otherwise(pl.lit("PROHIBITIVO"))    # coste por encima del umbral 3B
)

costs_summary = (
    sb.select([
        "symbol",
        "asset_class",
        "spread_bps",
        "commission_bps",
        "slippage_bps",
        "cost_bps",
        "threshold_bps",
        "eligible",
        "reason",
    ])
    .with_columns(cost_flag_expr.alias("cost_flag"))
)

costs_summary.write_parquet(COSTS_SUMMARY_PATH, compression="zstd", statistics=True)
_log("INFO", f"costs_summary.parquet escrito en {COSTS_SUMMARY_PATH} ({costs_summary.height} filas)")

# --------------------------- Impresiones de auditoría ---------------------------
print("================================================================================")
print(">>> Celda 05 :: Filtro de Costes (Spread + Comisiones)")
print(f"📁 INPUT → {SYMBOLS_BROKER_PATH}  (rows={sb.height})")
print(f"⚙️  slippage_bps={slippage_bps} | require_valid_tick={require_valid_tick}")
print("⚙️  thresholds_bps por clase:")
for k, v in thresholds_map.items():
    print(f"   - {k:<9}: {v:.2f} bps")

print("--------------------------------------------------------------------------------")
def _print_stats(name: str, stats: Optional[dict]):
    print(f"{name} percentiles (bps):")
    if not stats:
        print("  (sin datos válidos)")
        return
    print(f"  p50={stats['p50']:.2f} | p90={stats['p90']:.2f} | p95={stats['p95']:.2f} | p99={stats['p99']:.2f} | n={int(stats['n'])}")

_print_stats("spread_bps", spread_stats)
_print_stats("commission_bps", comm_stats)
_print_stats("cost_bps", cost_stats)

print("--------------------------------------------------------------------------------")
total = report["counts"]["total_symbols"]; n_ok = report["counts"]["eligible"]; n_bad = report["counts"]["not_eligible"]
print(f"Σ símbolos={total} | ✅ elegibles={n_ok} | ❌ no elegibles={n_bad}")
print(f"faltan spread_bps={report['counts']['missing_spread_bps']} | faltan commission_bps={report['counts']['missing_commission_bps']} | cost_undefined={report['counts']['cost_undefined']}")

worst = sb.sort("cost_bps", descending=True, nulls_last=True).head(10) \
          .select(["symbol","asset_class","cost_bps","spread_bps","commission_bps","threshold_bps","eligible","reason"])
best_ok = eligible_out.sort("cost_bps").head(10)

print("--------------------------------------------------------------------------------")
print("Top-10 COST más altos (bps):")
for i, r in enumerate(worst.to_dicts(), start=1):
    cb = "NA" if r["cost_bps"] is None else f"{r['cost_bps']:.2f}"
    sp = "NA" if r["spread_bps"] is None else f"{r['spread_bps']:.2f}"
    cm = "NA" if r["commission_bps"] is None else f"{r['commission_bps']:.2f}"
    print(f"  #{i:02d} {r['symbol']:<15} class={r['asset_class']:<8} cost={cb:>6} | spread={sp:>6} | comm={cm:>6} | thr={r['threshold_bps']:.2f} | elig={bool(r['eligible'])} | {r['reason']}")

print("--------------------------------------------------------------------------------")
print("Top-10 elegibles con menor COST (bps):")
for i, r in enumerate(best_ok.to_dicts(), start=1):
    cb = "NA" if r["cost_bps"] is None else f"{r['cost_bps']:.2f}"
    sp = "NA" if r["spread_bps"] is None else f"{r['spread_bps']:.2f}"
    cm = "NA" if r["commission_bps"] is None else f"{r['commission_bps']:.2f}"
    print(f"  #{i:02d} {r['symbol']:<15} class={r['asset_class']:<8} cost={cb:>6} | spread={sp:>6} | comm={cm:>6} | thr={r['threshold_bps']:.2f}")

print("--------------------------------------------------------------------------------")
print(f"💾 OUTPUT → {ELIGIBLE_PARQUET}     (OK, rows={eligible_out.height}, cols={len(eligible_out.columns)})")
print(f"💾 OUTPUT → {ELIGIBLE_TXT}         (OK, lines={eligible_out.height})")
print(f"💾 OUTPUT → {REPORT_JSON}         (OK)")
print(f"💾 OUTPUT → {COSTS_SUMMARY_PATH}  (OK, rows={costs_summary.height}, cols={len(costs_summary.columns)})")
print(">>> Celda 05 :: OK — Universo elegible por coste y resumen de costes listos para consumo")
# ======================================================================================================
# Out:
# ⚠️  commissions.json no encontrado. Se asume comisión 0.0 USD (round-trip).
# [2025-12-02 23:22:58] [20251202_232253] [WARNING] [05-Costs] commissions.json no encontrado. Se asume comisión 0.0 USD (round-trip).
# [2025-12-02 23:22:58] [20251202_232253] [INFO] [05-Costs] Snapshot de símbolos cargado: C:\Quant\MT5_Data_Extraction\data\metadata\symbols_broker.parquet (131 filas)
# [2025-12-02 23:22:58] [20251202_232253] [INFO] [05-Costs] eligible_symbols_by_cost.parquet escrito (107 filas)
# [2025-12-02 23:22:58] [20251202_232253] [INFO] [05-Costs] costs_summary.parquet escrito en C:\Quant\MT5_Data_Extraction\data\metadata\costs_summary.parquet (131 filas)
# ================================================================================
# >>> Celda 05 :: Filtro de Costes (Spread + Comisiones)
# 📁 INPUT → C:\Quant\MT5_Data_Extraction\data\metadata\symbols_broker.parquet  (rows=131)
# ⚙️  slippage_bps=0.0 | require_valid_tick=True
# ⚙️  thresholds_bps por clase:
#    - FX_MAJOR : 3.00 bps
#    - FX_MINOR : 6.00 bps
#    - METAL    : 10.00 bps
#    - INDEX    : 8.00 bps
#    - CRYPTO   : 50.00 bps
#    - ENERGY   : 12.00 bps
#    - EQUITY   : 12.00 bps
#    - OTHER    : 12.00 bps
# --------------------------------------------------------------------------------
# spread_bps percentiles (bps):
#   p50=4.59 | p90=35.49 | p95=49.95 | p99=82.93 | n=130
# commission_bps percentiles (bps):
#   p50=0.00 | p90=0.00 | p95=0.00 | p99=0.00 | n=131
# cost_bps percentiles (bps):
#   p50=4.47 | p90=35.49 | p95=49.95 | p99=82.93 | n=131
# --------------------------------------------------------------------------------
# Σ símbolos=131 | ✅ elegibles=107 | ❌ no elegibles=24
# faltan spread_bps=1 | faltan commission_bps=0 | cost_undefined=0
# --------------------------------------------------------------------------------
# Top-10 COST más altos (bps):
#   #01 NEOUSD          class=CRYPTO   cost=198.02 | spread=198.02 | comm=  0.00 | thr=50.00 | elig=False | COST>50.0bps
#   #02 SUGAR.c         class=OTHER    cost= 82.93 | spread= 82.93 | comm=  0.00 | thr=12.00 | elig=False | COST>12.0bps
#   #03 NATGAS.cash     class=INDEX    cost= 77.53 | spread= 77.53 | comm=  0.00 | thr=8.00 | elig=False | COST>8.0bps
#   #04 XTZUSD          class=CRYPTO   cost= 64.86 | spread= 64.86 | comm=  0.00 | thr=50.00 | elig=False | COST>50.0bps
#   #05 HEATOIL.c       class=OTHER    cost= 63.87 | spread= 63.87 | comm=  0.00 | thr=12.00 | elig=False | COST>12.0bps
#   #06 COTTON.c        class=OTHER    cost= 62.89 | spread= 62.89 | comm=  0.00 | thr=12.00 | elig=False | COST>12.0bps
#   #07 XPDUSD          class=METAL    cost= 49.95 | spread= 49.95 | comm=  0.00 | thr=10.00 | elig=False | COST>10.0bps
#   #08 NERUSD          class=CRYPTO   cost= 41.29 | spread= 41.29 | comm=  0.00 | thr=50.00 | elig=True |
#   #09 COCOA.c         class=OTHER    cost= 39.61 | spread= 39.61 | comm=  0.00 | thr=12.00 | elig=False | COST>12.0bps
#   #10 PFE             class=OTHER    cost= 39.51 | spread= 39.51 | comm=  0.00 | thr=12.00 | elig=False | COST>12.0bps
# --------------------------------------------------------------------------------
# Top-10 elegibles con menor COST (bps):
#   #01 EURUSD          class=FX_MAJOR cost=  0.00 | spread=    NA | comm=  0.00 | thr=3.00
#   #02 BTCUSD          class=CRYPTO   cost=  0.12 | spread=  0.12 | comm=  0.00 | thr=50.00
#   #03 BNBUSD          class=CRYPTO   cost=  0.12 | spread=  0.12 | comm=  0.00 | thr=50.00
#   #04 EURGBP          class=FX_MAJOR cost=  0.23 | spread=  0.23 | comm=  0.00 | thr=3.00
#   #05 USDCAD          class=FX_MAJOR cost=  0.29 | spread=  0.29 | comm=  0.00 | thr=3.00
#   #06 GBPUSD          class=FX_MAJOR cost=  0.30 | spread=  0.30 | comm=  0.00 | thr=3.00
#   #07 AUDUSD          class=FX_MAJOR cost=  0.31 | spread=  0.31 | comm=  0.00 | thr=3.00
#   #08 USDJPY          class=FX_MAJOR cost=  0.32 | spread=  0.32 | comm=  0.00 | thr=3.00
#   #09 US30.cash       class=INDEX    cost=  0.33 | spread=  0.33 | comm=  0.00 | thr=8.00
#   #10 USDHKD          class=OTHER    cost=  0.33 | spread=  0.33 | comm=  0.00 | thr=12.00
# --------------------------------------------------------------------------------
# 💾 OUTPUT → C:\Quant\MT5_Data_Extraction\data\metadata\filters\eligible_symbols_by_cost.parquet     (OK, rows=107, cols=8)
# 💾 OUTPUT → C:\Quant\MT5_Data_Extraction\data\metadata\filters\eligible_symbols_by_cost.txt         (OK, lines=107)
# 💾 OUTPUT → C:\Quant\MT5_Data_Extraction\data\metadata\filters\cost_filter_report.json         (OK)
# 💾 OUTPUT → C:\Quant\MT5_Data_Extraction\data\metadata\costs_summary.parquet  (OK, rows=131, cols=10)
# >>> Celda 05 :: OK — Universo elegible por coste y resumen de costes listos para consumo

# %%
# ======================== Celda 06 — Descarga masiva M5 (4 años, UTC+GYE, Polars-only, v2-debug) ========================
# Reglas:
#   - TF estricto: M5.
#   - Ventana "teórica": últimos 4 años hasta ayer 23:55 UTC (WS, WE).
#   - Modo profesional:
#       * BULK_MODE_08 = "AUTO" (defecto):
#             - Símbolo NO está en catálogo -> descarga FULL [WS, WE] (bootstrap).
#             - Símbolo SÍ está en catálogo -> descarga INCREMENTAL desde last_ts_utc + 1 vela M5
#               con backfill de INCR_BACKFILL_DAYS_08 (para cubrir huecos / correcciones).
#       * BULK_MODE_08 = "FULL": siempre descarga [WS, WE] para todos los símbolos.
#       * BULK_MODE_08 = "INCREMENTAL": siempre usa modo incremental si hay last_ts_utc; si no, cae a FULL.
#   - Descarga mensual -> partición diaria -> 1 archivo/día.
#   - PAD:
#       <DATA_ROOT>/bulk_data/m5_raw/symbol=SYMBOL/year=YYYY/month=MM/part=YYYYMMDD.parquet
#   - Idempotencia: si el día existe, no reescribe salvo FORCE_*.
#   - Catálogo actualizado + logs JSONL.
#   - Lista elegible por coste (Celda 3B/5): metadata/filters/eligible_symbols_by_cost.parquet|.txt (columna 'symbol')
#   - Esquema: timestamp_utc (Int64 ms UTC) + timestamp_gye (Datetime[ms,'America/Guayaquil'])
#   - Polars-only (sin pandas), sin paths absolutos hardcodeados.
#
# v2-debug:
#   - Verificación explícita de cobertura M5:
#       * Barras totales por mes para primeros símbolos.
#       * Barras por día (min/p50/max) en cada mes (para debug).
#       * Reapertura de varios part=YYYYMMDD.parquet recién escritos para comprobar n_bars y rango temporal.
#   - Mensajes claros si medianas de barras/día << 288 (posible D1/M15 o extracción rota).
# =======================================================================================================================

from __future__ import annotations
import json, time
from pathlib import Path
from datetime import datetime, timedelta, timezone

# Dependencias
try:
    import polars as pl
except Exception as e:
    raise RuntimeError("Polars es obligatorio en la Celda 06. Instala 'polars'.") from e

try:
    import MetaTrader5 as mt5
except Exception as e:
    raise RuntimeError("MetaTrader5 no está disponible. Instala 'MetaTrader5'.") from e

# Ventanas exactas por mes/año (opcional)
try:
    from dateutil.relativedelta import relativedelta
    _HAS_REL = True
except Exception:
    _HAS_REL = False

# ----------------------- Config global y PADs -----------------------
CELL_LABEL = "06-BulkM5"
RUN_ID = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))

# DATA_ROOT debe definirse en celdas previas (ROOT único del proyecto)
if "DATA_ROOT" not in globals():
    raise RuntimeError("DATA_ROOT no está definido. Establécelo en la Celda 02 (config & rutas).")

DATA_ROOT      = Path(globals()["DATA_ROOT"])
BULK_M5_DIR    = DATA_ROOT / "bulk_data" / "m5_raw"
META_DIR       = DATA_ROOT / "metadata"
FILTERS_DIR    = META_DIR / "filters"
CATALOG_PATH   = META_DIR / "dataset_catalog.parquet"
SYMBOLS_BROKER = META_DIR / "symbols_broker.parquet"
SCHEMA_JSON    = META_DIR / "schema_m5.json"
RUN_LOG        = META_DIR / "run_log.jsonl"

# Zona horaria local para timestamp_gye (IANA explícito)
TIMEZONE_IANA = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# Lista elegible Celda 3B/5
ELIGIBLE_PARQUET = FILTERS_DIR / "eligible_symbols_by_cost.parquet"
ELIGIBLE_TXT     = FILTERS_DIR / "eligible_symbols_by_cost.txt"

# Flags
TIMEFRAME_LABEL   = globals().get("TIMEFRAME_LABEL", "M5")
FORCE_REDOWNLOAD  = bool(globals().get("FORCE_REDOWNLOAD_BULK_M5", False))
FORCE_REWRITE_DAY = bool(globals().get("FORCE_REWRITE_DAY", False))

# Ventana fija "teórica": últimos 4 años
WINDOW_YEARS = 4
WINDOW_DAYS_FALLBACK = 1461  # si no hay dateutil

# Retries
RETRIES_CONN = 5
RETRIES_REQ  = 3
SLEEP_BASE   = 0.8

# Afinadores
MAX_SYMBOLS: int | None = globals().get("MAX_SYMBOLS_08", None)
WHITELIST = globals().get("WHITELIST_08", None)
BLACKLIST = globals().get("BLACKLIST_08", None)

# Flag para controlar el precheck estricto de 4 años (por defecto DESACTIVADO)
STRICT_4Y_PRECHECK = bool(globals().get("STRICT_4Y_PRECHECK", False))

# ----------------- Modo de descarga FULL / INCREMENTAL -----------------
BULK_MODE = str(globals().get("BULK_MODE_08", "AUTO")).upper()
if BULK_MODE not in {"AUTO", "FULL", "INCREMENTAL"}:
    BULK_MODE = "AUTO"

INCR_BACKFILL_DAYS = int(globals().get("INCR_BACKFILL_DAYS_08", 3))  # días de solape en modo incremental

# ----------------- Parámetros de debug de cobertura M5 -----------------
DEBUG_08 = bool(globals().get("DEBUG_08", True))
DEBUG_MAX_SYMBOLS = int(globals().get("DEBUG_MAX_SYMBOLS_08", 2))                  # símbolos con debug detallado
DEBUG_MAX_MONTHS_PER_SYMBOL = int(globals().get("DEBUG_MAX_MONTHS_08", 2))         # meses con stats detalladas
DEBUG_SAMPLE_DAYS_PER_MONTH = int(globals().get("DEBUG_SAMPLE_DAYS_PER_MONTH_08", 3))   # días ejemplo/mes
DEBUG_SAMPLE_DAYS_PER_SYMBOL = int(globals().get("DEBUG_SAMPLE_DAYS_PER_SYMBOL_08", 3)) # días re-leídos desde disco
MIN_EXPECTED_BARS_PER_DAY_DEBUG = int(globals().get("MIN_EXPECTED_BARS_PER_DAY_DEBUG_08", 200))
EXPECTED_BARS_M5 = int(globals().get("EXPECTED_BARS_M5", 288))

# ----------------------- Utilidades -----------------------
def _log(level: str, msg: str) -> None:
    ts = datetime.now(timezone.utc).isoformat(timespec="seconds")
    print(f"[{ts}] [{RUN_ID}] [{level}] [{CELL_LABEL}] {msg}", flush=True)

def _ensure_dirs() -> None:
    BULK_M5_DIR.mkdir(parents=True, exist_ok=True)
    META_DIR.mkdir(parents=True, exist_ok=True)
    FILTERS_DIR.mkdir(parents=True, exist_ok=True)
    if not CATALOG_PATH.exists():
        pl.DataFrame(
            {
                "symbol": pl.Series([], dtype=pl.Utf8),
                "first_ts_utc": pl.Series([], dtype=pl.Int64),
                "last_ts_utc": pl.Series([], dtype=pl.Int64),
                "n_files": pl.Series([], dtype=pl.Int64),
                "n_days": pl.Series([], dtype=pl.Int64),
                "n_months": pl.Series([], dtype=pl.Int64),
                "n_years": pl.Series([], dtype=pl.Int64),
                "bytes": pl.Series([], dtype=pl.Int64),
                "last_update_ts_utc": pl.Series([], dtype=pl.Int64),
                "notes": pl.Series([], dtype=pl.Utf8),
            }
        ).write_parquet(CATALOG_PATH, compression="zstd", statistics=True)

def _write_jsonl(path: Path, obj: dict) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    with open(path, "a", encoding="utf-8") as f:
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

def _mt5_init_with_retries() -> None:
    print("=" * 110)
    print(f"Inicio Celda 06 — Descarga masiva M5 | TZ objetivo: {TIMEZONE_IANA}")
    try:
        from zoneinfo import ZoneInfo
        gye_now = datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
        print(f"Hora GYE: {gye_now} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
    except Exception:
        print(f"Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')} (instala 'tzdata' para TZ locales)")
    print("-" * 110)
    print(f"DATA_ROOT       : {DATA_ROOT}")
    print(f"PAD salida M5   : {BULK_M5_DIR}")
    print(f"BULK_MODE_08    : {BULK_MODE}")
    print(f"INCR_BACKFILL_DAYS_08 : {INCR_BACKFILL_DAYS}")
    print(f"STRICT_4Y_PRECHECK    : {STRICT_4Y_PRECHECK}")
    print(f"FORCE_REDOWNLOAD_BULK_M5 = {FORCE_REDOWNLOAD}")
    print(f"FORCE_REWRITE_DAY        = {FORCE_REWRITE_DAY}")
    print(f"DEBUG_08                 = {DEBUG_08}")
    print("-" * 110)
    _log("INFO", "Conectando a MT5 con reintentos...")
    for k in range(RETRIES_CONN):
        if mt5.initialize():
            _log("INFO", "Conexión MT5 establecida.")
            return
        time.sleep((2 ** k) * SLEEP_BASE)
    raise RuntimeError("No se pudo inicializar MT5 tras varios intentos.")

def _mt5_shutdown() -> None:
    try:
        mt5.shutdown()
        _log("INFO", "Conexión MT5 cerrada.")
    except Exception:
        pass

def _read_eligible_symbols_if_any(strict_on_empty: bool = True) -> list[str] | None:
    if ELIGIBLE_PARQUET.exists():
        df = pl.read_parquet(ELIGIBLE_PARQUET)
        col = "symbol" if "symbol" in df.columns else df.columns[0]
        syms = sorted({str(s).strip() for s in df.get_column(col).to_list() if str(s).strip()})
        if len(syms) == 0 and strict_on_empty:
            raise RuntimeError("eligible_symbols_by_cost.parquet está vacío. Revisa la Celda 05.")
        return syms if syms else (None if not strict_on_empty else [])
    if ELIGIBLE_TXT.exists():
        syms = []
        with open(ELIGIBLE_TXT, "r", encoding="utf-8") as f:
            for line in f:
                v = line.strip()
                if v:
                    syms.append(v)
        syms = sorted({s for s in syms})
        if len(syms) == 0 and strict_on_empty:
            raise RuntimeError("eligible_symbols_by_cost.txt está vacío. Revisa la Celda 05.")
        return syms if syms else (None if not strict_on_empty else [])
    return None

def _read_symbols() -> list[str]:
    if not SYMBOLS_BROKER.exists():
        raise FileNotFoundError(f"No existe {SYMBOLS_BROKER}. Ejecuta la Celda 04 (inventario de símbolos).")
    df = pl.read_parquet(SYMBOLS_BROKER)
    col = "symbol" if "symbol" in df.columns else df.columns[0]
    if WHITELIST:
        df = df.filter(pl.col(col).is_in(WHITELIST))
    if BLACKLIST:
        df = df.filter(~pl.col(col).is_in(BLACKLIST))
    syms = [str(s) for s in df.get_column(col).to_list()]
    if MAX_SYMBOLS is not None:
        syms = syms[:int(MAX_SYMBOLS)]
    return syms

def _window_edges() -> tuple[datetime, datetime]:
    now_utc = datetime.now(timezone.utc)
    # Ayer 23:55 UTC: evitamos última vela en formación
    end_day = (now_utc - timedelta(days=1)).replace(hour=23, minute=55, second=0, microsecond=0)
    if _HAS_REL:
        start_day = (end_day - relativedelta(years=WINDOW_YEARS)).replace(
            hour=0, minute=0, second=0, microsecond=0
        )
    else:
        start_day = (end_day - timedelta(days=WINDOW_DAYS_FALLBACK - 1)).replace(
            hour=0, minute=0, second=0, microsecond=0
        )
    return start_day, end_day

def _month_iter(start_dt: datetime, end_dt: datetime):
    ms = start_dt.replace(day=1, hour=0, minute=0, second=0, microsecond=0)
    while ms <= end_dt:
        if _HAS_REL:
            me = ms + relativedelta(months=1)
        else:
            me = (ms + timedelta(days=32)).replace(day=1, hour=0, minute=0, second=0, microsecond=0)
        yield ms, me
        ms = me

def _load_schema_column_order() -> list[str]:
    try:
        schema = json.loads(SCHEMA_JSON.read_text(encoding="utf-8"))
        return list(schema["column_order"])
    except Exception:
        return [
            "timestamp_utc", "timestamp_gye", "symbol", "open", "high", "low", "close",
            "tick_volume", "real_volume", "spread_points", "broker", "server_tz",
        ]

def _ensure_schema_order(df: pl.DataFrame, col_order: list[str]) -> pl.DataFrame:
    cols = set(df.columns)
    add_exprs = []
    for c in col_order:
        if c not in cols:
            if c == "timestamp_utc":
                add_exprs.append(pl.lit(None, dtype=pl.Int64).alias(c))
            elif c == "timestamp_gye":
                add_exprs.append(pl.lit(None, dtype=pl.Datetime("ms", TIMEZONE_IANA)).alias(c))
            elif c in {"open", "high", "low", "close", "spread_points"}:
                add_exprs.append(pl.lit(None, dtype=pl.Float64).alias(c))
            elif c in {"tick_volume", "real_volume"}:
                add_exprs.append(pl.lit(None, dtype=pl.Int64).alias(c))
            else:
                add_exprs.append(pl.lit(None, dtype=pl.Utf8).alias(c))
    if add_exprs:
        df = df.with_columns(add_exprs)
    return df.select(col_order)

def _update_catalog_for_symbol(symbol: str) -> None:
    sym_dir = BULK_M5_DIR / f"symbol={symbol}"
    if not sym_dir.exists():
        return
    parts = list(sym_dir.rglob("part=*.parquet"))
    if not parts:
        return
    total_b = 0
    days = set()
    for p in parts:
        try:
            total_b += p.stat().st_size
            days.add(p.name.split("part=")[1].split(".parquet")[0][:8])
        except Exception:
            pass
    n_files = len(parts)
    n_days  = len(days)

    pattern = str(sym_dir / "year=*" / "month=*" / "part=*.parquet")
    minmax = pl.scan_parquet(pattern).select(
        pl.min("timestamp_utc").alias("ts_min"),
        pl.max("timestamp_utc").alias("ts_max")
    ).collect()

    if minmax.height == 0 or minmax[0, "ts_min"] is None:
        return

    ts_min = int(minmax[0, "ts_min"])
    ts_max = int(minmax[0, "ts_max"])
    dt0 = datetime.fromtimestamp(ts_min / 1000, tz=timezone.utc)
    dt1 = datetime.fromtimestamp(ts_max / 1000, tz=timezone.utc)
    n_months = (dt1.year - dt0.year) * 12 + (dt1.month - dt0.month) + 1
    n_years  = dt1.year - dt0.year + 1

    base = pl.read_parquet(CATALOG_PATH) if CATALOG_PATH.exists() else pl.DataFrame(
        schema=[
            pl.Field("symbol", pl.Utf8),
            pl.Field("first_ts_utc", pl.Int64),
            pl.Field("last_ts_utc", pl.Int64),
            pl.Field("n_files", pl.Int64),
            pl.Field("n_days", pl.Int64),
            pl.Field("n_months", pl.Int64),
            pl.Field("n_years", pl.Int64),
            pl.Field("bytes", pl.Int64),
            pl.Field("last_update_ts_utc", pl.Int64),
            pl.Field("notes", pl.Utf8),
        ]
    )
    updated_row = pl.DataFrame(
        {
            "symbol": [symbol],
            "first_ts_utc": [ts_min],
            "last_ts_utc": [ts_max],
            "n_files": [n_files],
            "n_days": [n_days],
            "n_months": [n_months],
            "n_years": [n_years],
            "bytes": [total_b],
            "last_update_ts_utc": [int(datetime.now(timezone.utc).timestamp() * 1000)],
            "notes": [""],
        }
    )
    others = base.filter(pl.col("symbol") != symbol)
    pl.concat([others, updated_row], how="vertical").write_parquet(CATALOG_PATH, compression="zstd", statistics=True)

def _precheck_symbol(symbol: str, ws: datetime, we: datetime) -> bool:
    """Precheck de cobertura M5 ~4 años (solo si STRICT_4Y_PRECHECK=True)."""
    try:
        mt5.symbol_select(symbol, True)
    except Exception:
        pass
    wk = timedelta(days=7)
    ranges = [(ws, ws + wk), (we - wk, we + timedelta(days=1))]
    for (a, b) in ranges:
        got = False
        last_err = None
        for r in range(RETRIES_REQ):
            try:
                arr = mt5.copy_rates_range(symbol, mt5.TIMEFRAME_M5, a, b)
                got = (arr is not None) and (len(arr) > 0)
                if got:
                    break
            except Exception as e:
                last_err = e
            time.sleep((2 ** r) * SLEEP_BASE)
        if not got:
            _write_jsonl(
                RUN_LOG,
                {
                    "run_id": RUN_ID,
                    "cell": CELL_LABEL,
                    "symbol": symbol,
                    "status": "precheck_fail",
                    "msg": f"sin_barras_en_{a.date()}_{b.date()}",
                    "err": str(last_err) if last_err else "",
                },
            )
            return False
    return True

def _month_span_limited(ms: datetime, me: datetime, ws: datetime, we: datetime) -> tuple[datetime, datetime]:
    real_start = max(ms, ws)
    real_end   = min(me, we + timedelta(days=1))
    return real_start, real_end  # [real_start, real_end) exclusivo

def _mt5_array_to_polars(arr) -> pl.DataFrame:
    """Convierte el structured array de MT5 a DataFrame Polars (sin pandas)."""
    if arr is None or len(arr) == 0:
        return pl.DataFrame()
    names = getattr(arr, "dtype", None)
    names = names.names if names is not None else None
    if names:
        return pl.DataFrame({n: arr[n].tolist() for n in names})
    try:
        return pl.DataFrame(arr)
    except Exception:
        try:
            return pl.from_dicts([dict(x) for x in arr])
        except Exception as e:
            raise ValueError(f"No se pudo convertir la respuesta MT5 a Polars: {e}")

# ----------------------- Inicio y setup -----------------------
_ensure_dirs()

# Cargar catálogo actual para detectar símbolos "ya vistos"
_catalog_df = pl.read_parquet(CATALOG_PATH)
catalog_last_ts = {row["symbol"]: row["last_ts_utc"] for row in _catalog_df.to_dicts()} if _catalog_df.height > 0 else {}

eligible_syms = _read_eligible_symbols_if_any(strict_on_empty=True)
if eligible_syms is not None:
    _log("INFO", f"Usando lista elegible por coste (Celda 05): {len(eligible_syms)} símbolos")
    WHITELIST = eligible_syms
else:
    _log("WARNING", "No se encontró lista elegible por coste. Se usarán todos los símbolos del broker.")

WS, WE = _window_edges()
print(f"Ventana objetivo (UTC teórica): {WS.date()} → {WE.date()} (últimos {WINDOW_YEARS} años)")

# Conteo total sin filtros (denominador)
try:
    total_all = pl.read_parquet(SYMBOLS_BROKER).height
except Exception:
    total_all = None

symbols_all = _read_symbols()
if MAX_SYMBOLS is not None:
    symbols_all = symbols_all[:int(MAX_SYMBOLS)]

print(
    f"Universo de símbolos (filtro costes Celda 05 + broker): {len(symbols_all)}"
    + (f" / {total_all}" if total_all is not None else "")
)
if symbols_all:
    print("Ejemplo de símbolos:", ", ".join(symbols_all[:min(10, len(symbols_all))]))
print(f"STRICT_4Y_PRECHECK = {STRICT_4Y_PRECHECK} | BULK_MODE_08 = {BULK_MODE}")
print(f"FORCE_REDOWNLOAD_BULK_M5={FORCE_REDOWNLOAD} | FORCE_REWRITE_DAY={FORCE_REWRITE_DAY}")
print("-" * 110)

# Conexión a MT5
_mt5_init_with_retries()

# Guard de timeframe
TIMEFRAME = mt5.TIMEFRAME_M5
assert TIMEFRAME_LABEL == "M5", "TIMEFRAME_LABEL debe ser 'M5'."
_log("INFO", f"Usando TIMEFRAME_M5 de MT5 (valor interno={TIMEFRAME}).")

# ----------------------- Prefiltro cobertura (opcional) -----------------------
kept: list[str] = []
dropped: list[str] = []

if STRICT_4Y_PRECHECK:
    for i, s in enumerate(symbols_all, start=1):
        _log("INFO", f"[Prefiltro {i}/{len(symbols_all)}] {s} → chequeo 4y (estricto)...")
        if _precheck_symbol(s, WS, WE):
            kept.append(s)
        else:
            dropped.append(s)

    print("-" * 110)
    print(f"Prefiltro cobertura >=4y (estricto) → kept={len(kept)} | dropped={len(dropped)}")
    if kept:
        print("Ejemplo kept:", ", ".join(kept[:min(10, len(kept))]))
        print("Ejemplo dropped:", ", ".join(dropped[:min(10, len(dropped))]))
    if not kept:
        _mt5_shutdown()
        print("⚠️  Ningún símbolo cumple el requisito de 4 años en esta sesión/servidor (modo estricto).")
        print("✅ Descarga M5: SIN cambios. OK para continuar con la siguiente celda.")
        raise SystemExit
else:
    kept = list(symbols_all)
    dropped = []
    print("-" * 110)
    print(
        "Prefiltro cobertura >=4y DESACTIVADO (STRICT_4Y_PRECHECK=False). "
        f"Se intentará descargar M5 para todos los símbolos elegibles: {len(kept)}"
    )

# ----------------------- Descarga por símbolo en bloques mensuales -----------------------
total_days_written = 0
total_bytes = 0
symbols_ok = 0
col_order = _load_schema_column_order()

for idx, symbol in enumerate(kept, start=1):
    # -------- Decidir ventana por símbolo según catálogo + BULK_MODE --------
    last_ts = catalog_last_ts.get(symbol, None)

    if BULK_MODE == "FULL" or last_ts is None:
        sym_mode = "FULL"
        sym_ws, sym_we = WS, WE
    else:
        last_dt = datetime.fromtimestamp(int(last_ts) / 1000, tz=timezone.utc)
        incr_start = (last_dt + timedelta(minutes=5)).replace(second=0, microsecond=0)
        incr_start -= timedelta(days=INCR_BACKFILL_DAYS)
        if incr_start < WS:
            incr_start = WS
        sym_ws, sym_we = incr_start, WE
        if sym_ws >= sym_we:
            _log("INFO", f"[{idx}/{len(kept)}] {symbol}: ya actualizado hasta {last_dt.isoformat()}, sin días nuevos.")
            continue
        sym_mode = "INCREMENTAL"

    debug_this_symbol = DEBUG_08 and (idx <= DEBUG_MAX_SYMBOLS)
    _log(
        "INFO",
        f"[{idx}/{len(kept)}] {symbol}: modo={sym_mode}, ventana efectiva {sym_ws.date()} → {sym_we.date()} | "
        f"BULK_MODE_08={BULK_MODE}, INCR_BACKFILL_DAYS_08={INCR_BACKFILL_DAYS}"
    )

    try:
        mt5.symbol_select(symbol, True)
    except Exception:
        pass

    months = list(_month_iter(sym_ws, sym_we))
    days_written_sym = 0
    debug_days_checked = 0  # relectura de part=YYYYMMDD.parquet

    for m_idx, (m_start, m_end) in enumerate(months, start=1):
        real_start, real_end = _month_span_limited(m_start, m_end, sym_ws, sym_we)
        if real_start >= real_end:
            continue

        yyyy, mm = f"{real_start.year:04d}", f"{real_start.month:02d}"
        yyyy_mm = f"{yyyy}-{mm}"

        ok = False
        last_err = None
        for r in range(RETRIES_REQ):
            try:
                arr = mt5.copy_rates_range(symbol, TIMEFRAME, real_start, real_end)
                if arr is None:
                    raise RuntimeError(f"copy_rates_range devolvió None (last_error={mt5.last_error()})")
                ok = True
                break
            except Exception as e:
                last_err = e
                time.sleep((2 ** r) * SLEEP_BASE)
        if not ok:
            _log("WARNING", f"{symbol} {yyyy_mm}: fallo mensual tras reintentos: {last_err}")
            _write_jsonl(
                RUN_LOG,
                {
                    "run_id": RUN_ID,
                    "cell": CELL_LABEL,
                    "symbol": symbol,
                    "status": "month_error",
                    "month": yyyy_mm,
                    "msg": str(last_err),
                },
            )
            continue

        if len(arr) == 0:
            _log("INFO", f"{symbol} {yyyy_mm}: mes sin barras (feriado/activo sin trading o fuera de ventana).")
            continue

        df = _mt5_array_to_polars(arr)
        if df.height == 0:
            _log("WARNING", f"{symbol} {yyyy_mm}: df vacío tras conversión a Polars.")
            continue

        # Transformaciones básicas y schema M5
        df = (
            df
            .with_columns(
                pl.lit(symbol).alias("symbol"),
                (pl.col("time").cast(pl.Int64) * pl.lit(1000, dtype=pl.Int64)).alias("timestamp_utc"),
            )
            .with_columns(
                pl.col("timestamp_utc")
                  .cast(pl.Datetime("ms"))
                  .dt.replace_time_zone("UTC")
                  .alias("_ts_utc_dt"),
            )
            .with_columns(
                pl.col("_ts_utc_dt").dt.convert_time_zone(TIMEZONE_IANA).alias("timestamp_gye"),
                pl.when(pl.col("spread").is_not_null())
                  .then(pl.col("spread").cast(pl.Float64))
                  .otherwise(pl.lit(None, dtype=pl.Float64))
                  .alias("spread_points"),
                pl.col("tick_volume").cast(pl.Int64).alias("tick_volume"),
                pl.when(pl.col("real_volume").is_not_null())
                  .then(pl.col("real_volume").cast(pl.Int64))
                  .otherwise(pl.lit(None, dtype=pl.Int64))
                  .alias("real_volume"),
                pl.lit(None, dtype=pl.Utf8).alias("broker"),
                pl.lit(None, dtype=pl.Utf8).alias("server_tz"),
            )
        )

        df = df.sort("timestamp_utc").unique(subset=["timestamp_utc"], keep="last")

        df = df.with_columns(
            pl.col("_ts_utc_dt").dt.strftime("%Y%m%d").alias("_date_utc_str"),
        )

        # ------------------------ DEBUG: cobertura mensual M5 ------------------------
        if debug_this_symbol and (m_idx <= DEBUG_MAX_MONTHS_PER_SYMBOL):
            n_bars_month = df.height
            day_counts = (
                df.group_by("_date_utc_str")
                  .agg(pl.len().alias("n_bars_day"))
                  .sort("_date_utc_str")
            )
            n_days_month = day_counts.height
            if n_days_month > 0:
                stats = day_counts.select([
                    pl.col("n_bars_day").min().alias("n_min"),
                    pl.col("n_bars_day").median().alias("n_p50"),
                    pl.col("n_bars_day").max().alias("n_max"),
                ]).to_dicts()[0]
                n_min = int(stats["n_min"])
                n_p50 = float(stats["n_p50"])
                n_max = int(stats["n_max"])
            else:
                n_min = n_max = 0
                n_p50 = 0.0

            _log(
                "INFO",
                f"[DEBUG] {symbol} {yyyy_mm}: barras_totales_mes={n_bars_month} | dias_mes={n_days_month} | "
                f"barras/día min={n_min}, p50={n_p50:.1f}, max={n_max}"
            )

            if n_p50 < MIN_EXPECTED_BARS_PER_DAY_DEBUG:
                _log(
                    "WARNING",
                    f"[DEBUG] {symbol} {yyyy_mm}: MEDIANA barras/día={n_p50:.1f} << {MIN_EXPECTED_BARS_PER_DAY_DEBUG} "
                    f"(EXPECTED_BARS_M5={EXPECTED_BARS_M5}). Posible timeframe incorrecto (D1/M15) o extracción rota."
                )

            # Imprimir algunos días de ejemplo
            print(f"Ejemplo días {symbol} {yyyy_mm} (barras/día):")
            for r in day_counts.head(DEBUG_SAMPLE_DAYS_PER_MONTH).iter_rows(named=True):
                print(f"  - {r['_date_utc_str']}: n_bars_day={r['n_bars_day']}")
            print("-" * 80)
        # ---------------------------------------------------------------------------

        unique_days = df.select(pl.col("_date_utc_str").unique().alias("_d")).to_series().to_list()

        for day_str in unique_days:
            y = int(day_str[0:4])
            m = int(day_str[4:6])
            d = int(day_str[6:8])
            day_date = datetime(y, m, d, tzinfo=timezone.utc).date()
            if not (WS.date() <= day_date <= WE.date()):
                continue

            out_dir  = BULK_M5_DIR / f"symbol={symbol}" / f"year={y:04d}" / f"month={m:02d}"
            out_file = out_dir / f"part={day_str}.parquet"

            if out_file.exists() and not (FORCE_REDOWNLOAD or FORCE_REWRITE_DAY):
                continue

            out_day = df.filter(pl.col("_date_utc_str") == day_str).select(
                "timestamp_utc",
                "timestamp_gye",
                "symbol",
                pl.col("open").cast(pl.Float64),
                pl.col("high").cast(pl.Float64),
                pl.col("low").cast(pl.Float64),
                pl.col("close").cast(pl.Float64),
                "tick_volume",
                "real_volume",
                "spread_points",
                "broker",
                "server_tz",
            )
            out_day = _ensure_schema_order(out_day, col_order)

            out_dir.mkdir(parents=True, exist_ok=True)
            out_day.write_parquet(out_file, compression="zstd", statistics=True)

            try:
                total_bytes += out_file.stat().st_size
            except Exception:
                pass
            total_days_written += 1
            days_written_sym += 1

            # ---------------- DEBUG: re-lectura de algunos días concretos ----------------
            if debug_this_symbol and (debug_days_checked < DEBUG_SAMPLE_DAYS_PER_SYMBOL):
                try:
                    df_chk = pl.read_parquet(out_file)
                    nb = int(df_chk.height)
                    nu = int(df_chk.get_column("timestamp_utc").n_unique()) if "timestamp_utc" in df_chk.columns else -1
                    if "timestamp_utc" in df_chk.columns and nb > 0:
                        tmin = int(df_chk["timestamp_utc"].min())
                        tmax = int(df_chk["timestamp_utc"].max())
                        dt0 = datetime.fromtimestamp(tmin / 1000, tz=timezone.utc)
                        dt1 = datetime.fromtimestamp(tmax / 1000, tz=timezone.utc)
                        _log(
                            "INFO",
                            f"[DEBUG] Relectura {out_file.name}: n_bars={nb}, n_unique_ts={nu}, "
                            f"ts_min_utc={dt0.isoformat()}, ts_max_utc={dt1.isoformat()}"
                        )
                    else:
                        _log(
                            "INFO",
                            f"[DEBUG] Relectura {out_file.name}: n_bars={nb}, columnas={df_chk.columns}"
                        )

                    if nb < MIN_EXPECTED_BARS_PER_DAY_DEBUG:
                        _log(
                            "WARNING",
                            f"[DEBUG] {symbol} día {day_str}: sólo {nb} barras en part=*.parquet "
                            f"(esperado ~{EXPECTED_BARS_M5}). Comprueba TIMEFRAME y extracción."
                        )
                except Exception as e:
                    _log("WARNING", f"[DEBUG] No se pudo re-leer {out_file}: {type(e).__name__}: {e}")
                debug_days_checked += 1
            # ---------------------------------------------------------------------------

        _log("INFO", f"{symbol} {yyyy_mm} → días escritos acumulados (run para este símbolo): {days_written_sym}")

        del df

    if days_written_sym > 0:
        symbols_ok += 1
        _log("INFO", f"{symbol}: total días escritos en este run = {days_written_sym}")
        try:
            _update_catalog_for_symbol(symbol)
        except Exception as e:
            _log("WARNING", f"Catálogo no actualizado para {symbol}: {e}")
    else:
        _log("WARNING", f"{symbol}: no se escribió ningún día en esta corrida (modo={sym_mode}).")
        _write_jsonl(
            RUN_LOG,
            {
                "run_id": RUN_ID,
                "cell": CELL_LABEL,
                "symbol": symbol,
                "status": "no_new_days",
                "mode": sym_mode,
                "msg": "sin_días_nuevos_en_ventana_o_activo_sin_trading",
            },
        )

# Cerrar MT5
_mt5_shutdown()

# ----------------------- Impresiones finales -----------------------
print("=" * 110)
print(f">>> Celda 06 :: Descarga masiva M5 (4 años, UTC+GYE, Polars-only, v2-debug)")
print(f"Salida base M5 raw: {BULK_M5_DIR}")
if STRICT_4Y_PRECHECK:
    modo_label = "símbolos elegibles (>=4y, modo estricto)"
else:
    modo_label = "símbolos elegibles (sin precheck estricto; Celda 05 + broker)"
print(f"{modo_label}: {len(kept)} | Símbolos con datos escritos (en esta corrida): {symbols_ok}")
print(f"Días/archivos escritos (esta corrida): {total_days_written}")
print(f"BULK_MODE_08 = {BULK_MODE} | INCR_BACKFILL_DAYS_08 = {INCR_BACKFILL_DAYS}")
print(f"FORCE_REDOWNLOAD_BULK_M5={FORCE_REDOWNLOAD} | FORCE_REWRITE_DAY={FORCE_REWRITE_DAY}")
print("-" * 110)
MiB = (total_bytes / (1024 * 1024)) if total_bytes else 0.0
GiB = (total_bytes / (1024 * 1024 * 1024)) if total_bytes else 0.0
print(f"Tamaño total escrito: {total_bytes} bytes ({MiB:0.2f} MiB | {GiB:0.2f} GiB)")
print("-" * 110)
sym_dirs = sorted([p.name for p in BULK_M5_DIR.glob("symbol=*") if p.is_dir()])
print(f"Subcarpetas en m5_raw: {len(sym_dirs)}")
if sym_dirs:
    print("Ejemplos de subcarpetas:", ", ".join(sym_dirs[:10]))
print("-" * 110)
try:
    from zoneinfo import ZoneInfo
    print(
        f"Hora GYE fin: {datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec='seconds')} "
        f"| Hora UTC fin: {datetime.now(timezone.utc).isoformat(timespec='seconds')}"
    )
except Exception:
    print(f"Hora UTC fin: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("✅ Celda 06 — Bulk M5 completada: OK para continuar con la siguiente celda (Catálogo m5_raw / QA).")
# =======================================================================================================================
# Out:
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] Usando lista elegible por coste (Celda 05): 107 símbolos
# Ventana objetivo (UTC teórica): 2021-12-02 → 2025-12-02 (últimos 4 años)
# Universo de símbolos (filtro costes Celda 05 + broker): 107 / 131
# Ejemplo de símbolos: EURUSD, GBPUSD, USDCHF, USDJPY, USDCAD, AUDUSD, AUDNZD, AUDCAD, AUDCHF, AUDJPY
# STRICT_4Y_PRECHECK = False | BULK_MODE_08 = AUTO
# FORCE_REDOWNLOAD_BULK_M5=False | FORCE_REWRITE_DAY=False
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
# Inicio Celda 06 — Descarga masiva M5 | TZ objetivo: America/Guayaquil
# Hora GYE: 2025-12-02T23:22:58-05:00 | Hora UTC: 2025-12-03T04:22:58+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT       : C:\Quant\MT5_Data_Extraction\data
# PAD salida M5   : C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# BULK_MODE_08    : AUTO
# INCR_BACKFILL_DAYS_08 : 3
# STRICT_4Y_PRECHECK    : False
# FORCE_REDOWNLOAD_BULK_M5 = False
# FORCE_REWRITE_DAY        = False
# DEBUG_08                 = True
# --------------------------------------------------------------------------------------------------------------
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] Conectando a MT5 con reintentos...
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] Conexión MT5 establecida.
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] Usando TIMEFRAME_M5 de MT5 (valor interno=5).
# --------------------------------------------------------------------------------------------------------------
# Prefiltro cobertura >=4y DESACTIVADO (STRICT_4Y_PRECHECK=False). Se intentará descargar M5 para todos los símbolos elegibles: 107
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] [1/107] EURUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] EURUSD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] [DEBUG] EURUSD 2025-12: barras_totales_mes=423 | dias_mes=3 | barras/día min=61, p50=76.0, max=286
# [2025-12-03T04:22:58+00:00] [20251202_232253] [WARNING] [06-BulkM5] [DEBUG] EURUSD 2025-12: MEDIANA barras/día=76.0 << 200 (EXPECTED_BARS_M5=288). Posible timeframe incorrecto (D1/M15) o extracción rota.
# Ejemplo días EURUSD 2025-12 (barras/día):
#   - 20251201: n_bars_day=286
#   - 20251202: n_bars_day=61
#   - 20251203: n_bars_day=76
# --------------------------------------------------------------------------------
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] [DEBUG] Relectura part=20251202.parquet: n_bars=61, n_unique_ts=61, ts_min_utc=2025-12-02T00:05:00+00:00, ts_max_utc=2025-12-02T05:05:00+00:00
# [2025-12-03T04:22:58+00:00] [20251202_232253] [WARNING] [06-BulkM5] [DEBUG] EURUSD día 20251202: sólo 61 barras en part=*.parquet (esperado ~288). Comprueba TIMEFRAME y extracción.
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] EURUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] EURUSD: total días escritos en este run = 1
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] [2/107] GBPUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPUSD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] [DEBUG] GBPUSD 2025-12: barras_totales_mes=648 | dias_mes=3 | barras/día min=76, p50=286.0, max=286
# Ejemplo días GBPUSD 2025-12 (barras/día):
#   - 20251201: n_bars_day=286
#   - 20251202: n_bars_day=286
#   - 20251203: n_bars_day=76
# --------------------------------------------------------------------------------
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] [DEBUG] Relectura part=20251202.parquet: n_bars=286, n_unique_ts=286, ts_min_utc=2025-12-02T00:05:00+00:00, ts_max_utc=2025-12-02T23:50:00+00:00
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:22:58+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPUSD: total días escritos en este run = 1
# [2025-12-03T04:22:59+00:00] [20251202_232253] [INFO] [06-BulkM5] [3/107] USDCHF: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:22:59+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCHF 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:22:59+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCHF 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:22:59+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCHF: total días escritos en este run = 1
# [2025-12-03T04:23:00+00:00] [20251202_232253] [INFO] [06-BulkM5] [4/107] USDJPY: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:00+00:00] [20251202_232253] [INFO] [06-BulkM5] USDJPY 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:00+00:00] [20251202_232253] [INFO] [06-BulkM5] USDJPY 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:00+00:00] [20251202_232253] [INFO] [06-BulkM5] USDJPY: total días escritos en este run = 1
# [2025-12-03T04:23:00+00:00] [20251202_232253] [INFO] [06-BulkM5] [5/107] USDCAD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:00+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCAD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:00+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCAD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:00+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCAD: total días escritos en este run = 1
# [2025-12-03T04:23:01+00:00] [20251202_232253] [INFO] [06-BulkM5] [6/107] AUDUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:01+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDUSD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:01+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:01+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDUSD: total días escritos en este run = 1
# [2025-12-03T04:23:02+00:00] [20251202_232253] [INFO] [06-BulkM5] [7/107] AUDNZD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:02+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDNZD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:02+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDNZD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:02+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDNZD: total días escritos en este run = 7
# [2025-12-03T04:23:03+00:00] [20251202_232253] [INFO] [06-BulkM5] [8/107] AUDCAD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:03+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDCAD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:03+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDCAD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:03+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDCAD: total días escritos en este run = 7
# [2025-12-03T04:23:04+00:00] [20251202_232253] [INFO] [06-BulkM5] [9/107] AUDCHF: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:04+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDCHF 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:04+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDCHF 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:04+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDCHF: total días escritos en este run = 7
# [2025-12-03T04:23:04+00:00] [20251202_232253] [INFO] [06-BulkM5] [10/107] AUDJPY: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:05+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDJPY 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:05+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDJPY 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:05+00:00] [20251202_232253] [INFO] [06-BulkM5] AUDJPY: total días escritos en este run = 7
# [2025-12-03T04:23:05+00:00] [20251202_232253] [INFO] [06-BulkM5] [11/107] CHFJPY: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:05+00:00] [20251202_232253] [INFO] [06-BulkM5] CHFJPY 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:05+00:00] [20251202_232253] [INFO] [06-BulkM5] CHFJPY 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:05+00:00] [20251202_232253] [INFO] [06-BulkM5] CHFJPY: total días escritos en este run = 7
# [2025-12-03T04:23:06+00:00] [20251202_232253] [INFO] [06-BulkM5] [12/107] EURGBP: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:06+00:00] [20251202_232253] [INFO] [06-BulkM5] EURGBP 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:06+00:00] [20251202_232253] [INFO] [06-BulkM5] EURGBP 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:06+00:00] [20251202_232253] [INFO] [06-BulkM5] EURGBP: total días escritos en este run = 1
# [2025-12-03T04:23:07+00:00] [20251202_232253] [INFO] [06-BulkM5] [13/107] EURAUD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:07+00:00] [20251202_232253] [INFO] [06-BulkM5] EURAUD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:07+00:00] [20251202_232253] [INFO] [06-BulkM5] EURAUD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:07+00:00] [20251202_232253] [INFO] [06-BulkM5] EURAUD: total días escritos en este run = 7
# [2025-12-03T04:23:07+00:00] [20251202_232253] [INFO] [06-BulkM5] [14/107] EURCHF: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:07+00:00] [20251202_232253] [INFO] [06-BulkM5] EURCHF 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:07+00:00] [20251202_232253] [INFO] [06-BulkM5] EURCHF 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:07+00:00] [20251202_232253] [INFO] [06-BulkM5] EURCHF: total días escritos en este run = 1
# [2025-12-03T04:23:08+00:00] [20251202_232253] [INFO] [06-BulkM5] [15/107] EURJPY: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:08+00:00] [20251202_232253] [INFO] [06-BulkM5] EURJPY 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:08+00:00] [20251202_232253] [INFO] [06-BulkM5] EURJPY 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:08+00:00] [20251202_232253] [INFO] [06-BulkM5] EURJPY: total días escritos en este run = 1
# [2025-12-03T04:23:09+00:00] [20251202_232253] [INFO] [06-BulkM5] [16/107] EURNZD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:09+00:00] [20251202_232253] [INFO] [06-BulkM5] EURNZD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:09+00:00] [20251202_232253] [INFO] [06-BulkM5] EURNZD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:09+00:00] [20251202_232253] [INFO] [06-BulkM5] EURNZD: total días escritos en este run = 7
# [2025-12-03T04:23:10+00:00] [20251202_232253] [INFO] [06-BulkM5] [17/107] EURCAD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:10+00:00] [20251202_232253] [INFO] [06-BulkM5] EURCAD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:10+00:00] [20251202_232253] [INFO] [06-BulkM5] EURCAD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:10+00:00] [20251202_232253] [INFO] [06-BulkM5] EURCAD: total días escritos en este run = 7
# [2025-12-03T04:23:10+00:00] [20251202_232253] [INFO] [06-BulkM5] [18/107] GBPCHF: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:11+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPCHF 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:11+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPCHF 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:11+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPCHF: total días escritos en este run = 7
# [2025-12-03T04:23:11+00:00] [20251202_232253] [INFO] [06-BulkM5] [19/107] GBPJPY: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:12+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPJPY 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:12+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPJPY 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:12+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPJPY: total días escritos en este run = 7
# [2025-12-03T04:23:12+00:00] [20251202_232253] [INFO] [06-BulkM5] [20/107] CADCHF: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:12+00:00] [20251202_232253] [INFO] [06-BulkM5] CADCHF 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:12+00:00] [20251202_232253] [INFO] [06-BulkM5] CADCHF 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:12+00:00] [20251202_232253] [INFO] [06-BulkM5] CADCHF: total días escritos en este run = 7
# [2025-12-03T04:23:13+00:00] [20251202_232253] [INFO] [06-BulkM5] [21/107] CADJPY: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:13+00:00] [20251202_232253] [INFO] [06-BulkM5] CADJPY 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:13+00:00] [20251202_232253] [INFO] [06-BulkM5] CADJPY 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:13+00:00] [20251202_232253] [INFO] [06-BulkM5] CADJPY: total días escritos en este run = 7
# [2025-12-03T04:23:14+00:00] [20251202_232253] [INFO] [06-BulkM5] [22/107] GBPAUD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:14+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPAUD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:14+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPAUD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:14+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPAUD: total días escritos en este run = 7
# [2025-12-03T04:23:15+00:00] [20251202_232253] [INFO] [06-BulkM5] [23/107] GBPCAD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:15+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPCAD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:15+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPCAD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:15+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPCAD: total días escritos en este run = 7
# [2025-12-03T04:23:16+00:00] [20251202_232253] [INFO] [06-BulkM5] [24/107] GBPNZD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:16+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPNZD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:16+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPNZD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:16+00:00] [20251202_232253] [INFO] [06-BulkM5] GBPNZD: total días escritos en este run = 7
# [2025-12-03T04:23:17+00:00] [20251202_232253] [INFO] [06-BulkM5] [25/107] NZDCAD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:17+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDCAD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:17+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDCAD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:17+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDCAD: total días escritos en este run = 7
# [2025-12-03T04:23:18+00:00] [20251202_232253] [INFO] [06-BulkM5] [26/107] NZDCHF: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:18+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDCHF 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:18+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDCHF 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:18+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDCHF: total días escritos en este run = 7
# [2025-12-03T04:23:19+00:00] [20251202_232253] [INFO] [06-BulkM5] [27/107] NZDJPY: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:19+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDJPY 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:19+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDJPY 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:19+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDJPY: total días escritos en este run = 7
# [2025-12-03T04:23:20+00:00] [20251202_232253] [INFO] [06-BulkM5] [28/107] NZDUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:20+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDUSD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:20+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:20+00:00] [20251202_232253] [INFO] [06-BulkM5] NZDUSD: total días escritos en este run = 1
# [2025-12-03T04:23:21+00:00] [20251202_232253] [INFO] [06-BulkM5] [29/107] EURCZK: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:21+00:00] [20251202_232253] [INFO] [06-BulkM5] EURCZK 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:21+00:00] [20251202_232253] [INFO] [06-BulkM5] EURCZK 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:21+00:00] [20251202_232253] [INFO] [06-BulkM5] EURCZK: total días escritos en este run = 7
# [2025-12-03T04:23:22+00:00] [20251202_232253] [INFO] [06-BulkM5] [30/107] EURHUF: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:22+00:00] [20251202_232253] [INFO] [06-BulkM5] EURHUF 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:22+00:00] [20251202_232253] [INFO] [06-BulkM5] EURHUF 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:22+00:00] [20251202_232253] [INFO] [06-BulkM5] EURHUF: total días escritos en este run = 7
# [2025-12-03T04:23:23+00:00] [20251202_232253] [INFO] [06-BulkM5] [31/107] EURNOK: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:23+00:00] [20251202_232253] [INFO] [06-BulkM5] EURNOK 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:23+00:00] [20251202_232253] [INFO] [06-BulkM5] EURNOK 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:23+00:00] [20251202_232253] [INFO] [06-BulkM5] EURNOK: total días escritos en este run = 7
# [2025-12-03T04:23:24+00:00] [20251202_232253] [INFO] [06-BulkM5] [32/107] EURPLN: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:24+00:00] [20251202_232253] [INFO] [06-BulkM5] EURPLN 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:24+00:00] [20251202_232253] [INFO] [06-BulkM5] EURPLN 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:24+00:00] [20251202_232253] [INFO] [06-BulkM5] EURPLN: total días escritos en este run = 7
# [2025-12-03T04:23:24+00:00] [20251202_232253] [INFO] [06-BulkM5] [33/107] USDCZK: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:24+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCZK 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:24+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCZK 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:24+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCZK: total días escritos en este run = 7
# [2025-12-03T04:23:25+00:00] [20251202_232253] [INFO] [06-BulkM5] [34/107] USDHKD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:25+00:00] [20251202_232253] [INFO] [06-BulkM5] USDHKD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:25+00:00] [20251202_232253] [INFO] [06-BulkM5] USDHKD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:25+00:00] [20251202_232253] [INFO] [06-BulkM5] USDHKD: total días escritos en este run = 1
# [2025-12-03T04:23:26+00:00] [20251202_232253] [INFO] [06-BulkM5] [35/107] USDHUF: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:26+00:00] [20251202_232253] [INFO] [06-BulkM5] USDHUF 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:26+00:00] [20251202_232253] [INFO] [06-BulkM5] USDHUF 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:26+00:00] [20251202_232253] [INFO] [06-BulkM5] USDHUF: total días escritos en este run = 7
# [2025-12-03T04:23:27+00:00] [20251202_232253] [INFO] [06-BulkM5] [36/107] USDMXN: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:27+00:00] [20251202_232253] [INFO] [06-BulkM5] USDMXN 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:27+00:00] [20251202_232253] [INFO] [06-BulkM5] USDMXN 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:27+00:00] [20251202_232253] [INFO] [06-BulkM5] USDMXN: total días escritos en este run = 1
# [2025-12-03T04:23:28+00:00] [20251202_232253] [INFO] [06-BulkM5] [37/107] USDNOK: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:28+00:00] [20251202_232253] [INFO] [06-BulkM5] USDNOK 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:28+00:00] [20251202_232253] [INFO] [06-BulkM5] USDNOK 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:28+00:00] [20251202_232253] [INFO] [06-BulkM5] USDNOK: total días escritos en este run = 7
# [2025-12-03T04:23:29+00:00] [20251202_232253] [INFO] [06-BulkM5] [38/107] USDPLN: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:29+00:00] [20251202_232253] [INFO] [06-BulkM5] USDPLN 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:29+00:00] [20251202_232253] [INFO] [06-BulkM5] USDPLN 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:29+00:00] [20251202_232253] [INFO] [06-BulkM5] USDPLN: total días escritos en este run = 7
# [2025-12-03T04:23:30+00:00] [20251202_232253] [INFO] [06-BulkM5] [39/107] USDZAR: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:30+00:00] [20251202_232253] [INFO] [06-BulkM5] USDZAR 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:30+00:00] [20251202_232253] [INFO] [06-BulkM5] USDZAR 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:30+00:00] [20251202_232253] [INFO] [06-BulkM5] USDZAR: total días escritos en este run = 7
# [2025-12-03T04:23:31+00:00] [20251202_232253] [INFO] [06-BulkM5] [40/107] USDSEK: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:31+00:00] [20251202_232253] [INFO] [06-BulkM5] USDSEK 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:31+00:00] [20251202_232253] [INFO] [06-BulkM5] USDSEK 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:31+00:00] [20251202_232253] [INFO] [06-BulkM5] USDSEK: total días escritos en este run = 7
# [2025-12-03T04:23:32+00:00] [20251202_232253] [INFO] [06-BulkM5] [41/107] USDILS: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:32+00:00] [20251202_232253] [INFO] [06-BulkM5] USDILS 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:32+00:00] [20251202_232253] [INFO] [06-BulkM5] USDILS 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:32+00:00] [20251202_232253] [INFO] [06-BulkM5] USDILS: total días escritos en este run = 7
# [2025-12-03T04:23:33+00:00] [20251202_232253] [INFO] [06-BulkM5] [42/107] USDSGD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:33+00:00] [20251202_232253] [INFO] [06-BulkM5] USDSGD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:33+00:00] [20251202_232253] [INFO] [06-BulkM5] USDSGD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:33+00:00] [20251202_232253] [INFO] [06-BulkM5] USDSGD: total días escritos en este run = 1
# [2025-12-03T04:23:33+00:00] [20251202_232253] [INFO] [06-BulkM5] [43/107] USDCNH: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:33+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCNH 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:33+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCNH 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:33+00:00] [20251202_232253] [INFO] [06-BulkM5] USDCNH: total días escritos en este run = 1
# [2025-12-03T04:23:34+00:00] [20251202_232253] [INFO] [06-BulkM5] [44/107] UK100.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:34+00:00] [20251202_232253] [INFO] [06-BulkM5] UK100.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:34+00:00] [20251202_232253] [INFO] [06-BulkM5] UK100.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:34+00:00] [20251202_232253] [INFO] [06-BulkM5] UK100.cash: total días escritos en este run = 1
# [2025-12-03T04:23:34+00:00] [20251202_232253] [INFO] [06-BulkM5] [45/107] US100.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:34+00:00] [20251202_232253] [INFO] [06-BulkM5] US100.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:34+00:00] [20251202_232253] [INFO] [06-BulkM5] US100.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:34+00:00] [20251202_232253] [INFO] [06-BulkM5] US100.cash: total días escritos en este run = 1
# [2025-12-03T04:23:35+00:00] [20251202_232253] [INFO] [06-BulkM5] [46/107] US30.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:35+00:00] [20251202_232253] [INFO] [06-BulkM5] US30.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:35+00:00] [20251202_232253] [INFO] [06-BulkM5] US30.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:35+00:00] [20251202_232253] [INFO] [06-BulkM5] US30.cash: total días escritos en este run = 1
# [2025-12-03T04:23:36+00:00] [20251202_232253] [INFO] [06-BulkM5] [47/107] US500.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:36+00:00] [20251202_232253] [INFO] [06-BulkM5] US500.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:36+00:00] [20251202_232253] [INFO] [06-BulkM5] US500.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:36+00:00] [20251202_232253] [INFO] [06-BulkM5] US500.cash: total días escritos en este run = 1
# [2025-12-03T04:23:37+00:00] [20251202_232253] [INFO] [06-BulkM5] [48/107] GER40.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:37+00:00] [20251202_232253] [INFO] [06-BulkM5] GER40.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:37+00:00] [20251202_232253] [INFO] [06-BulkM5] GER40.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:37+00:00] [20251202_232253] [INFO] [06-BulkM5] GER40.cash: total días escritos en este run = 1
# [2025-12-03T04:23:37+00:00] [20251202_232253] [INFO] [06-BulkM5] [49/107] AUS200.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:37+00:00] [20251202_232253] [INFO] [06-BulkM5] AUS200.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] AUS200.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] AUS200.cash: total días escritos en este run = 1
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] [50/107] EU50.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] EU50.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] EU50.cash 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:38+00:00] [20251202_232253] [WARNING] [06-BulkM5] EU50.cash: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] [51/107] FRA40.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] FRA40.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] FRA40.cash 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:38+00:00] [20251202_232253] [WARNING] [06-BulkM5] FRA40.cash: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] [52/107] HK50.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] HK50.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] HK50.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:38+00:00] [20251202_232253] [INFO] [06-BulkM5] HK50.cash: total días escritos en este run = 1
# [2025-12-03T04:23:39+00:00] [20251202_232253] [INFO] [06-BulkM5] [53/107] JP225.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:39+00:00] [20251202_232253] [INFO] [06-BulkM5] JP225.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:39+00:00] [20251202_232253] [INFO] [06-BulkM5] JP225.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:39+00:00] [20251202_232253] [INFO] [06-BulkM5] JP225.cash: total días escritos en este run = 1
# [2025-12-03T04:23:40+00:00] [20251202_232253] [INFO] [06-BulkM5] [54/107] SPN35.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:40+00:00] [20251202_232253] [INFO] [06-BulkM5] SPN35.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:40+00:00] [20251202_232253] [INFO] [06-BulkM5] SPN35.cash 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:40+00:00] [20251202_232253] [WARNING] [06-BulkM5] SPN35.cash: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:40+00:00] [20251202_232253] [INFO] [06-BulkM5] [55/107] US2000.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:40+00:00] [20251202_232253] [INFO] [06-BulkM5] US2000.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:40+00:00] [20251202_232253] [INFO] [06-BulkM5] US2000.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:40+00:00] [20251202_232253] [INFO] [06-BulkM5] US2000.cash: total días escritos en este run = 1
# [2025-12-03T04:23:41+00:00] [20251202_232253] [INFO] [06-BulkM5] [56/107] UKOIL.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:41+00:00] [20251202_232253] [INFO] [06-BulkM5] UKOIL.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:41+00:00] [20251202_232253] [INFO] [06-BulkM5] UKOIL.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:41+00:00] [20251202_232253] [INFO] [06-BulkM5] UKOIL.cash: total días escritos en este run = 1
# [2025-12-03T04:23:41+00:00] [20251202_232253] [INFO] [06-BulkM5] [57/107] USOIL.cash: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:41+00:00] [20251202_232253] [INFO] [06-BulkM5] USOIL.cash 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:41+00:00] [20251202_232253] [INFO] [06-BulkM5] USOIL.cash 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:41+00:00] [20251202_232253] [INFO] [06-BulkM5] USOIL.cash: total días escritos en este run = 1
# [2025-12-03T04:23:42+00:00] [20251202_232253] [INFO] [06-BulkM5] [58/107] XAGUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:42+00:00] [20251202_232253] [INFO] [06-BulkM5] XAGUSD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:42+00:00] [20251202_232253] [INFO] [06-BulkM5] XAGUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:42+00:00] [20251202_232253] [INFO] [06-BulkM5] XAGUSD: total días escritos en este run = 1
# [2025-12-03T04:23:43+00:00] [20251202_232253] [INFO] [06-BulkM5] [59/107] XAGAUD: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:43+00:00] [20251202_232253] [INFO] [06-BulkM5] XAGAUD 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:43+00:00] [20251202_232253] [INFO] [06-BulkM5] XAGAUD 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:43+00:00] [20251202_232253] [INFO] [06-BulkM5] XAGAUD: total días escritos en este run = 7
# [2025-12-03T04:23:43+00:00] [20251202_232253] [INFO] [06-BulkM5] [60/107] XAGEUR: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:44+00:00] [20251202_232253] [INFO] [06-BulkM5] XAGEUR 2025-11 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:44+00:00] [20251202_232253] [INFO] [06-BulkM5] XAGEUR 2025-12 → días escritos acumulados (run para este símbolo): 7
# [2025-12-03T04:23:44+00:00] [20251202_232253] [INFO] [06-BulkM5] XAGEUR: total días escritos en este run = 7
# [2025-12-03T04:23:44+00:00] [20251202_232253] [INFO] [06-BulkM5] [61/107] XAUUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:44+00:00] [20251202_232253] [INFO] [06-BulkM5] XAUUSD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:44+00:00] [20251202_232253] [INFO] [06-BulkM5] XAUUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:44+00:00] [20251202_232253] [INFO] [06-BulkM5] XAUUSD: total días escritos en este run = 1
# [2025-12-03T04:23:45+00:00] [20251202_232253] [INFO] [06-BulkM5] [62/107] XAUAUD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:45+00:00] [20251202_232253] [INFO] [06-BulkM5] XAUAUD 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:45+00:00] [20251202_232253] [INFO] [06-BulkM5] XAUAUD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:45+00:00] [20251202_232253] [INFO] [06-BulkM5] XAUAUD: total días escritos en este run = 1
# [2025-12-03T04:23:46+00:00] [20251202_232253] [INFO] [06-BulkM5] [63/107] XAUEUR: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:46+00:00] [20251202_232253] [INFO] [06-BulkM5] XAUEUR 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:46+00:00] [20251202_232253] [INFO] [06-BulkM5] XAUEUR 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:46+00:00] [20251202_232253] [INFO] [06-BulkM5] XAUEUR: total días escritos en este run = 1
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] [64/107] AAPL: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] AAPL 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] AAPL 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:47+00:00] [20251202_232253] [WARNING] [06-BulkM5] AAPL: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] [65/107] AMZN: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] AMZN 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] AMZN 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:47+00:00] [20251202_232253] [WARNING] [06-BulkM5] AMZN: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] [66/107] MSFT: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] MSFT 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] MSFT 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:47+00:00] [20251202_232253] [WARNING] [06-BulkM5] MSFT: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] [67/107] GOOG: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] GOOG 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] GOOG 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:47+00:00] [20251202_232253] [WARNING] [06-BulkM5] GOOG: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] [68/107] V: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] V 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] V 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:47+00:00] [20251202_232253] [WARNING] [06-BulkM5] V: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] [69/107] NVDA: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] NVDA 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] NVDA 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:47+00:00] [20251202_232253] [WARNING] [06-BulkM5] NVDA: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] [70/107] TSLA: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] TSLA 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] TSLA 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:47+00:00] [20251202_232253] [WARNING] [06-BulkM5] TSLA: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] [71/107] WMT: modo=INCREMENTAL, ventana efectiva 2025-11-18 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] WMT 2025-11 → días escritos acumulados (run para este símbolo): 4
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] WMT 2025-12 → días escritos acumulados (run para este símbolo): 5
# [2025-12-03T04:23:47+00:00] [20251202_232253] [INFO] [06-BulkM5] WMT: total días escritos en este run = 5
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] [72/107] ALVG: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] ALVG 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] ALVG 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:48+00:00] [20251202_232253] [WARNING] [06-BulkM5] ALVG: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] [73/107] LVMH: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] LVMH 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] LVMH 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:48+00:00] [20251202_232253] [WARNING] [06-BulkM5] LVMH: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] [74/107] BAYGn: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] BAYGn 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] BAYGn 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:48+00:00] [20251202_232253] [WARNING] [06-BulkM5] BAYGn: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] [75/107] DBKGn: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] DBKGn 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] DBKGn 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:48+00:00] [20251202_232253] [WARNING] [06-BulkM5] DBKGn: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] [76/107] IBE: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] IBE 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] IBE 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:48+00:00] [20251202_232253] [WARNING] [06-BulkM5] IBE: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] [77/107] COFFEE.c: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] COFFEE.c 2025-11: mes sin barras (feriado/activo sin trading o fuera de ventana).
# [2025-12-03T04:23:48+00:00] [20251202_232253] [INFO] [06-BulkM5] COFFEE.c 2025-12 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:48+00:00] [20251202_232253] [WARNING] [06-BulkM5] COFFEE.c: no se escribió ningún día en esta corrida (modo=INCREMENTAL).
# ...
# [2025-12-03T04:23:53+00:00] [20251202_232253] [INFO] [06-BulkM5] LTCUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:53+00:00] [20251202_232253] [INFO] [06-BulkM5] LTCUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:53+00:00] [20251202_232253] [INFO] [06-BulkM5] LTCUSD: total días escritos en este run = 1
# [2025-12-03T04:23:54+00:00] [20251202_232253] [INFO] [06-BulkM5] [83/107] DOTUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:54+00:00] [20251202_232253] [INFO] [06-BulkM5] DOTUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:54+00:00] [20251202_232253] [INFO] [06-BulkM5] DOTUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:54+00:00] [20251202_232253] [INFO] [06-BulkM5] DOTUSD: total días escritos en este run = 1
# [2025-12-03T04:23:55+00:00] [20251202_232253] [INFO] [06-BulkM5] [84/107] XRPUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:55+00:00] [20251202_232253] [INFO] [06-BulkM5] XRPUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:55+00:00] [20251202_232253] [INFO] [06-BulkM5] XRPUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:55+00:00] [20251202_232253] [INFO] [06-BulkM5] XRPUSD: total días escritos en este run = 1
# [2025-12-03T04:23:57+00:00] [20251202_232253] [INFO] [06-BulkM5] [85/107] ADAUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:57+00:00] [20251202_232253] [INFO] [06-BulkM5] ADAUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:57+00:00] [20251202_232253] [INFO] [06-BulkM5] ADAUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:57+00:00] [20251202_232253] [INFO] [06-BulkM5] ADAUSD: total días escritos en este run = 1
# [2025-12-03T04:23:58+00:00] [20251202_232253] [INFO] [06-BulkM5] [86/107] BCHUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:58+00:00] [20251202_232253] [INFO] [06-BulkM5] BCHUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:58+00:00] [20251202_232253] [INFO] [06-BulkM5] BCHUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:58+00:00] [20251202_232253] [INFO] [06-BulkM5] BCHUSD: total días escritos en este run = 1
# [2025-12-03T04:23:59+00:00] [20251202_232253] [INFO] [06-BulkM5] [87/107] SOLUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:59+00:00] [20251202_232253] [INFO] [06-BulkM5] SOLUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:59+00:00] [20251202_232253] [INFO] [06-BulkM5] SOLUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:59+00:00] [20251202_232253] [INFO] [06-BulkM5] SOLUSD: total días escritos en este run = 1
# [2025-12-03T04:23:59+00:00] [20251202_232253] [INFO] [06-BulkM5] [88/107] AVAUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:23:59+00:00] [20251202_232253] [INFO] [06-BulkM5] AVAUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:23:59+00:00] [20251202_232253] [INFO] [06-BulkM5] AVAUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:23:59+00:00] [20251202_232253] [INFO] [06-BulkM5] AVAUSD: total días escritos en este run = 1
# [2025-12-03T04:24:00+00:00] [20251202_232253] [INFO] [06-BulkM5] [89/107] ETCUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:00+00:00] [20251202_232253] [INFO] [06-BulkM5] ETCUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:00+00:00] [20251202_232253] [INFO] [06-BulkM5] ETCUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:00+00:00] [20251202_232253] [INFO] [06-BulkM5] ETCUSD: total días escritos en este run = 1
# [2025-12-03T04:24:02+00:00] [20251202_232253] [INFO] [06-BulkM5] [90/107] XMRUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:02+00:00] [20251202_232253] [INFO] [06-BulkM5] XMRUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:02+00:00] [20251202_232253] [INFO] [06-BulkM5] XMRUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:02+00:00] [20251202_232253] [INFO] [06-BulkM5] XMRUSD: total días escritos en este run = 1
# [2025-12-03T04:24:03+00:00] [20251202_232253] [INFO] [06-BulkM5] [91/107] DOGEUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:03+00:00] [20251202_232253] [INFO] [06-BulkM5] DOGEUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:03+00:00] [20251202_232253] [INFO] [06-BulkM5] DOGEUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:03+00:00] [20251202_232253] [INFO] [06-BulkM5] DOGEUSD: total días escritos en este run = 1
# [2025-12-03T04:24:04+00:00] [20251202_232253] [INFO] [06-BulkM5] [92/107] BNBUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:04+00:00] [20251202_232253] [INFO] [06-BulkM5] BNBUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:04+00:00] [20251202_232253] [INFO] [06-BulkM5] BNBUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:04+00:00] [20251202_232253] [INFO] [06-BulkM5] BNBUSD: total días escritos en este run = 1
# [2025-12-03T04:24:05+00:00] [20251202_232253] [INFO] [06-BulkM5] [93/107] SANUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:05+00:00] [20251202_232253] [INFO] [06-BulkM5] SANUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:05+00:00] [20251202_232253] [INFO] [06-BulkM5] SANUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:05+00:00] [20251202_232253] [INFO] [06-BulkM5] SANUSD: total días escritos en este run = 1
# [2025-12-03T04:24:06+00:00] [20251202_232253] [INFO] [06-BulkM5] [94/107] LNKUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:06+00:00] [20251202_232253] [INFO] [06-BulkM5] LNKUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:06+00:00] [20251202_232253] [INFO] [06-BulkM5] LNKUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:06+00:00] [20251202_232253] [INFO] [06-BulkM5] LNKUSD: total días escritos en este run = 1
# [2025-12-03T04:24:07+00:00] [20251202_232253] [INFO] [06-BulkM5] [95/107] NERUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:07+00:00] [20251202_232253] [INFO] [06-BulkM5] NERUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:07+00:00] [20251202_232253] [INFO] [06-BulkM5] NERUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:07+00:00] [20251202_232253] [INFO] [06-BulkM5] NERUSD: total días escritos en este run = 1
# [2025-12-03T04:24:08+00:00] [20251202_232253] [INFO] [06-BulkM5] [96/107] ALGUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:08+00:00] [20251202_232253] [INFO] [06-BulkM5] ALGUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:08+00:00] [20251202_232253] [INFO] [06-BulkM5] ALGUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:08+00:00] [20251202_232253] [INFO] [06-BulkM5] ALGUSD: total días escritos en este run = 1
# [2025-12-03T04:24:10+00:00] [20251202_232253] [INFO] [06-BulkM5] [97/107] ICPUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:10+00:00] [20251202_232253] [INFO] [06-BulkM5] ICPUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:10+00:00] [20251202_232253] [INFO] [06-BulkM5] ICPUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:10+00:00] [20251202_232253] [INFO] [06-BulkM5] ICPUSD: total días escritos en este run = 1
# [2025-12-03T04:24:10+00:00] [20251202_232253] [INFO] [06-BulkM5] [98/107] AAVUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:10+00:00] [20251202_232253] [INFO] [06-BulkM5] AAVUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:10+00:00] [20251202_232253] [INFO] [06-BulkM5] AAVUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:10+00:00] [20251202_232253] [INFO] [06-BulkM5] AAVUSD: total días escritos en este run = 1
# [2025-12-03T04:24:11+00:00] [20251202_232253] [INFO] [06-BulkM5] [99/107] BARUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:11+00:00] [20251202_232253] [INFO] [06-BulkM5] BARUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:11+00:00] [20251202_232253] [INFO] [06-BulkM5] BARUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:11+00:00] [20251202_232253] [INFO] [06-BulkM5] BARUSD: total días escritos en este run = 1
# [2025-12-03T04:24:12+00:00] [20251202_232253] [INFO] [06-BulkM5] [100/107] GALUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:12+00:00] [20251202_232253] [INFO] [06-BulkM5] GALUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:12+00:00] [20251202_232253] [INFO] [06-BulkM5] GALUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:12+00:00] [20251202_232253] [INFO] [06-BulkM5] GALUSD: total días escritos en este run = 1
# [2025-12-03T04:24:13+00:00] [20251202_232253] [INFO] [06-BulkM5] [101/107] GRTUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:13+00:00] [20251202_232253] [INFO] [06-BulkM5] GRTUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:13+00:00] [20251202_232253] [INFO] [06-BulkM5] GRTUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:13+00:00] [20251202_232253] [INFO] [06-BulkM5] GRTUSD: total días escritos en este run = 1
# [2025-12-03T04:24:14+00:00] [20251202_232253] [INFO] [06-BulkM5] [102/107] IMXUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:14+00:00] [20251202_232253] [INFO] [06-BulkM5] IMXUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:14+00:00] [20251202_232253] [INFO] [06-BulkM5] IMXUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:14+00:00] [20251202_232253] [INFO] [06-BulkM5] IMXUSD: total días escritos en este run = 1
# [2025-12-03T04:24:15+00:00] [20251202_232253] [INFO] [06-BulkM5] [103/107] MANUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:15+00:00] [20251202_232253] [INFO] [06-BulkM5] MANUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:15+00:00] [20251202_232253] [INFO] [06-BulkM5] MANUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:15+00:00] [20251202_232253] [INFO] [06-BulkM5] MANUSD: total días escritos en este run = 1
# [2025-12-03T04:24:16+00:00] [20251202_232253] [INFO] [06-BulkM5] [104/107] VECUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:16+00:00] [20251202_232253] [INFO] [06-BulkM5] VECUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:16+00:00] [20251202_232253] [INFO] [06-BulkM5] VECUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:16+00:00] [20251202_232253] [INFO] [06-BulkM5] VECUSD: total días escritos en este run = 1
# [2025-12-03T04:24:17+00:00] [20251202_232253] [INFO] [06-BulkM5] [105/107] XLMUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:17+00:00] [20251202_232253] [INFO] [06-BulkM5] XLMUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:17+00:00] [20251202_232253] [INFO] [06-BulkM5] XLMUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:17+00:00] [20251202_232253] [INFO] [06-BulkM5] XLMUSD: total días escritos en este run = 1
# [2025-12-03T04:24:18+00:00] [20251202_232253] [INFO] [06-BulkM5] [106/107] UNIUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:18+00:00] [20251202_232253] [INFO] [06-BulkM5] UNIUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:18+00:00] [20251202_232253] [INFO] [06-BulkM5] UNIUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:18+00:00] [20251202_232253] [INFO] [06-BulkM5] UNIUSD: total días escritos en este run = 1
# [2025-12-03T04:24:19+00:00] [20251202_232253] [INFO] [06-BulkM5] [107/107] FETUSD: modo=INCREMENTAL, ventana efectiva 2025-11-28 → 2025-12-02 | BULK_MODE_08=AUTO, INCR_BACKFILL_DAYS_08=3
# [2025-12-03T04:24:19+00:00] [20251202_232253] [INFO] [06-BulkM5] FETUSD 2025-11 → días escritos acumulados (run para este símbolo): 0
# [2025-12-03T04:24:19+00:00] [20251202_232253] [INFO] [06-BulkM5] FETUSD 2025-12 → días escritos acumulados (run para este símbolo): 1
# [2025-12-03T04:24:19+00:00] [20251202_232253] [INFO] [06-BulkM5] FETUSD: total días escritos en este run = 1
# [2025-12-03T04:24:19+00:00] [20251202_232253] [INFO] [06-BulkM5] Conexión MT5 cerrada.
# ==============================================================================================================
# >>> Celda 06 :: Descarga masiva M5 (4 años, UTC+GYE, Polars-only, v2-debug)
# Salida base M5 raw: C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# símbolos elegibles (sin precheck estricto; Celda 05 + broker): 107 | Símbolos con datos escritos (en esta corrida): 91
# Días/archivos escritos (esta corrida): 281
# BULK_MODE_08 = AUTO | INCR_BACKFILL_DAYS_08 = 3
# FORCE_REDOWNLOAD_BULK_M5=False | FORCE_REWRITE_DAY=False
# --------------------------------------------------------------------------------------------------------------
# Tamaño total escrito: 2979535 bytes (2.84 MiB | 0.00 GiB)
# --------------------------------------------------------------------------------------------------------------
# Subcarpetas en m5_raw: 110
# Ejemplos de subcarpetas: symbol=AAPL, symbol=AAVUSD, symbol=ADAUSD, symbol=AIRF, symbol=ALGUSD, symbol=ALVG, symbol=AMZN, symbol=AUDCAD, symbol=AUDCHF, symbol=AUDJPY
# --------------------------------------------------------------------------------------------------------------
# Hora GYE fin: 2025-12-02T23:24:19-05:00 | Hora UTC fin: 2025-12-03T04:24:19+00:00
# ✅ Celda 06 — Bulk M5 completada: OK para continuar con la siguiente celda (Catálogo m5_raw / QA).

# %%
# ===================== Celda 07 — Catálogo m5_raw (sobre lo ya descargado) =====================
# Objetivo:
#   - Escanear bulk_data/m5_raw y construir:
#       (a) Catálogo por símbolo (ligero, agregado)  -> metadata/dataset_catalog.parquet
#       (b) Manifest por archivo con metadatos       -> metadata/m5_manifest.parquet
#   - Manifest incluye: first_ts_utc / last_ts_utc (Int64 ms UTC) por archivo, para búsquedas rápidas.
#   - Extrae símbolo y fecha del path: symbol=.../year=YYYY/month=MM/part=YYYYMMDD.parquet
#   - Polars-only, sin pandas.
#   - Se asume que la Celda 06 (Descarga masiva M5) YA corrió y llenó bulk_data/m5_raw.
# =======================================================================================================

from __future__ import annotations
from pathlib import Path
from datetime import datetime, timezone
import re
from typing import Dict, Any, List, Optional, Tuple

import polars as pl

CELL_LABEL   = "07-Catalogo-M5"
RUN_ID       = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))

# *** Uso estricto del ROOT definido en celdas previas (sin fallback absoluto) ***
if "DATA_ROOT" not in globals():
    raise RuntimeError("DATA_ROOT no está definido. Ejecuta primero la Celda 02 (Configuración y Rutas base).")
DATA_ROOT    = Path(globals()["DATA_ROOT"]).resolve()

M5_DIR         = DATA_ROOT / "bulk_data" / "m5_raw"
META_DIR       = DATA_ROOT / "metadata"
CATALOG_PATH   = META_DIR / "dataset_catalog.parquet"   # agregado por símbolo
MANIFEST_PATH  = META_DIR / "m5_manifest.parquet"       # detalle por archivo (incluye rangos)
TIMEZONE_IANA  = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# Permitir desactivar el cálculo de min/max por archivo si se desea solo inventario rápido
READ_TS_MINMAX = bool(globals().get("READ_TS_MINMAX", True))

def _log(level: str, msg: str):
    ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{ts}] [{RUN_ID}] [{level.upper()}] [{CELL_LABEL}] {msg}", flush=True)

def _now_local():
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return datetime.now(timezone.utc).isoformat(timespec="seconds") + "Z"

def _fmt_size(b: int) -> str:
    mib = b / (1024**2)
    gib = b / (1024**3)
    return f"{b} bytes ({mib:.2f} MiB | {gib:.2f} GiB)"

# --- Utilidad para min/max timestamp_utc por archivo (rápida y robusta) ---
def _minmax_ts_in_parquet(fp: Path) -> Tuple[Optional[int], Optional[int]]:
    """
    Lee SOLO la columna 'timestamp_utc' y devuelve (min_ms, max_ms) como enteros.
    Si no existe la columna, retorna (None, None).
    Preferimos Polars Lazy para evitar cargar columnas innecesarias.
    """
    try:
        # Intento 1: Lazy scan y agregaciones (rápido en Parquet columnar)
        lf = pl.scan_parquet(str(fp))
        mm = (
            lf.select([
                pl.col("timestamp_utc").cast(pl.Int64, strict=False).min().alias("_min"),
                pl.col("timestamp_utc").cast(pl.Int64, strict=False).max().alias("_max"),
            ])
            .collect()
        )
        vmin = mm["_min"][0]
        vmax = mm["_max"][0]
        if vmin is not None and vmax is not None:
            return int(vmin), int(vmax)

        # Intento 2: Read columns (fallback)
        df = pl.read_parquet(str(fp), columns=["timestamp_utc"])
        if df.height == 0:
            return None, None
        vmin = df.select(pl.col("timestamp_utc").cast(pl.Int64, strict=False).min()).item()
        vmax = df.select(pl.col("timestamp_utc").cast(pl.Int64, strict=False).max()).item()
        return (
            int(vmin) if vmin is not None else None,
            int(vmax) if vmax is not None else None,
        )
    except Exception:
        # Si falla (archivo corrupto o columna ausente), devolvemos None
        return None, None

# Header
print("="*100)
print(f"Inicio Celda 07 — Catálogo m5_raw | TZ objetivo: {TIMEZONE_IANA}")
print(f"Hora GYE: {_now_local()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-"*100)
print(f"Escaneando carpeta m5_raw: {M5_DIR}")

if not M5_DIR.exists():
    raise FileNotFoundError(
        f"No existe {M5_DIR}.\n"
        "Esta celda SOLO cataloga lo que ya está en disco.\n"
        "Ejecuta primero la Celda 06 — Descarga masiva M5."
    )

# Escaneo de archivos: part=YYYYMMDD.parquet
part_re = re.compile(r"part=(\d{8})\.parquet$", re.IGNORECASE)
files: List[Path] = list(M5_DIR.rglob("part=*.parquet"))
n_files = len(files)

if n_files == 0:
    print("⚠️  Catálogo m5_raw: no se encontraron archivos 'part=YYYYMMDD.parquet' en m5_raw.")
    print("    Ruta escaneada : ", M5_DIR)
    print("")
    print("    Esta celda **NO** descarga datos. Solo cataloga lo que YA existe en disco.")
    print("    Acción: ejecuta antes la Celda 06 — Descarga masiva M5 y vuelve a correr esta Celda 07.")
    raise SystemExit("Catálogo m5_raw abortado: carpeta vacía. Ejecuta Celda 06 primero.")

total_bytes = 0

# Acumuladores por símbolo
agg: Dict[str, Dict[str, Any]] = {}
# Manifest detallado
manifest_rows: List[Dict[str, Any]] = []

for fp in files:
    try:
        st = fp.stat()
        sz = st.st_size
        total_bytes += sz
    except Exception:
        sz = 0

    # Extraer symbol=... de la ruta
    sym = None
    for part in fp.parts:
        if part.startswith("symbol="):
            sym = part.split("=", 1)[-1]
            break
    if sym is None:
        sym = "(UNKNOWN)"

    # Extraer fecha del nombre de archivo
    m = part_re.search(fp.name)
    day_str = m.group(1) if m else None  # 'YYYYMMDD' o None

    # first/last timestamp en ms (por archivo)
    if READ_TS_MINMAX:
        fmin, fmax = _minmax_ts_in_parquet(fp)
    else:
        fmin, fmax = None, None

    # Inicializar acumulador por símbolo
    if sym not in agg:
        agg[sym] = {
            "symbol": sym,
            "n_files": 0,
            "bytes": 0,
            "days": set(),          # set de 'YYYYMMDD'
            "first_ts_utc": None,   # min(ms) por símbolo
            "last_ts_utc": None,    # max(ms) por símbolo
        }

    rec = agg[sym]
    rec["n_files"] += 1
    rec["bytes"]   += sz

    if day_str:
        rec["days"].add(day_str)

    # Agregado de min/max ms por símbolo
    if fmin is not None:
        rec["first_ts_utc"] = fmin if rec["first_ts_utc"] is None else min(rec["first_ts_utc"], fmin)
    if fmax is not None:
        rec["last_ts_utc"]  = fmax if rec["last_ts_utc"]  is None else max(rec["last_ts_utc"],  fmax)

    # Manifest (por archivo)
    manifest_rows.append({
        "symbol": sym,
        "day": day_str,
        "size_bytes": sz,
        "relpath": str(fp.relative_to(DATA_ROOT)),
        "first_ts_utc": fmin,  # Int64 ms UTC (o None si no disponible)
        "last_ts_utc":  fmax,  # Int64 ms UTC (o None si no disponible)
    })

print(f"Archivos Parquet encontrados: {n_files} | Tamaño total aprox: {_fmt_size(total_bytes)}")

# --------------------------------- Construir catálogo final (por símbolo) ---------------------------------
now_ms_utc = int(datetime.now(timezone.utc).timestamp() * 1000)
catalog_rows: List[Dict[str, Any]] = []

for sym, rec in agg.items():
    days_set = rec["days"]
    n_days   = len(days_set)
    first_day = min(days_set) if days_set else None
    last_day  = max(days_set) if days_set else None

    f_ts = rec["first_ts_utc"]
    l_ts = rec["last_ts_utc"]

    if f_ts is not None and l_ts is not None:
        dt0 = datetime.fromtimestamp(f_ts / 1000, tz=timezone.utc)
        dt1 = datetime.fromtimestamp(l_ts / 1000, tz=timezone.utc)
        n_months = (dt1.year - dt0.year) * 12 + (dt1.month - dt0.month) + 1
        n_years  = dt1.year - dt0.year + 1
    else:
        n_months = 0
        n_years  = 0

    bytes_total = rec["bytes"]
    mib = bytes_total / (1024**2) if bytes_total is not None else 0.0

    catalog_rows.append({
        "symbol": sym,
        "first_ts_utc": f_ts,
        "last_ts_utc":  l_ts,
        "n_files": rec["n_files"],
        "n_days":  n_days,
        "n_months": n_months,
        "n_years":  n_years,
        "bytes": bytes_total,
        "last_update_ts_utc": now_ms_utc,
        "notes": "",
        # columnas extra para QA/lectura humana
        "first_day": first_day,
        "last_day":  last_day,
        "mib": mib,
    })

# --------------------------------- DataFrames y persistencia ---------------------------------
META_DIR.mkdir(parents=True, exist_ok=True)

catalog_df = pl.DataFrame(
    catalog_rows,
    schema={
        "symbol": pl.Utf8,
        "first_ts_utc": pl.Int64,
        "last_ts_utc":  pl.Int64,
        "n_files": pl.Int64,
        "n_days":  pl.Int64,
        "n_months": pl.Int64,
        "n_years":  pl.Int64,
        "bytes": pl.Int64,
        "last_update_ts_utc": pl.Int64,
        "notes": pl.Utf8,
        "first_day": pl.Utf8,
        "last_day":  pl.Utf8,
        "mib": pl.Float64,
    },
).sort("symbol")

catalog_df.write_parquet(CATALOG_PATH, compression="zstd", statistics=True)

manifest_df = pl.DataFrame(
    manifest_rows,
    schema={
        "symbol": pl.Utf8,
        "day": pl.Utf8,            # 'YYYYMMDD' o None
        "size_bytes": pl.Int64,
        "relpath": pl.Utf8,
        "first_ts_utc": pl.Int64,  # ms (nullable)
        "last_ts_utc":  pl.Int64,  # ms (nullable)
    },
)
manifest_df.write_parquet(MANIFEST_PATH, compression="zstd", statistics=True)

# --------------------------------- Prints finales / QA rápido ---------------------------------
print("-"*100)
print(f"Catálogo por símbolo guardado en: {CATALOG_PATH}")
print(f"Manifest por archivo guardado en: {MANIFEST_PATH}")
print("-"*100)

# Top-10 por número de archivos
top_by_files = catalog_df.sort("n_files", descending=True).head(10)

print("Top-10 por n_files:")
for r in top_by_files.iter_rows(named=True):
    print(
        f"  - {r['symbol']}: files={r['n_files']} | days={r['n_days']} | "
        f"rango_días={r['first_day']}→{r['last_day']} | "
        f"rango_ms={r['first_ts_utc']}→{r['last_ts_utc']} | "
        f"{r['mib']:.2f} MiB"
    )

print("-"*100)

# Top-10 por n_days
top_by_days  = catalog_df.sort("n_days", descending=True).head(10)
print("Top-10 por n_days:")
for r in top_by_days.iter_rows(named=True):
    print(
        f"  - {r['symbol']}: days={r['n_days']} | files={r['n_files']} | "
        f"rango_días={r['first_day']}→{r['last_day']} | "
        f"rango_ms={r['first_ts_utc']}→{r['last_ts_utc']} | "
        f"{r['mib']:.2f} MiB"
    )

print("-"*100)
print("✅ Catálogo m5_raw generado.")
print("   - metadata/dataset_catalog.parquet  (agregado por símbolo)")
print("   - metadata/m5_manifest.parquet      (detalle por archivo, con first_ts_utc/last_ts_utc en ms UTC)")
print("   OK para continuar con la siguiente celda del pipeline.")
# =======================================================================================================
# Out:
# ====================================================================================================
# Inicio Celda 07 — Catálogo m5_raw | TZ objetivo: America/Guayaquil
# Hora GYE: 2025-12-02T23:24:19-05:00 | Hora UTC: 2025-12-03T04:24:19+00:00
# ----------------------------------------------------------------------------------------------------
# Escaneando carpeta m5_raw: C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# Archivos Parquet encontrados: 121428 | Tamaño total aprox: 1256437183 bytes (1198.23 MiB | 1.17 GiB)
# ----------------------------------------------------------------------------------------------------
# Catálogo por símbolo guardado en: C:\Quant\MT5_Data_Extraction\data\metadata\dataset_catalog.parquet
# Manifest por archivo guardado en: C:\Quant\MT5_Data_Extraction\data\metadata\m5_manifest.parquet
# ----------------------------------------------------------------------------------------------------
# Top-10 por n_files:
#   - AAVUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 12.70 MiB
#   - AVAUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 12.42 MiB
#   - BARUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 15.85 MiB
#   - BCHUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 13.68 MiB
#   - BNBUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 13.51 MiB
#   - ETCUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 15.76 MiB
#   - GALUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 13.80 MiB
#   - LNKUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 15.29 MiB
#   - MANUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 14.18 MiB
#   - NERUSD: files=1471 | days=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 13.61 MiB
# ----------------------------------------------------------------------------------------------------
# Top-10 por n_days:
#   - AAVUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 12.70 MiB
#   - AVAUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 12.42 MiB
#   - BARUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 15.85 MiB
#   - BCHUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 13.68 MiB
#   - BNBUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 13.51 MiB
#   - ETCUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 15.76 MiB
#   - GALUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 13.80 MiB
#   - LNKUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 15.29 MiB
#   - MANUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 14.18 MiB
#   - NERUSD: days=1471 | files=1471 | rango_días=20211119→20251202 | rango_ms=1637280000000→1764654600000 | 13.61 MiB
# ----------------------------------------------------------------------------------------------------
# ✅ Catálogo m5_raw generado.
#    - metadata/dataset_catalog.parquet  (agregado por símbolo)
#    - metadata/m5_manifest.parquet      (detalle por archivo, con first_ts_utc/last_ts_utc en ms UTC)
#    OK para continuar con la siguiente celda del pipeline.

# %%
# ============================ Celda 08 — Contrato/schema M5 (UTC+GYE, idempotente) ============================
# Objetivo (UNA función):
#   - Definir y persistir el contrato de esquema M5 en metadata/schema_m5.json (SCHEMA_M5_PATH).
#   - EXIGIR doble sello temporal:
#         * timestamp_utc  -> int64 epoch milisegundos (UTC)
#         * timestamp_gye  -> datetime con zona IANA TIMEZONE_IANA (America/Guayaquil por defecto)
#   - Documentar columnas, tipos, unidades y políticas:
#         - Particionado físico en m5_raw: symbol=SYMBOL/year=YYYY/month=MM/part=YYYYMMDD.parquet
#         - Parquet (compresión, estadísticas, tz explícita en timestamp_gye)
#         - spread_points en "points" (no pips).
#   - NO leer ni escribir datos de mercado (solo metadata).
#
# Uso:
#   - Obligatoria al menos una vez por entorno/proyecto.
#   - Idempotente: si se re-ejecuta, reescribe schema_m5.json con el mismo contrato (o con ajustes explícitos).
# ============================================================================================================

from pathlib import Path
from datetime import datetime, timezone
import json

# --------------------------------- Guardas de contexto del pipeline ---------------------------------
# Se apoya en las variables definidas en Celdas 01–02. Si alguna falta, se fijan valores seguros.
if "DATA_ROOT" not in globals():
    # Fallback seguro si alguien ejecuta esta celda aislada.
    DATA_ROOT = (Path.cwd() / "data").resolve()

if "METADATA_DIR" not in globals():
    METADATA_DIR = (DATA_ROOT / "metadata").resolve()
    METADATA_DIR.mkdir(parents=True, exist_ok=True)

if "SCHEMA_M5_PATH" not in globals():
    SCHEMA_M5_PATH = METADATA_DIR / "schema_m5.json"

RUN_ID = globals().get("RUN_ID", datetime.now().strftime("%Y%m%d_%H%M%S"))
TIMEFRAME_LABEL = globals().get("TIMEFRAME_LABEL", "M5")
DATA_VERSION = globals().get("DATA_VERSION", "v1")
PARQUET_COMPRESSION = globals().get("PARQUET_COMPRESSION", "zstd")
PARQUET_WRITE_STATISTICS = bool(globals().get("PARQUET_WRITE_STATISTICS", True))
TIMEZONE_IANA = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# Directorios físicos relevantes (para documentación, no para escribir datos aquí)
BULK_DATA_DIR = globals().get("BULK_DATA_DIR", DATA_ROOT / "bulk_data")
M5_RAW_DIR = globals().get("M5_RAW_DIR", BULK_DATA_DIR / "m5_raw")
HISTORICAL_DATA_DIR = globals().get("HISTORICAL_DATA_DIR", DATA_ROOT / "historical_data")
M5_CLEAN_DIR = globals().get("M5_CLEAN_DIR", HISTORICAL_DATA_DIR / "m5_clean")

# =================================== Contrato de esquema M5 ===================================
# Decisiones de diseño (acorde a Celda 06 / 07 del pipeline):
#   - timestamp_utc:
#         * Columna canónica de ordenación y joins entre datasets.
#         * Int64 ms UTC (epoch * 1000).
#   - timestamp_gye:
#         * Datetime[ms, TIMEZONE_IANA] (ej. 'America/Guayaquil').
#         * Se deriva SIEMPRE de timestamp_utc en el write-path (no se calcula "a mano" en cada celda).
#   - Campos OHLC, volúmenes y spread_points:
#         * Tipos numéricos float64/int64 para evitar sorpresas.
#         * spread_points en "points" (no pips) tal como devuelve MT5 en la estructura de rates.
#   - Particionado físico:
#         * m5_raw: symbol=SYMBOL/year=YYYY/month=MM/part=YYYYMMDD.parquet
#         * Cada archivo = un día/símbolo.
#   - Capa GOLD (m5_clean):
#         * Debe respetar el mismo esquema lógico (doble sello + OHLC + volúmenes + spread_points opcional).
schema_m5 = {
    "dataset": {
        "name": "mt5_rates_m5",
        "layer_raw": str(M5_RAW_DIR),
        "layer_clean": str(M5_CLEAN_DIR),
        "description": (
            "Barras de 5 minutos (M5) normalizadas con doble sello temporal (UTC + local IANA) "
            "para el servidor MT5 usado en este proyecto."
        ),
        "timeframe_label": TIMEFRAME_LABEL,
        "data_version": DATA_VERSION,
        "run_id": RUN_ID,
        "created_ts_utc": datetime.now(timezone.utc).isoformat(),
        "notes": [
            "timestamp_utc es int64 (ms epoch UTC) y es la clave de ordenación y joins.",
            f"timestamp_gye es datetime[ms,'{TIMEZONE_IANA}'], derivado 1:1 de timestamp_utc.",
            "spread_points está en 'points' (no pips); no se infiere desde ticks en este cuaderno.",
            "m5_raw y m5_clean deben respetar este contrato de columnas y tipos.",
        ],
    },
    "columns": [
        {
            "name": "timestamp_utc",
            "dtype": "int64_epoch_ms_utc",
            "required": True,
            "unit": "ms_since_epoch_UTC",
            "description": "Marca temporal de la barra (UTC) en milisegundos desde epoch (1970-01-01T00:00:00Z).",
            "examples": [1713312000000, 1713312300000],
        },
        {
            "name": "timestamp_gye",
            "dtype": "datetime_tz_ms",
            "tz": TIMEZONE_IANA,
            "required": True,
            "unit": "datetime_with_tz",
            "description": f"Marca temporal en zona IANA '{TIMEZONE_IANA}', derivada de timestamp_utc.",
            "examples": ["2024-04-17T00:00:00-05:00", "2024-04-17T00:05:00-05:00"],
        },
        {
            "name": "symbol",
            "dtype": "string",
            "required": True,
            "unit": None,
            "description": "Nombre canónico del símbolo en MT5 (ej. 'EURUSD', 'XAUUSD', 'US500.cash').",
            "examples": ["EURUSD", "XAUUSD"],
        },
        {
            "name": "open",
            "dtype": "float64",
            "required": True,
            "unit": "price_native",
            "description": "Precio de apertura de la barra.",
        },
        {
            "name": "high",
            "dtype": "float64",
            "required": True,
            "unit": "price_native",
            "description": "Máximo de la barra.",
        },
        {
            "name": "low",
            "dtype": "float64",
            "required": True,
            "unit": "price_native",
            "description": "Mínimo de la barra.",
        },
        {
            "name": "close",
            "dtype": "float64",
            "required": True,
            "unit": "price_native",
            "description": "Cierre de la barra.",
        },
        {
            "name": "tick_volume",
            "dtype": "int64",
            "required": True,
            "unit": "ticks_count",
            "description": "Volumen en ticks reportado por MT5 para la barra.",
        },
        {
            "name": "real_volume",
            "dtype": "int64_nullable",
            "required": False,
            "unit": "contracts_or_lots",
            "description": "Volumen real si el bróker lo provee; en caso contrario NULL.",
        },
        {
            "name": "spread_points",
            "dtype": "float64_nullable",
            "required": False,
            "unit": "points",
            "description": (
                "Spread de la barra en 'points' (normalizado por Point del símbolo). "
                "Si MT5 no lo provee en el rate M5, se persiste NULL."
            ),
        },
        {
            "name": "broker",
            "dtype": "string_nullable",
            "required": False,
            "unit": None,
            "description": "Identificador del bróker/servidor MT5 (opcional).",
        },
        {
            "name": "server_tz",
            "dtype": "string_nullable",
            "required": False,
            "unit": "IANA_or_vendor_label",
            "description": "Etiqueta de zona del servidor MT5 (opcional, orientativa; no se usa para joins).",
        },
    ],
    # Orden lógico y físico esperado por Celda 06 (Bulk M5) y Capa GOLD
    "column_order": [
        "timestamp_utc",
        "timestamp_gye",
        "symbol",
        "open",
        "high",
        "low",
        "close",
        "tick_volume",
        "real_volume",
        "spread_points",
        "broker",
        "server_tz",
    ],
    "parquet": {
        "compression": PARQUET_COMPRESSION,
        "write_statistics": PARQUET_WRITE_STATISTICS,
        "encoding_notes": [
            "Se recomienda escribir con compresión y estadísticas activadas para permitir predicate/pushdown.",
            f"timestamp_gye debe escribirse como Arrow timestamp[ms,tz='{TIMEZONE_IANA}'] (no como string).",
            "timestamp_utc se almacena como Int64 (ms epoch) para joins rápidos y robustos.",
        ],
    },
    "partitioning": {
        "raw_layout": "symbol=SYMBOL/year=YYYY/month=MM/part=YYYYMMDD.parquet",
        "raw_root": str(M5_RAW_DIR),
        "keys": ["symbol", "year", "month"],
        "filename_pattern": "part=YYYYMMDD.parquet",
        "rationale": (
            "Escrituras idempotentes por día y lecturas selectivas por rango/símbolo. "
            "El manifest y el dataset_catalog se basan en este layout."
        ),
    },
    "timestamp_policy": {
        "double_stamp_required": True,
        "utc_column": "timestamp_utc",
        "local_column": "timestamp_gye",
        "local_tz": TIMEZONE_IANA,
        "utc_representation": "int64_epoch_ms",
        "local_representation": "datetime_tz_ms",
        "conversion_rules": [
            "timestamp_gye = convert_time_zone(from='UTC', to=TIMEZONE_IANA) aplicado sobre timestamp_utc.",
            "NO se almacenan datetime 'naive'.",
            "En todas las celdas de I/O se deben reportar rangos en UTC y TZ local.",
        ],
    },
    "spread_policy": {
        "unit": "points",
        "source": "bar_level_if_available",
        "inference": "no_inference_from_ticks_in_this_notebook",
        "notes": [
            "Si el rate M5 entrega spread, se normaliza a points usando Point del símbolo (responsabilidad de la celda de descarga).",
            "Si no lo entrega, se persiste NULL y se reporta en QA (rejilla/coverage).",
        ],
    },
    "idempotency_policy": {
        "flags": {
            "FORCE_REDOWNLOAD_BULK_M5": (
                "Re-descarga histórica completa por símbolo/ventana en Celda 06 (ignora ficheros existentes)."
            ),
            "FORCE_REWRITE_DAY": (
                "Reescritura puntual de un día (symbol + YYYYMMDD) incluso si el archivo part=YYYYMMDD.parquet existe."
            ),
        },
        "default": "append_or_skip_if_exists",
        "notes": [
            "Antes de persistir: deduplicar por (symbol, timestamp_utc) en la celda de descarga/limpieza.",
            "Si existe el archivo del día y no hay flags de fuerza, se omite para evitar duplicados.",
        ],
    },
    "quality_checks": {
        "duplicates": "No se permiten duplicados por (symbol, timestamp_utc) dentro de cada archivo ni a nivel de símbolo.",
        "ohlc_consistency": "Debe cumplirse low <= high y no NaN en OHLC obligatorios.",
        "m5_grid": (
            "Validar ~288 barras/día por símbolo (rejilla M5 completa) salvo festivos/huecos explicados. "
            "La QA en celdas posteriores debe cuantificar esta rejilla."
        ),
        "tz_consistency": (
            "timestamp_gye debe corresponder EXACTAMENTE a timestamp_utc convertido a TIMEZONE_IANA "
            "(sin desfaces ni offset dobles)."
        ),
    },
}

# =================================== Persistir y validar lectura ===================================
SCHEMA_M5_PATH.parent.mkdir(parents=True, exist_ok=True)

with open(SCHEMA_M5_PATH, "w", encoding="utf-8") as f:
    json.dump(schema_m5, f, ensure_ascii=False, indent=2)

with open(SCHEMA_M5_PATH, "r", encoding="utf-8") as f:
    loaded = json.load(f)

# =================================== Impresiones obligatorias ===================================
print("================================================================================")
print("Celda 08 — Contrato/schema M5 (UTC+GYE)")
print("--------------------------------------------------------------------------------")
print(f"Esquema M5 guardado en : {SCHEMA_M5_PATH}")
print(f"DATA_ROOT              : {DATA_ROOT}")
print(f"m5_raw (capa raw)      : {M5_RAW_DIR}")
print(f"m5_clean (capa GOLD)   : {M5_CLEAN_DIR}")
print("--------------------------------------------------------------------------------")
print("Columnas (orden, tipos, required, unidad):")
for col in loaded["column_order"]:
    cdef = next((c for c in loaded["columns"] if c["name"] == col), None)
    if not cdef:
        continue
    extra = ""
    if cdef["name"] == "timestamp_gye":
        extra = f" | tz={cdef.get('tz', TIMEZONE_IANA)}"
    print(
        f"  - {cdef['name']:<14} : {cdef['dtype']:<18} "
        f"| required={str(cdef['required']):<5} | unit={str(cdef['unit']):<18}{extra}"
    )

print("--------------------------------------------------------------------------------")
print("Parquet (config por defecto del contrato):")
print(f"  - compresión       : {loaded['parquet']['compression']}")
print(f"  - write_statistics : {loaded['parquet']['write_statistics']}")
print("--------------------------------------------------------------------------------")
print("Particionado físico (capa m5_raw):")
print(f"  - root             : {loaded['partitioning']['raw_root']}")
print(f"  - layout           : {loaded['partitioning']['raw_layout']}")
print(f"  - filename_pattern : {loaded['partitioning']['filename_pattern']}")
print(f"  - keys             : {', '.join(loaded['partitioning']['keys'])}")
print("--------------------------------------------------------------------------------")
tp = loaded["timestamp_policy"]
print("Política de doble sello (UTC + TZ local):")
print(f"  - double_stamp_required = {tp['double_stamp_required']}")
print(f"  - utc_column / local_column = {tp['utc_column']} / {tp['local_column']}")
print(f"  - utc_rep / local_rep      = {tp['utc_representation']} / {tp['local_representation']}")
print(f"  - local_tz                 = {tp['local_tz']}")
print("--------------------------------------------------------------------------------")
print("Notas de spread_points:")
for note in loaded["spread_policy"]["notes"]:
    print(f"  * {note}")
print("--------------------------------------------------------------------------------")
print("✅ Celda 08 — Contrato/schema M5 normalizado: OK para continuar con la siguiente celda del pipeline.")
# ============================================================================================================
# Out:
# ================================================================================
# Celda 08 — Contrato/schema M5 (UTC+GYE)
# --------------------------------------------------------------------------------
# Esquema M5 guardado en : C:\Quant\MT5_Data_Extraction\data\metadata\schema_m5.json
# DATA_ROOT              : C:\Quant\MT5_Data_Extraction\data
# m5_raw (capa raw)      : C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# m5_clean (capa GOLD)   : C:\Quant\MT5_Data_Extraction\data\historical_data\m5_clean
# --------------------------------------------------------------------------------
# Columnas (orden, tipos, required, unidad):
#   - timestamp_utc  : int64_epoch_ms_utc | required=True  | unit=ms_since_epoch_UTC
#   - timestamp_gye  : datetime_tz_ms     | required=True  | unit=datetime_with_tz   | tz=America/Guayaquil
#   - symbol         : string             | required=True  | unit=None
#   - open           : float64            | required=True  | unit=price_native
#   - high           : float64            | required=True  | unit=price_native
#   - low            : float64            | required=True  | unit=price_native
#   - close          : float64            | required=True  | unit=price_native
#   - tick_volume    : int64              | required=True  | unit=ticks_count
#   - real_volume    : int64_nullable     | required=False | unit=contracts_or_lots
#   - spread_points  : float64_nullable   | required=False | unit=points
#   - broker         : string_nullable    | required=False | unit=None
#   - server_tz      : string_nullable    | required=False | unit=IANA_or_vendor_label
# --------------------------------------------------------------------------------
# Parquet (config por defecto del contrato):
#   - compresión       : zstd
#   - write_statistics : True
# --------------------------------------------------------------------------------
# Particionado físico (capa m5_raw):
#   - root             : C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
#   - layout           : symbol=SYMBOL/year=YYYY/month=MM/part=YYYYMMDD.parquet
#   - filename_pattern : part=YYYYMMDD.parquet
#   - keys             : symbol, year, month
# --------------------------------------------------------------------------------
# Política de doble sello (UTC + TZ local):
#   - double_stamp_required = True
#   - utc_column / local_column = timestamp_utc / timestamp_gye
#   - utc_rep / local_rep      = int64_epoch_ms / datetime_tz_ms
#   - local_tz                 = America/Guayaquil
# --------------------------------------------------------------------------------
# Notas de spread_points:
#   * Si el rate M5 entrega spread, se normaliza a points usando Point del símbolo (responsabilidad de la celda de descarga).
#   * Si no lo entrega, se persiste NULL y se reporta en QA (rejilla/coverage).
# --------------------------------------------------------------------------------
# ✅ Celda 08 — Contrato/schema M5 normalizado: OK para continuar con la siguiente celda del pipeline.

# %%
# ======================= Celda 08 — Diagnóstico rápido QA M5 (opcional) =======================
# Propósito:
#   - Inspeccionar rápidamente el resultado de qa_m5_bulk.parquet (Celda 10).
#   - NO forma parte del pipeline "duro": es sólo para debug / análisis manual.
#   - NO pisa DATA_ROOT: reutiliza el DATA_ROOT definido en la Celda 02.
#
# Qué hace:
#   1) Lee metadata/qa_m5_bulk.parquet.
#   2) Muestra el nº de días por status (OK / WARN / FAIL / EMPTY), con porcentaje.
#   3) Lista las causas de FAIL más frecuentes (columna 'notes'), top 20.
#   4) (Opcional) Si quieres, aquí puedes extender con más análisis de WARN, rejilla_pct, etc.
# ==============================================================================================

from pathlib import Path
import polars as pl

# Usamos el DATA_ROOT definido en la Celda 02
if "DATA_ROOT" not in globals():
    raise RuntimeError(
        "DATA_ROOT no está definido en globals(). "
        "Ejecuta la Celda 02 antes de correr esta Celda 08 de diagnóstico QA."
    )

DATA_ROOT = Path(globals()["DATA_ROOT"]).resolve()
QA_OUT_PATH = DATA_ROOT / "metadata" / "qa_m5_bulk.parquet"

if not QA_OUT_PATH.exists():
    raise FileNotFoundError(
        f"No se encontró qa_m5_bulk.parquet en:\n  {QA_OUT_PATH}\n"
        "Ejecuta la Celda 10 (QA operativa M5) antes de esta celda de diagnóstico."
    )

print("================================================================================")
print("Celda 08 — Diagnóstico rápido de QA M5 (qa_m5_bulk.parquet)")
print(f"DATA_ROOT   : {DATA_ROOT}")
print(f"QA_OUT_PATH : {QA_OUT_PATH}")
print("================================================================================")

df_qa = pl.read_parquet(QA_OUT_PATH)

# -------------------- 1) Resumen por status (OK / WARN / FAIL / EMPTY) ------------------------
if df_qa.height == 0:
    print("⚠️  qa_m5_bulk.parquet está vacío: no hay días auditados para este RUN_ID.")
else:
    print("✔ Resumen de días por status:")
    resumen_status = (
        df_qa
        .group_by("status")
        .agg(pl.len().alias("n_dias"))
        .with_columns(
            (pl.col("n_dias") / pl.col("n_dias").sum() * 100.0).alias("pct")
        )
        .sort("n_dias", descending=True)
    )
    print(resumen_status)

# -------------------- 2) Causas de FAIL más frecuentes (notes) -------------------------------
if "status" not in df_qa.columns:
    print("\n⚠️  La tabla QA no tiene columna 'status'; no se puede desglosar FAIL por notas.")
else:
    df_fail = df_qa.filter(pl.col("status") == "FAIL")

    if df_fail.height == 0:
        print("\n✔ No hay días con status FAIL en qa_m5_bulk.parquet.")
    else:
        if "notes" not in df_fail.columns:
            print("\n⚠️  Hay días FAIL pero no existe columna 'notes'; no se pueden listar las causas.")
        else:
            print("\n✔ Top 20 causas de FAIL (columna 'notes'):")
            top_notes = (
                df_fail
                .group_by("notes")
                .agg(pl.len().alias("n"))
                .sort("n", descending=True)
                .head(20)
            )
            print(top_notes)

# -------------------- 3) (Opcional) Rejilla global por status (útil para acciones) -----------
if "rejilla_pct" in df_qa.columns:
    print("\n✔ Rejilla_pct media por status (para entender por qué hay WARN/FAIL):")
    rejilla_por_status = (
        df_qa
        .group_by("status")
        .agg([
            pl.col("rejilla_pct").mean().alias("rejilla_mean"),
            pl.col("rejilla_pct").quantile(0.5).alias("rejilla_p50"),
            pl.col("rejilla_pct").min().alias("rejilla_min"),
            pl.col("rejilla_pct").max().alias("rejilla_max"),
        ])
        .sort("status")
    )
    print(rejilla_por_status)
else:
    print("\n⚠️  La tabla QA no tiene columna 'rejilla_pct'; se omite resumen de rejilla.")

print("================================================================================")
print("✅ Fin de Celda 08 — Diagnóstico QA M5 (esta celda NO altera el pipeline, sólo lee metadata).")
print("================================================================================")
# Out:
# ================================================================================
# Celda 08 — Diagnóstico rápido de QA M5 (qa_m5_bulk.parquet)
# DATA_ROOT   : C:\Quant\MT5_Data_Extraction\data
# QA_OUT_PATH : C:\Quant\MT5_Data_Extraction\data\metadata\qa_m5_bulk.parquet
# ================================================================================
# ✔ Resumen de días por status:
# shape: (2, 3)
# ┌────────┬────────┬───────────┐
# │ status ┆ n_dias ┆ pct       │
# │ ---    ┆ ---    ┆ ---       │
# │ str    ┆ u32    ┆ f64       │
# ╞════════╪════════╪═══════════╡
# │ OK     ┆ 63055  ┆ 75.730826 │
# │ WARN   ┆ 20207  ┆ 24.269174 │
# └────────┴────────┴───────────┘
#
# ✔ No hay días con status FAIL en qa_m5_bulk.parquet.
#
# ✔ Rejilla_pct media por status (para entender por qué hay WARN/FAIL):
# shape: (2, 5)
# ┌────────┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ status ┆ rejilla_mean ┆ rejilla_p50 ┆ rejilla_min ┆ rejilla_max │
# │ ---    ┆ ---          ┆ ---         ┆ ---         ┆ ---         │
# │ str    ┆ f64          ┆ f64         ┆ f64         ┆ f64         │
# ╞════════╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ OK     ┆ 97.833575    ┆ 99.31       ┆ 80.21       ┆ 100.0       │
# │ WARN   ┆ 29.19051     ┆ 27.08       ┆ 0.35        ┆ 79.86       │
# └────────┴──────────────┴─────────────┴─────────────┴─────────────┘
# ================================================================================
# ✅ Fin de Celda 08 — Diagnóstico QA M5 (esta celda NO altera el pipeline, sólo lee metadata).
# ================================================================================

# %%
# ======================= Celda 10 — QA operativa M5 (Polars, 3B, EAGER, robusta v4 + perfil sesión + QA económica) =======================
# - Toma DATA_ROOT de la Celda 02 (si no existe, falla).
# - EAGER por archivo; tipado estable y schema fijo para evitar ComputeError al construir el DataFrame.
#
# Cambios v4 (respecto a v3):
#   * Mantiene el mismo esquema de salida y los mismos artefactos:
#       - metadata/qa_m5_bulk.parquet  (nivel día: símbolo+fecha)
#       - metadata/qa_operativa_summary.parquet (nivel símbolo)
#   * Nueva lógica de status por día:
#       - FAIL  → errores FATALES de estructura: missing_OHLC, OHLC_null, OHLC_nan, low>high, errores de lectura.
#       - WARN  → estructura sana pero problemas corregibles: dups>0 y/o rejilla_pct < WARN_GRID_PCT.
#       - OK    → estructura sana, sin dups y con rejilla_pct >= WARN_GRID_PCT.
#   * Mantiene días vacíos como status="EMPTY" (no contaminan QA).
#   * Añade sanity-check global de cobertura M5:
#       - Calcula n_bars_mean, n_bars_p50, rejilla_mean, rejilla_p50.
#       - Si rejilla_mean < MIN_MEAN_REJILLA_HARD y n_bars_mean < MIN_MEAN_NBARS_HARD:
#             lanza RuntimeError → el dataset NO se considera M5 operativo.
#
# Perfil de sesión + flags por símbolo:
#   * Resumen por símbolo (qa_operativa_summary.parquet):
#       - n_bars_mean, n_bars_p50
#       - expected_bars_per_day_symbol ≈ n_bars_p50
#       - session_type ∈ {SESSION_24H, SESSION_DIURNA, SESSION_ILLQ}
#       - qa_struct_flag ∈ {OK_STRUCT, WARN_STRUCT, BAD_STRUCT} (sólo estructura, sin rejilla_pct).
#
#   * qa_operativa_flag (OK/WARN/BAD), ahora *session-aware*:
#       - BAD:
#           · qa_struct_flag == "BAD_STRUCT"
#           · o fail_ratio ≥ QA_BAD_MIN_FAIL_RATIO
#           · o empty_ratio > QA_BAD_MAX_EMPTY_RATIO
#           · o (session_type == "SESSION_24H" y rejilla_pct_mean < QA_BAD_MAX_REJILLA_MEAN)
#         ⇒ sólo FX/CFD 24h se castigan por rejilla 24h muy baja.
#       - OK:
#           · ok_ratio alto, fail_ratio bajo,
#           · y cobertura razonable, ajustada al tipo de sesión:
#               · 24h → rejilla_pct_mean ≥ QA_OK_MIN_REJILLA_MEAN
#               · diurnas/illíquidas → no se exige rejilla 24h alta.
#       - WARN:
#           · todo lo demás (incluidas acciones 100% WARN por rejilla 24h baja, pero estructura sana).
#
# Cambios extra en esta versión:
#   * QA económica diaria:
#       - pct_ret_zero: % de retornos 5m exactamente 0.0
#       - qa_price_flag_day ∈ {OK, BAD, EMPTY, FAIL}
#   * QA económica por símbolo:
#       - days_price_ok, days_price_bad, ratios asociados
#       - qa_price_flag ∈ {OK, WARN, BAD} a nivel símbolo
# =======================================================================================================================================

from __future__ import annotations
from pathlib import Path
from datetime import datetime, timezone
from typing import Tuple, Optional, List
import re, time
import polars as pl

# ----------------------------- Parámetros / Paths -----------------------------
CELL_LABEL   = "10-QA-M5-Operativa"
RUN_ID       = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))

# ✅ Tomar DATA_ROOT desde la Celda 02 (sin fallback)
if "DATA_ROOT" not in globals():
    raise RuntimeError("DATA_ROOT no está definido. Ejecuta la Celda 02 antes de esta celda.")
DATA_ROOT    = Path(globals()["DATA_ROOT"]).resolve()

BULK_M5_DIR  = DATA_ROOT / "bulk_data" / "m5_raw"
META_DIR     = DATA_ROOT / "metadata"
FILTERS_DIR  = META_DIR / "filters"

ELIGIBLE_PARQUET     = FILTERS_DIR / "eligible_symbols_by_cost.parquet"
ELIGIBLE_TXT         = FILTERS_DIR / "eligible_symbols_by_cost.txt"
QA_OUT_PATH          = META_DIR / "qa_m5_bulk.parquet"
QA_SUMMARY_PATH      = META_DIR / "qa_operativa_summary.parquet"

# Barras esperadas y umbrales de rejilla/QA
EXPECTED_BARS_M5     = int(globals().get("EXPECTED_BARS_M5", 288))
EXPECTED_BARS        = EXPECTED_BARS_M5               # alias local
WARN_GRID_PCT        = float(globals().get("WARN_GRID_PCT", 80.0))
PARQUET_COMP         = "zstd"

PROGRESS_EVERY_FILES   = int(globals().get("PROGRESS_EVERY_FILES_QA10", 2000))
PROGRESS_EVERY_SECONDS = float(globals().get("PROGRESS_EVERY_SECONDS_QA10", 2.0))

WHITELIST_QA10   = set(globals().get("WHITELIST_QA10", []) or [])
BLACKLIST_QA10   = set(globals().get("BLACKLIST_QA10", []) or [])
MAX_SYMBOLS_QA10 = globals().get("MAX_SYMBOLS_QA10", None)
TIMEZONE_IANA    = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# Umbrales para el flag qa_operativa_flag (ajustables vía Celda 02)
QA_OK_MIN_OK_RATIO       = float(globals().get("QA_OK_MIN_OK_RATIO", 0.90))     # ≥ 90% días OK
QA_OK_MAX_FAIL_RATIO     = float(globals().get("QA_OK_MAX_FAIL_RATIO", 0.05))   # ≤ 5% días FAIL
QA_OK_MIN_REJILLA_MEAN   = float(globals().get("QA_OK_MIN_REJILLA_MEAN", 80.0)) # rejilla media ≥ 80% (24h)

QA_BAD_MIN_FAIL_RATIO    = float(globals().get("QA_BAD_MIN_FAIL_RATIO", 0.20))  # ≥ 20% FAIL → BAD
QA_BAD_MAX_REJILLA_MEAN  = float(globals().get("QA_BAD_MAX_REJILLA_MEAN", 60.0))# rejilla media < 60 (24h) → BAD
QA_BAD_MAX_EMPTY_RATIO   = float(globals().get("QA_BAD_MAX_EMPTY_RATIO", 0.20)) # > 20% EMPTY → BAD

# Sanity-check global de cobertura M5 (definidos en Celda 02)
MIN_MEAN_REJILLA_HARD    = float(globals().get("MIN_MEAN_REJILLA_HARD", 5.0))
MIN_MEAN_NBARS_HARD      = float(globals().get("MIN_MEAN_NBARS_HARD", EXPECTED_BARS * 0.20))

# <<< NEW QA ECON >>> Umbrales para QA económica simple (precio) por símbolo/día
STUCK_RATIO_BAD        = float(globals().get("STUCK_RATIO_BAD", 0.80))   # ≥80% retornos 0.0 → "stuck"
RET_SPIKE_ABS_HARD     = float(globals().get("RET_SPIKE_ABS_HARD", 0.50))# |ret| ≥50% en un 5m → spike sospechoso
QA_PRICE_BAD_MIN_RATIO = float(globals().get("QA_PRICE_BAD_MIN_RATIO", 0.10))  # ≥10% días BAD_price → símbolo BAD

# Umbrales para perfil de sesión (configurables en Celda 02)
SESSION_24H_MIN_COVERAGE_RATIO = float(globals().get("SESSION_24H_MIN_COVERAGE_RATIO", 0.70))
SESSION_DIURNA_MIN_NBARS       = float(globals().get("SESSION_DIURNA_MIN_NBARS", 60.0))
# (SESSION_ILLQ es simplemente n_bars_mean < SESSION_DIURNA_MIN_NBARS)

# Umbrales para qa_struct_flag (solo estructura, sin rejilla)
QA_STRUCT_OK_MAX_FAIL_RATIO            = float(globals().get("QA_STRUCT_OK_MAX_FAIL_RATIO", 0.05))
QA_STRUCT_OK_MAX_LOW_GT_HIGH_RATIO     = float(globals().get("QA_STRUCT_OK_MAX_LOW_GT_HIGH_RATIO", 0.0))
QA_STRUCT_BAD_MIN_FAIL_RATIO           = float(globals().get("QA_STRUCT_BAD_MIN_FAIL_RATIO", 0.20))
QA_STRUCT_BAD_MIN_LOW_GT_HIGH_RATIO    = float(globals().get("QA_STRUCT_BAD_MIN_LOW_GT_HIGH_RATIO", 0.01))

# ----------------------------- Logger helper (usa Celda 03 si existe) -----------------------------
def _log(level: str, msg: str):
    """
    Usa log_msg(celda, level, message) si está disponible (Celda 03),
    si no, hace un print() formateado.
    """
    if "log_msg" in globals():
        try:
            log_msg(CELL_LABEL, level, msg)
            return
        except Exception:
            # Fallback a print si algo falla con el logger
            pass
    ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{ts}] [{RUN_ID}] [{level.upper()}] [{CELL_LABEL}] {msg}", flush=True)

# ----------------------------- Utilidades -----------------------------
def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return ""

def _read_eligible_symbols() -> Tuple[Optional[set[str]], Optional[str]]:
    if ELIGIBLE_PARQUET.exists():
        try:
            df = pl.read_parquet(ELIGIBLE_PARQUET)
            col = "symbol" if "symbol" in df.columns else df.columns[0]
            s = df.get_column(col).cast(pl.Utf8, strict=False).str.strip_chars()
            syms = [x for x in s.to_list() if x]
            return set(syms), "parquet"
        except Exception as e:
            _log("WARNING", f"No se pudo leer {ELIGIBLE_PARQUET}: {e}. Probando TXT...")
    if ELIGIBLE_TXT.exists():
        try:
            with open(ELIGIBLE_TXT, "r", encoding="utf-8") as f:
                syms = [ln.strip() for ln in f if ln.strip()]
            return set(syms), "txt"
        except Exception as e:
            _log("WARNING", f"No se pudo leer {ELIGIBLE_TXT}: {e}.")
    return None, None

def _parse_date_from_filename(fp: Path) -> Optional[str]:
    m = re.search(r"part=([0-9]{8})", fp.name)
    if m: return m.group(1)
    m = re.search(r"part=([0-9]{4})[-/]?([0-9]{2})[-/]?([0-9]{2})", fp.name)
    if m: return f"{m.group(1)}{m.group(2)}{m.group(3)}"
    return None

def _safe_quantile(s: pl.Series, q: float) -> Optional[float]:
    if s is None or s.len() == 0 or s.null_count() == s.len():
        return None
    try:
        v = s.drop_nulls()
        if v.len() == 0:
            return None
        return float(v.quantile(q))
    except Exception:
        return None

# ----------------------------- Header -----------------------------
print("="*110)
print(f"Inicio Celda 10 — QA operativa M5 (v4 + perfil sesión + QA económica) | TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-"*110)
print(f"DATA_ROOT: {DATA_ROOT}")
print(f"Fuente: {BULK_M5_DIR}")
print("-"*110)
_log("INFO", f"Inicio QA operativa M5 sobre {BULK_M5_DIR}")

# ----------------------------- Guardas -----------------------------
if not BULK_M5_DIR.exists():
    raise FileNotFoundError(f"No existe {BULK_M5_DIR}. Ejecuta la celda de descarga M5 primero.")
META_DIR.mkdir(parents=True, exist_ok=True)

# ----------------------------- Universo (m5_raw ∩ 3B) -----------------------------
symbols_found = [p.name.split("=",1)[-1] for p in sorted(BULK_M5_DIR.glob("symbol=*")) if p.is_dir()]
if WHITELIST_QA10:
    symbols_found = [s for s in symbols_found if s in WHITELIST_QA10]
if BLACKLIST_QA10:
    symbols_found = [s for s in symbols_found if s not in BLACKLIST_QA10]
if MAX_SYMBOLS_QA10 is not None:
    symbols_found = symbols_found[:int(MAX_SYMBOLS_QA10)]

elig_set, elig_src = _read_eligible_symbols()
if elig_set is not None:
    base_set        = set(symbols_found)
    audited_symbols = sorted(base_set & elig_set)
    omitted_symbols = sorted(base_set - elig_set)
    _log("INFO", f"Filtro 3B activo ({elig_src}). elegibles={len(elig_set)} | encontrados={len(base_set)} → auditados={len(audited_symbols)} | omitidos={len(omitted_symbols)}")
else:
    audited_symbols = sorted(set(symbols_found))
    omitted_symbols = []
    _log("WARNING", "No se encontró lista elegible (3B). Se auditan todos los símbolos presentes en m5_raw.")

if not audited_symbols:
    raise SystemExit("No hay símbolos para auditar después de aplicar filtros/elegible.")

# ----------------------------- Recolección de archivos -----------------------------
files: List[Path] = []
for sym in audited_symbols:
    sdir = BULK_M5_DIR / f"symbol={sym}"
    if sdir.exists():
        files.extend(sorted(sdir.rglob("part=*.parquet")))
total_files = len(files)

print("="*110, flush=True)
print(f"Inicio QA M5 (EAGER v4) → archivos a auditar: {total_files} | símbolos auditados: {len(audited_symbols)} | omitidos: {len(omitted_symbols)}", flush=True)
_log("INFO", f"Archivos a auditar: {total_files} para {len(audited_symbols)} símbolo(s)")

# ----------------------------- Acumuladores TIPO-FIJO por columna -----------------------------
C = {
    "symbol": [], "date": [],
    "n_bars": [], "n_unique_ts": [], "dups": [], "rejilla_pct": [],
    "has_null_ohlc": [], "has_nan_ohlc": [], "low_gt_high": [],
    "p50_spread_points": [], "p90_spread_points": [], "p99_spread_points": [],
    "p50_spread_bps": [], "p90_spread_bps": [], "p99_spread_bps": [],
    # <<< NEW QA ECON >>> QA económica diaria
    "pct_ret_zero": [],          # % de retornos 5m exactamente 0.0
    "qa_price_flag_day": [],     # {OK, BAD, EMPTY, FAIL}
    # QA estructural
    "status": [], "notes": []
}

t0 = time.monotonic()
last_beat = t0
req_cols = ["timestamp_utc","open","high","low","close","spread_points"]

# ----------------------------- Loop EAGER por archivo -----------------------------
for i, fp in enumerate(files, 1):
    # Extraer symbol de forma robusta desde la ruta
    sym_from_path = next((p.split("=", 1)[-1] for p in fp.parts if p.startswith("symbol=")), None)
    symbol = sym_from_path or "(UNKNOWN)"

    date_str = _parse_date_from_filename(fp)

    try:
        df = pl.read_parquet(fp, use_statistics=True)

        n_bars = int(df.height)

        # Derivar date si no está en filename
        if date_str is None:
            if "timestamp_utc" in df.columns and n_bars > 0:
                dmin = pl.from_epoch(df.get_column("timestamp_utc"), time_unit="ms").dt.truncate("1d").min()
                try:
                    date_str = dmin.strftime("%Y%m%d")
                except Exception:
                    date_str = "(unknown)"
            else:
                date_str = "(unknown)"

        # Si el archivo está vacío → marcar como EMPTY, sin tocar flags OHLC
        if n_bars == 0:
            C["symbol"].append(str(symbol))
            C["date"].append(str(date_str))
            C["n_bars"].append(int(0))
            C["n_unique_ts"].append(int(0))
            C["dups"].append(int(0))
            C["rejilla_pct"].append(float(0.0))
            C["has_null_ohlc"].append(False)
            C["has_nan_ohlc"].append(False)
            C["low_gt_high"].append(False)
            C["p50_spread_points"].append(None)
            C["p90_spread_points"].append(None)
            C["p99_spread_points"].append(None)
            C["p50_spread_bps"].append(None)
            C["p90_spread_bps"].append(None)
            C["p99_spread_bps"].append(None)
            # <<< NEW QA ECON >>> día vacío
            C["pct_ret_zero"].append(None)
            C["qa_price_flag_day"].append("EMPTY")
            C["status"].append("EMPTY")
            C["notes"].append("no_bars_in_file")
        else:
            # Nos quedamos solo con columnas relevantes si existen
            cols_available = set(df.columns)
            use_cols = [c for c in req_cols if c in cols_available]
            if use_cols:
                df = df.select(use_cols)

            # Casts seguros (strict=False para evitar ValueError)
            if "timestamp_utc" in df.columns:
                df = df.with_columns(pl.col("timestamp_utc").cast(pl.Int64, strict=False))
            for c in ["open","high","low","close","spread_points"]:
                if c in df.columns:
                    df = df.with_columns(pl.col(c).cast(pl.Float64, strict=False))

            # Métricas básicas
            if "timestamp_utc" in df.columns:
                n_unique_ts = int(df.get_column("timestamp_utc").n_unique())
            else:
                n_unique_ts = 0

            dups = int(max(n_bars - n_unique_ts, 0))
            rejilla_pct = float(round((n_unique_ts * 100.0 / float(EXPECTED_BARS)), 2)) if EXPECTED_BARS else 0.0

            have_ohlc = all(c in df.columns for c in ["open","high","low","close"])
            have_low_high = all(c in df.columns for c in ["low","high"])

            # ========= PARCHE: detección de nulls/NaNs/low>high SIN usar `.item()` =========
            if have_ohlc and n_bars > 0:
                # ¿Alguna barra con OHLC nulo?
                has_null_ohlc = (
                    df.filter(
                        pl.any_horizontal([
                            pl.col("open").is_null(),
                            pl.col("high").is_null(),
                            pl.col("low").is_null(),
                            pl.col("close").is_null(),
                        ])
                    ).height > 0
                )

                # ¿Alguna barra con OHLC NaN?
                has_nan_ohlc = (
                    df.filter(
                        pl.any_horizontal([
                            pl.col("open").is_nan(),
                            pl.col("high").is_nan(),
                            pl.col("low").is_nan(),
                            pl.col("close").is_nan(),
                        ])
                    ).height > 0
                )
            else:
                has_null_ohlc = False
                has_nan_ohlc  = False

            if have_low_high and n_bars > 0:
                # ¿Alguna barra con low > high?
                low_gt_high = df.filter(pl.col("low") > pl.col("high")).height > 0
            else:
                low_gt_high = False
            # =========================================================================

            # Spreads
            p50_sp = p90_sp = p99_sp = None
            p50_bps = p90_bps = p99_bps = None

            if "spread_points" in df.columns:
                sp = df.get_column("spread_points")
                p50_sp = _safe_quantile(sp, 0.50)
                p90_sp = _safe_quantile(sp, 0.90)
                p99_sp = _safe_quantile(sp, 0.99)

            if {"spread_points","close"}.issubset(set(df.columns)):
                df_sp = df.with_columns(
                    pl.when(pl.col("close") > 0.0)
                      .then((pl.col("spread_points")/pl.col("close")) * 10_000.0)
                      .otherwise(None)
                      .alias("spread_bps")
                )
                sp_bps = df_sp.get_column("spread_bps")
                p50_bps = _safe_quantile(sp_bps, 0.50)
                p90_bps = _safe_quantile(sp_bps, 0.90)
                p99_bps = _safe_quantile(sp_bps, 0.99)

            # <<< NEW QA ECON >>> QA económica simple: retornos y "stuck quotes"
            pct_ret_zero = None
            qa_price_flag_day = "EMPTY"

            if "close" in df.columns and n_bars > 1:
                close = df.get_column("close")
                close_prev = close.shift(1)

                # Sólo retornos con close_prev válido y distinto de 0
                mask_valid = close_prev.is_not_null() & (close_prev != 0.0)
                if mask_valid.sum() > 0:
                    close_valid = close.filter(mask_valid)
                    close_prev_valid = close_prev.filter(mask_valid)

                    ret = (close_valid / close_prev_valid) - 1.0
                    ret_abs = ret.abs()

                    # Máximo retorno absoluto intradía
                    ret_abs_max = float(ret_abs.max())
                    n_ret = ret_abs.len()

                    # % de retornos exactamente 0.0 → stuck quotes
                    n_zero = int((ret == 0.0).sum())
                    pct_ret_zero = n_zero / float(n_ret)

                    bad_spike = ret_abs_max >= RET_SPIKE_ABS_HARD
                    bad_stuck = pct_ret_zero >= STUCK_RATIO_BAD

                    if bad_spike or bad_stuck:
                        qa_price_flag_day = "BAD"
                    else:
                        qa_price_flag_day = "OK"
                else:
                    qa_price_flag_day = "EMPTY"
            else:
                qa_price_flag_day = "EMPTY"

            # -------------------- Nueva lógica v4: Status / notas --------------------
            fatal_reasons: List[str] = []
            warn_reasons: List[str]  = []

            # Errores estructurales (FATALES → FAIL)
            if not have_ohlc:
                fatal_reasons.append("missing_OHLC")
            if has_null_ohlc:
                fatal_reasons.append("OHLC_null")
            if has_nan_ohlc:
                fatal_reasons.append("OHLC_nan")
            if low_gt_high:
                fatal_reasons.append("low>high")

            # Problemas corregibles (avisos → WARN)
            if dups > 0:
                warn_reasons.append(f"dups={dups}")

            # Decisión de status
            if fatal_reasons:
                status = "FAIL"
                # <<< NEW QA ECON >>> si la estructura es fatal, el día entero va como FAIL en QA de precio
                qa_price_flag_day = "FAIL"
            else:
                status = "OK"
                # Cobertura insuficiente (rejilla) → WARN, no FAIL
                if rejilla_pct < WARN_GRID_PCT:
                    warn_reasons.append(f"rejilla<{WARN_GRID_PCT}%")
                    status = "WARN"
                # Duplicados también son WARN (si no hay errores fatales)
                if dups > 0 and status == "OK":
                    status = "WARN"

            reasons = fatal_reasons + warn_reasons
            notes   = ",".join(reasons)

            # Append TIPADO
            C["symbol"].append(str(symbol))
            C["date"].append(str(date_str))
            C["n_bars"].append(int(n_bars))
            C["n_unique_ts"].append(int(n_unique_ts))
            C["dups"].append(int(dups))
            C["rejilla_pct"].append(float(rejilla_pct))
            C["has_null_ohlc"].append(bool(has_null_ohlc))
            C["has_nan_ohlc"].append(bool(has_nan_ohlc))
            C["low_gt_high"].append(bool(low_gt_high))
            C["p50_spread_points"].append(None if p50_sp is None else float(p50_sp))
            C["p90_spread_points"].append(None if p90_sp is None else float(p90_sp))
            C["p99_spread_points"].append(None if p99_sp is None else float(p99_sp))
            C["p50_spread_bps"].append(None if p50_bps is None else float(p50_bps))
            C["p90_spread_bps"].append(None if p90_bps is None else float(p90_bps))
            C["p99_spread_bps"].append(None if p99_bps is None else float(p99_bps))
            # <<< NEW QA ECON >>> guardamos métricas económicas diarias
            C["pct_ret_zero"].append(None if pct_ret_zero is None else float(pct_ret_zero))
            C["qa_price_flag_day"].append(str(qa_price_flag_day))
            C["status"].append(str(status))
            C["notes"].append(str(notes))

    except Exception as e:
        # Error de lectura/parseo → marcar FAIL pero sin inflar flags OHLC
        msg = f"exception_read:{type(e).__name__}:{e}"
        C["symbol"].append(str(symbol))
        C["date"].append(str(date_str or "(unknown)"))
        C["n_bars"].append(int(0))
        C["n_unique_ts"].append(int(0))
        C["dups"].append(int(0))
        C["rejilla_pct"].append(float(0.0))
        C["has_null_ohlc"].append(False)
        C["has_nan_ohlc"].append(False)
        C["low_gt_high"].append(False)
        C["p50_spread_points"].append(None)
        C["p90_spread_points"].append(None)
        C["p99_spread_points"].append(None)
        C["p50_spread_bps"].append(None)
        C["p90_spread_bps"].append(None)
        C["p99_spread_bps"].append(None)
        # <<< NEW QA ECON >>> error duro de lectura → FAIL
        C["pct_ret_zero"].append(None)
        C["qa_price_flag_day"].append("FAIL")
        C["status"].append("FAIL")
        C["notes"].append(msg)

    # Heartbeat
    now = time.monotonic()
    if (i % PROGRESS_EVERY_FILES == 0) or (now - last_beat >= PROGRESS_EVERY_SECONDS):
        rate = i / max(now - t0, 1e-6)
        _log("INFO", f"Progreso QA: {i}/{total_files} archivos | {rate:.1f} files/s")
        last_beat = now

elapsed = time.monotonic() - t0
rate = total_files / max(elapsed, 1e-6)
_log("INFO", f"QA completada. Procesados {total_files} archivos en {elapsed:.1f}s ({rate:.1f} files/s)")

# ----------------------------- Persistencia (schema FIJO) -----------------------------
schema_map = {
    "symbol": pl.Utf8, "date": pl.Utf8,
    "n_bars": pl.Int64, "n_unique_ts": pl.Int64, "dups": pl.Int64,
    "rejilla_pct": pl.Float64,
    "has_null_ohlc": pl.Boolean, "has_nan_ohlc": pl.Boolean, "low_gt_high": pl.Boolean,
    "p50_spread_points": pl.Float64, "p90_spread_points": pl.Float64, "p99_spread_points": pl.Float64,
    "p50_spread_bps": pl.Float64, "p90_spread_bps": pl.Float64, "p99_spread_bps": pl.Float64,
    # <<< NEW QA ECON >>> columnas nuevas en qa_m5_bulk.parquet
    "pct_ret_zero": pl.Float64,
    "qa_price_flag_day": pl.Utf8,
    "status": pl.Utf8, "notes": pl.Utf8
}
if C["symbol"]:
    out_df = pl.DataFrame(C, schema=schema_map)
else:
    out_df = pl.DataFrame(schema=schema_map)

QA_OUT_PATH.parent.mkdir(parents=True, exist_ok=True)
out_df.write_parquet(QA_OUT_PATH, compression=PARQUET_COMP)
_log("INFO", f"qa_m5_bulk.parquet escrito en {QA_OUT_PATH} ({out_df.height} filas)")

# ----------------------------- Resúmenes / Prints (nivel día) -----------------------------
print("-"*110)
print(f"Lectura desde: {BULK_M5_DIR}")
print(f"Reporte QA escrito en: {QA_OUT_PATH}")
print("-"*110)

if out_df.height == 0:
    print("Dataset QA vacío; no hay métricas para resumir.")
else:
    by_status = out_df.group_by("status").agg(pl.len().alias("n")).sort("status")
    counts = {r["status"]: int(r["n"]) for r in by_status.iter_rows(named=True)}
    tot_days = int(out_df.height)
    n_ok    = counts.get("OK", 0)
    n_warn  = counts.get("WARN", 0)
    n_fail  = counts.get("FAIL", 0)
    n_empty = counts.get("EMPTY", 0)
    _pct = lambda n: (100.0 * n / tot_days) if tot_days else 0.0
    print(
        f"Totales por status (días auditados): "
        f"OK={n_ok} ({_pct(n_ok):.1f}%) | "
        f"WARN={n_warn} ({_pct(n_warn):.1f}%) | "
        f"FAIL={n_fail} ({_pct(n_fail):.1f}%) | "
        f"EMPTY={n_empty} ({_pct(n_empty):.1f}%)"
    )
    print("-"*110)

    # ====================== Sanity-check global de cobertura M5 ======================
    coverage_stats = (
        out_df
        .select([
            pl.col("n_bars").mean().alias("n_bars_mean"),
            pl.col("n_bars").median().alias("n_bars_p50"),
            pl.col("rejilla_pct").mean().alias("rejilla_mean"),
            pl.col("rejilla_pct").quantile(0.5).alias("rejilla_p50"),
        ])
        .to_dicts()[0]
    )

    n_bars_mean   = float(coverage_stats.get("n_bars_mean", 0.0) or 0.0)
    n_bars_p50    = float(coverage_stats.get("n_bars_p50", 0.0) or 0.0)
    rejilla_mean  = float(coverage_stats.get("rejilla_mean", 0.0) or 0.0)
    rejilla_p50   = float(coverage_stats.get("rejilla_p50", 0.0) or 0.0)

    print(
        f"Cobertura global M5 (sobre días auditados): "
        f"n_bars_mean={n_bars_mean:.1f} | n_bars_p50={n_bars_p50:.1f} | "
        f"rejilla_mean={rejilla_mean:.2f}% | rejilla_p50={rejilla_p50:.2f}%"
    )

    if (rejilla_mean < MIN_MEAN_REJILLA_HARD) and (n_bars_mean < MIN_MEAN_NBARS_HARD):
        msg = (
            "❌ QA M5: Cobertura media M5 ridículamente baja.\n"
            f"   EXPECTED_BARS={EXPECTED_BARS}, n_bars_mean={n_bars_mean:.1f}, rejilla_mean={rejilla_mean:.2f}%.\n"
            "   Esto no parece un dataset M5 operativo (puede ser D1 mal etiquetado, "
            "extracción rota en Celda 08 o datos vacíos).\n"
            "   Acción profesional:\n"
            "     1) Revisar Celda 08 (TIMEFRAME=MT5.TIMEFRAME_M5, ventanas WS/WE, etc.).\n"
            "     2) Forzar re-descarga con FORCE_REDOWNLOAD_BULK_M5=True y FORCE_REWRITE_DAY=True.\n"
            "     3) Inspeccionar manualmente 2–3 archivos de m5_raw (al menos 100–200 velas/día) "
            "antes de volver a correr QA y GOLD."
        )
        _log("ERROR", msg.replace("\n", " "))
        raise RuntimeError(msg)
    # ================================================================================

    # ---------------------- Resumen por símbolo (qa_operativa_summary) ----------------------
    qa_sym_summary = (
        out_df.group_by("symbol")
              .agg([
                  pl.len().alias("n_days"),
                  (pl.col("status") == "OK").cast(pl.Int32).sum().alias("days_ok"),
                  (pl.col("status") == "WARN").cast(pl.Int32).sum().alias("days_warn"),
                  (pl.col("status") == "FAIL").cast(pl.Int32).sum().alias("days_fail"),
                  (pl.col("status") == "EMPTY").cast(pl.Int32).sum().alias("days_empty"),
                  pl.col("n_bars").mean().alias("n_bars_mean"),
                  pl.col("n_bars").median().alias("n_bars_p50"),
                  pl.col("rejilla_pct").mean().alias("rejilla_pct_mean"),
                  (pl.col("rejilla_pct") >= WARN_GRID_PCT).cast(pl.Int32).sum().alias("days_rejilla_ge_warn"),
                  pl.col("low_gt_high").cast(pl.Int32).sum().alias("days_low_gt_high"),
                  pl.col("p50_spread_bps").mean().alias("p50_spread_bps_mean"),
                  pl.col("p90_spread_bps").mean().alias("p90_spread_bps_mean"),
                  pl.col("p99_spread_bps").mean().alias("p99_spread_bps_mean"),
                  # <<< NEW QA ECON >>> contadores de QA económica diaria
                  (pl.col("qa_price_flag_day") == "OK").cast(pl.Int32).sum().alias("days_price_ok"),
                  (pl.col("qa_price_flag_day") == "WARN").cast(pl.Int32).sum().alias("days_price_warn"),
                  (pl.col("qa_price_flag_day") == "BAD").cast(pl.Int32).sum().alias("days_price_bad"),
                  (pl.col("qa_price_flag_day") == "EMPTY").cast(pl.Int32).sum().alias("days_price_empty"),
              ])
              .with_columns([
                  (pl.col("days_ok")    / pl.col("n_days")).alias("ok_ratio"),
                  (pl.col("days_warn")  / pl.col("n_days")).alias("warn_ratio"),
                  (pl.col("days_fail")  / pl.col("n_days")).alias("fail_ratio"),
                  (pl.col("days_empty") / pl.col("n_days")).alias("empty_ratio"),
                  (pl.col("days_rejilla_ge_warn") / pl.col("n_days")).alias("rejilla_ge_warn_ratio"),
                  (pl.col("days_low_gt_high") / pl.col("n_days")).alias("low_gt_high_ratio"),
                  # <<< NEW QA ECON >>> ratios de QA económica por símbolo
                  (pl.col("days_price_ok")  / pl.col("n_days")).alias("price_ok_ratio"),
                  (pl.col("days_price_bad") / pl.col("n_days")).alias("price_bad_ratio"),
              ])
    )

    # Campos de perfil de sesión y estructura primero
    qa_sym_summary = qa_sym_summary.with_columns([
        # Expected bars por símbolo (perfil de sesión puro, sin 24h hardcoded)
        pl.col("n_bars_p50").alias("expected_bars_per_day_symbol"),

        # session_type sólo en función de n_bars_mean (volumen temporal / cobertura)
        pl.when(
            pl.col("n_bars_mean") >= pl.lit(EXPECTED_BARS * SESSION_24H_MIN_COVERAGE_RATIO)
        ).then(pl.lit("SESSION_24H"))
         .when(
            pl.col("n_bars_mean") >= pl.lit(SESSION_DIURNA_MIN_NBARS)
        ).then(pl.lit("SESSION_DIURNA"))
         .otherwise(pl.lit("SESSION_ILLQ"))
         .alias("session_type"),

        # qa_struct_flag: solo estructura (fail_ratio + low_gt_high_ratio), sin rejilla_pct
        pl.when(
            (pl.col("fail_ratio")        <= QA_STRUCT_OK_MAX_FAIL_RATIO) &
            (pl.col("low_gt_high_ratio") <= QA_STRUCT_OK_MAX_LOW_GT_HIGH_RATIO)
        ).then(pl.lit("OK_STRUCT"))
         .when(
            (pl.col("fail_ratio")        >= QA_STRUCT_BAD_MIN_FAIL_RATIO) |
            (pl.col("low_gt_high_ratio") >= QA_STRUCT_BAD_MIN_LOW_GT_HIGH_RATIO)
        ).then(pl.lit("BAD_STRUCT"))
         .otherwise(pl.lit("WARN_STRUCT"))
         .alias("qa_struct_flag"),
    ])

    # Flag qa_operativa_flag (OK/WARN/BAD), ahora *session-aware*:
    # - BAD: problemas estructurales serios (BAD_STRUCT), muchos FAIL/EMPTY,
    #        o cobertura 24h muy mala en símbolos SESSION_24H.
    # - OK : mayoría de días OK, pocos FAIL, y cobertura aceptable para su tipo de sesión.
    # - WARN: el resto (incluidas acciones diurnas con rejilla 24h "baja" pero estructura sana).
    qa_sym_summary = qa_sym_summary.with_columns([
        pl.when(
            (pl.col("qa_struct_flag") == "BAD_STRUCT") |
            (pl.col("fail_ratio")   >= QA_BAD_MIN_FAIL_RATIO) |
            (pl.col("empty_ratio")  >  QA_BAD_MAX_EMPTY_RATIO) |
            (
                (pl.col("session_type") == "SESSION_24H") &
                (pl.col("rejilla_pct_mean") < QA_BAD_MAX_REJILLA_MEAN)
            )
        ).then(pl.lit("BAD"))
         .when(
            (pl.col("ok_ratio")   >= QA_OK_MIN_OK_RATIO) &
            (pl.col("fail_ratio") <= QA_OK_MAX_FAIL_RATIO) &
            (
                ((pl.col("session_type") == "SESSION_24H") & (pl.col("rejilla_pct_mean") >= QA_OK_MIN_REJILLA_MEAN)) |
                (pl.col("session_type") != "SESSION_24H")
            )
        ).then(pl.lit("OK"))
         .otherwise(pl.lit("WARN"))
         .alias("qa_operativa_flag")
    ])

    # <<< NEW QA ECON >>> Flag de QA económica por símbolo (OK/WARN/BAD) según price_bad_ratio
    qa_sym_summary = qa_sym_summary.with_columns([
        pl.when(pl.col("price_bad_ratio") >= QA_PRICE_BAD_MIN_RATIO)
          .then(pl.lit("BAD"))
          .when(pl.col("price_bad_ratio") > 0.0)
          .then(pl.lit("WARN"))
          .otherwise(pl.lit("OK"))
          .alias("qa_price_flag")
    ])

    # Persistir resumen de QA operativa por símbolo
    qa_sym_summary.write_parquet(QA_SUMMARY_PATH, compression=PARQUET_COMP)
    _log("INFO", f"qa_operativa_summary.parquet escrito en {QA_SUMMARY_PATH} ({qa_sym_summary.height} filas)")

    # ---------------------- Prints de resumen por símbolo (usando qa_sym_summary) ----------------------
    sym_summary_for_print = (
        qa_sym_summary
        .with_columns([
            (pl.col("ok_ratio")   * 100.0).round(1).alias("ok_pct"),
            (pl.col("warn_ratio") * 100.0).round(1).alias("warn_pct"),
            (pl.col("fail_ratio") * 100.0).round(1).alias("fail_pct"),
            (pl.col("empty_ratio")* 100.0).round(1).alias("empty_pct"),
            pl.col("rejilla_pct_mean").round(2).alias("rejilla_pct_avg"),
        ])
        .select([
            "symbol","n_days","ok_pct","warn_pct","fail_pct","empty_pct",
            "rejilla_pct_avg","qa_operativa_flag"
        ])
    )

    top_worst = (
        sym_summary_for_print
        .sort(["fail_pct","warn_pct","ok_pct"], descending=[True, True, False])
        .head(10)
    )

    if top_worst.height > 0:
        print("Top-10 símbolos con mayor % de días FAIL/WARN (y flag QA):")
        for r in top_worst.iter_rows(named=True):
            print(
                f"  - {r['symbol']}: "
                f"FAIL={r['fail_pct']}% | WARN={r['warn_pct']}% | "
                f"EMPTY={r['empty_pct']}% | OK={r['ok_pct']}% | "
                f"rejilla_avg={r['rejilla_pct_avg']}% | "
                f"flag={r['qa_operativa_flag']} "
                f"(n_days={r['n_days']})"
            )
    else:
        print("No hay filas para resumen por símbolo.")

    print("-"*110)

    best = out_df.sort("rejilla_pct", descending=True).head(5)
    worst_days = out_df.sort("rejilla_pct", descending=False).head(5)

    if best.height > 0:
        print("Top-5 días con mayor %rejilla_5m:")
        for r in best.iter_rows(named=True):
            print(f"  - {r['symbol']} {r['date']} | rejilla={r['rejilla_pct']}% | status={r['status']} | dups={r['dups']}")
        print("-"*110)
    if worst_days.height > 0:
        print("Top-5 días con menor %rejilla_5m:")
        for r in worst_days.iter_rows(named=True):
            print(f"  - {r['symbol']} {r['date']} | rejilla={r['rejilla_pct']}% | status={r['status']} | dups={r['dups']}")

print("-"*110)
print(f"Símbolos auditados (elegibles): {len(audited_symbols)}")
print(f"Símbolos encontrados fuera de la elegible (omitidos): {len(omitted_symbols)}")
print(f"Resumen QA operativa por símbolo: {QA_SUMMARY_PATH}")
print("-"*110)
print("✅ QA operativa M5 completada (EAGER, robusta v4 + perfil de sesión + QA económica por símbolo, Polars, 3B, UTC + resumen por símbolo).")
# ===========================================================================================================
# Out:
# ==============================================================================================================
# Inicio Celda 10 — QA operativa M5 (v4 + perfil sesión + QA económica) | TZ local: America/Guayaquil
# Hora local: 2025-12-02T23:27:42-05:00 | Hora UTC: 2025-12-03T04:27:42+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT: C:\Quant\MT5_Data_Extraction\data
# Fuente: C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# --------------------------------------------------------------------------------------------------------------
# [2025-12-02 23:27:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Inicio QA operativa M5 sobre C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# [2025-12-02 23:27:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Filtro 3B activo (parquet). elegibles=107 | encontrados=110 → auditados=107 | omitidos=3
# ==============================================================================================================
# Inicio QA M5 (EAGER v4) → archivos a auditar: 118385 | símbolos auditados: 107 | omitidos: 3
# [2025-12-02 23:27:43] [20251202_232253] [INFO] [10-QA-M5-Operativa] Archivos a auditar: 118385 para 107 símbolo(s)
# [2025-12-02 23:27:45] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 415/118385 archivos | 207.5 files/s
# [2025-12-02 23:27:47] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 823/118385 archivos | 205.8 files/s
# [2025-12-02 23:27:49] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 1268/118385 archivos | 211.3 files/s
# [2025-12-02 23:27:51] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 1685/118385 archivos | 210.6 files/s
# [2025-12-02 23:27:53] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 1999/118385 archivos | 199.9 files/s
# [2025-12-02 23:27:53] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 2000/118385 archivos | 200.0 files/s
# [2025-12-02 23:27:55] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 2301/118385 archivos | 191.8 files/s
# [2025-12-02 23:27:57] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 2706/118385 archivos | 193.3 files/s
# [2025-12-02 23:27:59] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 3165/118385 archivos | 197.8 files/s
# [2025-12-02 23:28:01] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 3619/118385 archivos | 201.1 files/s
# [2025-12-02 23:28:03] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 4000/118385 archivos | 203.3 files/s
# [2025-12-02 23:28:05] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 4468/118385 archivos | 206.2 files/s
# [2025-12-02 23:28:07] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 4932/118385 archivos | 208.4 files/s
# [2025-12-02 23:28:09] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 5386/118385 archivos | 209.8 files/s
# [2025-12-02 23:28:11] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 5834/118385 archivos | 210.8 files/s
# [2025-12-02 23:28:11] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 6000/118385 archivos | 211.6 files/s
# [2025-12-02 23:28:13] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 6447/118385 archivos | 212.4 files/s
# [2025-12-02 23:28:15] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 6894/118385 archivos | 213.0 files/s
# [2025-12-02 23:28:17] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 7365/118385 archivos | 214.4 files/s
# [2025-12-02 23:28:19] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 7783/118385 archivos | 214.1 files/s
# [2025-12-02 23:28:20] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 8000/118385 archivos | 214.0 files/s
# [2025-12-02 23:28:22] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 8444/118385 archivos | 214.5 files/s
# [2025-12-02 23:28:24] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 8882/118385 archivos | 214.7 files/s
# [2025-12-02 23:28:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 9332/118385 archivos | 215.1 files/s
# [2025-12-02 23:28:28] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 9755/118385 archivos | 215.0 files/s
# [2025-12-02 23:28:29] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 10000/118385 archivos | 215.5 files/s
# [2025-12-02 23:28:31] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 10452/118385 archivos | 215.9 files/s
# [2025-12-02 23:28:33] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 10898/118385 archivos | 216.2 files/s
# [2025-12-02 23:28:35] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 11348/118385 archivos | 216.5 files/s
# [2025-12-02 23:28:37] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 11786/118385 archivos | 216.6 files/s
# [2025-12-02 23:28:38] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 12000/118385 archivos | 216.5 files/s
# [2025-12-02 23:28:40] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 12409/118385 archivos | 216.1 files/s
# [2025-12-02 23:28:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 12849/118385 archivos | 216.2 files/s
# [2025-12-02 23:28:44] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 13289/118385 archivos | 216.4 files/s
# [2025-12-02 23:28:46] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 13722/118385 archivos | 216.4 files/s
# [2025-12-02 23:28:48] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 14000/118385 archivos | 215.9 files/s
# [2025-12-02 23:28:50] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 14403/118385 archivos | 215.4 files/s
# [2025-12-02 23:28:52] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 14814/118385 archivos | 215.1 files/s
# [2025-12-02 23:28:54] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 15204/118385 archivos | 214.6 files/s
# [2025-12-02 23:28:56] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 15626/118385 archivos | 214.5 files/s
# [2025-12-02 23:28:58] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 16000/118385 archivos | 214.2 files/s
# [2025-12-02 23:29:00] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 16391/118385 archivos | 213.7 files/s
# [2025-12-02 23:29:02] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 16783/118385 archivos | 213.3 files/s
# [2025-12-02 23:29:04] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 17080/118385 archivos | 211.7 files/s
# [2025-12-02 23:29:06] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 17342/118385 archivos | 209.7 files/s
# [2025-12-02 23:29:08] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 17644/118385 archivos | 208.3 files/s
# [2025-12-02 23:29:10] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 17941/118385 archivos | 207.0 files/s
# [2025-12-02 23:29:10] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 18000/118385 archivos | 206.6 files/s
# [2025-12-02 23:29:12] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 18296/118385 archivos | 205.3 files/s
# [2025-12-02 23:29:14] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 18595/118385 archivos | 204.1 files/s
# [2025-12-02 23:29:16] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 18896/118385 archivos | 202.9 files/s
# [2025-12-02 23:29:18] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 19189/118385 archivos | 201.8 files/s
# [2025-12-02 23:29:20] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 19484/118385 archivos | 200.6 files/s
# [2025-12-02 23:29:22] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 19779/118385 archivos | 199.6 files/s
# [2025-12-02 23:29:24] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 20000/118385 archivos | 198.8 files/s
# [2025-12-02 23:29:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 20294/118385 archivos | 197.8 files/s
# [2025-12-02 23:29:28] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 20591/118385 archivos | 196.9 files/s
# [2025-12-02 23:29:30] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 20981/118385 archivos | 196.8 files/s
# [2025-12-02 23:29:32] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 21276/118385 archivos | 195.9 files/s
# [2025-12-02 23:29:34] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 21568/118385 archivos | 195.0 files/s
# [2025-12-02 23:29:36] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 21863/118385 archivos | 194.2 files/s
# [2025-12-02 23:29:37] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 22000/118385 archivos | 193.8 files/s
# [2025-12-02 23:29:39] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 22285/118385 archivos | 192.9 files/s
# [2025-12-02 23:29:41] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 22547/118385 archivos | 191.8 files/s
# [2025-12-02 23:29:43] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 22802/118385 archivos | 190.7 files/s
# [2025-12-02 23:29:45] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 23056/118385 archivos | 189.7 files/s
# [2025-12-02 23:29:47] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 23315/118385 archivos | 188.7 files/s
# [2025-12-02 23:29:49] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 23610/118385 archivos | 188.1 files/s
# [2025-12-02 23:29:51] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 23904/118385 archivos | 187.4 files/s
# [2025-12-02 23:29:51] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 24000/118385 archivos | 187.2 files/s
# [2025-12-02 23:29:53] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 24297/118385 archivos | 186.6 files/s
# [2025-12-02 23:29:55] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 24590/118385 archivos | 186.0 files/s
# [2025-12-02 23:29:57] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 24891/118385 archivos | 185.5 files/s
# [2025-12-02 23:29:59] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 25188/118385 archivos | 185.0 files/s
# [2025-12-02 23:30:01] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 25488/118385 archivos | 184.4 files/s
# [2025-12-02 23:30:03] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 25784/118385 archivos | 183.9 files/s
# [2025-12-02 23:30:05] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 26000/118385 archivos | 183.7 files/s
# [2025-12-02 23:30:07] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 26379/118385 archivos | 183.8 files/s
# [2025-12-02 23:30:09] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 26678/118385 archivos | 183.3 files/s
# [2025-12-02 23:30:11] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 26974/118385 archivos | 182.8 files/s
# [2025-12-02 23:30:13] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 27271/118385 archivos | 182.4 files/s
# [2025-12-02 23:30:15] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 27573/118385 archivos | 182.0 files/s
# [2025-12-02 23:30:17] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 27882/118385 archivos | 181.6 files/s
# [2025-12-02 23:30:17] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 28000/118385 archivos | 181.5 files/s
# [2025-12-02 23:30:19] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 28301/118385 archivos | 181.1 files/s
# [2025-12-02 23:30:21] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 28697/118385 archivos | 181.3 files/s
# [2025-12-02 23:30:23] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 29001/118385 archivos | 180.9 files/s
# [2025-12-02 23:30:25] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 29301/118385 archivos | 180.5 files/s
# [2025-12-02 23:30:27] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 29595/118385 archivos | 180.1 files/s
# [2025-12-02 23:30:29] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 29892/118385 archivos | 179.8 files/s
# [2025-12-02 23:30:30] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 30000/118385 archivos | 179.9 files/s
# [2025-12-02 23:30:32] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 30356/118385 archivos | 179.9 files/s
# [2025-12-02 23:30:34] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 30653/118385 archivos | 179.5 files/s
# [2025-12-02 23:30:36] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 30941/118385 archivos | 179.1 files/s
# [2025-12-02 23:30:38] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 31228/118385 archivos | 178.7 files/s
# [2025-12-02 23:30:40] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 31507/118385 archivos | 178.2 files/s
# [2025-12-02 23:30:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 31785/118385 archivos | 177.8 files/s
# [2025-12-02 23:30:43] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 32000/118385 archivos | 177.5 files/s
# [2025-12-02 23:30:45] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 32282/118385 archivos | 177.1 files/s
# [2025-12-02 23:30:47] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 32572/118385 archivos | 176.7 files/s
# [2025-12-02 23:30:49] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 32859/118385 archivos | 176.4 files/s
# [2025-12-02 23:30:51] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 33166/118385 archivos | 176.1 files/s
# [2025-12-02 23:30:53] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 33537/118385 archivos | 176.2 files/s
# [2025-12-02 23:30:55] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 33801/118385 archivos | 175.7 files/s
# [2025-12-02 23:30:57] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 34000/118385 archivos | 175.5 files/s
# [2025-12-02 23:30:59] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 34233/118385 archivos | 174.9 files/s
# [2025-12-02 23:31:01] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 34521/118385 archivos | 174.6 files/s
# [2025-12-02 23:31:03] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 34886/118385 archivos | 174.6 files/s
# [2025-12-02 23:31:05] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 35252/118385 archivos | 174.7 files/s
# [2025-12-02 23:31:07] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 35634/118385 archivos | 174.9 files/s
# [2025-12-02 23:31:08] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 36000/118385 archivos | 175.3 files/s
# [2025-12-02 23:31:10] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 36442/118385 archivos | 175.7 files/s
# [2025-12-02 23:31:12] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 36835/118385 archivos | 175.9 files/s
# [2025-12-02 23:31:14] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 37238/118385 archivos | 176.1 files/s
# [2025-12-02 23:31:16] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 37626/118385 archivos | 176.3 files/s
# [2025-12-02 23:31:18] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 38000/118385 archivos | 176.6 files/s
# [2025-12-02 23:31:20] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 38394/118385 archivos | 176.8 files/s
# [2025-12-02 23:31:22] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 38807/118385 archivos | 177.0 files/s
# [2025-12-02 23:31:24] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 39223/118385 archivos | 177.3 files/s
# [2025-12-02 23:31:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 39626/118385 archivos | 177.5 files/s
# [2025-12-02 23:31:28] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 40000/118385 archivos | 177.8 files/s
# [2025-12-02 23:31:30] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 40410/118385 archivos | 178.0 files/s
# [2025-12-02 23:31:32] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 40816/118385 archivos | 178.2 files/s
# [2025-12-02 23:31:34] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 41237/118385 archivos | 178.5 files/s
# [2025-12-02 23:31:36] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 41643/118385 archivos | 178.7 files/s
# [2025-12-02 23:31:38] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 42000/118385 archivos | 178.9 files/s
# [2025-12-02 23:31:40] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 42404/118385 archivos | 179.1 files/s
# [2025-12-02 23:31:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 42822/118385 archivos | 179.3 files/s
# [2025-12-02 23:31:44] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 43225/118385 archivos | 179.5 files/s
# [2025-12-02 23:31:46] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 43642/118385 archivos | 179.7 files/s
# [2025-12-02 23:31:48] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 44000/118385 archivos | 179.9 files/s
# [2025-12-02 23:31:50] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 44425/118385 archivos | 180.2 files/s
# [2025-12-02 23:31:52] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 44837/118385 archivos | 180.4 files/s
# [2025-12-02 23:31:54] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 45244/118385 archivos | 180.6 files/s
# [2025-12-02 23:31:56] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 45657/118385 archivos | 180.8 files/s
# [2025-12-02 23:31:57] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 46000/118385 archivos | 180.9 files/s
# [2025-12-02 23:31:59] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 46408/118385 archivos | 181.1 files/s
# [2025-12-02 23:32:01] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 46830/118385 archivos | 181.3 files/s
# [2025-12-02 23:32:03] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 47235/118385 archivos | 181.5 files/s
# [2025-12-02 23:32:05] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 47654/118385 archivos | 181.7 files/s
# [2025-12-02 23:32:07] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 48000/118385 archivos | 181.9 files/s
# [2025-12-02 23:32:09] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 48403/118385 archivos | 182.0 files/s
# [2025-12-02 23:32:11] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 48812/118385 archivos | 182.2 files/s
# [2025-12-02 23:32:13] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 49235/118385 archivos | 182.4 files/s
# [2025-12-02 23:32:15] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 49647/118385 archivos | 182.6 files/s
# [2025-12-02 23:32:17] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 50000/118385 archivos | 182.8 files/s
# [2025-12-02 23:32:19] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 50405/118385 archivos | 182.9 files/s
# [2025-12-02 23:32:21] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 50828/118385 archivos | 183.1 files/s
# [2025-12-02 23:32:23] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 51238/118385 archivos | 183.3 files/s
# [2025-12-02 23:32:25] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 51641/118385 archivos | 183.4 files/s
# [2025-12-02 23:32:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 52000/118385 archivos | 183.6 files/s
# [2025-12-02 23:32:28] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 52425/118385 archivos | 183.8 files/s
# [2025-12-02 23:32:30] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 52829/118385 archivos | 183.9 files/s
# [2025-12-02 23:32:32] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 53242/118385 archivos | 184.0 files/s
# [2025-12-02 23:32:34] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 53649/118385 archivos | 184.2 files/s
# [2025-12-02 23:32:36] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 54000/118385 archivos | 184.3 files/s
# [2025-12-02 23:32:38] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 54413/118385 archivos | 184.5 files/s
# [2025-12-02 23:32:40] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 54822/118385 archivos | 184.6 files/s
# [2025-12-02 23:32:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 55241/118385 archivos | 184.8 files/s
# [2025-12-02 23:32:44] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 55655/118385 archivos | 184.9 files/s
# [2025-12-02 23:32:46] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 56000/118385 archivos | 185.0 files/s
# [2025-12-02 23:32:48] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 56423/118385 archivos | 185.2 files/s
# [2025-12-02 23:32:50] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 56841/118385 archivos | 185.3 files/s
# [2025-12-02 23:32:52] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 57229/118385 archivos | 185.4 files/s
# [2025-12-02 23:32:54] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 57638/118385 archivos | 185.5 files/s
# [2025-12-02 23:32:55] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 58000/118385 archivos | 185.6 files/s
# [2025-12-02 23:32:57] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 58421/118385 archivos | 185.8 files/s
# [2025-12-02 23:32:59] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 58856/118385 archivos | 186.0 files/s
# [2025-12-02 23:33:01] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 59263/118385 archivos | 186.1 files/s
# [2025-12-02 23:33:03] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 59686/118385 archivos | 186.3 files/s
# [2025-12-02 23:33:05] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 60000/118385 archivos | 186.4 files/s
# [2025-12-02 23:33:07] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 60404/118385 archivos | 186.5 files/s
# [2025-12-02 23:33:09] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 60818/118385 archivos | 186.6 files/s
# [2025-12-02 23:33:11] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 61229/118385 archivos | 186.7 files/s
# [2025-12-02 23:33:13] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 61649/118385 archivos | 186.8 files/s
# [2025-12-02 23:33:15] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 62000/118385 archivos | 187.0 files/s
# [2025-12-02 23:33:17] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 62408/118385 archivos | 187.1 files/s
# [2025-12-02 23:33:19] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 62843/118385 archivos | 187.2 files/s
# [2025-12-02 23:33:21] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 63261/118385 archivos | 187.4 files/s
# [2025-12-02 23:33:23] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 63674/118385 archivos | 187.5 files/s
# [2025-12-02 23:33:24] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 64000/118385 archivos | 187.6 files/s
# [2025-12-02 23:33:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 64410/118385 archivos | 187.7 files/s
# [2025-12-02 23:33:28] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 64810/118385 archivos | 187.7 files/s
# [2025-12-02 23:33:30] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 65230/118385 archivos | 187.9 files/s
# [2025-12-02 23:33:32] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 65636/118385 archivos | 188.0 files/s
# [2025-12-02 23:33:34] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 66000/118385 archivos | 188.1 files/s
# [2025-12-02 23:33:36] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 66402/118385 archivos | 188.1 files/s
# [2025-12-02 23:33:38] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 66898/118385 archivos | 188.5 files/s
# [2025-12-02 23:33:40] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 67310/118385 archivos | 188.6 files/s
# [2025-12-02 23:33:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 67733/118385 archivos | 188.7 files/s
# [2025-12-02 23:33:43] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 68000/118385 archivos | 188.7 files/s
# [2025-12-02 23:33:45] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 68419/118385 archivos | 188.9 files/s
# [2025-12-02 23:33:47] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 68843/118385 archivos | 189.0 files/s
# [2025-12-02 23:33:49] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 69273/118385 archivos | 189.1 files/s
# [2025-12-02 23:33:51] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 69697/118385 archivos | 189.2 files/s
# [2025-12-02 23:33:53] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 70000/118385 archivos | 189.3 files/s
# [2025-12-02 23:33:55] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 70416/118385 archivos | 189.4 files/s
# [2025-12-02 23:33:57] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 70842/118385 archivos | 189.5 files/s
# [2025-12-02 23:33:59] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 71255/118385 archivos | 189.6 files/s
# [2025-12-02 23:34:01] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 71685/118385 archivos | 189.8 files/s
# [2025-12-02 23:34:02] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 72000/118385 archivos | 189.8 files/s
# [2025-12-02 23:34:04] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 72416/118385 archivos | 189.9 files/s
# [2025-12-02 23:34:06] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 72835/118385 archivos | 190.0 files/s
# [2025-12-02 23:34:08] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 73221/118385 archivos | 190.1 files/s
# [2025-12-02 23:34:10] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 73631/118385 archivos | 190.1 files/s
# [2025-12-02 23:34:12] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 74000/118385 archivos | 190.2 files/s
# [2025-12-02 23:34:14] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 74403/118385 archivos | 190.3 files/s
# [2025-12-02 23:34:16] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 74816/118385 archivos | 190.4 files/s
# [2025-12-02 23:34:18] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 75233/118385 archivos | 190.5 files/s
# [2025-12-02 23:34:20] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 75648/118385 archivos | 190.6 files/s
# [2025-12-02 23:34:22] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 76000/118385 archivos | 190.6 files/s
# [2025-12-02 23:34:24] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 76414/118385 archivos | 190.7 files/s
# [2025-12-02 23:34:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 76823/118385 archivos | 190.8 files/s
# [2025-12-02 23:34:28] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 77232/118385 archivos | 190.9 files/s
# [2025-12-02 23:34:30] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 77639/118385 archivos | 190.9 files/s
# [2025-12-02 23:34:31] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 78000/118385 archivos | 191.0 files/s
# [2025-12-02 23:34:33] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 78416/118385 archivos | 191.1 files/s
# [2025-12-02 23:34:35] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 78827/118385 archivos | 191.2 files/s
# [2025-12-02 23:34:37] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 79243/118385 archivos | 191.2 files/s
# [2025-12-02 23:34:39] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 79668/118385 archivos | 191.3 files/s
# [2025-12-02 23:34:41] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 80000/118385 archivos | 191.4 files/s
# [2025-12-02 23:34:43] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 80426/118385 archivos | 191.5 files/s
# [2025-12-02 23:34:45] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 80841/118385 archivos | 191.6 files/s
# [2025-12-02 23:34:47] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 81245/118385 archivos | 191.6 files/s
# [2025-12-02 23:34:49] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 81658/118385 archivos | 191.7 files/s
# [2025-12-02 23:34:51] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 82000/118385 archivos | 191.7 files/s
# [2025-12-02 23:34:53] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 82412/118385 archivos | 191.7 files/s
# [2025-12-02 23:34:55] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 82815/118385 archivos | 191.8 files/s
# [2025-12-02 23:34:57] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 83212/118385 archivos | 191.8 files/s
# [2025-12-02 23:34:59] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 83628/118385 archivos | 191.9 files/s
# [2025-12-02 23:35:01] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 84000/118385 archivos | 191.9 files/s
# [2025-12-02 23:35:03] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 84409/118385 archivos | 192.0 files/s
# [2025-12-02 23:35:05] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 84824/118385 archivos | 192.0 files/s
# [2025-12-02 23:35:07] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 85241/118385 archivos | 192.1 files/s
# [2025-12-02 23:35:09] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 85653/118385 archivos | 192.2 files/s
# [2025-12-02 23:35:10] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 86000/118385 archivos | 192.2 files/s
# [2025-12-02 23:35:12] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 86397/118385 archivos | 192.3 files/s
# [2025-12-02 23:35:14] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 86810/118385 archivos | 192.3 files/s
# [2025-12-02 23:35:16] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 87222/118385 archivos | 192.4 files/s
# [2025-12-02 23:35:18] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 87631/118385 archivos | 192.4 files/s
# [2025-12-02 23:35:20] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 88000/118385 archivos | 192.5 files/s
# [2025-12-02 23:35:22] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 88398/118385 archivos | 192.5 files/s
# [2025-12-02 23:35:24] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 88801/118385 archivos | 192.5 files/s
# [2025-12-02 23:35:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 89210/118385 archivos | 192.6 files/s
# [2025-12-02 23:35:28] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 89614/118385 archivos | 192.6 files/s
# [2025-12-02 23:35:30] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 90000/118385 archivos | 192.7 files/s
# [2025-12-02 23:35:32] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 90420/118385 archivos | 192.8 files/s
# [2025-12-02 23:35:34] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 90829/118385 archivos | 192.8 files/s
# [2025-12-02 23:35:36] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 91237/118385 archivos | 192.9 files/s
# [2025-12-02 23:35:38] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 91647/118385 archivos | 192.9 files/s
# [2025-12-02 23:35:40] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 92000/118385 archivos | 193.0 files/s
# [2025-12-02 23:35:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 92416/118385 archivos | 193.0 files/s
# [2025-12-02 23:35:44] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 92818/118385 archivos | 193.1 files/s
# [2025-12-02 23:35:46] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 93234/118385 archivos | 193.1 files/s
# [2025-12-02 23:35:48] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 93648/118385 archivos | 193.2 files/s
# [2025-12-02 23:35:49] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 94000/118385 archivos | 193.2 files/s
# [2025-12-02 23:35:51] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 94418/118385 archivos | 193.3 files/s
# [2025-12-02 23:35:53] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 94831/118385 archivos | 193.4 files/s
# [2025-12-02 23:35:55] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 95239/118385 archivos | 193.4 files/s
# [2025-12-02 23:35:57] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 95658/118385 archivos | 193.5 files/s
# [2025-12-02 23:35:59] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 96000/118385 archivos | 193.5 files/s
# [2025-12-02 23:36:01] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 96417/118385 archivos | 193.6 files/s
# [2025-12-02 23:36:03] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 96829/118385 archivos | 193.6 files/s
# [2025-12-02 23:36:05] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 97235/118385 archivos | 193.6 files/s
# [2025-12-02 23:36:07] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 97650/118385 archivos | 193.7 files/s
# [2025-12-02 23:36:09] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 98000/118385 archivos | 193.8 files/s
# [2025-12-02 23:36:11] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 98406/118385 archivos | 193.8 files/s
# [2025-12-02 23:36:13] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 98829/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:15] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 99235/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:17] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 99649/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:18] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 100000/118385 archivos | 194.0 files/s
# [2025-12-02 23:36:20] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 100363/118385 archivos | 194.0 files/s
# [2025-12-02 23:36:22] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 100715/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:24] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 101090/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 101498/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:28] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 101905/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:29] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 102000/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:31] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 102380/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:33] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 102752/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:35] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 103134/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:37] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 103505/118385 archivos | 193.9 files/s
# [2025-12-02 23:36:39] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 103881/118385 archivos | 193.8 files/s
# [2025-12-02 23:36:40] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 104000/118385 archivos | 193.8 files/s
# [2025-12-02 23:36:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 104368/118385 archivos | 193.8 files/s
# [2025-12-02 23:36:44] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 104749/118385 archivos | 193.8 files/s
# [2025-12-02 23:36:46] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 105120/118385 archivos | 193.7 files/s
# [2025-12-02 23:36:48] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 105436/118385 archivos | 193.6 files/s
# [2025-12-02 23:36:50] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 105608/118385 archivos | 193.2 files/s
# [2025-12-02 23:36:52] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 105775/118385 archivos | 192.8 files/s
# [2025-12-02 23:36:54] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 105932/118385 archivos | 192.4 files/s
# [2025-12-02 23:36:54] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 106000/118385 archivos | 192.2 files/s
# [2025-12-02 23:36:56] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 106164/118385 archivos | 191.8 files/s
# [2025-12-02 23:36:58] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 106333/118385 archivos | 191.4 files/s
# [2025-12-02 23:37:00] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 106504/118385 archivos | 191.1 files/s
# [2025-12-02 23:37:02] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 106676/118385 archivos | 190.7 files/s
# [2025-12-02 23:37:04] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 106843/118385 archivos | 190.3 files/s
# [2025-12-02 23:37:06] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 107010/118385 archivos | 189.9 files/s
# [2025-12-02 23:37:08] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 107162/118385 archivos | 189.5 files/s
# [2025-12-02 23:37:10] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 107332/118385 archivos | 189.2 files/s
# [2025-12-02 23:37:12] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 107492/118385 archivos | 188.8 files/s
# [2025-12-02 23:37:14] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 107650/118385 archivos | 188.4 files/s
# [2025-12-02 23:37:16] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 107810/118385 archivos | 188.0 files/s
# [2025-12-02 23:37:18] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 107967/118385 archivos | 187.6 files/s
# [2025-12-02 23:37:19] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 108000/118385 archivos | 187.5 files/s
# [2025-12-02 23:37:21] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 108159/118385 archivos | 187.2 files/s
# [2025-12-02 23:37:23] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 108319/118385 archivos | 186.8 files/s
# [2025-12-02 23:37:25] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 108481/118385 archivos | 186.4 files/s
# [2025-12-02 23:37:27] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 108639/118385 archivos | 186.1 files/s
# [2025-12-02 23:37:29] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 108800/118385 archivos | 185.7 files/s
# [2025-12-02 23:37:31] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 108960/118385 archivos | 185.3 files/s
# [2025-12-02 23:37:33] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 109114/118385 archivos | 185.0 files/s
# [2025-12-02 23:37:35] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 109277/118385 archivos | 184.6 files/s
# [2025-12-02 23:37:37] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 109439/118385 archivos | 184.3 files/s
# [2025-12-02 23:37:39] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 109597/118385 archivos | 183.9 files/s
# [2025-12-02 23:37:41] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 109756/118385 archivos | 183.6 files/s
# [2025-12-02 23:37:43] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 109918/118385 archivos | 183.2 files/s
# [2025-12-02 23:37:44] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 110000/118385 archivos | 183.1 files/s
# [2025-12-02 23:37:46] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 110156/118385 archivos | 182.7 files/s
# [2025-12-02 23:37:48] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 110314/118385 archivos | 182.4 files/s
# [2025-12-02 23:37:50] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 110471/118385 archivos | 182.0 files/s
# [2025-12-02 23:37:52] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 110630/118385 archivos | 181.7 files/s
# [2025-12-02 23:37:54] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 110791/118385 archivos | 181.4 files/s
# [2025-12-02 23:37:56] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 110946/118385 archivos | 181.0 files/s
# [2025-12-02 23:37:58] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 111102/118385 archivos | 180.7 files/s
# [2025-12-02 23:38:00] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 111258/118385 archivos | 180.3 files/s
# [2025-12-02 23:38:02] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 111402/118385 archivos | 180.0 files/s
# [2025-12-02 23:38:04] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 111566/118385 archivos | 179.7 files/s
# [2025-12-02 23:38:06] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 111727/118385 archivos | 179.4 files/s
# [2025-12-02 23:38:08] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 111892/118385 archivos | 179.0 files/s
# [2025-12-02 23:38:09] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 112000/118385 archivos | 178.8 files/s
# [2025-12-02 23:38:11] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 112160/118385 archivos | 178.5 files/s
# [2025-12-02 23:38:13] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 112322/118385 archivos | 178.2 files/s
# [2025-12-02 23:38:15] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 112476/118385 archivos | 177.9 files/s
# [2025-12-02 23:38:17] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 112635/118385 archivos | 177.6 files/s
# [2025-12-02 23:38:19] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 112799/118385 archivos | 177.3 files/s
# [2025-12-02 23:38:21] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 112958/118385 archivos | 177.0 files/s
# [2025-12-02 23:38:23] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 113112/118385 archivos | 176.7 files/s
# [2025-12-02 23:38:25] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 113271/118385 archivos | 176.4 files/s
# [2025-12-02 23:38:27] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 113435/118385 archivos | 176.1 files/s
# [2025-12-02 23:38:29] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 113595/118385 archivos | 175.8 files/s
# [2025-12-02 23:38:31] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 113767/118385 archivos | 175.5 files/s
# [2025-12-02 23:38:33] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 113939/118385 archivos | 175.2 files/s
# [2025-12-02 23:38:34] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 114000/118385 archivos | 175.1 files/s
# [2025-12-02 23:38:36] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 114167/118385 archivos | 174.9 files/s
# [2025-12-02 23:38:38] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 114339/118385 archivos | 174.6 files/s
# [2025-12-02 23:38:40] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 114507/118385 archivos | 174.3 files/s
# [2025-12-02 23:38:42] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 114664/118385 archivos | 174.0 files/s
# [2025-12-02 23:38:44] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 114831/118385 archivos | 173.7 files/s
# [2025-12-02 23:38:46] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 114997/118385 archivos | 173.5 files/s
# [2025-12-02 23:38:48] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 115155/118385 archivos | 173.2 files/s
# [2025-12-02 23:38:50] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 115322/118385 archivos | 172.9 files/s
# [2025-12-02 23:38:52] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 115528/118385 archivos | 172.7 files/s
# [2025-12-02 23:38:54] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 115734/118385 archivos | 172.5 files/s
# [2025-12-02 23:38:56] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 115907/118385 archivos | 172.2 files/s
# [2025-12-02 23:38:57] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 116000/118385 archivos | 172.1 files/s
# [2025-12-02 23:38:59] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 116156/118385 archivos | 171.8 files/s
# [2025-12-02 23:39:01] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 116315/118385 archivos | 171.5 files/s
# [2025-12-02 23:39:03] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 116473/118385 archivos | 171.3 files/s
# [2025-12-02 23:39:05] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 116631/118385 archivos | 171.0 files/s
# [2025-12-02 23:39:07] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 116792/118385 archivos | 170.7 files/s
# [2025-12-02 23:39:09] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 116996/118385 archivos | 170.5 files/s
# [2025-12-02 23:39:11] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 117193/118385 archivos | 170.3 files/s
# [2025-12-02 23:39:13] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 117356/118385 archivos | 170.1 files/s
# [2025-12-02 23:39:15] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 117510/118385 archivos | 169.8 files/s
# [2025-12-02 23:39:17] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 117669/118385 archivos | 169.5 files/s
# [2025-12-02 23:39:19] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 117821/118385 archivos | 169.3 files/s
# [2025-12-02 23:39:21] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 117983/118385 archivos | 169.0 files/s
# [2025-12-02 23:39:21] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 118000/118385 archivos | 169.0 files/s
# [2025-12-02 23:39:23] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 118157/118385 archivos | 168.7 files/s
# [2025-12-02 23:39:25] [20251202_232253] [INFO] [10-QA-M5-Operativa] Progreso QA: 118316/118385 archivos | 168.5 files/s
# [2025-12-02 23:39:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] QA completada. Procesados 118385 archivos en 703.2s (168.4 files/s)
# [2025-12-02 23:39:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] qa_m5_bulk.parquet escrito en C:\Quant\MT5_Data_Extraction\data\metadata\qa_m5_bulk.parquet (118385 filas)
# --------------------------------------------------------------------------------------------------------------
# Lectura desde: C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# Reporte QA escrito en: C:\Quant\MT5_Data_Extraction\data\metadata\qa_m5_bulk.parquet
# --------------------------------------------------------------------------------------------------------------
# Totales por status (días auditados): OK=96873 (81.8%) | WARN=21512 (18.2%) | FAIL=0 (0.0%) | EMPTY=0 (0.0%)
# --------------------------------------------------------------------------------------------------------------
# Cobertura global M5 (sobre días auditados): n_bars_mean=246.5 | n_bars_p50=286.0 | rejilla_mean=85.59% | rejilla_p50=99.31%
# [2025-12-02 23:39:26] [20251202_232253] [INFO] [10-QA-M5-Operativa] qa_operativa_summary.parquet escrito en C:\Quant\MT5_Data_Extraction\data\metadata\qa_operativa_summary.parquet (107 filas)
# Top-10 símbolos con mayor % de días FAIL/WARN (y flag QA):
#   - V: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=26.78% | flag=WARN (n_days=1011)
#   - NVDA: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=26.59% | flag=WARN (n_days=1011)
#   - AMZN: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=26.82% | flag=WARN (n_days=1011)
#   - ALVG: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=35.1% | flag=WARN (n_days=1030)
#   - SPN35.cash: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=47.62% | flag=WARN (n_days=1032)
#   - LVMH: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=35.11% | flag=WARN (n_days=1031)
#   - MSFT: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=26.8% | flag=WARN (n_days=1011)
#   - COFFEE.c: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=37.72% | flag=WARN (n_days=721)
#   - AAPL: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=26.82% | flag=WARN (n_days=1011)
#   - BAYGn: FAIL=0.0% | WARN=100.0% | EMPTY=0.0% | OK=0.0% | rejilla_avg=35.12% | flag=WARN (n_days=1030)
# --------------------------------------------------------------------------------------------------------------
# Top-5 días con mayor %rejilla_5m:
#   - AAVUSD 20220531 | rejilla=100.0% | status=OK | dups=0
#   - AAVUSD 20220602 | rejilla=100.0% | status=OK | dups=0
#   - AAVUSD 20220604 | rejilla=100.0% | status=OK | dups=0
#   - AAVUSD 20220606 | rejilla=100.0% | status=OK | dups=0
#   - AAVUSD 20220607 | rejilla=100.0% | status=OK | dups=0
# --------------------------------------------------------------------------------------------------------------
# Top-5 días con menor %rejilla_5m:
#   - AAVUSD 20211201 | rejilla=0.35% | status=WARN | dups=0
#   - AAVUSD 20220101 | rejilla=0.35% | status=WARN | dups=0
#   - AAVUSD 20220201 | rejilla=0.35% | status=WARN | dups=0
#   - AAVUSD 20220301 | rejilla=0.35% | status=WARN | dups=0
#   - AAVUSD 20220401 | rejilla=0.35% | status=WARN | dups=0
# --------------------------------------------------------------------------------------------------------------
# Símbolos auditados (elegibles): 107
# Símbolos encontrados fuera de la elegible (omitidos): 3
# Resumen QA operativa por símbolo: C:\Quant\MT5_Data_Extraction\data\metadata\qa_operativa_summary.parquet
# --------------------------------------------------------------------------------------------------------------
# ✅ QA operativa M5 completada (EAGER, robusta v4 + perfil de sesión + QA económica por símbolo, Polars, 3B, UTC + resumen por símbolo).

# %%
# ======================= Celda 11 — Ingesta incremental diaria M5 (Polars lazy + UTC/GYE) =======================
# Propósito:
#   - Detectar días faltantes por símbolo en bulk_data/m5_raw y descargar incrementos hasta AYER 23:55 UTC.
#   - Escribir idempotente: symbol=SYMBOL/year=YYYY/month=MM/part=YYYYMMDD.parquet
#   - Actualizar catálogo (metadata/dataset_catalog.parquet) usando Polars (lazy) para conteos/bytes/yyy-mm.
#   - Registrar acciones en metadata/run_log.jsonl.
#   - (NUEVO) Reprocesar días señalados por QA (rejilla < umbral) mediante:
#       * REPROCESS_RANGE_YYYYMMDD="YYYYMMDD:YYYYMMDD" [aplica a todos o a REPROCESS_SYMBOLS]
#       * metadata/reprocess_days.txt con líneas "SYMBOL,YYYYMMDD" o "YYYYMMDD" (comodín para todos)
#
# Impresiones obligatorias:
#   - "Incremento M5 escrito en: <DATA_ROOT>/bulk_data/m5_raw/"
#   - "Días añadidos por símbolo (top-5): ..."
#   - Totales agregados de archivos/bytes
#   - "Catálogo actualizado: <DATASET_CATALOG_PATH> | Filas=<n> | Columnas=<m>"
#   - Esquema (columnas:tipo) del catálogo
#   - Timestamps en UTC y TZ local America/Guayaquil
# ==============================================================================================================

from __future__ import annotations

import json, time, re, math, os
from pathlib import Path
from datetime import datetime, date, timedelta, timezone
from typing import Dict, List, Optional, Tuple, Set

import polars as pl

# --------- MT5 (requiere terminal instalado y logueado) ---------
try:
    import MetaTrader5 as mt5
except Exception as e:
    raise ImportError("No se pudo importar 'MetaTrader5'. Verifica instalación/terminal MT5.") from e

# --------------------------------- Config/paths ---------------------------------
CELL_LABEL   = "11-IngestaM5"
RUN_ID       = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))

# *** Requiere ROOT único definido antes ***
if "DATA_ROOT" not in globals():
    raise RuntimeError("DATA_ROOT no está definido. Ejecuta la celda de configuración (ROOT único) antes de la Celda 11.")
DATA_ROOT    = Path(globals()["DATA_ROOT"]).resolve()

M5_RAW_DIR   = DATA_ROOT / "bulk_data" / "m5_raw"
META_DIR     = DATA_ROOT / "metadata"
FILTERS_DIR  = META_DIR / "filters"

SCHEMA_JSON  = META_DIR / "schema_m5.json"
DATASET_CATALOG_PATH = META_DIR / "dataset_catalog.parquet"
RUN_LOG_JSONL_PATH   = META_DIR / "run_log.jsonl"

# Parámetros de ejecución
TIMEFRAME_LABEL = globals().get("TIMEFRAME_LABEL", "M5")
FORCE_REWRITE_DAY = bool(globals().get("FORCE_REWRITE_DAY", False))  # si True, reescribe part=YYYYMMDD.parquet
FILL_GAPS        = bool(globals().get("FILL_GAPS_M5", False))        # si True, también rellena huecos intermedios
TIMEZONE_IANA    = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# (NUEVO) Reproceso simple para días marcados por QA (rejilla < umbral)
REPROCESS_RANGE_YYYYMMDD: Optional[str] = globals().get("REPROCESS_RANGE_YYYYMMDD", None)  # "YYYYMMDD:YYYYMMDD"
REPROCESS_SYMBOLS: Set[str] = set(globals().get("REPROCESS_SYMBOLS", []) or [])            # limita el rango anterior
REPROCESS_DAYS_FILE = META_DIR / "reprocess_days.txt"  # líneas "SYMBOL,YYYYMMDD" o "YYYYMMDD" (comodín)

# Fin de rango incremental: AYER UTC (exclusivo fin de día)
TODAY_UTC   = datetime.now(timezone.utc).date()
END_DAY_UTC = TODAY_UTC - timedelta(days=1)   # [00:00, 24:00) de AYER

# Retries
RETRIES_CONN = 5
RETRIES_DAY  = 3
SLEEP_BASE   = 1.0

# Parquet
PARQUET_COMPRESSION = "zstd"

# --------------------------------- Utilidades ---------------------------------
def _log(level: str, msg: str):
    ts = datetime.now(timezone.utc).isoformat(timespec="seconds")
    print(f"[{ts}] [{RUN_ID}] [{level.upper()}] [{CELL_LABEL}] {msg}", flush=True)

def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return "(instala 'tzdata' para TZ locales)"

def _append_runlog(record: dict) -> None:
    RUN_LOG_JSONL_PATH.parent.mkdir(parents=True, exist_ok=True)
    with open(RUN_LOG_JSONL_PATH, "a", encoding="utf-8") as f:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")

def _ensure_dirs():
    if not M5_RAW_DIR.exists():
        raise FileNotFoundError(f"No existe {M5_RAW_DIR}. Ejecuta la Celda 06 primero.")
    META_DIR.mkdir(parents=True, exist_ok=True)
    if not DATASET_CATALOG_PATH.exists():
        pl.DataFrame(
            {
                "symbol": pl.Series([], dtype=pl.Utf8),
                "first_ts_utc": pl.Series([], dtype=pl.Int64),
                "last_ts_utc": pl.Series([], dtype=pl.Int64),
                "n_files": pl.Series([], dtype=pl.Int64),
                "n_days": pl.Series([], dtype=pl.Int64),
                "n_months": pl.Series([], dtype=pl.Int64),
                "n_years": pl.Series([], dtype=pl.Int64),
                "bytes": pl.Series([], dtype=pl.Int64),
                "last_update_ts_utc": pl.Series([], dtype=pl.Int64),
                "notes": pl.Series([], dtype=pl.Utf8),
            }
        ).write_parquet(DATASET_CATALOG_PATH, compression="zstd", statistics=True)

def _day_edges_utc(d: date) -> Tuple[datetime, datetime]:
    s = datetime(d.year, d.month, d.day, 0, 0, 0, tzinfo=timezone.utc)
    e = s + timedelta(days=1)  # exclusivo
    return s, e

def _parse_day_from_name(name: str) -> Optional[str]:
    # part=YYYYMMDD.parquet
    m = re.search(r"part=([0-9]{8})", name)
    return m.group(1) if m else None

def _yyyymmdd_to_date(s: str) -> date:
    return date(int(s[0:4]), int(s[4:6]), int(s[6:8]))

def _ms_to_iso(ms: Optional[int]) -> str:
    if ms is None or (isinstance(ms, float) and (math.isnan(ms) or math.isinf(ms))):
        return "N/A"
    return datetime.fromtimestamp(int(ms)/1000, tz=timezone.utc).isoformat(timespec="seconds")

def _load_schema_column_order() -> list[str]:
    try:
        schema = json.loads(SCHEMA_JSON.read_text(encoding="utf-8"))
        cols = list(schema.get("column_order", []))
        if cols:
            return cols
    except Exception:
        pass
    # fallback razonable con doble sello
    return ["timestamp_utc","timestamp_gye","symbol","open","high","low","close",
            "tick_volume","real_volume","spread_points","broker","server_tz"]

def _ensure_schema_order(df: pl.DataFrame, col_order: list[str]) -> pl.DataFrame:
    cols = set(df.columns)
    add_exprs = []
    for c in col_order:
        if c not in cols:
            if c == "timestamp_utc":
                add_exprs.append(pl.lit(None, dtype=pl.Int64).alias(c))
            elif c == "timestamp_gye":
                add_exprs.append(pl.lit(None, dtype=pl.Datetime("ms", TIMEZONE_IANA)).alias(c))
            elif c in {"open","high","low","close","spread_points"}:
                add_exprs.append(pl.lit(None, dtype=pl.Float64).alias(c))
            elif c in {"tick_volume","real_volume"}:
                add_exprs.append(pl.lit(None, dtype=pl.Int64).alias(c))
            else:
                add_exprs.append(pl.lit(None, dtype=pl.Utf8).alias(c))
    if add_exprs:
        df = df.with_columns(add_exprs)
    return df.select(col_order)

def _mt5_array_to_polars(arr) -> pl.DataFrame:
    """Convierte el structured array de MT5 a DataFrame Polars (sin pandas)."""
    if arr is None or len(arr) == 0:
        return pl.DataFrame()
    names = getattr(arr, "dtype", None)
    names = names.names if names is not None else None
    if names:
        return pl.DataFrame({n: arr[n].tolist() for n in names})
    try:
        return pl.DataFrame(arr)
    except Exception:
        return pl.from_dicts([dict(x) for x in arr])

# --------------------------- NUEVO: carga de días a reprocesar ---------------------------
def _expand_range_yyyymmdd(rng: str) -> List[date]:
    """'YYYYMMDD:YYYYMMDD' -> lista de fechas (incluyente)."""
    try:
        a, b = rng.split(":")
        da, db = _yyyymmdd_to_date(a.strip()), _yyyymmdd_to_date(b.strip())
        if da > db: da, db = db, da
        out = []
        cur = da
        while cur <= db:
            out.append(cur)
            cur += timedelta(days=1)
        return out
    except Exception:
        return []

def _load_reprocess_days(symbols_all: List[str]) -> Dict[str, Set[date]]:
    """
    Retorna mapping {symbol -> set(fecha)} a reprocesar.
    Fuentes:
      - archivo metadata/reprocess_days.txt (líneas: 'SYMBOL,YYYYMMDD' o 'YYYYMMDD' comodín)
      - REPROCESS_RANGE_YYYYMMDD (aplica a todos o a REPROCESS_SYMBOLS si se indica)
    """
    mapping: Dict[str, Set[date]] = {}

    # 1) Archivo de reproc (opcional)
    if REPROCESS_DAYS_FILE.exists():
        try:
            for ln in REPROCESS_DAYS_FILE.read_text(encoding="utf-8").splitlines():
                s = ln.strip()
                if not s or s.startswith("#"):
                    continue
                if "," in s:
                    sym, d = [t.strip() for t in s.split(",", 1)]
                else:
                    sym, d = "*", s  # comodín
                try:
                    dd = _yyyymmdd_to_date(d)
                except Exception:
                    continue
                mapping.setdefault(sym, set()).add(dd)
        except Exception as e:
            _log("WARNING", f"No se pudo leer {REPROCESS_DAYS_FILE.name}: {e}")

    # 2) Rango global (opcional)
    if REPROCESS_RANGE_YYYYMMDD:
        days = set(_expand_range_yyyymmdd(REPROCESS_RANGE_YYYYMMDD))
        if days:
            targets = (REPROCESS_SYMBOLS if REPROCESS_SYMBOLS else set(["*"]))
            for sym in targets:
                mapping.setdefault(sym, set()).update(days)

    # Expandir comodín '*' a todos los símbolos presentes
    if "*" in mapping:
        wildcard = set(mapping.pop("*"))
        for sym in symbols_all:
            mapping.setdefault(sym, set()).update(wildcard)

    # Limitar al máximo (no re-procesar futuro)
    for sym in list(mapping.keys()):
        mapping[sym] = {d for d in mapping[sym] if d <= END_DAY_UTC}

    return mapping

# --------------------------------- Header ---------------------------------
print("="*110)
print(f"Inicio Celda 11 — Ingesta incremental diaria M5 | TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-"*110)
print(f"DATA_ROOT: {DATA_ROOT}")
print(f"Fuente (m5_raw): {M5_RAW_DIR}")
print("-"*110)

# --------------------------------- Guardas ---------------------------------
_ensure_dirs()
assert TIMEFRAME_LABEL == "M5", "TIMEFRAME_LABEL debe ser 'M5' en esta celda."
TIMEFRAME = mt5.TIMEFRAME_M5
_log("INFO", "Verificación TF: usando explícitamente TIMEFRAME_M5.")

# --------------------------------- Descubrimiento de archivos (lazy) ---------------------------------
# Inventario de part-files con Polars (para gap-detection/catálogo)
files_meta: List[dict] = []
for sym_dir in sorted(M5_RAW_DIR.glob("symbol=*")):
    if not sym_dir.is_dir():
        continue
    sym = sym_dir.name.split("=",1)[-1]
    for pf in sym_dir.rglob("part=*.parquet"):
        d = _parse_day_from_name(pf.name)
        if not d:
            continue
        y = d[0:4]; m = d[4:6]
        try:
            sz = pf.stat().st_size
        except Exception:
            sz = 0
        files_meta.append({
            "symbol": sym,
            "day_str": d,
            "year": y,
            "month": m,
            "path": str(pf),
            "bytes": int(sz),
        })

if not files_meta:
    raise SystemExit("No hay part=*.parquet en m5_raw; ejecuta primero la ingesta masiva inicial.")

files_df = pl.DataFrame(files_meta).lazy()

# Último día existente por símbolo (lazy)
last_day_per_symbol = (
    files_df
    .group_by("symbol")
    .agg([
        pl.col("day_str").max().alias("last_day_str"),
        pl.len().alias("n_files"),
    ])
    .collect()
)

symbols = last_day_per_symbol.get_column("symbol").to_list()
last_day_map = dict(zip(
    last_day_per_symbol.get_column("symbol").to_list(),
    last_day_per_symbol.get_column("last_day_str").to_list()
))

# (opcional) detectar huecos intermedios si se habilita FILL_GAPS
days_by_symbol: Dict[str, set] = {}
if FILL_GAPS:
    by_sym = (
        files_df
        .group_by("symbol")
        .agg(pl.col("day_str"))
        .collect()
    )
    for sym, days_list in zip(by_sym["symbol"].to_list(), by_sym["day_str"].to_list()):
        days_by_symbol[str(sym)] = set(days_list)

# (NUEVO) Cargar días a reprocesar
reprocess_map = _load_reprocess_days(symbols)

if reprocess_map:
    n_pairs = sum(len(v) for v in reprocess_map.values())
    _log("INFO", f"Días a reprocesar (desde QA / parámetros): {n_pairs} pares símbolo-fecha detectados.")

# --------------------------------- Conexión MT5 ---------------------------------
_log("INFO", "Conectando a MT5 con reintentos...")
for i in range(RETRIES_CONN):
    if mt5.initialize():
        _log("INFO", "Conexión a MT5 establecida.")
        break
    time.sleep(SLEEP_BASE * (2 ** i))
else:
    raise RuntimeError("No se pudo inicializar MT5 tras múltiples intentos.")

total_days_added = 0
total_bytes_added = 0
per_symbol_added: Dict[str, int] = {}
per_symbol_minmax: Dict[str, Dict[str, Optional[int]]] = {}  # ms
per_symbol_reprocess_forced: Dict[str, int] = {}             # NUEVO

col_order = _load_schema_column_order()

# --------------------------------- Cálculo y descarga de incrementos ---------------------------------
for sym in symbols:
    last_day_str = last_day_map.get(sym, None)
    if not last_day_str or not last_day_str.isdigit():
        _log("WARNING", f"{sym}: no se pudo determinar último día; omitido.")
        continue

    last_day = _yyyymmdd_to_date(last_day_str)
    start_missing = last_day + timedelta(days=1)

    # 1) días "naturales" faltantes desde el último día hasta AYER
    missing_days: List[date] = []
    if start_missing <= END_DAY_UTC:
        d = start_missing
        while d <= END_DAY_UTC:
            missing_days.append(d)
            d += timedelta(days=1)

    # 2) (opcional) huecos intermedios
    if FILL_GAPS:
        existing = days_by_symbol.get(sym, set())
        if existing:
            min_d = _yyyymmdd_to_date(min(existing))
            max_d = _yyyymmdd_to_date(max(existing))
            dd = min_d
            while dd <= max_d:
                ds = f"{dd.year:04d}{dd.month:02d}{dd.day:02d}"
                if ds not in existing:
                    missing_days.append(dd)
                dd += timedelta(days=1)

    # 3) (NUEVO) días marcados para reprocesar por QA/parametrización
    repro_days: Set[date] = reprocess_map.get(sym, set())

    # Unificar lista de trabajo (mantener orden cronológico y sin duplicados)
    union_days: List[date] = []
    seen: Set[date] = set()
    for d in sorted(set(missing_days).union(repro_days)):
        if d not in seen:
            union_days.append(d); seen.add(d)

    if not union_days:
        continue

    # Descargar por día
    for d in union_days:
        yyyy, mm, dd = f"{d.year:04d}", f"{d.month:02d}", f"{d.day:02d}"
        out_dir  = M5_RAW_DIR / f"symbol={sym}" / f"year={yyyy}" / f"month={mm}"
        out_file = out_dir / f"part={yyyy}{mm}{dd}.parquet"

        # Forzar reescritura si el día está en reproceso por QA o si FORCE_REWRITE_DAY=True global
        force_this_day = FORCE_REWRITE_DAY or (d in repro_days)

        if out_file.exists() and not force_this_day:
            _append_runlog({
                "ts_utc": datetime.now(timezone.utc).isoformat(timespec="seconds"),
                "run_id": RUN_ID, "stage": "incremental_m5",
                "symbol": sym, "date": f"{yyyy}-{mm}-{dd}",
                "status": "skipped_exists", "path": str(out_file),
                "message": "Archivo existente (idempotencia)."
            })
            continue

        day_start, day_end = _day_edges_utc(d)
        ok = False; last_err = None
        for k in range(RETRIES_DAY):
            try:
                rates = mt5.copy_rates_range(sym, mt5.TIMEFRAME_M5, day_start, day_end)
                if rates is None:
                    raise RuntimeError(f"copy_rates_range devolvió None (last_error={mt5.last_error()})")
                if len(rates) == 0:
                    _append_runlog({
                        "ts_utc": datetime.now(timezone.utc).isoformat(timespec="seconds"),
                        "run_id": RUN_ID, "stage": "incremental_m5",
                        "symbol": sym, "date": f"{yyyy}-{mm}-{dd}",
                        "status": "empty", "path": str(out_file),
                        "message": "Sin barras (feriado/cierre)."
                    })
                    ok = True
                    break

                # Conversión a Polars (sin pandas)
                df = _mt5_array_to_polars(rates)
                if df.height == 0:
                    ok = True
                    break

                # Campos obligatorios/derivados
                df = (
                    df
                    .with_columns([
                        pl.lit(sym).alias("symbol"),
                        (pl.col("time").cast(pl.Int64) * 1000).alias("timestamp_utc"),
                    ])
                    .with_columns([
                        pl.col("timestamp_utc").cast(pl.Datetime("ms")).dt.replace_time_zone("UTC").alias("_ts_utc_dt"),
                    ])
                    .with_columns([
                        pl.col("_ts_utc_dt").dt.convert_time_zone(TIMEZONE_IANA).alias("timestamp_gye"),
                        pl.col("open").cast(pl.Float64).alias("open"),
                        pl.col("high").cast(pl.Float64).alias("high"),
                        pl.col("low").cast(pl.Float64).alias("low"),
                        pl.col("close").cast(pl.Float64).alias("close"),
                        pl.when(pl.col("tick_volume").is_not_null()).then(pl.col("tick_volume").cast(pl.Int64)).otherwise(pl.lit(None, dtype=pl.Int64)).alias("tick_volume"),
                        pl.when(pl.col("real_volume").is_not_null()).then(pl.col("real_volume").cast(pl.Int64)).otherwise(pl.lit(None, dtype=pl.Int64)).alias("real_volume"),
                        pl.when(pl.col("spread").is_not_null()).then(pl.col("spread").cast(pl.Float64)).otherwise(pl.lit(None, dtype=pl.Float64)).alias("spread_points"),
                        pl.lit(None, dtype=pl.Utf8).alias("broker"),
                        pl.lit(None, dtype=pl.Utf8).alias("server_tz"),
                    ])
                    .sort("timestamp_utc")
                    .unique(subset=["timestamp_utc"], keep="last")
                )

                # Particionar por día UTC
                df = df.with_columns(pl.col("_ts_utc_dt").dt.strftime("%Y%m%d").alias("_date_utc_str"))
                unique_days = df.select(pl.col("_date_utc_str").unique()).to_series().to_list()

                out_dir.mkdir(parents=True, exist_ok=True)
                for day_str in unique_days:
                    y = int(day_str[0:4]); m = int(day_str[4:6]); ddd = int(day_str[6:8])
                    # dentro de la ventana incremental (seguridad básica)
                    if date(y,m,ddd) > END_DAY_UTC:
                        continue

                    out_dir_day  = M5_RAW_DIR / f"symbol={sym}" / f"year={y:04d}" / f"month={m:02d}"
                    out_file_day = out_dir_day / f"part={day_str}.parquet"

                    # Evaluar si este día específico viene de reproceso QA
                    force_day_specific = force_this_day or (_yyyymmdd_to_date(day_str) in repro_days)

                    if out_file_day.exists() and not force_day_specific:
                        continue

                    out_day = df.filter(pl.col("_date_utc_str") == day_str).select(
                        "timestamp_utc","timestamp_gye","symbol",
                        "open","high","low","close",
                        "tick_volume","real_volume","spread_points","broker","server_tz",
                    )
                    out_day = _ensure_schema_order(out_day, col_order)

                    out_dir_day.mkdir(parents=True, exist_ok=True)
                    out_day.write_parquet(out_file_day, compression=PARQUET_COMPRESSION, statistics=True)

                    try:
                        total_bytes_added += out_file_day.stat().st_size
                    except Exception:
                        pass
                    total_days_added += 1
                    per_symbol_added[sym] = per_symbol_added.get(sym, 0) + 1

                    # Conteo de reprocesos forzados (solo si realmente se reescribió)
                    if force_day_specific:
                        per_symbol_reprocess_forced[sym] = per_symbol_reprocess_forced.get(sym, 0) + 1

                    # min/max por símbolo (para el print de rango)
                    mm = out_day.select([pl.min("timestamp_utc").alias("mn"), pl.max("timestamp_utc").alias("mx")]).to_dicts()[0]
                    vmin, vmax = mm["mn"], mm["mx"]
                    if sym not in per_symbol_minmax:
                        per_symbol_minmax[sym] = {"min": vmin, "max": vmax}
                    else:
                        per_symbol_minmax[sym]["min"] = min(per_symbol_minmax[sym]["min"], vmin)
                        per_symbol_minmax[sym]["max"] = max(per_symbol_minmax[sym]["max"], vmax)

                    _append_runlog({
                        "ts_utc": datetime.now(timezone.utc).isoformat(timespec="seconds"),
                        "run_id": RUN_ID, "stage": "incremental_m5",
                        "symbol": sym, "date": f"{y:04d}-{m:02d}-{ddd:02d}",
                        "status": ("reprocess_forced" if force_day_specific else "ok"),
                        "path": str(out_file_day),
                        "bytes": int(out_file_day.stat().st_size) if out_file_day.exists() else None,
                        "message": ("Reescritura forzada por QA (rejilla<umbral)" if force_day_specific else "Escritura incremental completada")
                    })

                ok = True
                break

            except Exception as e:
                last_err = repr(e)
                time.sleep(SLEEP_BASE * (2 ** k))

        if not ok:
            _append_runlog({
                "ts_utc": datetime.now(timezone.utc).isoformat(timespec="seconds"),
                "run_id": RUN_ID, "stage": "incremental_m5",
                "symbol": sym, "date": f"{yyyy}-{mm}-{dd}",
                "status": "fail", "path": str(out_file),
                "message": f"Fallo tras reintentos: {last_err}"
            })
            _log("WARNING", f"{sym} {yyyy}-{mm}-{dd}: fallo definitivo tras reintentos.")

# Cerrar MT5
try:
    mt5.shutdown()
    _log("INFO", "Conexión MT5 cerrada.")
except Exception:
    pass

# --------------------------------- Re-scan final (para catálogo) ---------------------------------
# Recalcular inventario post-ingesta (puede haber nuevos archivos)
files_meta2: List[dict] = []
for sym_dir in sorted(M5_RAW_DIR.glob("symbol=*")):
    if not sym_dir.is_dir(): continue
    sym = sym_dir.name.split("=",1)[-1]
    for pf in sym_dir.rglob("part=*.parquet"):
        d = _parse_day_from_name(pf.name)
        if not d: continue
        y = d[0:4]; m = d[4:6]
        try:
            sz = pf.stat().st_size
        except Exception:
            sz = 0
        files_meta2.append({"symbol": sym, "day_str": d, "year": y, "month": m, "path": str(pf), "bytes": int(sz)})

files_all_lf = pl.DataFrame(files_meta2).lazy()

# Métricas de catálogo (lazy)
agg = (
    files_all_lf
    .group_by("symbol")
    .agg([
        pl.len().alias("n_files"),
        pl.col("day_str").n_unique().alias("n_days"),
        pl.col("month").n_unique().alias("n_months"),
        pl.col("year").n_unique().alias("n_years"),
        pl.col("bytes").sum().alias("bytes"),
        pl.col("day_str").min().alias("min_day_str"),
        pl.col("day_str").max().alias("max_day_str"),
    ])
    .collect()
)

# Índice (symbol, day_str) -> path
idx_lf = files_all_lf.select(["symbol","day_str","path"]).collect()
paths_lookup: Dict[Tuple[str,str], str] = {}
for sym, d, p in zip(idx_lf["symbol"].to_list(), idx_lf["day_str"].to_list(), idx_lf["path"].to_list()):
    paths_lookup[(str(sym), str(d))] = str(p)

# first_ts_utc / last_ts_utc leyendo SOLO el archivo más antiguo y el más reciente por símbolo
first_ts_map: Dict[str, Optional[int]] = {}
last_ts_map:  Dict[str, Optional[int]] = {}
for row in agg.iter_rows(named=True):
    sym = row["symbol"]
    min_day = row["min_day_str"]
    max_day = row["max_day_str"]
    first_ts_map[sym] = None
    last_ts_map[sym]  = None
    p_min = paths_lookup.get((sym, min_day))
    if p_min and os.path.exists(p_min):
        try:
            tmin = pl.read_parquet(p_min, columns=["timestamp_utc"])
            if tmin.height > 0:
                first_ts_map[sym] = int(tmin.select(pl.col("timestamp_utc").min()).item())
        except Exception as e:
            _log("WARNING", f"{sym}: no se pudo leer first_ts de {Path(p_min).name}: {e}")
    p_max = paths_lookup.get((sym, max_day))
    if p_max and os.path.exists(p_max):
        try:
            tmax = pl.read_parquet(p_max, columns=["timestamp_utc"])
            if tmax.height > 0:
                last_ts_map[sym] = int(tmax.select(pl.col("timestamp_utc").max()).item())
        except Exception as e:
            _log("WARNING", f"{sym}: no se pudo leer last_ts de {Path(p_max).name}: {e}")

# Construir catálogo final y persistir (Polars)
now_ms = int(datetime.now(timezone.utc).timestamp() * 1000)
cat_rows: List[dict] = []
for r in agg.iter_rows(named=True):
    sym = r["symbol"]
    cat_rows.append({
        "symbol": sym,
        "first_ts_utc": None if first_ts_map.get(sym) is None else int(first_ts_map[sym]),
        "last_ts_utc":  None if last_ts_map.get(sym)  is None else int(last_ts_map[sym]),
        "n_files": int(r["n_files"]),
        "n_days": int(r["n_days"]),
        "n_months": int(r["n_months"]),
        "n_years": int(r["n_years"]),
        "bytes": int(r["bytes"]),
        "last_update_ts_utc": int(now_ms),
        "notes": "",
    })

catalog_pl = pl.from_dicts(cat_rows).with_columns([
    pl.col("symbol").cast(pl.Utf8),
    pl.col("first_ts_utc").cast(pl.Int64),
    pl.col("last_ts_utc").cast(pl.Int64),
    pl.col("n_files").cast(pl.Int64),
    pl.col("n_days").cast(pl.Int64),
    pl.col("n_months").cast(pl.Int64),
    pl.col("n_years").cast(pl.Int64),
    pl.col("bytes").cast(pl.Int64),
    pl.col("last_update_ts_utc").cast(pl.Int64),
    pl.col("notes").cast(pl.Utf8),
])
catalog_pl.write_parquet(DATASET_CATALOG_PATH, compression="zstd", statistics=True)

# --------------------------------- Impresiones requeridas ---------------------------------
print("="*80)
print(f"Incremento M5 escrito en: {M5_RAW_DIR}")
print(f"Archivos (días) agregados: {total_days_added}")

ranking = sorted(per_symbol_added.items(), key=lambda kv: kv[1], reverse=True)[:5]
print("Días añadidos por símbolo (top-5):")
if ranking:
    for sym, cnt in ranking:
        vmin = per_symbol_minmax.get(sym, {}).get("min", None)
        vmax = per_symbol_minmax.get(sym, {}).get("max", None)
        print(f"  - {sym}: {cnt} días | {_ms_to_iso(vmin)} → {_ms_to_iso(vmax)}")
else:
    print("  - (sin días añadidos en esta corrida)")

# (NUEVO) Resumen de reprocesos forzados por QA
if per_symbol_reprocess_forced:
    print("-"*80)
    print("Reprocesos forzados por símbolo (QA rejilla<umbral):")
    for sym, cnt in sorted(per_symbol_reprocess_forced.items(), key=lambda kv: kv[1], reverse=True)[:10]:
        print(f"  - {sym}: {cnt} día(s) reprocesado(s)")

mib = total_bytes_added / (1024 ** 2)
gib = total_bytes_added / (1024 ** 3)
print("-"*80)
print(f"Tamaño total agregado: {total_bytes_added} bytes ({mib:.2f} MiB | {gib:.2f} GiB)")

# Catálogo (leer con Polars y mostrar esquema)
try:
    cat = pl.read_parquet(DATASET_CATALOG_PATH)
    cols = list(cat.columns)
    dtypes = [str(dt) for dt in cat.dtypes]
    print("-"*80)
    print(f"Catálogo actualizado: {DATASET_CATALOG_PATH} | Filas={cat.height} | Columnas={len(cols)}")
    print("Esquema catálogo:")
    for c, t in zip(cols, dtypes):
        print(f"  - {c}: {t}")
except Exception as e:
    print("-"*80)
    print(f"⚠️  No se pudo leer el catálogo tras la actualización: {e}")

print("-"*80)
print("✅ Incremental M5 completado: OK para continuar con Celda 12")
# ==============================================================================================================
# Out:
# ==============================================================================================================
# Inicio Celda 11 — Ingesta incremental diaria M5 | TZ local: America/Guayaquil
# Hora local: 2025-12-02T23:39:26-05:00 | Hora UTC: 2025-12-03T04:39:26+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT: C:\Quant\MT5_Data_Extraction\data
# Fuente (m5_raw): C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# --------------------------------------------------------------------------------------------------------------
# [2025-12-03T04:39:26+00:00] [20251202_232253] [INFO] [11-IngestaM5] Verificación TF: usando explícitamente TIMEFRAME_M5.
# [2025-12-03T04:39:29+00:00] [20251202_232253] [INFO] [11-IngestaM5] Conectando a MT5 con reintentos...
# [2025-12-03T04:39:29+00:00] [20251202_232253] [INFO] [11-IngestaM5] Conexión a MT5 establecida.
# [2025-12-03T04:39:30+00:00] [20251202_232253] [INFO] [11-IngestaM5] Conexión MT5 cerrada.
# ================================================================================
# Incremento M5 escrito en: C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# Archivos (días) agregados: 29
# Días añadidos por símbolo (top-5):
#   - AIRF: 6 días | 2025-11-24T10:05:00+00:00 → 2025-12-01T18:25:00+00:00
#   - META: 5 días | 2025-11-24T16:35:00+00:00 → 2025-12-01T22:55:00+00:00
#   - TSLA: 1 días | 2025-12-02T16:35:00+00:00 → 2025-12-02T22:55:00+00:00
#   - EU50.cash: 1 días | 2025-12-02T09:05:00+00:00 → 2025-12-02T22:50:00+00:00
#   - GOOG: 1 días | 2025-12-02T16:35:00+00:00 → 2025-12-02T22:55:00+00:00
# --------------------------------------------------------------------------------
# Tamaño total agregado: 184636 bytes (0.18 MiB | 0.00 GiB)
# --------------------------------------------------------------------------------
# Catálogo actualizado: C:\Quant\MT5_Data_Extraction\data\metadata\dataset_catalog.parquet | Filas=110 | Columnas=10
# Esquema catálogo:
#   - symbol: String
#   - first_ts_utc: Int64
#   - last_ts_utc: Int64
#   - n_files: Int64
#   - n_days: Int64
#   - n_months: Int64
#   - n_years: Int64
#   - bytes: Int64
#   - last_update_ts_utc: Int64
#   - notes: String
# --------------------------------------------------------------------------------
# ✅ Incremental M5 completado: OK para continuar con Celda 12

# %%
# ======================= Celda 12 — Materializaciones listas para filtrar (POLARS, ventanas y QA) =======================
# Propósito:
#   - Construir ventanas last_{30,90,180}d desde m5_clean (o fallback m5_raw→limpieza on-the-fly).
#   - Validar ANTES de escribir: duplicados=0 y nulls críticos (timestamp_utc, OHLC) = 0.
#   - Escribir en processed_data/m5_windows/window=<win>/symbol=<sym>/part=YYYYMMDD.parquet (idempotente).
#   - Imprimir métricas claras: filas/columnas, esquema, rangos UTC/GYE, nulls críticos, duplicados.
#   - Progreso (heartbeat).
# ========================================================================================================================

from __future__ import annotations
import os, re, time, shutil, json
from pathlib import Path
from datetime import datetime, timedelta, timezone, date
from typing import List, Dict, Optional, Tuple

try:
    import polars as pl
except Exception as e:
    raise RuntimeError("Se requiere 'polars'. Instálalo e intenta de nuevo.") from e

# ---------------------------------- Config y rutas ----------------------------------
CELL_LABEL = "12-M5-Windows"
RUN_ID = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))

DATA_ROOT = Path(globals().get("DATA_ROOT", str(path_contract.data_root()))).resolve()

RAW_DIR   = DATA_ROOT / "bulk_data" / "m5_raw"
CLEAN_DIR = DATA_ROOT / "historical_data" / "m5_clean"
WIN_DIR   = DATA_ROOT / "processed_data" / "m5_windows"

META_DIR  = DATA_ROOT / "metadata"
SCHEMA_JSON = META_DIR / "schema_m5.json"
FILTERS_DIR  = META_DIR / "filters"
ELIGIBLE_PARQUET = FILTERS_DIR / "eligible_symbols_by_cost.parquet"
ELIGIBLE_TXT     = FILTERS_DIR / "eligible_symbols_by_cost.txt"

# Flags
FORCE_REWRITE_WINDOWS  = bool(globals().get("FORCE_REWRITE_WINDOWS", False))
TIMEZONE_IANA          = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# Ventanas (días; hasta AYER UTC)
WINDOWS = {"last_30d": 30, "last_90d": 90, "last_180d": 180}

# Parquet
PARQUET_COMP = "zstd"
PARQUET_STATS = True

# Progreso
PROGRESS_EVERY_FILES   = int(globals().get("PROGRESS_EVERY_FILES_WIN", 200))
PROGRESS_EVERY_SECONDS = float(globals().get("PROGRESS_EVERY_SECONDS_WIN", 2.0))

# ---------------------------------- Utils ----------------------------------
def _log(level: str, msg: str):
    ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{ts}] [{RUN_ID}] [{level}] [{CELL_LABEL}] {msg}", flush=True)

def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return "(instala 'tzdata' para TZ locales)"

def _schema_column_order() -> list[str]:
    try:
        obj = json.loads(SCHEMA_JSON.read_text(encoding="utf-8"))
        cols = obj.get("column_order")
        if cols: return cols
    except Exception:
        pass
    return ["timestamp_utc","symbol","open","high","low","close","tick_volume",
            "real_volume","spread_points","broker","server_tz"]

def _ensure_cols(df: pl.DataFrame, cols: list[str]) -> pl.DataFrame:
    miss = [c for c in cols if c not in df.columns]
    if miss:
        df = df.with_columns([pl.lit(None).alias(c) for c in miss])
    return df.select([c for c in cols if c in df.columns])

def _clean_day(df: pl.DataFrame, symbol: str) -> pl.DataFrame:
    cols = _schema_column_order()
    df = _ensure_cols(df, cols)

    casts = []
    for c in ["open","high","low","close","spread_points"]:
        if c in df.columns:
            casts.append(pl.col(c).cast(pl.Float64, strict=False).fill_nan(None))
    for c in ["tick_volume","real_volume","timestamp_utc"]:
        if c in df.columns:
            casts.append(pl.col(c).cast(pl.Float64, strict=False).fill_nan(None).cast(pl.Int64, strict=False))
    for c in ["symbol","broker","server_tz"]:
        if c in df.columns:
            casts.append(pl.col(c).cast(pl.Utf8, strict=False))
    df = df.with_columns(casts)

    df = df.with_columns(pl.lit(symbol).alias("symbol"))
    df = df.filter(pl.all_horizontal(pl.col(["timestamp_utc","open","high","low","close"]).is_not_null()))
    df = df.filter(pl.col("low") <= pl.col("high"))
    df = df.sort("timestamp_utc").unique(subset=["timestamp_utc"], keep="last")

    fin_cast = {
        "spread_points": pl.Float32,
        "open": pl.Float64, "high": pl.Float64, "low": pl.Float64, "close": pl.Float64,
        "tick_volume": pl.Int64, "real_volume": pl.Int64, "timestamp_utc": pl.Int64,
        "symbol": pl.Utf8, "broker": pl.Utf8, "server_tz": pl.Utf8,
    }
    df = df.with_columns([pl.col(k).cast(v, strict=False) for k, v in fin_cast.items() if k in df.columns])
    return _ensure_cols(df, cols)

def _symbols_from_dir(base: Path) -> list[str]:
    if not base.exists(): return []
    return sorted([p.name.split("=",1)[-1] for p in base.glob("symbol=*") if p.is_dir()])

def _day_from_name(name: str) -> Optional[str]:
    m = re.search(r"part=([0-9]{8})", name)
    return m.group(1) if m else None

def _ymd(d: date) -> str:
    return f"{d.year:04d}{d.month:02d}{d.day:02d}"

def _out_window_path(window_name: str, symbol: str, ymd: str) -> Path:
    return WIN_DIR / f"window={window_name}" / f"symbol={symbol}" / f"part={ymd}.parquet"

def _clean_path(symbol: str, ymd: str) -> Path:
    return CLEAN_DIR / f"symbol={symbol}" / f"year={ymd[:4]}" / f"month={ymd[4:6]}" / f"part={ymd}.parquet"

def _raw_path(symbol: str, ymd: str) -> Optional[Path]:
    p = RAW_DIR / f"symbol={symbol}" / f"year={ymd[:4]}" / f"month={ymd[4:6]}" / f"part={ymd}.parquet"
    return p if p.exists() else None

def _utc_ms_to_local_iso(ms: int) -> str:
    try:
        from zoneinfo import ZoneInfo
        dt = datetime.fromtimestamp(int(ms)/1000, tz=timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA))
        return dt.isoformat(timespec="seconds")
    except Exception:
        return datetime.fromtimestamp(int(ms)/1000, tz=timezone.utc).isoformat(timespec="seconds")

def _read_eligible_set() -> tuple[set[str] | None, str | None]:
    try:
        if ELIGIBLE_PARQUET.exists():
            df = pl.read_parquet(ELIGIBLE_PARQUET)
            col = "symbol" if "symbol" in df.columns else df.columns[0]
            return set(df[col].cast(pl.Utf8).to_list()), "parquet"
    except Exception:
        pass
    if ELIGIBLE_TXT.exists():
        s = set()
        for ln in ELIGIBLE_TXT.read_text(encoding="utf-8").splitlines():
            v = ln.strip()
            if v: s.add(v)
        return s, "txt"
    return None, None

# ---------------------------------- Header ----------------------------------
print("="*110)
print(f"Inicio Celda 12 — Materializaciones listas para filtrar | TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-"*110)
print(f"DATA_ROOT: {DATA_ROOT}")
print(f"Entradas preferidas: {CLEAN_DIR}  (fallback a {RAW_DIR} si falta algún día)")
print(f"Salida: {WIN_DIR}")
print("-"*110)

# ---------------------------------- Descubrimiento ----------------------------------
CLEAN_DIR.mkdir(parents=True, exist_ok=True)
WIN_DIR.mkdir(parents=True, exist_ok=True)
META_DIR.mkdir(parents=True, exist_ok=True)

syms_clean = _symbols_from_dir(CLEAN_DIR)
syms_raw   = _symbols_from_dir(RAW_DIR)

elig_set, elig_src = _read_eligible_set()
if elig_set is not None:
    print(f"Filtro 3B detectado ({elig_src}): símbolos elegibles={len(elig_set)}", flush=True)
else:
    print("Filtro 3B no encontrado; ventanas se construyen para todos los símbolos presentes.", flush=True)

print(f"Símbolos con clean: {len(syms_clean)} | símbolos con raw: {len(syms_raw)}", flush=True)

# ---------------------------------- Construcción de ventanas ----------------------------------
now_utc = datetime.now(timezone.utc)
end_day = (now_utc - timedelta(days=1)).date()  # ayer UTC

schema_cols = _schema_column_order()

def _build_window(window_name: str, n_days: int) -> Dict[str, object]:
    start_day = end_day - timedelta(days=n_days-1)
    expected = [_ymd(start_day + timedelta(days=i)) for i in range(n_days)]
    expected_set = set(expected)

    # Universo de símbolos
    symbols = syms_clean if syms_clean else syms_raw
    if elig_set is not None:
        symbols = [s for s in symbols if s in elig_set]

    files_written = 0
    bytes_written = 0

    qa_dups_flag_files = 0
    qa_nulls_flag_files = 0
    qa_bad_lowhigh_flag_files = 0

    written_paths: List[str] = []

    t0 = time.monotonic()
    last_beat = t0
    processed = 0

    _log("INFO", f"[{window_name}] símbolos a procesar: {len(symbols)} | días esperados por símbolo: {n_days}")

    # --- Escritura idempotente por símbolo/día con QA previa ---
    for si, symbol in enumerate(symbols, start=1):
        for ymd in expected:
            src_path = _clean_path(symbol, ymd)
            src_kind = "clean"
            if not src_path.exists():
                alt = _raw_path(symbol, ymd)
                if alt is None:
                    continue
                src_path = alt
                src_kind = "raw"

            dst = _out_window_path(window_name, symbol, ymd)
            if dst.exists() and not FORCE_REWRITE_WINDOWS:
                # No escribimos, pero contará para métricas finales
                processed += 1
                now = time.monotonic()
                if (processed % PROGRESS_EVERY_FILES == 0) or (now - last_beat >= PROGRESS_EVERY_SECONDS):
                    rate = processed / max(now - t0, 1e-6)
                    _log("INFO", f"[{window_name}] progreso: proc={processed} | escritos={files_written} | {rate:.1f} files/s")
                    last_beat = now
                continue

            try:
                df = pl.read_parquet(src_path)
                if src_kind == "raw":
                    df = _clean_day(df, symbol)  # normaliza y deduplica
                else:
                    df = _ensure_cols(df, schema_cols)

                # QA previa (archivo fuente)
                has_nulls = bool(df.select(pl.any_horizontal([pl.col(c).is_null() for c in ["timestamp_utc","open","high","low","close"]])).to_series()[0])
                bad_lh    = bool(df.select((pl.col("low") > pl.col("high")).any()).to_series()[0])
                dups_cnt  = int(df.height - df.select(pl.col("timestamp_utc").n_unique()).to_series()[0])

                if has_nulls: qa_nulls_flag_files += 1
                if bad_lh:    qa_bad_lowhigh_flag_files += 1
                if dups_cnt:  qa_dups_flag_files += 1

                # Si hay problemas, limpiar de forma robusta
                if has_nulls or bad_lh or dups_cnt:
                    df = _clean_day(df, symbol)

                # Post-limpieza: chequeo duro
                has_nulls2 = bool(df.select(pl.any_horizontal([pl.col(c).is_null() for c in ["timestamp_utc","open","high","low","close"]])).to_series()[0])
                bad_lh2    = bool(df.select((pl.col("low") > pl.col("high")).any()).to_series()[0])
                dups_cnt2  = int(df.height - df.select(pl.col("timestamp_utc").n_unique()).to_series()[0])

                if (not has_nulls2) and (not bad_lh2) and (dups_cnt2 == 0) and (df.height > 0):
                    dst.parent.mkdir(parents=True, exist_ok=True)
                    df.write_parquet(dst, compression=PARQUET_COMP, statistics=PARQUET_STATS)
                    files_written += 1
                    try:
                        bytes_written += dst.stat().st_size
                    except Exception:
                        pass
                    written_paths.append(str(dst))
                else:
                    _log("WARNING", f"[{window_name}] {symbol} {ymd}: QA no superada tras limpieza (omitido).")

            except Exception as e:
                _log("WARNING", f"[{window_name}] {symbol} {ymd}: error {e.__class__.__name__}")

            processed += 1
            now = time.monotonic()
            if (processed % PROGRESS_EVERY_FILES == 0) or (now - last_beat >= PROGRESS_EVERY_SECONDS):
                rate = processed / max(now - t0, 1e-6)
                _log("INFO", f"[{window_name}] progreso: proc={processed} | escritos={files_written} | {rate:.1f} files/s")
                last_beat = now

    # --- Cálculo de completitud y paths para métricas (incluye existentes) ---
    symbols_any = 0
    symbols_complete = 0
    symbols_partial = 0
    metric_paths: List[str] = []

    for symbol in symbols:
        present_after = 0
        for ymd in expected:
            p = _out_window_path(window_name, symbol, ymd)
            if p.exists():
                present_after += 1
                metric_paths.append(str(p))
        if present_after > 0:
            symbols_any += 1
            if present_after == len(expected):
                symbols_complete += 1
            else:
                symbols_partial += 1

    # Remover duplicados de metric_paths
    metric_paths = sorted(set(metric_paths))

    # --- Métricas agregadas (sobre TODA la ventana presente: escritos hoy + existentes) ---
    agg_rows = 0
    schema_dict = {}
    ts_min = None
    ts_max = None
    nulls_ohlc = 0
    dups_union = 0

    if metric_paths:
        lf = pl.scan_parquet(metric_paths, low_memory=True)

        schema_obj = lf.collect_schema()
        try:
            schema_dict = {k: str(v) for k, v in schema_obj.items()}
        except Exception:
            try:
                schema_dict = {k: str(v) for k, v in zip(schema_obj.names(), schema_obj.dtypes())}
            except Exception:
                schema_dict = {}

        # Duplicados UNION correctos por (symbol, timestamp_utc)
        dups_union_expr = (
            pl.len() - pl.concat_str([
                pl.col("symbol"),
                pl.lit("|"),
                pl.col("timestamp_utc").cast(pl.Utf8),
            ]).n_unique()
        ).alias("dups_union")

        agg = lf.select([
            pl.len().alias("rows"),
            pl.col("timestamp_utc").min().alias("ts_min"),
            pl.col("timestamp_utc").max().alias("ts_max"),
            dups_union_expr,
            pl.any_horizontal([pl.col(c).is_null() for c in ["open","high","low","close"]]).sum().alias("null_rows_ohlc"),
        ]).collect()

        agg_rows = int(agg["rows"][0])
        ts_min = None if agg["ts_min"][0] is None else int(agg["ts_min"][0])
        ts_max = None if agg["ts_max"][0] is None else int(agg["ts_max"][0])
        dups_union = int(agg["dups_union"][0])
        nulls_ohlc = int(agg["null_rows_ohlc"][0])

    return {
        "window": window_name,
        "days": n_days,
        "symbols_any": symbols_any,
        "symbols_complete": symbols_complete,
        "symbols_partial": symbols_partial,
        "files_written": files_written,
        "bytes_written": bytes_written,
        "agg_rows": agg_rows,
        "schema": schema_dict,
        "ts_min": ts_min,
        "ts_max": ts_max,
        "dups_union": dups_union,
        "nulls_ohlc": nulls_ohlc,
        "qa_inputs_flagged": {
            "files_with_nulls": qa_nulls_flag_files,
            "files_with_low_gt_high": qa_bad_lowhigh_flag_files,
            "files_with_dups": qa_dups_flag_files,
        }
    }

reports = []
for wname, nd in WINDOWS.items():
    reports.append(_build_window(wname, nd))

# ---------------------------------- Impresiones finales requeridas ----------------------------------
print("-"*110)
for rep in reports:
    print(f"Ventana: {rep['window']} (últimos {rep['days']} días) → {WIN_DIR / ('window=' + rep['window'])}")
    print(f"  - Símbolos con datos: {rep['symbols_any']} | COMPLETAS: {rep['symbols_complete']} | PARCIALES: {rep['symbols_partial']}")
    print(f"  - Archivos escritos: {rep['files_written']} | Bytes: {rep['bytes_written']} ({rep['bytes_written']/1048576:.2f} MiB)")
    print(f"  - Filas totales (ventana presente): {rep['agg_rows']}")
    if rep['schema']:
        print("  - Esquema:")
        for k, v in rep['schema'].items():
            print(f"      • {k}: {v}")
    if rep["ts_min"] is not None and rep["ts_max"] is not None:
        utc_min = datetime.fromtimestamp(rep["ts_min"]/1000, tz=timezone.utc).isoformat(timespec="seconds")
        utc_max = datetime.fromtimestamp(rep["ts_max"]/1000, tz=timezone.utc).isoformat(timespec="seconds")
        gye_min = _utc_ms_to_local_iso(rep["ts_min"])
        gye_max = _utc_ms_to_local_iso(rep["ts_max"])
        print(f"  - Rango UTC: {utc_min} → {utc_max}")
        print(f"  - Rango {TIMEZONE_IANA}: {gye_min} → {gye_max}")
    else:
        print("  - Rango: (sin filas)")
    print(f"  - QA union: duplicados (symbol,timestamp_utc) = {rep['dups_union']}  |  nulls críticos (OHLC) = {rep['nulls_ohlc']}")
    qaf = rep["qa_inputs_flagged"]
    print(f"  - QA entrada (antes de limpiar): files con nulls={qaf['files_with_nulls']}, low>high={qaf['files_with_low_gt_high']}, dups={qaf['files_with_dups']}")
    print("-"*110)

total_files = sum(r["files_written"] for r in reports)
total_bytes = sum(r["bytes_written"] for r in reports)
print(f"Total ventanas escritas: {total_files} archivos | {total_bytes} bytes ({total_bytes/1048576:.2f} MiB)")
print("✅ Materializaciones listas para filtrar (ventanas construidas con QA previa).")
# ========================================================================================================================
# Out:
# ==============================================================================================================
# Inicio Celda 12 — Materializaciones listas para filtrar | TZ local: America/Guayaquil
# Hora local: 2025-12-02T23:39:34-05:00 | Hora UTC: 2025-12-03T04:39:34+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT: C:\Quant\MT5_Data_Extraction\data
# Entradas preferidas: C:\Quant\MT5_Data_Extraction\data\historical_data\m5_clean  (fallback a C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw si falta algún día)
# Salida: C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows
# --------------------------------------------------------------------------------------------------------------
# Filtro 3B detectado (parquet): símbolos elegibles=107
# Símbolos con clean: 92 | símbolos con raw: 110
# [2025-12-02 23:39:34] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] símbolos a procesar: 89 | días esperados por símbolo: 30
# [2025-12-02 23:39:34] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=200 | escritos=22 | 711.7 files/s
# [2025-12-02 23:39:35] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=400 | escritos=43 | 775.2 files/s
# [2025-12-02 23:39:35] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=600 | escritos=72 | 685.7 files/s
# [2025-12-02 23:39:35] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=800 | escritos=110 | 588.7 files/s
# [2025-12-02 23:39:36] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=1000 | escritos=159 | 504.0 files/s
# [2025-12-02 23:39:36] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=1200 | escritos=181 | 533.3 files/s
# [2025-12-02 23:39:36] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=1400 | escritos=193 | 593.5 files/s
# [2025-12-02 23:39:37] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=1600 | escritos=217 | 605.8 files/s
# [2025-12-02 23:39:37] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=1800 | escritos=255 | 579.0 files/s
# [2025-12-02 23:39:38] [20251202_232253] [INFO] [12-M5-Windows] [last_30d] progreso: proc=2000 | escritos=301 | 563.9 files/s
# [2025-12-02 23:39:39] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] símbolos a procesar: 89 | días esperados por símbolo: 90
# [2025-12-02 23:39:39] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=200 | escritos=2 | 6451.6 files/s
# [2025-12-02 23:39:39] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=400 | escritos=5 | 6451.6 files/s
# [2025-12-02 23:39:39] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=600 | escritos=22 | 2955.7 files/s
# [2025-12-02 23:39:39] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=800 | escritos=39 | 2439.0 files/s
# [2025-12-02 23:39:39] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=1000 | escritos=41 | 2785.5 files/s
# [2025-12-02 23:39:39] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=1200 | escritos=43 | 3076.9 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=1400 | escritos=60 | 2718.4 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=1600 | escritos=70 | 2627.3 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=1800 | escritos=72 | 2880.0 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=2000 | escritos=89 | 2614.4 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=2200 | escritos=99 | 2657.0 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=2400 | escritos=116 | 2479.3 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=2600 | escritos=133 | 2411.9 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=2800 | escritos=138 | 2488.9 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=3000 | escritos=167 | 2207.5 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=3200 | escritos=177 | 2202.3 files/s
# [2025-12-02 23:39:40] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=3400 | escritos=179 | 2266.7 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=3600 | escritos=181 | 2328.6 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=3800 | escritos=184 | 2385.4 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=4000 | escritos=186 | 2461.5 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=4200 | escritos=204 | 2379.6 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=4400 | escritos=213 | 2387.4 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=4600 | escritos=216 | 2453.3 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=4800 | escritos=219 | 2518.4 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=5000 | escritos=229 | 2520.2 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=5200 | escritos=246 | 2465.6 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=5400 | escritos=263 | 2434.6 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=5600 | escritos=280 | 2405.5 files/s
# [2025-12-02 23:39:41] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=5800 | escritos=289 | 2426.8 files/s
# [2025-12-02 23:39:42] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=6000 | escritos=313 | 2341.9 files/s
# [2025-12-02 23:39:42] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=6200 | escritos=316 | 2391.1 files/s
# [2025-12-02 23:39:42] [20251202_232253] [INFO] [12-M5-Windows] [last_90d] progreso: proc=6400 | escritos=318 | 2453.0 files/s
# [2025-12-02 23:39:45] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] símbolos a procesar: 89 | días esperados por símbolo: 180
# [2025-12-02 23:39:45] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=200 | escritos=1 | 12500.0 files/s
# [2025-12-02 23:39:45] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=400 | escritos=2 | 12903.2 files/s
# [2025-12-02 23:39:45] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=600 | escritos=3 | 9523.8 files/s
# [2025-12-02 23:39:45] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=800 | escritos=5 | 5673.8 files/s
# [2025-12-02 23:39:45] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=1000 | escritos=6 | 5814.0 files/s
# [2025-12-02 23:39:45] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=1200 | escritos=22 | 3833.9 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=1400 | escritos=30 | 3580.6 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=1600 | escritos=39 | 3411.5 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=1800 | escritos=40 | 3711.3 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=2000 | escritos=41 | 4000.0 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=2200 | escritos=42 | 4263.6 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=2400 | escritos=43 | 4519.8 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=2600 | escritos=52 | 4262.3 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=2800 | escritos=60 | 4069.8 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=3000 | escritos=69 | 3916.4 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=3200 | escritos=70 | 4097.3 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=3400 | escritos=71 | 4266.0 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=3600 | escritos=72 | 4347.8 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=3800 | escritos=73 | 4502.4 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=4000 | escritos=89 | 4128.0 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=4200 | escritos=98 | 4073.7 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=4400 | escritos=99 | 4139.2 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=4600 | escritos=108 | 4031.6 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=4800 | escritos=116 | 3990.0 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=5000 | escritos=132 | 3765.1 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=5200 | escritos=133 | 3823.5 files/s
# [2025-12-02 23:39:46] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=5400 | escritos=134 | 3927.3 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=5600 | escritos=143 | 3894.3 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=5800 | escritos=151 | 3825.9 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=6000 | escritos=167 | 3656.3 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=6200 | escritos=175 | 3640.6 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=6400 | escritos=177 | 3688.8 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=6600 | escritos=178 | 3771.4 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=6800 | escritos=179 | 3850.5 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=7000 | escritos=181 | 3895.4 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=7200 | escritos=182 | 3971.3 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=7400 | escritos=183 | 4013.0 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=7600 | escritos=184 | 4086.0 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=7800 | escritos=186 | 4124.8 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=8000 | escritos=187 | 4197.3 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=8200 | escritos=192 | 4198.7 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=8400 | escritos=204 | 4103.6 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=8600 | escritos=213 | 4047.1 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=8800 | escritos=214 | 4110.2 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=9000 | escritos=215 | 4174.4 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=9200 | escritos=216 | 4235.7 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=9400 | escritos=218 | 4266.9 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=9600 | escritos=219 | 4326.3 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=9800 | escritos=228 | 4266.4 files/s
# [2025-12-02 23:39:47] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=10000 | escritos=229 | 4295.5 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=10200 | escritos=245 | 4183.8 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=10400 | escritos=247 | 4212.2 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=10600 | escritos=255 | 4188.1 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=10800 | escritos=271 | 4066.3 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=11000 | escritos=272 | 4092.3 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=11200 | escritos=281 | 4072.7 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=11400 | escritos=282 | 4099.2 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=11600 | escritos=297 | 4012.5 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=11800 | escritos=305 | 3995.9 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=12000 | escritos=314 | 3959.1 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=12200 | escritos=315 | 4003.9 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=12400 | escritos=317 | 4028.6 files/s
# [2025-12-02 23:39:48] [20251202_232253] [INFO] [12-M5-Windows] [last_180d] progreso: proc=12600 | escritos=318 | 4072.4 files/s
# --------------------------------------------------------------------------------------------------------------
# Ventana: last_30d (últimos 30 días) → C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows\window=last_30d
#   - Símbolos con datos: 89 | COMPLETAS: 29 | PARCIALES: 60
#   - Archivos escritos: 319 | Bytes: 3461802 (3.30 MiB)
#   - Filas totales (ventana presente): 549749
#   - Esquema:
#       • timestamp_utc: Int64
#       • timestamp_gye: Datetime(time_unit='ms', time_zone='America/Guayaquil')
#       • symbol: String
#       • open: Float64
#       • high: Float64
#       • low: Float64
#       • close: Float64
#       • tick_volume: Int64
#       • real_volume: Int64
#       • spread_points: Float32
#       • broker: String
#       • server_tz: String
#   - Rango UTC: 2025-11-03T00:05:00+00:00 → 2025-12-02T23:50:00+00:00
#   - Rango America/Guayaquil: 2025-11-02T19:05:00-05:00 → 2025-12-02T18:50:00-05:00
#   - QA union: duplicados (symbol,timestamp_utc) = 0  |  nulls críticos (OHLC) = 0
#   - QA entrada (antes de limpiar): files con nulls=0, low>high=0, dups=0
# --------------------------------------------------------------------------------------------------------------
# Ventana: last_90d (últimos 90 días) → C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows\window=last_90d
#   - Símbolos con datos: 89 | COMPLETAS: 0 | PARCIALES: 89
#   - Archivos escritos: 319 | Bytes: 3461802 (3.30 MiB)
#   - Filas totales (ventana presente): 1640659
#   - Esquema:
#       • timestamp_utc: Int64
#       • timestamp_gye: Datetime(time_unit='ms', time_zone='America/Guayaquil')
#       • symbol: String
#       • open: Float64
#       • high: Float64
#       • low: Float64
#       • close: Float64
#       • tick_volume: Int64
#       • real_volume: Int64
#       • spread_points: Float32
#       • broker: String
#       • server_tz: String
#   - Rango UTC: 2025-09-04T00:05:00+00:00 → 2025-12-02T23:50:00+00:00
#   - Rango America/Guayaquil: 2025-09-03T19:05:00-05:00 → 2025-12-02T18:50:00-05:00
#   - QA union: duplicados (symbol,timestamp_utc) = 0  |  nulls críticos (OHLC) = 0
#   - QA entrada (antes de limpiar): files con nulls=0, low>high=0, dups=0
# --------------------------------------------------------------------------------------------------------------
# Ventana: last_180d (últimos 180 días) → C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows\window=last_180d
#   - Símbolos con datos: 89 | COMPLETAS: 0 | PARCIALES: 89
#   - Archivos escritos: 319 | Bytes: 3461802 (3.30 MiB)
#   - Filas totales (ventana presente): 3292039
#   - Esquema:
#       • timestamp_utc: Int64
#       • timestamp_gye: Datetime(time_unit='ms', time_zone='America/Guayaquil')
#       • symbol: String
#       • open: Float64
#       • high: Float64
#       • low: Float64
#       • close: Float64
#       • tick_volume: Int64
#       • real_volume: Int64
#       • spread_points: Float32
#       • broker: String
#       • server_tz: String
#   - Rango UTC: 2025-06-06T00:05:00+00:00 → 2025-12-02T23:50:00+00:00
#   - Rango America/Guayaquil: 2025-06-05T19:05:00-05:00 → 2025-12-02T18:50:00-05:00
#   - QA union: duplicados (symbol,timestamp_utc) = 0  |  nulls críticos (OHLC) = 0
#   - QA entrada (antes de limpiar): files con nulls=0, low>high=0, dups=0
# --------------------------------------------------------------------------------------------------------------
# Total ventanas escritas: 957 archivos | 10385406 bytes (9.90 MiB)
# ✅ Materializaciones listas para filtrar (ventanas construidas con QA previa).

# %%
# ======================= Celda 12A — Data Quality Summary por símbolo (POLARS, ventanas M5) =======================
# Propósito:
#   - Leer ventanas M5 trading-ready (window=last_180d por defecto).
#   - Resumir por símbolo: cobertura temporal, % días presentes, % velas faltantes, gaps grandes.
#   - Construir un score homogéneo de calidad (0–100) y un flag ("OK", "WARNING", "BAD").
#   - Escribir: metadata/data_quality_summary.parquet
#   - Si algo falla en la lectura, escribir un archivo vacío y NO romper el pipeline.
#
# v2 — Ajuste por tipo de sesión (no penalizar acciones como si fueran 24h):
#   - Lee metadata/qa_operativa_summary.parquet (Celda 10).
#   - Usa expected_bars_per_day_symbol por símbolo como "velas esperadas" de referencia.
#   - Fallback limpio a EXPECTED_BARS_PER_DAY_M5 (288) si:
#       * falta expected_bars_per_day_symbol,
#       * o < 10 (valor raro).
#   - missing_candles_pct y days_with_large_gaps se calculan contra expected_bars_symbol,
#     no contra 288 fijo.
# =================================================================================================================

from __future__ import annotations
import os, json
from pathlib import Path
from datetime import datetime, timezone

try:
    import polars as pl
except Exception as e:
    raise RuntimeError("Se requiere 'polars' para la Celda 12A. Instálalo e intenta de nuevo.") from e

# ---------------------------------- Config y rutas ----------------------------------
CELL_LABEL = "12A-DataQuality"
RUN_ID = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))
TIMEZONE_IANA = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# Para evitar líos de tz, usamos un offset fijo UTC→local (Ecuador = UTC-5, sin DST)
LOCAL_OFFSET_HOURS = int(globals().get("TIMEZONE_UTC_OFFSET_HOURS", -5))

DATA_ROOT = Path(globals().get("DATA_ROOT", str(path_contract.data_root()))).resolve()
WIN_DIR   = DATA_ROOT / "processed_data" / "m5_windows"
META_DIR  = DATA_ROOT / "metadata"
META_DIR.mkdir(parents=True, exist_ok=True)

DQ_PATH          = META_DIR / "data_quality_summary.parquet"
QA_SUMMARY_PATH  = META_DIR / "qa_operativa_summary.parquet"   # ← salida de Celda 10

# Ventana base para evaluar calidad (por defecto last_180d)
WINDOW_BASE_NAME = globals().get("DATA_QUALITY_WINDOW_BASE", "last_180d")
WINDOW_BASE_DIR  = WIN_DIR / f"window={WINDOW_BASE_NAME}"

# Parámetros de calidad
#   - EXPECTED_BARS_PER_DAY_M5 se convierte ahora en "fallback global" 24h (ej. FX).
#   - BIG_GAP_THRESHOLD: fracción mínima de velas en un día para NO considerarlo "gap grande".
EXPECTED_BARS_PER_DAY = int(globals().get("EXPECTED_BARS_PER_DAY_M5", 288))
BIG_GAP_THRESHOLD     = float(globals().get("BIG_GAP_THRESHOLD_FRACTION", 0.7))  # gap grande si candles < expected_bars_symbol * 0.7

# ---------------------------------- Utils ----------------------------------
def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return "(instala 'tzdata' para TZ locales)"

def _log(level: str, msg: str):
    ts = _now_local_iana()
    print(f"[{ts}] [{RUN_ID}] [{level}] [{CELL_LABEL}] {msg}", flush=True)

def _write_empty_summary(reason: str | None = None):
    """
    Escribe un parquet vacío pero con el esquema esperado, para no romper el pipeline.
    """
    schema = {
        "symbol": pl.String,
        "first_date": pl.Date,
        "last_date": pl.Date,
        "days_with_data": pl.Int32,
        "days_expected": pl.Int32,
        "coverage_days": pl.Float64,
        "total_candles": pl.Int64,
        "days_with_large_gaps": pl.Int32,
        "missing_candles_pct": pl.Float64,
        "bad_days_ratio": pl.Float64,
        "data_quality_score": pl.Float64,
        "data_quality_flag": pl.String,
        "comentario": pl.String,
    }
    df_empty = pl.DataFrame(schema=schema)
    df_empty.write_parquet(DQ_PATH, compression="zstd", statistics=True)
    print(f"Archivo vacío escrito en: {DQ_PATH}")
    if reason:
        print(f"Motivo: {reason}")
    print("⚠️ Celda 12A finalizada con error en lectura/agrupación, pero sin romper pipeline.")

def _ensure_ts_utc_datetime(df: pl.DataFrame) -> pl.DataFrame:
    """
    Normaliza la columna 'timestamp_utc' a Datetime(us) sin zona horaria,
    y la expone como 'ts_utc'.
    Soporta:
      - Datetime con o sin tz.
      - Int/Float (epoch, asumimos us por defecto).
      - Utf8 (ISO u otros formatos parseables).
    """
    if "timestamp_utc" not in df.columns:
        raise ValueError("El parquet no contiene columna 'timestamp_utc'.")

    dt = df.schema["timestamp_utc"]

    # Caso 1: ya es Datetime
    if isinstance(dt, pl.datatypes.Datetime):
        # Elimina tz si existe y fuerza a us
        return df.with_columns(
            pl.col("timestamp_utc")
            .dt.replace_time_zone(None)
            .cast(pl.Datetime("us"))
            .alias("ts_utc")
        )

    # Caso 2: numérico → epoch
    if dt in (pl.Int64, pl.Int32, pl.UInt64, pl.UInt32, pl.Float64, pl.Float32):
        # Asumimos microsegundos; si fuera ms, el error será muy pequeño para esta celda
        return df.with_columns(
            pl.from_epoch(pl.col("timestamp_utc"), time_unit="us")
            .cast(pl.Datetime("us"))
            .alias("ts_utc")
        )

    # Caso 3: texto → intentar parseo laxo
    if dt == pl.Utf8:
        return df.with_columns(
            pl.col("timestamp_utc")
            .str.strptime(pl.Datetime, strict=False, time_unit="us")
            .alias("ts_utc")
        )

    # Fallback: intentar cast directo
    return df.with_columns(
        pl.col("timestamp_utc").cast(pl.Datetime("us")).alias("ts_utc")
    )

def _read_qa_operativa_summary(path: Path) -> pl.DataFrame | None:
    """
    Lee qa_operativa_summary.parquet (Celda 10) y devuelve:
        symbol, expected_bars_per_day_symbol, session_type

    Si no está disponible, o no tiene columnas mínimas, devuelve None
    y la celda usará EXPECTED_BARS_PER_DAY como fallback global.
    """
    if not path.exists():
        _log("WARNING", f"No se encontró {path}; se usará EXPECTED_BARS_PER_DAY_M5={EXPECTED_BARS_PER_DAY} para todos los símbolos.")
        return None
    try:
        df = pl.read_parquet(path)
    except Exception as e:
        _log("WARNING", f"No se pudo leer {path}: {e}; se usará EXPECTED_BARS_PER_DAY_M5={EXPECTED_BARS_PER_DAY}.")
        return None

    if df.is_empty():
        _log("WARNING", f"{path} está vacío; se usará EXPECTED_BARS_PER_DAY_M5={EXPECTED_BARS_PER_DAY}.")
        return None

    cols = df.columns

    # Asegurar columna expected_bars_per_day_symbol: si no está, derivar de n_bars_p50 (Celda 10 v4)
    if "expected_bars_per_day_symbol" not in cols:
        if "n_bars_p50" in cols:
            df = df.with_columns(
                pl.col("n_bars_p50").alias("expected_bars_per_day_symbol")
            )
            _log("INFO", "Columna 'expected_bars_per_day_symbol' no encontrada en qa_operativa_summary; se derivó desde 'n_bars_p50'.")
        else:
            _log("WARNING", "qa_operativa_summary no contiene 'expected_bars_per_day_symbol' ni 'n_bars_p50'; se usará EXPECTED_BARS_PER_DAY_M5 global.")
            return None

    # Asegurar session_type (para posibles usos posteriores, aunque aquí no se persista)
    if "session_type" not in cols:
        df = df.with_columns(pl.lit("UNKNOWN_SESSION").alias("session_type"))

    return df.select(["symbol", "expected_bars_per_day_symbol", "session_type"])

# ---------------------------------- Header ----------------------------------
print("="*110)
print(f"Inicio Celda 12A — Data Quality Summary por símbolo | TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-"*110)
print(f"DATA_ROOT: {DATA_ROOT}")
print(f"Ventanas M5 (origen calidad): {WIN_DIR}")
print(f"Metadata: {META_DIR}")
print("-"*110)
print(f"Ventana base seleccionada: {WINDOW_BASE_NAME} → {WINDOW_BASE_DIR}")

# ---------------------------------- Lógica principal ----------------------------------
if not WINDOW_BASE_DIR.exists():
    _log("ERROR", f"No existe la carpeta de ventanas base: {WINDOW_BASE_DIR}")
    _write_empty_summary(f"Carpeta de ventana base inexistente: {WINDOW_BASE_DIR}")
else:
    # Recolectar todos los archivos part=*.parquet de todos los símbolos
    pattern = "symbol=*/part=*.parquet"
    all_files = sorted(WINDOW_BASE_DIR.glob(pattern))

    if not all_files:
        _log("WARNING", f"No se encontraron archivos con patrón {pattern} en {WINDOW_BASE_DIR}")
        _write_empty_summary("Ventana base sin archivos de datos.")
    else:
        try:
            _log("INFO", f"Número de archivos encontrados para calidad M5 = {len(all_files)}")
            day_frames: list[pl.DataFrame] = []
            files_ok = 0
            files_skipped = 0

            for fp in all_files:
                # Derivar símbolo desde la carpeta, por si el parquet no lo trae
                sym_from_dir = fp.parent.name
                if sym_from_dir.startswith("symbol="):
                    sym_from_dir = sym_from_dir.split("=", 1)[1]
                sym_from_dir = sym_from_dir.strip().upper()

                try:
                    # Leemos SOLO lo necesario para esta celda (symbol, timestamp_utc)
                    df = pl.read_parquet(str(fp), columns=["symbol", "timestamp_utc"])
                except Exception as e:
                    files_skipped += 1
                    _log("WARN", f"Error leyendo {fp}: {e.__class__.__name__}: {e} — archivo omitido.")
                    continue

                if df.is_empty():
                    files_skipped += 1
                    continue

                # Normalizar timestamp_utc a Datetime(us) sin tz → ts_utc
                try:
                    df = _ensure_ts_utc_datetime(df)
                except Exception as e:
                    files_skipped += 1
                    _log("WARN", f"Error normalizando timestamp_utc en {fp}: {e.__class__.__name__}: {e} — archivo omitido.")
                    continue

                # Normalizar symbol y derivar trading_day (usando ts_utc con offset fijo a local)
                df = df.with_columns([
                    pl.when(pl.col("symbol").is_null())
                      .then(pl.lit(sym_from_dir))
                      .otherwise(pl.col("symbol"))
                      .cast(pl.Utf8)
                      .str.to_uppercase()
                      .alias("symbol"),
                    (pl.col("ts_utc") + pl.duration(hours=LOCAL_OFFSET_HOURS))
                        .dt.date()
                        .alias("trading_day"),
                ])

                # Agregar por símbolo y día en este archivo
                df_day_file = (
                    df.group_by(["symbol", "trading_day"])
                      .agg([
                          pl.len().alias("candles"),  # pl.count() → pl.len() para evitar deprecation
                      ])
                )

                if not df_day_file.is_empty():
                    day_frames.append(df_day_file)
                    files_ok += 1

            _log("INFO", f"Archivos procesados OK = {files_ok}, archivos omitidos = {files_skipped}")

            if not day_frames:
                _log("WARNING", "Después de procesar archivos no hay datos agregados por día; escribiendo resumen vacío.")
                _write_empty_summary("Sin métricas por símbolo (no se pudo agregar por día).")
            else:
                # Concatenar todos los agregados por día
                df_day = pl.concat(day_frames, how="vertical_relaxed")

                # ---------------- Enriquecer con perfil de sesión desde Celda 10 ----------------
                qa_sym = _read_qa_operativa_summary(QA_SUMMARY_PATH)

                if qa_sym is None:
                    # Fallback: todos con EXPECTED_BARS_PER_DAY (ej. 288) como velas esperadas
                    _log(
                        "INFO",
                        f"Usando EXPECTED_BARS_PER_DAY_M5={EXPECTED_BARS_PER_DAY} como expected_bars_symbol para todos los símbolos (sin perfil de sesión)."
                    )
                    df_day = df_day.with_columns(
                        pl.lit(EXPECTED_BARS_PER_DAY).alias("expected_bars_symbol")
                    )
                else:
                    _log(
                        "INFO",
                        "Usando 'expected_bars_per_day_symbol' de qa_operativa_summary como perfil de sesión por símbolo."
                    )
                    df_day = (
                        df_day.join(qa_sym, on="symbol", how="left")
                              .with_columns([
                                  pl.when(
                                      pl.col("expected_bars_per_day_symbol").is_null()
                                      | (pl.col("expected_bars_per_day_symbol") < 10)
                                  )
                                  .then(pl.lit(EXPECTED_BARS_PER_DAY))
                                  .otherwise(pl.col("expected_bars_per_day_symbol"))
                                  .alias("expected_bars_symbol"),
                              ])
                    )
                # -------------------------------------------------------------------------

                # Agregar por símbolo para métricas finales (usando expected_bars_symbol por símbolo)
                _log("INFO", "Resumiendo métricas de calidad por símbolo (ajustadas a expected_bars_symbol)...")

                df_sym = (
                    df_day.group_by("symbol")
                    .agg([
                        pl.col("trading_day").min().alias("first_day"),
                        pl.col("trading_day").max().alias("last_day"),
                        pl.col("trading_day").n_unique().alias("days_with_data"),
                        pl.col("candles").sum().alias("total_candles"),
                        pl.col("candles").mean().alias("avg_candles_per_day"),
                        pl.col("expected_bars_symbol").first().alias("expected_bars_symbol"),
                        (pl.col("candles") < pl.col("expected_bars_symbol") * BIG_GAP_THRESHOLD)
                            .sum()
                            .alias("days_with_large_gaps"),
                    ])
                )

                if df_sym.height == 0:
                    _log("WARNING", "Después de agrupar por símbolo no quedaron filas; escribiendo resumen vacío.")
                    _write_empty_summary("Sin métricas por símbolo.")
                else:
                    # Paso 4: métricas derivadas + score
                    # days_expected = (last_day - first_day) + 1, usando representación interna de Date (días desde epoch)
                    df_sym = df_sym.with_columns([
                        (
                            (
                                pl.col("last_day").cast(pl.Date).cast(pl.Int64)
                                - pl.col("first_day").cast(pl.Date).cast(pl.Int64)
                            ) + 1
                        )
                        .clip(1, None)   # min=1, max=None
                        .cast(pl.Int32)
                        .alias("days_expected"),
                    ])

                    df_sym = df_sym.with_columns([
                        (pl.col("days_with_data") / pl.col("days_expected")).alias("coverage_days"),

                        # missing_candles_pct medido contra expected_bars_symbol (perfil de sesión),
                        # con fallback ya resuelto en expected_bars_symbol.
                        pl.when(pl.col("days_with_data") > 0)
                          .then(
                              1.0 - (
                                  pl.col("total_candles")
                                  / (pl.col("days_with_data") * pl.col("expected_bars_symbol"))
                              )
                          )
                          .otherwise(1.0)
                          .clip(0.0, 1.0)   # min=0.0, max=1.0
                          .alias("missing_candles_pct"),

                        # bad_days_ratio: días con "gap grande" sobre días con datos,
                        # donde "gap grande" ya se midió vs expected_bars_symbol * BIG_GAP_THRESHOLD.
                        pl.when(pl.col("days_with_data") > 0)
                          .then(pl.col("days_with_large_gaps") / pl.col("days_with_data"))
                          .otherwise(1.0)
                          .clip(0.0, 1.0)   # min=0.0, max=1.0
                          .alias("bad_days_ratio"),
                    ])

                    df_sym = df_sym.with_columns([
                        (
                            (
                                0.6 * pl.col("coverage_days")
                                + 0.3 * (1.0 - pl.col("missing_candles_pct"))
                                + 0.1 * (1.0 - pl.col("bad_days_ratio"))
                            ) * 100.0
                        )
                        .clip(0.0, 100.0)   # min=0.0, max=100.0
                        .round(2)
                        .alias("data_quality_score")
                    ])

                    # Primero creamos data_quality_flag SOLO en base al score
                    df_sym = df_sym.with_columns([
                        pl.when(pl.col("data_quality_score") >= 90.0)
                          .then(pl.lit("OK"))
                          .when(pl.col("data_quality_score") >= 70.0)
                          .then(pl.lit("WARNING"))
                          .otherwise(pl.lit("BAD"))
                          .alias("data_quality_flag")
                    ])

                    # Luego, en un segundo with_columns, creamos comentario (ya existe data_quality_flag)
                    df_sym = df_sym.with_columns([
                        pl.when(pl.col("data_quality_flag") == pl.lit("OK"))
                          .then(pl.lit("Cobertura y completitud altas; apto para trading."))
                          .when(pl.col("data_quality_flag") == pl.lit("WARNING"))
                          .then(pl.lit("Cobertura/velas con algunas carencias; revisar antes de usar con size alto."))
                          .otherwise(pl.lit("Datos con huecos importantes; usar sólo para exploración."))
                          .alias("comentario")
                    ])

                    # Ajustes de tipos para ser coherentes con el esquema "vacío"
                    df_sym = df_sym.with_columns([
                        pl.col("days_with_data").cast(pl.Int32),
                        pl.col("days_expected").cast(pl.Int32),
                        pl.col("days_with_large_gaps").cast(pl.Int32),
                        pl.col("total_candles").cast(pl.Int64),
                    ])

                    # Salida: mantenemos el MISMO esquema que la versión anterior (no exponemos expected_bars_symbol aquí)
                    df_out = (
                        df_sym
                        .select([
                            pl.col("symbol"),
                            pl.col("first_day").alias("first_date"),
                            pl.col("last_day").alias("last_date"),
                            pl.col("days_with_data"),
                            pl.col("days_expected"),
                            pl.col("coverage_days"),
                            pl.col("total_candles"),
                            pl.col("days_with_large_gaps"),
                            pl.col("missing_candles_pct"),
                            pl.col("bad_days_ratio"),
                            pl.col("data_quality_score"),
                            pl.col("data_quality_flag"),
                            pl.col("comentario"),
                        ])
                        .sort("symbol")
                    )

                    df_out.write_parquet(DQ_PATH, compression="zstd", statistics=True)
                    print(f"Archivo de resumen de calidad escrito en: {DQ_PATH}")
                    print(f"Símbolos evaluados: {df_out.height}")
                    print("Preview (primeros 10 símbolos):")
                    print(df_out.head(10))
                    print("✅ Celda 12A — Data Quality Summary (ajustada por tipo de sesión) completada correctamente.")

        except Exception as e:
            _log("ERROR", f"Error al leer/agrupar ventanas M5: {e.__class__.__name__}: {e}")
            _write_empty_summary(str(e))

# =================================================================================================================
# Out:
# ==============================================================================================================
# Inicio Celda 12A — Data Quality Summary por símbolo | TZ local: America/Guayaquil
# Hora local: 2025-12-02T23:39:57-05:00 | Hora UTC: 2025-12-03T04:39:57+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT: C:\Quant\MT5_Data_Extraction\data
# Ventanas M5 (origen calidad): C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows
# Metadata: C:\Quant\MT5_Data_Extraction\data\metadata
# --------------------------------------------------------------------------------------------------------------
# Ventana base seleccionada: last_180d → C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows\window=last_180d
# [2025-12-02T23:39:58-05:00] [20251202_232253] [INFO] [12A-DataQuality] Número de archivos encontrados para calidad M5 = 16073
# [2025-12-02T23:40:43-05:00] [20251202_232253] [INFO] [12A-DataQuality] Archivos procesados OK = 16073, archivos omitidos = 0
# [2025-12-02T23:40:43-05:00] [20251202_232253] [INFO] [12A-DataQuality] Usando 'expected_bars_per_day_symbol' de qa_operativa_summary como perfil de sesión por símbolo.
# [2025-12-02T23:40:43-05:00] [20251202_232253] [INFO] [12A-DataQuality] Resumiendo métricas de calidad por símbolo (ajustadas a expected_bars_symbol)...
# Archivo de resumen de calidad escrito en: C:\Quant\MT5_Data_Extraction\data\metadata\data_quality_summary.parquet
# Símbolos evaluados: 108
# Preview (primeros 10 símbolos):
# shape: (10, 13)
# ┌────────┬────────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ symbol ┆ first_date ┆ last_date  ┆ days_with ┆ … ┆ bad_days_ ┆ data_qual ┆ data_qual ┆ comentari │
# │ ---    ┆ ---        ┆ ---        ┆ _data     ┆   ┆ ratio     ┆ ity_score ┆ ity_flag  ┆ o         │
# │ str    ┆ date       ┆ date       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │        ┆            ┆            ┆ i32       ┆   ┆ f64       ┆ f64       ┆ str       ┆ str       │
# ╞════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ AAPL   ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 1.0       ┆ 90.0      ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# │ AAVUSD ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 1.0       ┆ 90.0      ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# │ ADAUSD ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 1.0       ┆ 90.0      ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# │ AIRF   ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 1.0       ┆ 90.0      ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# │ ALGUSD ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 1.0       ┆ 90.0      ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# │ ALVG   ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 0.0       ┆ 100.0     ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# │ AMZN   ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 1.0       ┆ 90.0      ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# │ AUDCAD ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 1.0       ┆ 90.0      ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# │ AUDCHF ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 1.0       ┆ 90.0      ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# │ AUDJPY ┆ 1970-01-21 ┆ 1970-01-21 ┆ 1         ┆ … ┆ 1.0       ┆ 90.0      ┆ OK        ┆ Cobertura │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ y complet │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ itud      │
# │        ┆            ┆            ┆           ┆   ┆           ┆           ┆           ┆ altas;…   │
# └────────┴────────────┴────────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# ✅ Celda 12A — Data Quality Summary (ajustada por tipo de sesión) completada correctamente.

# %%
# ======================= Celda 12B — Universe snapshot M5 (QA + DQ + 3B + QA económica) =======================
# Propósito:
#   - Combinar:
#       * metadata/qa_operativa_summary.parquet  (Celda 10, QA operativa + perfil de sesión + qa_struct_flag + qa_price_flag)
#       * metadata/data_quality_summary.parquet (Celda 12A, calidad de ventanas last_180d)
#       * filters/eligible_symbols_by_cost.*    (lista 3B de símbolos elegibles por coste)
#   - Construir un “universe snapshot” por símbolo, con:
#       * Símbolos auditados en QA (Celda 10).
#       * Campos QA (qa_operativa_flag, qa_price_flag, qa_struct_flag, session_type, expected_bars_per_day_symbol, etc.).
#       * Campos de calidad de datos (data_quality_score, data_quality_flag, coverage_days, etc.).
#       * Campo de selección final:
#             universe_flag ∈ {"IN", "OUT"}
#         basado en QA + QA económica + DQ + estructura + 3B.
#       * Copia explícita de qa_struct_flag como qa_struct_flag_qa para la Celda 12C.
#   - Escribir:
#       * metadata/universe_snapshot_{RUN_ID}.parquet
#
# Notas de diseño (v2 parchada):
#   - No rompe el pipeline si falta data_quality_summary: en ese caso se construye el universo sólo con QA,
#     marcando data_quality_flag="MISSING" y data_quality_score=0.0 (y universe_flag se puede relajar vía parámetros).
#   - Usa los mismos filtros 3B que Celda 10 y Celda 12 (eligible_symbols_by_cost.{parquet,txt}).
#   - Es totalmente compatible con Celda 12C:
#       * La columna 'symbol' siempre está presente.
#       * Incluye 'qa_struct_flag' y 'qa_struct_flag_qa'.
#       * universe_flag hoy no se usa en 12C, pero queda listo para el siguiente notebook.
#
# Nota sobre sesgo de supervivencia:
#   - Este universe_snapshot se construye "as of RUN_ID" usando:
#       * QA operativa (Celda 10, sobre todo el histórico disponible).
#       * Data Quality last_180d (Celda 12A).
#       * Filtro de costes 3B actual (Celda 05).
#   - Si usas este universe_snapshot para backtests en 2018–2021, estás testeando
#     sobre el universo que HOY sobrevive (sesgo de supervivencia aceptado por diseño).
# =================================================================================================

from __future__ import annotations
from pathlib import Path
from datetime import datetime, timezone
from typing import Tuple, Optional, Set

import polars as pl

# ---------------------------------- Identidad / paths ----------------------------------
CELL_LABEL = "12B-Universe-Snapshot"
RUN_ID     = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))

# DATA_ROOT viene de la Celda 02 (igual que en 10, 12, 12A, 12C)
if "DATA_ROOT" not in globals():
    raise RuntimeError("DATA_ROOT no está definido. Ejecuta la Celda 02 antes de la Celda 12B.")

DATA_ROOT = Path(globals()["DATA_ROOT"]).resolve()

META_DIR     = DATA_ROOT / "metadata"
FILTERS_DIR  = META_DIR / "filters"

QA_SUMMARY_PATH = META_DIR / "qa_operativa_summary.parquet"   # salida Celda 10
DQ_PATH         = META_DIR / "data_quality_summary.parquet"   # salida Celda 12A

ELIGIBLE_PARQUET = FILTERS_DIR / "eligible_symbols_by_cost.parquet"
ELIGIBLE_TXT     = FILTERS_DIR / "eligible_symbols_by_cost.txt"

UNIVERSE_PATH        = META_DIR / f"universe_snapshot_{RUN_ID}.parquet"
UNIVERSE_LATEST_PATH = META_DIR / "universe_snapshot_latest.parquet"

TIMEZONE_IANA = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# Parámetros de selección de universo (ajustables en Celda 02)
# Flags de QA operativa aceptados en el universo
UNIVERSE_KEEP_QA_FLAGS      = list(globals().get("UNIVERSE_KEEP_QA_FLAGS", ["OK", "WARN"]))

# Flags de Data Quality aceptados en el universo
UNIVERSE_KEEP_DQ_FLAGS      = list(globals().get("UNIVERSE_KEEP_DQ_FLAGS", ["OK", "WARNING"]))

# Excluir símbolos con problemas estructurales serios
UNIVERSE_EXCLUDE_BAD_STRUCT = bool(globals().get("UNIVERSE_EXCLUDE_BAD_STRUCT", True))

# Mínimo score de Data Quality para estar en universo
UNIVERSE_MIN_DQ_SCORE       = float(globals().get("UNIVERSE_MIN_DQ_SCORE", 60.0))

# <<< NEW QA ECON >>> Flags de QA económica aceptados en el universo
UNIVERSE_KEEP_PRICE_QA_FLAGS = list(globals().get("UNIVERSE_KEEP_PRICE_QA_FLAGS", ["OK", "WARN"]))

PARQUET_COMP_UNIVERSE = globals().get("PARQUET_COMP_UNIVERSE", "zstd")

# ---------------------------------- Utils / logging ----------------------------------
def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return datetime.now(timezone.utc).isoformat(timespec="seconds")

def _log(level: str, msg: str):
    ts = _now_local_iana()
    print(f"[{ts}] [{RUN_ID}] [{level}] [{CELL_LABEL}] {msg}", flush=True)

def _read_eligible_set() -> Tuple[Optional[Set[str]], Optional[str]]:
    """
    Lee la lista 3B de símbolos elegibles por coste.
    - Primero intenta parquet.
    - Si falla o no existe, intenta TXT.
    - Devuelve (set_de_símbolos, origen) o (None, None) si no hay lista.
    """
    # parquet
    try:
        if ELIGIBLE_PARQUET.exists():
            df = pl.read_parquet(ELIGIBLE_PARQUET)
            col = "symbol" if "symbol" in df.columns else df.columns[0]
            syms = (
                df.get_column(col)
                  .cast(pl.Utf8, strict=False)
                  .str.strip_chars()
                  .str.to_uppercase()
                  .drop_nulls()
                  .to_list()
            )
            syms = [s for s in syms if s]
            return set(syms), "parquet"
    except Exception as e:
        _log("WARNING", f"No se pudo leer {ELIGIBLE_PARQUET}: {e}. Probando TXT...")

    # txt
    try:
        if ELIGIBLE_TXT.exists():
            txt = ELIGIBLE_TXT.read_text(encoding="utf-8", errors="ignore")
            syms = []
            for ln in txt.splitlines():
                v = ln.strip()
                if not v:
                    continue
                syms.append(v.upper())
            return set(syms), "txt"
    except Exception as e:
        _log("WARNING", f"No se pudo leer {ELIGIBLE_TXT}: {e}.")

    return None, None

# ---------------------------------- Header ----------------------------------
print("=" * 110)
print(f"Inicio Celda 12B — Universe snapshot M5 | TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-" * 110)
print(f"DATA_ROOT              : {DATA_ROOT}")
print(f"QA summary (Celda 10)  : {QA_SUMMARY_PATH}")
print(f"DQ summary (Celda 12A) : {DQ_PATH}")
print(f"3B filters (eligible)  : {FILTERS_DIR}")
print(f"Universe OUT path      : {UNIVERSE_PATH}")
print("-" * 110)
print("Parámetros de selección de universo:")
print(f"  UNIVERSE_KEEP_QA_FLAGS        = {UNIVERSE_KEEP_QA_FLAGS}")
print(f"  UNIVERSE_KEEP_DQ_FLAGS        = {UNIVERSE_KEEP_DQ_FLAGS}")
print(f"  UNIVERSE_EXCLUDE_BAD_STRUCT   = {UNIVERSE_EXCLUDE_BAD_STRUCT}")
print(f"  UNIVERSE_MIN_DQ_SCORE         = {UNIVERSE_MIN_DQ_SCORE}")
print(f"  UNIVERSE_KEEP_PRICE_QA_FLAGS  = {UNIVERSE_KEEP_PRICE_QA_FLAGS}")  # <<< NEW QA ECON >>>
print(f"  PARQUET_COMP_UNIVERSE         = '{PARQUET_COMP_UNIVERSE}'")
print("-" * 110)

META_DIR.mkdir(parents=True, exist_ok=True)
FILTERS_DIR.mkdir(parents=True, exist_ok=True)

# ---------------------------------- Guardas básicas ----------------------------------
if not QA_SUMMARY_PATH.exists():
    msg = f"No se encontró qa_operativa_summary.parquet en: {QA_SUMMARY_PATH}. Ejecuta la Celda 10 antes de 12B."
    _log("ERROR", msg)
    raise FileNotFoundError(msg)

# DQ es deseable pero no estrictamente obligatorio
dq_available = DQ_PATH.exists()

# ---------------------------------- Lectura de QA y normalización ----------------------------------
qa = pl.read_parquet(QA_SUMMARY_PATH)

if qa.is_empty():
    msg = "qa_operativa_summary.parquet está vacío; no hay símbolos auditados en QA. Universe snapshot no tiene sentido."
    _log("ERROR", msg)
    raise RuntimeError(msg)

# Normalizar símbolo en QA
qa = qa.with_columns(
    pl.col("symbol")
      .cast(pl.Utf8, strict=False)
      .str.strip_chars()
      .str.to_uppercase()
      .alias("symbol")
)

n_qa_syms = qa.get_column("symbol").n_unique()
_log("INFO", f"Símbolos en QA operativa (Celda 10): {n_qa_syms}")

# Asegurar columnas clave de QA (por compatibilidad futura)
if "qa_operativa_flag" not in qa.columns:
    raise RuntimeError("qa_operativa_summary.parquet no contiene columna 'qa_operativa_flag' (Celda 10).")

if "qa_struct_flag" not in qa.columns:
    # En el peor caso, creamos un flag neutro para no romper 12C
    _log("WARNING", "qa_operativa_summary no contiene 'qa_struct_flag'; se crea 'qa_struct_flag'='WARN_STRUCT' para todos.")
    qa = qa.with_columns(
        pl.lit("WARN_STRUCT").alias("qa_struct_flag")
    )

if "session_type" not in qa.columns:
    _log("WARNING", "qa_operativa_summary no contiene 'session_type'; se crea 'session_type'='UNKNOWN_SESSION'.")
    qa = qa.with_columns(
        pl.lit("UNKNOWN_SESSION").alias("session_type")
    )

if "expected_bars_per_day_symbol" not in qa.columns:
    _log("WARNING", "qa_operativa_summary no contiene 'expected_bars_per_day_symbol'; se crea con n_bars_p50 o fallback a 288.")
    if "n_bars_p50" in qa.columns:
        qa = qa.with_columns(
            pl.col("n_bars_p50").alias("expected_bars_per_day_symbol")
        )
    else:
        expected_default = int(globals().get("EXPECTED_BARS_M5", 288))
        qa = qa.with_columns(
            pl.lit(expected_default).alias("expected_bars_per_day_symbol")
        )

# <<< NEW QA ECON >>> asegurar columna qa_price_flag (para backward compatibility)
if "qa_price_flag" not in qa.columns:
    _log("WARNING", "qa_operativa_summary no contiene 'qa_price_flag'; se crea 'qa_price_flag'='OK' para todos.")
    qa = qa.with_columns(
        pl.lit("OK").alias("qa_price_flag")
    )

# ---------------------------------- Lectura de DQ (Data Quality) ----------------------------------
dq = None
if dq_available:
    try:
        dq = pl.read_parquet(DQ_PATH)
        if dq.is_empty():
            _log("WARNING", f"{DQ_PATH} está vacío; se usará data_quality_flag='MISSING' y score=0.0 en todo el universo.")
            dq = None
        else:
            dq = dq.with_columns(
                pl.col("symbol")
                  .cast(pl.Utf8, strict=False)
                  .str.strip_chars()
                  .str.to_uppercase()
                  .alias("symbol")
            )
            n_dq_syms = dq.get_column("symbol").n_unique()
            _log("INFO", f"Símbolos en Data Quality (Celda 12A): {n_dq_syms}")
    except Exception as e:
        _log("WARNING", f"No se pudo leer {DQ_PATH}: {e}; continúo sin DQ (fallback).")
        dq = None
else:
    _log("WARNING", f"No se encontró {DQ_PATH}; continúo sin DQ (fallback).")

# ---------------------------------- Filtro 3B (eligible_symbols_by_cost) ----------------------------------
elig_set, elig_src = _read_eligible_set()
if elig_set is not None:
    base_syms = set(qa.get_column("symbol").to_list())
    audited_syms = sorted(base_syms & elig_set)
    omitted_syms = sorted(base_syms - elig_set)
    _log(
        "INFO",
        f"Filtro 3B activo ({elig_src}): elegibles={len(elig_set)} | QA={len(base_syms)} → "
        f"auditados={len(audited_syms)} | omitidos={len(omitted_syms)}"
    )
    qa = qa.filter(pl.col("symbol").is_in(audited_syms))
    if dq is not None:
        dq = dq.filter(pl.col("symbol").is_in(audited_syms))
else:
    _log("WARNING", "No se encontró lista elegible 3B; el universo se construirá con TODOS los símbolos presentes en QA.")

# Recalcular n_qa_syms tras aplicar 3B
n_qa_syms_post = qa.get_column("symbol").n_unique()
_log("INFO", f"Símbolos tras filtro 3B en QA: {n_qa_syms_post}")

# ---------------------------------- Join QA + DQ ----------------------------------
if dq is not None:
    # Join left: mantenemos todos los símbolos de QA, anexando métricas de DQ cuando existan
    uni = qa.join(dq, on="symbol", how="left")
else:
    # Sin DQ: creamos columnas placeholders para no romper notebooks posteriores
    _log("INFO", "Construyendo universe snapshot sin DQ; se crean columnas de Data Quality con valores por defecto.")
    uni = qa.with_columns([
        pl.lit(None).cast(pl.Date).alias("first_date"),
        pl.lit(None).cast(pl.Date).alias("last_date"),
        pl.lit(0).cast(pl.Int32).alias("days_with_data"),
        pl.lit(0).cast(pl.Int32).alias("days_expected"),
        pl.lit(0.0).cast(pl.Float64).alias("coverage_days"),
        pl.lit(0).cast(pl.Int64).alias("total_candles"),
        pl.lit(0).cast(pl.Int32).alias("days_with_large_gaps"),
        pl.lit(1.0).cast(pl.Float64).alias("missing_candles_pct"),
        pl.lit(1.0).cast(pl.Float64).alias("bad_days_ratio"),
        pl.lit(0.0).cast(pl.Float64).alias("data_quality_score"),
        pl.lit("MISSING").cast(pl.Utf8).alias("data_quality_flag"),
        pl.lit("Sin DQ disponible en 12A.").cast(pl.Utf8).alias("comentario"),
    ])

# ---------------------------------- Enriquecimiento y flags de selección ----------------------------------
# Copia explícita de qa_struct_flag como qa_struct_flag_qa para que 12C pueda detectarla sin ambigüedad
if "qa_struct_flag" not in uni.columns:
    uni = uni.with_columns(pl.lit("WARN_STRUCT").alias("qa_struct_flag"))

uni = uni.with_columns(
    pl.col("qa_struct_flag").alias("qa_struct_flag_qa")
)

# Asegurar columnas de DQ, incluso si vinieron parcialmente nulas
if "data_quality_flag" not in uni.columns:
    uni = uni.with_columns(pl.lit("MISSING").alias("data_quality_flag"))

if "data_quality_score" not in uni.columns:
    uni = uni.with_columns(pl.lit(0.0).cast(pl.Float64).alias("data_quality_score"))

# Normalizar algunos campos clave
uni = uni.with_columns([
    pl.col("qa_operativa_flag").cast(pl.Utf8),
    pl.col("qa_struct_flag").cast(pl.Utf8),
    pl.col("qa_struct_flag_qa").cast(pl.Utf8),
    pl.col("session_type").cast(pl.Utf8),
    pl.col("data_quality_flag").fill_null("MISSING").cast(pl.Utf8),
    pl.col("data_quality_score").fill_null(0.0).cast(pl.Float64),
    pl.col("qa_price_flag").fill_null("OK").cast(pl.Utf8),   # <<< NEW QA ECON >>> normalización
])

# Flag 3B explícito
if elig_set is not None:
    uni = uni.with_columns(
        pl.col("symbol").is_in(list(elig_set)).alias("is_eligible_3b")
    )
else:
    uni = uni.with_columns(
        pl.lit(True).alias("is_eligible_3b")
    )

# Flags intermedios de selección
uni = uni.with_columns([
    pl.col("qa_operativa_flag").is_in(UNIVERSE_KEEP_QA_FLAGS).alias("keep_by_qa"),
    pl.col("data_quality_flag").is_in(UNIVERSE_KEEP_DQ_FLAGS).alias("keep_by_dq"),
    pl.when(UNIVERSE_EXCLUDE_BAD_STRUCT)
      .then(pl.col("qa_struct_flag").fill_null("BAD_STRUCT") != "BAD_STRUCT")
      .otherwise(pl.lit(True))
      .alias("keep_by_struct"),
    # <<< NEW QA ECON >>> QA económica por símbolo (si no existe, ya la hemos normalizado a 'OK')
    pl.col("qa_price_flag").fill_null("OK").is_in(UNIVERSE_KEEP_PRICE_QA_FLAGS).alias("keep_by_price_qa"),
])

# universe_flag final:
#   - qa_operativa_flag ∈ UNIVERSE_KEEP_QA_FLAGS (OK/WARN por defecto).
#   - qa_price_flag ∈ UNIVERSE_KEEP_PRICE_QA_FLAGS (OK/WARN por defecto).
#   - data_quality_flag ∈ UNIVERSE_KEEP_DQ_FLAGS (OK/WARNING por defecto).
#   - opcionalmente excluimos BAD_STRUCT.
#   - data_quality_score ≥ UNIVERSE_MIN_DQ_SCORE (60.0 por defecto).
uni = uni.with_columns([
    pl.when(
        pl.col("is_eligible_3b") &
        pl.col("keep_by_qa") &
        pl.col("keep_by_dq") &
        pl.col("keep_by_struct") &
        pl.col("keep_by_price_qa") &
        (pl.col("data_quality_score") >= UNIVERSE_MIN_DQ_SCORE)
    )
    .then(pl.lit("IN"))
    .otherwise(pl.lit("OUT"))
    .alias("universe_flag")
])

# ---------------------------------- Orden de columnas / salida ----------------------------------
# Aseguramos que symbol y universe_flag estén al principio para legibilidad
cols_front = [
    "symbol",
    "universe_flag",
    "is_eligible_3b",
    "qa_operativa_flag",
    "qa_price_flag",              # <<< NEW QA ECON >>>
    "qa_struct_flag",
    "qa_struct_flag_qa",
    "session_type",
    "expected_bars_per_day_symbol",
    "data_quality_score",
    "data_quality_flag",
]

cols_existing = [c for c in cols_front if c in uni.columns]
cols_rest = [c for c in uni.columns if c not in cols_existing]

uni_out = uni.select(cols_existing + cols_rest).sort("symbol")

# ---------------------------------- Persistencia ----------------------------------
uni_out.write_parquet(UNIVERSE_PATH, compression=PARQUET_COMP_UNIVERSE)
# Alias "latest" para facilitar consumo por otros notebooks sin preocuparse por RUN_ID
uni_out.write_parquet(UNIVERSE_LATEST_PATH, compression=PARQUET_COMP_UNIVERSE)

# ---------------------------------- Resumen ----------------------------------
n_total = uni_out.height
n_in    = uni_out.filter(pl.col("universe_flag") == "IN").height
n_out   = n_total - n_in

print("=" * 110)
print(">>> Celda 12B :: Universe snapshot M5")
print(f"📁 QA summary (in)        → {QA_SUMMARY_PATH}")
print(f"📁 DQ summary (in)        → {DQ_PATH if dq_available else '[NO DQ / FALLBACK]'}")
print(f"📁 Universe snapshot (out)→ {UNIVERSE_PATH}")
print(f"📁 Universe latest (out)  → {UNIVERSE_LATEST_PATH}")
print("-" * 110)
print(f"Σ símbolos QA tras 3B         = {n_qa_syms_post}")
print(f"Σ símbolos en universe file   = {n_total}")
print(f"Σ símbolos universe_flag='IN' = {n_in}")
print(f"Σ símbolos universe_flag='OUT'= {n_out}")
print("-" * 110)

if n_in > 0:
    top_preview = (
        uni_out
        .select([
            "symbol",
            "universe_flag",
            "qa_operativa_flag",
            "qa_price_flag",        # <<< NEW QA ECON >>>
            "qa_struct_flag",
            "session_type",
            "data_quality_flag",
            "data_quality_score",
        ])
        .head(20)
    )
    print("Preview (primeros 20 símbolos en universe_snapshot):")
    print(top_preview)
else:
    print("⚠️  No hay símbolos con universe_flag='IN'. Revisa umbrales UNIVERSE_* o QA/DQ antes de seguir.")

print("=" * 110)
print("✅ Celda 12B — Universe snapshot M5 generado correctamente.")
# =================================================================================================
# Out:
# ==============================================================================================================
# Inicio Celda 12B — Universe snapshot M5 | TZ local: America/Guayaquil
# Hora local: 2025-12-02T23:40:43-05:00 | Hora UTC: 2025-12-03T04:40:43+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT              : C:\Quant\MT5_Data_Extraction\data
# QA summary (Celda 10)  : C:\Quant\MT5_Data_Extraction\data\metadata\qa_operativa_summary.parquet
# DQ summary (Celda 12A) : C:\Quant\MT5_Data_Extraction\data\metadata\data_quality_summary.parquet
# 3B filters (eligible)  : C:\Quant\MT5_Data_Extraction\data\metadata\filters
# Universe OUT path      : C:\Quant\MT5_Data_Extraction\data\metadata\universe_snapshot_20251202_232253.parquet
# --------------------------------------------------------------------------------------------------------------
# Parámetros de selección de universo:
#   UNIVERSE_KEEP_QA_FLAGS        = ['OK', 'WARN']
#   UNIVERSE_KEEP_DQ_FLAGS        = ['OK', 'WARNING']
#   UNIVERSE_EXCLUDE_BAD_STRUCT   = True
#   UNIVERSE_MIN_DQ_SCORE         = 60.0
#   UNIVERSE_KEEP_PRICE_QA_FLAGS  = ['OK', 'WARN']
#   PARQUET_COMP_UNIVERSE         = 'zstd'
# --------------------------------------------------------------------------------------------------------------
# [2025-12-02T23:40:43-05:00] [20251202_232253] [INFO] [12B-Universe-Snapshot] Símbolos en QA operativa (Celda 10): 107
# [2025-12-02T23:40:43-05:00] [20251202_232253] [INFO] [12B-Universe-Snapshot] Símbolos en Data Quality (Celda 12A): 108
# [2025-12-02T23:40:43-05:00] [20251202_232253] [INFO] [12B-Universe-Snapshot] Filtro 3B activo (parquet): elegibles=107 | QA=107 → auditados=107 | omitidos=0
# [2025-12-02T23:40:43-05:00] [20251202_232253] [INFO] [12B-Universe-Snapshot] Símbolos tras filtro 3B en QA: 107
# ==============================================================================================================
# >>> Celda 12B :: Universe snapshot M5
# 📁 QA summary (in)        → C:\Quant\MT5_Data_Extraction\data\metadata\qa_operativa_summary.parquet
# 📁 DQ summary (in)        → C:\Quant\MT5_Data_Extraction\data\metadata\data_quality_summary.parquet
# 📁 Universe snapshot (out)→ C:\Quant\MT5_Data_Extraction\data\metadata\universe_snapshot_20251202_232253.parquet
# 📁 Universe latest (out)  → C:\Quant\MT5_Data_Extraction\data\metadata\universe_snapshot_latest.parquet
# --------------------------------------------------------------------------------------------------------------
# Σ símbolos QA tras 3B         = 107
# Σ símbolos en universe file   = 107
# Σ símbolos universe_flag='IN' = 106
# Σ símbolos universe_flag='OUT'= 1
# --------------------------------------------------------------------------------------------------------------
# Preview (primeros 20 símbolos en universe_snapshot):
# shape: (20, 8)
# ┌────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ symbol ┆ universe_f ┆ qa_operati ┆ qa_price_f ┆ qa_struct_ ┆ session_ty ┆ data_quali ┆ data_qual │
# │ ---    ┆ lag        ┆ va_flag    ┆ lag        ┆ flag       ┆ pe         ┆ ty_flag    ┆ ity_score │
# │ str    ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str        ┆ str        ┆ f64       │
# ╞════════╪════════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ AAPL   ┆ IN         ┆ WARN       ┆ OK         ┆ OK_STRUCT  ┆ SESSION_DI ┆ OK         ┆ 90.0      │
# │        ┆            ┆            ┆            ┆            ┆ URNA       ┆            ┆           │
# │ AAVUSD ┆ IN         ┆ WARN       ┆ WARN       ┆ OK_STRUCT  ┆ SESSION_24 ┆ OK         ┆ 90.0      │
# │        ┆            ┆            ┆            ┆            ┆ H          ┆            ┆           │
# │ ADAUSD ┆ IN         ┆ WARN       ┆ WARN       ┆ OK_STRUCT  ┆ SESSION_24 ┆ OK         ┆ 90.0      │
# │        ┆            ┆            ┆            ┆            ┆ H          ┆            ┆           │
# │ ALGUSD ┆ IN         ┆ OK         ┆ OK         ┆ OK_STRUCT  ┆ SESSION_24 ┆ OK         ┆ 90.0      │
# │        ┆            ┆            ┆            ┆            ┆ H          ┆            ┆           │
# │ ALVG   ┆ IN         ┆ WARN       ┆ OK         ┆ OK_STRUCT  ┆ SESSION_DI ┆ OK         ┆ 100.0     │
# │        ┆            ┆            ┆            ┆            ┆ URNA       ┆            ┆           │
# │ …      ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …          ┆ …         │
# │ BCHUSD ┆ IN         ┆ OK         ┆ OK         ┆ OK_STRUCT  ┆ SESSION_24 ┆ OK         ┆ 90.0      │
# │        ┆            ┆            ┆            ┆            ┆ H          ┆            ┆           │
# │ BNBUSD ┆ IN         ┆ OK         ┆ OK         ┆ OK_STRUCT  ┆ SESSION_24 ┆ OK         ┆ 90.0      │
# │        ┆            ┆            ┆            ┆            ┆ H          ┆            ┆           │
# │ BTCUSD ┆ IN         ┆ WARN       ┆ OK         ┆ OK_STRUCT  ┆ SESSION_24 ┆ OK         ┆ 90.0      │
# │        ┆            ┆            ┆            ┆            ┆ H          ┆            ┆           │
# │ CADCHF ┆ IN         ┆ OK         ┆ OK         ┆ OK_STRUCT  ┆ SESSION_24 ┆ OK         ┆ 90.0      │
# │        ┆            ┆            ┆            ┆            ┆ H          ┆            ┆           │
# │ CADJPY ┆ IN         ┆ OK         ┆ OK         ┆ OK_STRUCT  ┆ SESSION_24 ┆ OK         ┆ 90.0      │
# │        ┆            ┆            ┆            ┆            ┆ H          ┆            ┆           │
# └────────┴────────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘
# ==============================================================================================================
# ✅ Celda 12B — Universe snapshot M5 generado correctamente.

# %%
# ======================= Celda 12C — Capa GOLD M5 (m5_clean) =======================
# Propósito:
#   - Construir la capa GOLD M5 (m5_clean) a partir de:
#       * bulk_data/m5_raw                               (RAW)
#       * metadata/qa_m5_bulk.parquet                    (QA diario símbolo+fecha, Celda 10)
#       * metadata/universe_snapshot_{RUN_ID}.parquet    (universo final, Celda 12B)
#   - Sólo se incluyen en GOLD los días/símbolos que:
#       * Están en el universo snapshot.
#       * Son estructuralmente sanos:
#            - status ∈ QA_GOLD_KEEP_STATUSES (por defecto ["OK", "WARN"] si no se definió antes).
#            - opcionalmente: símbolo con qa_struct_flag == "OK_STRUCT" si existe en el universe.
#
# Cambios clave vs diseño antiguo:
#   - Se ELIMINA el veto global por rejilla_pct ≥ MIN_REJILLA_FOR_GOLD.
#   - GOLD = datos estructuralmente sanos (FAIL/EMPTY quedan fuera).
#   - La cobertura (rejilla_pct) se evalúa:
#        * Globalmente en Celda 10 (sanity-check M5).
#        * Por símbolo en Celda 12A (DataQuality, ya ajustado por tipo de sesión).
#   - MIN_REJILLA_FOR_GOLD se mantiene como parámetro para futuros refinamientos
#     (por ejemplo, para SESSION_24H), pero NO se aplica en el filtro base.
#   - Búsqueda robusta de RAW por símbolo+fecha usando rglob(), y escritura GOLD
#     compatible con layout particionado por year/month.
# ===================================================================================

from __future__ import annotations
from pathlib import Path
from datetime import datetime, timezone
import time, re
from typing import Dict, List, Optional

import polars as pl

# ----------------------------- Identidad / Paths base -----------------------------
CELL_LABEL    = "12C-GOLD-M5"
RUN_ID        = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))
TIMEZONE_IANA = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# DATA_ROOT obligatorio (Celda 02)
if "DATA_ROOT" not in globals():
    raise RuntimeError("DATA_ROOT no está definido. Ejecuta la Celda 02 antes de esta celda.")

DATA_ROOT = Path(globals()["DATA_ROOT"]).resolve()

# Reutilizamos rutas creadas en Celda 02 si están en globals; si no, derivamos de DATA_ROOT.
META_DIR = Path(globals().get("METADATA_DIR", DATA_ROOT / "metadata")).resolve()

if "M5_RAW_DIR" in globals():
    M5_RAW_DIR = Path(globals()["M5_RAW_DIR"]).resolve()
else:
    M5_RAW_DIR = DATA_ROOT / "bulk_data" / "m5_raw"

if "M5_CLEAN_DIR" in globals():
    M5_CLEAN_DIR = Path(globals()["M5_CLEAN_DIR"]).resolve()
else:
    M5_CLEAN_DIR = DATA_ROOT / "historical_data" / "m5_clean"

QA_BULK_PATH         = META_DIR / "qa_m5_bulk.parquet"
UNIVERSE_PATH        = META_DIR / f"universe_snapshot_{RUN_ID}.parquet"
UNIVERSE_LATEST_PATH = META_DIR / "universe_snapshot_latest.parquet"

# ----------------------------- Parámetros ajustables -----------------------------
# Definidos idealmente en Celda 02; aquí SÓLO se leen.
#   - QA_GOLD_KEEP_STATUSES → viene de la Celda 02 (por defecto ["OK", "WARN"]).
#   - MIN_REJILLA_FOR_GOLD  → 80.0 (NO se usa en el filtro base; reservado para refinamientos futuros).

# Leemos los estados permitidos desde la configuración global (Celda 02).
# Si no existe, reventamos: eso indica que ejecutaste 12C sin pasar por 02.
QA_GOLD_KEEP_STATUSES = list(globals()["QA_GOLD_KEEP_STATUSES"])
QA_KEEP_STATUSES      = QA_GOLD_KEEP_STATUSES  # alias local

MIN_REJILLA_FOR_GOLD  = float(globals().get("MIN_REJILLA_FOR_GOLD", 80.0))

OVERWRITE_M5_CLEAN     = bool(globals().get("OVERWRITE_M5_CLEAN", False))
PARQUET_COMP_GOLD      = globals().get("PARQUET_COMP_GOLD", "zstd")

PROGRESS_EVERY_FILES   = int(globals().get("PROGRESS_EVERY_FILES_GOLD", 2000))
PROGRESS_EVERY_SECONDS = float(globals().get("PROGRESS_EVERY_SECONDS_GOLD", 2.0))

# ----------------------------- Logger helper --------------------------------------
def _log(level: str, msg: str):
    """
    Usa log_msg(celda, level, message) si está disponible (Celda 03),
    si no, hace un print() formateado.
    """
    if "log_msg" in globals():
        try:
            log_msg(CELL_LABEL, level, msg)
            return
        except Exception:
            pass
    ts = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{ts}] [{RUN_ID}] [{level.upper()}] [{CELL_LABEL}] {msg}", flush=True)

def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return datetime.now(timezone.utc).isoformat(timespec="seconds")

# Log explícito de los estados GOLD efectivos
_log("INFO", f"QA_GOLD_KEEP_STATUSES (efectivos) = {QA_GOLD_KEEP_STATUSES}")

# ----------------------------- Helpers de paths/RAW --------------------------------
def _parse_date_from_filename(name: str) -> Optional[str]:
    """
    Extrae YYYYMMDD de nombres tipo 'part=YYYYMMDD.parquet' o variantes.
    """
    m = re.search(r"part=([0-9]{8})", name)
    if m:
        return m.group(1)
    m = re.search(r"part=([0-9]{4})[-_/]?([0-9]{2})[-_/]?([0-9]{2})", name)
    if m:
        return f"{m.group(1)}{m.group(2)}{m.group(3)}"
    return None

_RAW_INDEX: Dict[str, Dict[str, Path]] = {}

def _build_raw_index_for_symbol(sym: str) -> Dict[str, Path]:
    """
    Escanea M5_RAW_DIR/symbol=sym con rglob('part=*.parquet') y construye
    un índice date_str(YYYYMMDD) -> Path.
    Soporta layouts con year=/month= y layouts planos.
    """
    root = M5_RAW_DIR / f"symbol={sym}"
    index: Dict[str, Path] = {}
    if not root.exists():
        _log("WARNING", f"Directorio RAW no existe para símbolo {sym}: {root}")
        return index

    files = list(root.rglob("part=*.parquet"))
    for p in files:
        ds = _parse_date_from_filename(p.name)
        if not ds:
            continue
        # Si hubiera duplicados para el mismo día, se conserva el primero.
        index.setdefault(ds, p)

    _log("INFO", f"Índice RAW para {sym}: {len(index)} día(s) encontrados bajo {root}")
    return index

def _get_clean_paths(sym: str, d: str) -> tuple[Path, Path]:
    """
    Devuelve:
      - legacy_clean_path: symbol=SYM/part=YYYYMMDD.parquet
      - clean_path:        symbol=SYM/year=YYYY/month=MM/part=YYYYMMDD.parquet
    """
    year = d[:4]
    month = d[4:6]
    legacy_clean_path = M5_CLEAN_DIR / f"symbol={sym}" / f"part={d}.parquet"
    partitioned_dir   = M5_CLEAN_DIR / f"symbol={sym}" / f"year={year}" / f"month={month}"
    clean_path        = partitioned_dir / f"part={d}.parquet"
    return legacy_clean_path, clean_path

# ----------------------------- Header ---------------------------------------------
print("=" * 110)
print("Inicio Celda 12C — Capa GOLD M5 (m5_clean)")
print(f"TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-" * 110)
print(f"DATA_ROOT       : {DATA_ROOT}")
print(f"RAW (m5_raw)    : {M5_RAW_DIR}")
print(f"GOLD (m5_clean) : {M5_CLEAN_DIR}")
print(f"QA diario       : {QA_BULK_PATH}")
print(f"Universe        : {UNIVERSE_PATH}")
print("-" * 110)
print("Parámetros GOLD (estructura-base):")
print(f"  QA_GOLD_KEEP_STATUSES = {QA_GOLD_KEEP_STATUSES}   # status aceptados (FAIL/EMPTY fuera por defecto)")
print(f"  MIN_REJILLA_FOR_GOLD  = {MIN_REJILLA_FOR_GOLD}   # hoy NO se usa como veto global en GOLD")
print(f"  OVERWRITE_M5_CLEAN    = {OVERWRITE_M5_CLEAN}")
print(f"  PARQUET_COMP_GOLD     = '{PARQUET_COMP_GOLD}'")
print("-" * 110)

_log("INFO", "Inicio construcción de capa GOLD m5_clean (filtro estructural sin veto de rejilla).")

# ----------------------------- Guardas de existencia ------------------------------
if not M5_RAW_DIR.exists():
    raise FileNotFoundError(f"No existe M5_RAW_DIR: {M5_RAW_DIR}. Ejecuta la Celda 08 antes de esta.")

if not QA_BULK_PATH.exists():
    raise FileNotFoundError(f"No se encontró QA diario en: {QA_BULK_PATH}. Ejecuta la Celda 10 antes de esta.")

if not UNIVERSE_PATH.exists():
    if UNIVERSE_LATEST_PATH.exists():
        _log(
            "WARNING",
            f"No se encontró universe_snapshot para RUN_ID={RUN_ID} en {UNIVERSE_PATH}; "
            f"usando universe_snapshot_latest.parquet en su lugar."
        )
        UNIVERSE_PATH = UNIVERSE_LATEST_PATH
    else:
        raise FileNotFoundError(
            f"No se encontró universe_snapshot ni por RUN_ID ({UNIVERSE_PATH}) "
            f"ni universe_snapshot_latest.parquet."
        )

M5_CLEAN_DIR.mkdir(parents=True, exist_ok=True)
META_DIR.mkdir(parents=True, exist_ok=True)

# ----------------------------- Lectura de universe_snapshot y QA bulk ------------
uni = pl.read_parquet(UNIVERSE_PATH)
if "symbol" not in uni.columns:
    raise ValueError(f"{UNIVERSE_PATH} no tiene columna 'symbol'.")

universe_syms = set(uni.get_column("symbol").cast(pl.Utf8).to_list())
n_universe = len(universe_syms)
_log("INFO", f"Universe snapshot cargado: {n_universe} símbolo(s) en universo base.")

# Filtro estructural por símbolo usando qa_struct_flag (si existe en el snapshot)
qa_struct_col: Optional[str] = None
if "qa_struct_flag_qa" in uni.columns:
    qa_struct_col = "qa_struct_flag_qa"
elif "qa_struct_flag" in uni.columns:
    qa_struct_col = "qa_struct_flag"

candidate_syms = set(universe_syms)

if qa_struct_col is not None:
    struct_ok_syms = set(
        uni.filter(pl.col(qa_struct_col) == "OK_STRUCT")
           .get_column("symbol")
           .cast(pl.Utf8)
           .to_list()
    )
    if struct_ok_syms:
        before = len(candidate_syms)
        candidate_syms = candidate_syms & struct_ok_syms
        after = len(candidate_syms)
        _log(
            "INFO",
            f"Filtro estructural aplicado ({qa_struct_col} == 'OK_STRUCT'): "
            f"{before} → {after} símbolo(s) estructuralmente OK en universo."
        )
    else:
        _log(
            "WARNING",
            f"Columna {qa_struct_col} presente en universe pero ningún símbolo con 'OK_STRUCT'; "
            f"se usará el universo completo SIN filtro estructural por símbolo."
        )
else:
    _log("INFO", "No se encontró qa_struct_flag en universe snapshot; no se aplica filtro estructural por símbolo.")

# ----------------------------- Lectura y normalización de QA diario --------------
qa_cols_needed = ["symbol", "date", "status", "rejilla_pct"]
qa_bulk = pl.read_parquet(QA_BULK_PATH)

missing_cols = [c for c in qa_cols_needed if c not in qa_bulk.columns]
if missing_cols:
    raise ValueError(f"{QA_BULK_PATH} no tiene columnas requeridas: {missing_cols}")

qa_bulk = qa_bulk.select(qa_cols_needed)
tot_days_qa = qa_bulk.height

# Normalizamos la columna 'date' a string YYYYMMDD → 'date_ymd'
dt_type = qa_bulk.schema["date"]
if dt_type == pl.Date:
    qa_bulk = qa_bulk.with_columns(
        pl.col("date").dt.strftime("%Y%m%d").alias("date_ymd")
    )
else:
    # Cast laxo a texto, quitando separadores comunes ('-', '_', '/')
    qa_bulk = qa_bulk.with_columns(
        pl.col("date")
        .cast(pl.Utf8)
        .str.replace_all(r"[^0-9]", "")
        .alias("date_ymd")
    )

# ----------------------------- Selección de días buenos para GOLD ----------------
# Criterio base:
#   - symbol ∈ candidate_syms  (universo ∩ símbolos estructuralmente OK, si aplica)
#   - status ∈ QA_GOLD_KEEP_STATUSES (por defecto ["OK", "WARN"])
#   - NO se usa rejilla_pct como veto global.
_good_filter = (
    pl.col("symbol").is_in(list(candidate_syms)) &
    pl.col("status").is_in(QA_KEEP_STATUSES)
)

good_days = (
    qa_bulk
    .filter(_good_filter)
    .select(["symbol", "date_ymd"])
    .unique()
)

n_good_pairs = good_days.height
_log("INFO", f"Días candidatos a GOLD (símbolo+fecha) tras filtro estructural: {n_good_pairs}")

if n_good_pairs == 0:
    # ---------------------- Diagnóstico detallado cuando no hay candidatos -------
    print("⚠️  No hay días que cumplan los criterios para GOLD con los parámetros actuales.")
    print("-" * 110)
    print("Resumen de QA diario (qa_m5_bulk) para este RUN_ID:")
    print(f"  Σ días auditados en QA      = {tot_days_qa}")

    if tot_days_qa > 0:
        by_status = (
            qa_bulk
            .group_by("status")
            .agg(pl.len().alias("n"))
            .sort("status")
        )
        counts = {r["status"]: int(r["n"]) for r in by_status.iter_rows(named=True)}
        _pct = lambda n: (100.0 * n / tot_days_qa) if tot_days_qa else 0.0

        n_ok    = counts.get("OK", 0)
        n_warn  = counts.get("WARN", 0)
        n_fail  = counts.get("FAIL", 0)
        n_empty = counts.get("EMPTY", 0)

        print(
            f"  Distribución de status: "
            f"OK={n_ok} ({_pct(n_ok):.1f}%) | "
            f"WARN={n_warn} ({_pct(n_warn):.1f}%) | "
            f"FAIL={n_fail} ({_pct(n_fail):.1f}%) | "
            f"EMPTY={n_empty} ({_pct(n_empty):.1f}%)"
        )

        cov_stats = (
            qa_bulk
            .select([
                pl.col("rejilla_pct").mean().alias("rejilla_mean"),
                pl.col("rejilla_pct").quantile(0.5).alias("rejilla_p50"),
            ])
            .to_dicts()[0]
        )
        rejilla_mean = float(cov_stats.get("rejilla_mean", 0.0) or 0.0)
        rejilla_p50  = float(cov_stats.get("rejilla_p50", 0.0) or 0.0)

        print(f"  Rejilla global (sobre días auditados): rejilla_mean={rejilla_mean:.2f}% | rejilla_p50={rejilla_p50:.2f}%")
    else:
        print("  ⚠️  qa_m5_bulk.parquet no contiene filas para este RUN_ID.")

    print("-" * 110)
    print("Parámetros de filtrado hacia GOLD usados en esta celda:")
    print(f"  QA_GOLD_KEEP_STATUSES = {QA_GOLD_KEEP_STATUSES}")
    print(f"  MIN_REJILLA_FOR_GOLD  = {MIN_REJILLA_FOR_GOLD}  (NO usado como veto en esta celda)")
    print(f"  Σ símbolos en universo base                = {n_universe}")
    print(f"  Σ símbolos candidatos tras filtro estructural (qa_struct_flag, si aplica) = {len(candidate_syms)}")
    print("-" * 110)
    print("Interpretación profesional:")
    print("  - GOLD hoy descarta únicamente:")
    print("       * Días con status NO incluido en QA_GOLD_KEEP_STATUSES (p.ej. FAIL, EMPTY).")
    print("       * Opcionalmente, símbolos con qa_struct_flag != 'OK_STRUCT' si esa columna existe en el universe.")
    print("  - La rejilla_pct ya NO se usa como veto global en esta capa; la cobertura se evalúa en:")
    print("       * Celda 10 (sanity-check global de M5).")
    print("       * Celda 12A (DataQuality ajustado por tipo de sesión).")
    print("  - Si casi todos los días están en FAIL/EMPTY, o ningún símbolo queda con qa_struct_flag='OK_STRUCT',")
    print("    el problema NO está en esta celda, sino aguas arriba (extracción M5 o QA operativa).")
    print("-" * 110)
    print("La capa GOLD m5_clean NO se ha generado en este RUN_ID porque no hay días que cumplan")
    print("los criterios estructurales definidos. Ajusta QA_GOLD_KEEP_STATUSES o revisa QA/estructura")
    print("si esto no es intencionado.")
    print("=" * 110)

    _log(
        "WARNING",
        f"Sin candidatos a GOLD. tot_days_qa={tot_days_qa}, "
        f"QA_GOLD_KEEP_STATUSES={QA_GOLD_KEEP_STATUSES}, "
        f"MIN_REJILLA_FOR_GOLD={MIN_REJILLA_FOR_GOLD}, "
        f"n_universe={n_universe}, n_candidate_syms={len(candidate_syms)}"
    )

else:
    # Agrupar por símbolo para iterar de forma eficiente
    grouped = (
        good_days
        .group_by("symbol")
        .agg(pl.col("date_ymd").alias("dates_ymd"))
    )

    symbols_with_candidates = grouped.height
    print(f"Símbolos con al menos un día candidato a GOLD: {symbols_with_candidates}/{len(candidate_syms)}")

    # ----------------------------- Loop de construcción de GOLD -------------------
    total_candidates   = n_good_pairs
    files_written      = 0
    skipped_existing   = 0
    missing_raw_files  = 0
    days_written_by_symbol: Dict[str, int] = {}

    t0 = time.monotonic()
    last_beat = t0

    for row in grouped.iter_rows(named=True):
        sym = row["symbol"]
        dates: List[str] = row["dates_ymd"]  # lista de strings YYYYMMDD
        dates_sorted = sorted(dates)

        # Construir índice RAW una vez por símbolo si hace falta
        if sym not in _RAW_INDEX:
            _RAW_INDEX[sym] = _build_raw_index_for_symbol(sym)
        sym_raw_index = _RAW_INDEX.get(sym, {})

        for d in dates_sorted:
            legacy_clean_path, clean_path = _get_clean_paths(sym, d)

            # Si ya existe GOLD (legacy o particionado) y no se quiere overwrite → skip
            if (clean_path.exists() or legacy_clean_path.exists()) and not OVERWRITE_M5_CLEAN:
                skipped_existing += 1
                files_written += 1
                now = time.monotonic()
                if (files_written % PROGRESS_EVERY_FILES == 0) or (now - last_beat >= PROGRESS_EVERY_SECONDS):
                    rate = files_written / max(now - t0, 1e-6)
                    _log("INFO", f"GOLD progreso: {files_written}/{total_candidates} archivos (sym={sym}) | {rate:.1f} files/s")
                    last_beat = now
                continue

            # Intento directo: layout plano
            raw_path = M5_RAW_DIR / f"symbol={sym}" / f"part={d}.parquet"
            if not raw_path.exists():
                # Buscar en índice (soporta year=/month=)
                raw_path = sym_raw_index.get(d)

            if raw_path is None or not Path(raw_path).exists():
                missing_raw_files += 1
                files_written += 1
                _log("WARNING", f"Falta RAW para GOLD (sym={sym}, date={d}); no se encontró archivo en índice ni en layout plano.")
                now = time.monotonic()
                if (files_written % PROGRESS_EVERY_FILES == 0) or (now - last_beat >= PROGRESS_EVERY_SECONDS):
                    rate = files_written / max(now - t0, 1e-6)
                    _log("INFO", f"GOLD progreso: {files_written}/{total_candidates} archivos (sym={sym}) | {rate:.1f} files/s")
                    last_beat = now
                continue

            try:
                df = pl.read_parquet(raw_path, use_statistics=True)
            except Exception as e:
                files_written += 1
                _log("WARNING", f"No se pudo leer RAW {raw_path}: {type(e).__name__}: {e}")
                now = time.monotonic()
                if (files_written % PROGRESS_EVERY_FILES == 0) or (now - last_beat >= PROGRESS_EVERY_SECONDS):
                    rate = files_written / max(now - t0, 1e-6)
                    _log("INFO", f"GOLD progreso: {files_written}/{total_candidates} archivos (sym={sym}) | {rate:.1f} files/s")
                    last_beat = now
                continue

            # Tipado mínimo coherente con contrato M5
            cols = set(df.columns)

            if "timestamp_utc" in cols:
                df = df.with_columns(pl.col("timestamp_utc").cast(pl.Int64, strict=False))

            for c in ["open", "high", "low", "close", "spread_points", "real_volume"]:
                if c in cols:
                    df = df.with_columns(pl.col(c).cast(pl.Float64, strict=False))

            if "tick_volume" in cols:
                df = df.with_columns(pl.col("tick_volume").cast(pl.Int64, strict=False))

            # Limpieza mínima: filtrar nulos y deduplicar por timestamp_utc
            if "timestamp_utc" in cols:
                df = (
                    df
                    .filter(pl.col("timestamp_utc").is_not_null())
                    .sort("timestamp_utc")
                    .unique(subset=["timestamp_utc"], keep="first")
                )

            # Escribir como GOLD (layout particionado por year/month)
            clean_path.parent.mkdir(parents=True, exist_ok=True)
            df.write_parquet(clean_path, compression=PARQUET_COMP_GOLD)

            files_written += 1
            days_written_by_symbol[sym] = days_written_by_symbol.get(sym, 0) + 1

            now = time.monotonic()
            if (files_written % PROGRESS_EVERY_FILES == 0) or (now - last_beat >= PROGRESS_EVERY_SECONDS):
                rate = files_written / max(now - t0, 1e-6)
                _log("INFO", f"GOLD progreso: {files_written}/{total_candidates} archivos (sym={sym}) | {rate:.1f} files/s")
                last_beat = now

    # ----------------------------- Resumen de ejecución ---------------------------
    elapsed = time.monotonic() - t0
    rate    = files_written / max(elapsed, 1e-6)

    n_syms_gold     = len(days_written_by_symbol)
    total_days_gold = sum(days_written_by_symbol.values())

    print("=" * 110)
    print(">>> Celda 12C :: Capa GOLD M5 (m5_clean)")
    print(f"📁 INPUT RAW → {M5_RAW_DIR}")
    print(f"📁 INPUT QA  → {QA_BULK_PATH}")
    print(f"📁 INPUT UNI → {UNIVERSE_PATH}")
    print(f"📁 OUTPUT    → {M5_CLEAN_DIR}")
    print("-" * 110)
    print(f"Σ símbolos en universo base          = {n_universe}")
    print(f"Σ símbolos candidatos (estructura)   = {len(candidate_syms)}")
    print(f"Σ símbolos con al menos un día GOLD  = {n_syms_gold}")
    print(f"Σ días candidatos (QA estructural)   = {n_good_pairs}")
    print(f"Σ ficheros GOLD procesados           = {files_written}")
    print(f"Σ días GOLD escritos                  = {total_days_gold}")
    print(f"Σ RAW faltantes                      = {missing_raw_files}")
    print(f"Σ días ya existentes (skip)          = {skipped_existing}  (OVERWRITE_M5_CLEAN={OVERWRITE_M5_CLEAN})")
    print(f"Tiempo total                         = {elapsed:.1f}s ({rate:.1f} files/s)")
    print("-" * 110)

    if n_syms_gold > 0:
        top_syms = sorted(days_written_by_symbol.items(), key=lambda kv: kv[1], reverse=True)[:5]
        print("Top-5 símbolos por nº de días en GOLD:")
        for sym, nd in top_syms:
            print(f"  - {sym}: n_days_GOLD={nd}")
    else:
        print("⚠️  No se ha escrito ningún día en GOLD (revisa QA, universe y correspondencia con m5_raw).")

    print("=" * 110)
    print("✅ Celda 12C — m5_clean (GOLD) generada correctamente dentro de los criterios estructurales definidos.")

    _log(
        "INFO",
        f"GOLD m5_clean completado: syms_gold={n_syms_gold}, days_gold={total_days_gold}, "
        f"missing_raw={missing_raw_files}, skipped_existing={skipped_existing}, elapsed={elapsed:.1f}s"
    )
# ===================================================================================
# Out:
# [2025-12-02 23:40:43] [20251202_232253] [INFO] [12C-GOLD-M5] QA_GOLD_KEEP_STATUSES (efectivos) = ['OK', 'WARN']
# ==============================================================================================================
# Inicio Celda 12C — Capa GOLD M5 (m5_clean)
# TZ local: America/Guayaquil
# Hora local: 2025-12-02T23:40:43-05:00 | Hora UTC: 2025-12-03T04:40:43+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT       : C:\Quant\MT5_Data_Extraction\data
# RAW (m5_raw)    : C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# GOLD (m5_clean) : C:\Quant\MT5_Data_Extraction\data\historical_data\m5_clean
# QA diario       : C:\Quant\MT5_Data_Extraction\data\metadata\qa_m5_bulk.parquet
# Universe        : C:\Quant\MT5_Data_Extraction\data\metadata\universe_snapshot_20251202_232253.parquet
# --------------------------------------------------------------------------------------------------------------
# Parámetros GOLD (estructura-base):
#   QA_GOLD_KEEP_STATUSES = ['OK', 'WARN']   # status aceptados (FAIL/EMPTY fuera por defecto)
#   MIN_REJILLA_FOR_GOLD  = 80.0   # hoy NO se usa como veto global en GOLD
#   OVERWRITE_M5_CLEAN    = False
#   PARQUET_COMP_GOLD     = 'zstd'
# --------------------------------------------------------------------------------------------------------------
# [2025-12-02 23:40:43] [20251202_232253] [INFO] [12C-GOLD-M5] Inicio construcción de capa GOLD m5_clean (filtro estructural sin veto de rejilla).
# [2025-12-02 23:40:43] [20251202_232253] [INFO] [12C-GOLD-M5] Universe snapshot cargado: 107 símbolo(s) en universo base.
# [2025-12-02 23:40:43] [20251202_232253] [INFO] [12C-GOLD-M5] Filtro estructural aplicado (qa_struct_flag_qa == 'OK_STRUCT'): 107 → 107 símbolo(s) estructuralmente OK en universo.
# [2025-12-02 23:40:43] [20251202_232253] [INFO] [12C-GOLD-M5] Días candidatos a GOLD (símbolo+fecha) tras filtro estructural: 100882
# Símbolos con al menos un día candidato a GOLD: 89/107
# [2025-12-02 23:40:43] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURHUF: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURHUF
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDILS: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDILS
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 2000/100882 archivos (sym=USDILS) | 18348.6 files/s
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para XAUAUD: 1042 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=XAUAUD
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para XAGAUD: 1042 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=XAGAUD
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 4000/100882 archivos (sym=XAGAUD) | 14234.9 files/s
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para DOTUSD: 1469 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=DOTUSD
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDHUF: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDHUF
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 6000/100882 archivos (sym=USDHUF) | 11299.4 files/s
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para NZDCAD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=NZDCAD
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para GRTUSD: 1470 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=GRTUSD
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 8000/100882 archivos (sym=GRTUSD) | 10899.2 files/s
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para CADJPY: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=CADJPY
# [2025-12-02 23:40:44] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 10000/100882 archivos (sym=CADJPY) | 10846.0 files/s
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para GOOG: 1012 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=GOOG
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para MANUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=MANUSD
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 12000/100882 archivos (sym=MANUSD) | 9844.1 files/s
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para BCHUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=BCHUSD
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 14000/100882 archivos (sym=BCHUSD) | 9957.3 files/s
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para BTCUSD: 1469 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=BTCUSD
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para CADCHF: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=CADCHF
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 16000/100882 archivos (sym=CADCHF) | 9846.2 files/s
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para GBPCAD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=GBPCAD
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para LTCUSD: 1469 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=LTCUSD
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 18000/100882 archivos (sym=LTCUSD) | 10016.7 files/s
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para DASHUSD: 1469 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=DASHUSD
# [2025-12-02 23:40:45] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 20000/100882 archivos (sym=DASHUSD) | 10080.6 files/s
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para NERUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=NERUSD
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 22000/100882 archivos (sym=NERUSD) | 10128.9 files/s
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURAUD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURAUD
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDCHF: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDCHF
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 24000/100882 archivos (sym=USDCHF) | 9909.2 files/s
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURJPY: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURJPY
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para LVMH: 1032 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=LVMH
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 26000/100882 archivos (sym=LVMH) | 9730.5 files/s
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para XAUUSD: 1042 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=XAUUSD
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDNOK: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDNOK
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 28000/100882 archivos (sym=USDNOK) | 9793.6 files/s
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para XMRUSD: 1469 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=XMRUSD
# [2025-12-02 23:40:46] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDHKD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDHKD
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 30000/100882 archivos (sym=USDHKD) | 9897.7 files/s
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para ICPUSD: 543 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=ICPUSD
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para AUDCHF: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=AUDCHF
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 32000/100882 archivos (sym=AUDCHF) | 9569.4 files/s
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para GBPCHF: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=GBPCHF
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDCAD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDCAD
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 34000/100882 archivos (sym=USDCAD) | 9670.1 files/s
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURUSD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURUSD
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para AUDJPY: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=AUDJPY
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 36000/100882 archivos (sym=AUDJPY) | 9559.2 files/s
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para GBPUSD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=GBPUSD
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para XAUEUR: 1042 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=XAUEUR
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 38000/100882 archivos (sym=XAUEUR) | 9688.9 files/s
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para ALGUSD: 1467 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=ALGUSD
# [2025-12-02 23:40:47] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 40000/100882 archivos (sym=ALGUSD) | 9923.1 files/s
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para XAGUSD: 1042 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=XAGUSD
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURCAD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURCAD
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 42000/100882 archivos (sym=EURCAD) | 9810.8 files/s
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para AMZN: 1012 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=AMZN
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURNZD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURNZD
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 44000/100882 archivos (sym=EURNZD) | 9881.0 files/s
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para AAVUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=AAVUSD
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para GALUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=GALUSD
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 46000/100882 archivos (sym=GALUSD) | 9684.2 files/s
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURCZK: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURCZK
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 48000/100882 archivos (sym=EURCZK) | 9722.5 files/s
# [2025-12-02 23:40:48] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para TSLA: 1012 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=TSLA
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para XLMUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=XLMUSD
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 50000/100882 archivos (sym=XLMUSD) | 9756.1 files/s
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para WMT: 1012 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=WMT
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para AUDNZD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=AUDNZD
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 52000/100882 archivos (sym=AUDNZD) | 9846.6 files/s
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para ETCUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=ETCUSD
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 54000/100882 archivos (sym=ETCUSD) | 9988.9 files/s
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para UNIUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=UNIUSD
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDZAR: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDZAR
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 56000/100882 archivos (sym=USDZAR) | 9766.3 files/s
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para SOLUSD: 226 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=SOLUSD
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURCHF: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURCHF
# [2025-12-02 23:40:49] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 58000/100882 archivos (sym=EURCHF) | 9666.7 files/s
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para XRPUSD: 1469 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=XRPUSD
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para GBPJPY: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=GBPJPY
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 60000/100882 archivos (sym=GBPJPY) | 9481.7 files/s
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para AVAUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=AVAUSD
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 62000/100882 archivos (sym=AVAUSD) | 9631.8 files/s
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para MSFT: 1012 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=MSFT
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURPLN: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURPLN
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 64000/100882 archivos (sym=EURPLN) | 9548.0 files/s
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para SANUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=SANUSD
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDMXN: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDMXN
# [2025-12-02 23:40:50] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 66000/100882 archivos (sym=USDMXN) | 9492.3 files/s
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para NZDJPY: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=NZDJPY
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para CHFJPY: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=CHFJPY
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 68000/100882 archivos (sym=CHFJPY) | 9502.5 files/s
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDJPY: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDJPY
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDPLN: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDPLN
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 70000/100882 archivos (sym=USDPLN) | 9531.6 files/s
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para GBPNZD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=GBPNZD
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 72000/100882 archivos (sym=GBPNZD) | 9660.5 files/s
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para BARUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=BARUSD
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para NZDCHF: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=NZDCHF
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 74000/100882 archivos (sym=NZDCHF) | 9568.1 files/s
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para BNBUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=BNBUSD
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 76000/100882 archivos (sym=BNBUSD) | 9650.8 files/s
# [2025-12-02 23:40:51] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDSEK: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDSEK
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para V: 1012 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=V
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 78000/100882 archivos (sym=V) | 9600.0 files/s
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDCZK: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDCZK
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURNOK: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURNOK
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 80000/100882 archivos (sym=EURNOK) | 9642.0 files/s
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para IBE: 1031 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=IBE
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para DOGEUSD: 1469 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=DOGEUSD
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 82000/100882 archivos (sym=DOGEUSD) | 9647.1 files/s
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para ADAUSD: 1469 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=ADAUSD
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 84000/100882 archivos (sym=ADAUSD) | 9651.8 files/s
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para ALVG: 1031 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=ALVG
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para VECUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=VECUSD
# [2025-12-02 23:40:52] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 86000/100882 archivos (sym=VECUSD) | 9572.6 files/s
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para ETHUSD: 1469 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=ETHUSD
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 88000/100882 archivos (sym=ETHUSD) | 9627.0 files/s
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para GBPAUD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=GBPAUD
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para AUDUSD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=AUDUSD
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 90000/100882 archivos (sym=AUDUSD) | 9583.6 files/s
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDSGD: 499 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDSGD
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para LNKUSD: 1471 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=LNKUSD
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 92000/100882 archivos (sym=LNKUSD) | 9558.4 files/s
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para XAGEUR: 1042 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=XAGEUR
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para NVDA: 1012 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=NVDA
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 94000/100882 archivos (sym=NVDA) | 9519.0 files/s
# [2025-12-02 23:40:53] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para NZDUSD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=NZDUSD
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para FETUSD: 543 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=FETUSD
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para AAPL: 1012 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=AAPL
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 96000/100882 archivos (sym=AAPL) | 9365.9 files/s
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para USDCNH: 501 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=USDCNH
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para EURGBP: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=EURGBP
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 98000/100882 archivos (sym=EURGBP) | 9375.3 files/s
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para IMXUSD: 1419 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=IMXUSD
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] Índice RAW para AUDCAD: 1048 día(s) encontrados bajo C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw\symbol=AUDCAD
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD progreso: 100000/100882 archivos (sym=AUDCAD) | 9275.6 files/s
# ==============================================================================================================
# >>> Celda 12C :: Capa GOLD M5 (m5_clean)
# 📁 INPUT RAW → C:\Quant\MT5_Data_Extraction\data\bulk_data\m5_raw
# 📁 INPUT QA  → C:\Quant\MT5_Data_Extraction\data\metadata\qa_m5_bulk.parquet
# 📁 INPUT UNI → C:\Quant\MT5_Data_Extraction\data\metadata\universe_snapshot_20251202_232253.parquet
# 📁 OUTPUT    → C:\Quant\MT5_Data_Extraction\data\historical_data\m5_clean
# --------------------------------------------------------------------------------------------------------------
# Σ símbolos en universo base          = 107
# Σ símbolos candidatos (estructura)   = 107
# Σ símbolos con al menos un día GOLD  = 89
# Σ días candidatos (QA estructural)   = 100882
# Σ ficheros GOLD procesados           = 100882
# Σ días GOLD escritos                  = 737
# Σ RAW faltantes                      = 0
# Σ días ya existentes (skip)          = 100145  (OVERWRITE_M5_CLEAN=False)
# Tiempo total                         = 10.8s (9303.0 files/s)
# --------------------------------------------------------------------------------------------------------------
# Top-5 símbolos por nº de días en GOLD:
#   - DOTUSD: n_days_GOLD=11
#   - GRTUSD: n_days_GOLD=11
#   - MANUSD: n_days_GOLD=11
#   - BCHUSD: n_days_GOLD=11
#   - LTCUSD: n_days_GOLD=11
# ==============================================================================================================
# ✅ Celda 12C — m5_clean (GOLD) generada correctamente dentro de los criterios estructurales definidos.
# [2025-12-02 23:40:54] [20251202_232253] [INFO] [12C-GOLD-M5] GOLD m5_clean completado: syms_gold=89, days_gold=737, missing_raw=0, skipped_existing=100145, elapsed=10.8s

# %%
# ===================== Celda 13 — Backup, checksums y cierre (POLARS + QA + TZ homogénea) =====================
# Propósito:
#   - Manifest de corrida: metadata/manifest.json
#   - Checksums SHA-256 de archivos NUEVOS/MODIFICADOS en esta corrida: metadata/checksums.jsonl
#   - Backup (zip) de: historical_data/m5_clean (o bulk_data/m5_raw si no hay clean) + metadata/ + processed_data/m5_windows/
#   - Validaciones impresas: Nº archivos/bytes, tasa de hashing (files/s y MiB/s), mismatches=0, rutas de backup
#   - Cierre de sesión MT5 (si aplica)
#   - Progreso en vivo (heartbeats)
#   - Ajuste: indexar archivos a hashear desde catálogos/logs usando Polars cuando aplique
# ==============================================================================================================

from __future__ import annotations
import os, sys, json, time, platform, getpass, hashlib, zipfile
from datetime import datetime, timezone
from pathlib import Path
from typing import Iterable, List, Dict, Tuple

# Polars opcional (para indexar desde catálogos/logs)
try:
    import polars as pl
    _HAS_PL = True
except Exception:
    _HAS_PL = False

# MetaTrader5 opcional (para shutdown)
try:
    import MetaTrader5 as mt5
    _HAS_MT5 = True
except Exception:
    _HAS_MT5 = False

# ------------------------------- Config / rutas --------------------------------
CELL_LABEL = "13-Backup"
RUN_ID = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))
TIMEZONE_IANA = globals().get("TIMEZONE_IANA", "America/Guayaquil")
HEARTBEAT_SECS = float(globals().get("BACKUP_HEARTBEAT_SECS", 2.0))
MTIME_FALLBACK_HOURS = int(globals().get("MTIME_FALLBACK_HOURS", 12))

DATA_ROOT = Path(globals().get("DATA_ROOT", str(path_contract.data_root()))).resolve()
META_DIR  = DATA_ROOT / "metadata"
CLEAN_DIR = DATA_ROOT / "historical_data" / "m5_clean"
RAW_DIR   = DATA_ROOT / "bulk_data" / "m5_raw"
WIN_DIR   = DATA_ROOT / "processed_data" / "m5_windows"
BACKUPS_DIR = DATA_ROOT / "backups"

RUN_LOG = META_DIR / "run_log.jsonl"
CATALOG_PATH = META_DIR / "dataset_catalog.parquet"
MANIFEST_PATH = META_DIR / "manifest.json"
CHECKSUMS_PATH = META_DIR / "checksums.jsonl"

BACKUPS_DIR.mkdir(parents=True, exist_ok=True)
META_DIR.mkdir(parents=True, exist_ok=True)

# ------------------------------- Utilitarios -----------------------------------
def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return "(instala 'tzdata' para TZ locales)"

def _log(level: str, msg: str):
    ts = _now_local_iana()
    print(f"[{ts}] [{RUN_ID}] [{level}] [{CELL_LABEL}] {msg}", flush=True)

def _iter_files(base: Path) -> Iterable[Path]:
    for root, _, files in os.walk(base):
        for f in files:
            p = Path(root) / f
            if p.is_file():
                yield p

def _size_bytes(p: Path) -> int:
    try: return p.stat().st_size
    except Exception: return 0

def _fmt_bytes(n: int) -> str:
    if n < 1024: return f"{n} B"
    kib = n/1024
    if kib < 1024: return f"{kib:.2f} KiB"
    mib = kib/1024
    if mib < 1024: return f"{mib:.2f} MiB"
    gib = mib/1024
    return f"{gib:.2f} GiB"

def _sha256(path: Path, chunk_size: int = 2*1024*1024) -> str:
    h = hashlib.sha256()
    with open(path, "rb") as f:
        while True:
            b = f.read(chunk_size)
            if not b: break
            h.update(b)
    return h.hexdigest()

def _has_any_parquets(base: Path) -> bool:
    for p in _iter_files(base):
        if p.suffix.lower()==".parquet": return True
    return False

# --------------------------- Fuente principal para el backup ---------------------------
if _has_any_parquets(CLEAN_DIR):
    SOURCE_DIR = CLEAN_DIR
    source_label = "historical_data/m5_clean"
else:
    SOURCE_DIR = RAW_DIR
    source_label = "bulk_data/m5_raw"

# --------------------------- Descubrimiento de archivos a hashear ---------------------------
def _paths_from_runlog_polars(run_id: str) -> List[Path]:
    if not _HAS_PL or not RUN_LOG.exists():
        return []
    try:
        df = pl.scan_ndjson(str(RUN_LOG)).filter(pl.col("run_id")==run_id).select(
            pl.coalesce([pl.col("dst"), pl.col("path")]).alias("p")
        ).collect()
        vals = [Path(p) for p in df["p"].drop_nulls().to_list() if p]
        return [p.resolve() for p in vals if p.exists()]
    except Exception:
        return []

def _paths_from_runlog_python(run_id: str) -> List[Path]:
    paths = []
    if not RUN_LOG.exists():
        return paths
    with open(RUN_LOG, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line: continue
            try: obj = json.loads(line)
            except Exception: continue
            if str(obj.get("run_id","")) != run_id:
                continue
            for key in ("dst","path"):
                p = obj.get(key)
                if p:
                    P = Path(p)
                    if P.exists():
                        try: paths.append(P.resolve())
                        except Exception: paths.append(P)
    # únicos
    uniq, seen = [], set()
    for p in paths:
        if p not in seen:
            uniq.append(p); seen.add(p)
    return uniq

def _paths_recent_by_mtime(hours: int) -> List[Path]:
    cutoff = time.time() - hours*3600
    acc = []
    for base in (SOURCE_DIR, META_DIR, WIN_DIR):
        if not base.exists(): continue
        for p in _iter_files(base):
            try:
                if p.stat().st_mtime >= cutoff:
                    acc.append(p.resolve())
            except Exception:
                pass
    return acc

def _paths_from_catalog_polars() -> List[Path]:
    """Ajuste: indexar desde catálogos cuando aplique. Si existe dataset_catalog, devolvemos
    paths de 'symbol=*/year=*/month=*/part=*.parquet' sólo para símbolos presentes (rápido)."""
    if not _HAS_PL or not CATALOG_PATH.exists():
        return []
    try:
        df = pl.read_parquet(CATALOG_PATH, columns=["symbol"])
        syms = df["symbol"].unique().drop_nulls().cast(pl.Utf8).to_list()
        out = []
        for s in syms:
            sdir = SOURCE_DIR / f"symbol={s}"
            if sdir.exists():
                for p in sdir.rglob("part=*.parquet"):
                    out.append(p.resolve())
        return out
    except Exception:
        return []

# Construir set de archivos candidatos
changed_files = set()
# 1) run_log con Polars (preferido)
changed_files.update(_paths_from_runlog_polars(RUN_ID))
# 2) fallback a parsing Python
if not changed_files:
    changed_files.update(_paths_from_runlog_python(RUN_ID))
# 3) si sigue vacío, usar mtime reciente
if not changed_files:
    _log("WARNING", f"No se hallaron archivos por RUN_ID en run_log; usando fallback mtime ({MTIME_FALLBACK_HOURS}h).")
    changed_files.update(_paths_recent_by_mtime(MTIME_FALLBACK_HOURS))
# 4) Ajuste: añadir índice desde catálogo si aplica (para cubrir promociones en masa)
if _HAS_PL and CATALOG_PATH.exists():
    changed_files.update(_paths_from_catalog_polars())

# Quitar duplicados y asegurar pertenencia a DATA_ROOT
changed_files = sorted({p for p in changed_files if str(p).startswith(str(DATA_ROOT)) and p.is_file()})

# --------------------------- Cabecera homogénea TZ --------------------------------
print("="*110, flush=True)
print(f"Inicio Celda 13 — Backup, checksums y cierre | TZ local: {TIMEZONE_IANA}", flush=True)
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}", flush=True)
print("-"*110, flush=True)
print(f"DATA_ROOT: {DATA_ROOT}", flush=True)
print(f"Origen principal de backup: {source_label} → {SOURCE_DIR}", flush=True)
print(f"Ventanas (si existen): {WIN_DIR}", flush=True)
print(f"Metadata: {META_DIR}", flush=True)
print("-"*110, flush=True)

# --------------------------- Manifest --------------------------------------------
def _count_symbols_and_files(base: Path) -> Tuple[int, int, int]:
    if not base.exists(): return 0,0,0
    symbols, files, bytes_total = set(), 0, 0
    for p in _iter_files(base):
        files += 1
        bytes_total += _size_bytes(p)
        for pr in Path(p).parts:
            if pr.startswith("symbol="):
                symbols.add(pr.split("=",1)[-1]); break
    return len(symbols), files, bytes_total

def _pkg_ver(name: str) -> str | None:
    try:
        mod = __import__(name)
        return getattr(mod, "__version__", None)
    except Exception:
        return None

n_symbols_src, n_files_src, bytes_src = _count_symbols_and_files(SOURCE_DIR)

manifest = {
    "run_id": RUN_ID,
    "platform": platform.platform(),
    "user": getpass.getuser(),
    "python": sys.version.split()[0],
    "versions": {"polars": _pkg_ver("polars"), "pyarrow": _pkg_ver("pyarrow"), "MetaTrader5": _pkg_ver("MetaTrader5")},
    "tz_local": TIMEZONE_IANA,
    "data_root": str(DATA_ROOT),
    "paths": {"source": str(SOURCE_DIR), "windows": str(WIN_DIR), "metadata": str(META_DIR)},
    "source_used": source_label,
    "counts": {"symbols_source": n_symbols_src, "files_source": n_files_src, "bytes_source": bytes_src},
    "changed_files_in_run": len(changed_files),
    "timestamps": {"manifest_created_utc": datetime.now(timezone.utc).isoformat()}
}
MANIFEST_PATH.write_text(json.dumps(manifest, ensure_ascii=False, indent=2), encoding="utf-8")
print(f"Manifest escrito en: {MANIFEST_PATH}", flush=True)

# --------------------------- Checksums (SHA-256) con QA ---------------------------
print("-"*110, flush=True)
print("Calculando checksums SHA-256 de archivos nuevos/modificados en esta corrida...", flush=True)

# Cargar últimas huellas previas por path para detectar mismatches
prev_hash: Dict[str, str] = {}
if CHECKSUMS_PATH.exists():
    try:
        # Leemos sólo última ocurrencia por path (si hay muchas líneas puede ser pesado -> usamos Polars si hay)
        if _HAS_PL:
            df_prev = pl.scan_ndjson(str(CHECKSUMS_PATH)).select(["path","sha256"]).collect()
            # nos quedamos con la última por path (orden natural del archivo: no garantizado; pero un group_by_last basta)
            df_prev = df_prev.reverse().unique(subset=["path"], keep="first")
            prev_hash = {r["path"]: r["sha256"] for r in df_prev.iter_rows(named=True)}
        else:
            seen = set()
            with open(CHECKSUMS_PATH, "r", encoding="utf-8") as f:
                lines = f.readlines()
            for line in reversed(lines):
                try:
                    obj = json.loads(line)
                    pth = obj.get("path"); sh = obj.get("sha256")
                    if pth and sh and pth not in seen:
                        prev_hash[pth] = sh; seen.add(pth)
                except Exception:
                    continue
    except Exception:
        prev_hash = {}

failures: List[Path] = []
checksums_written = 0
mismatches = 0
hashed_bytes = 0

t0 = time.monotonic()
last_beat = t0

with open(CHECKSUMS_PATH, "a", encoding="utf-8") as outjs:
    for i, p in enumerate(changed_files, start=1):
        try:
            sha = _sha256(p)
            sz = _size_bytes(p)
            rec = {
                "run_id": RUN_ID,
                "path": str(p),
                "size": sz,
                "sha256": sha,
                "mtime_utc": datetime.fromtimestamp(p.stat().st_mtime, tz=timezone.utc).isoformat()
            }
            outjs.write(json.dumps(rec, ensure_ascii=False) + "\n")
            checksums_written += 1
            hashed_bytes += sz

            # Mismatch: si existía hash previo para este path y difiere → incremento
            prev = prev_hash.get(str(p))
            if prev is not None and prev != sha:
                mismatches += 1

        except Exception:
            failures.append(p)

        # Heartbeat
        now = time.monotonic()
        if (i % 50 == 0) or (now - last_beat >= HEARTBEAT_SECS):
            rate_files = i / max(now - t0, 1e-6)
            rate_mib = (hashed_bytes/1048576) / max(now - t0, 1e-6)
            _log("INFO", f"Checksums: {i}/{len(changed_files)} archivos | {rate_files:.1f} files/s | {rate_mib:.2f} MiB/s")
            last_beat = now

rate_files = (checksums_written / max(time.monotonic() - t0, 1e-6))
rate_mib = ((hashed_bytes/1048576) / max(time.monotonic() - t0, 1e-6))

print(f"Checksums escritos en: {CHECKSUMS_PATH} (líneas nuevas={checksums_written})", flush=True)
print(f"Hashing: archivos={checksums_written} | bytes={hashed_bytes} ({_fmt_bytes(hashed_bytes)}) | tasa={rate_files:.1f} files/s, {rate_mib:.2f} MiB/s", flush=True)

if failures:
    print("⚠️  Archivos con fallo de checksum/lectura:", flush=True)
    for p in failures[:20]:
        print("  -", str(p), flush=True)
    if len(failures) > 20:
        print(f"  ... y {len(failures)-20} más", flush=True)

print(f"Mismatches detectados respecto a último registro previo: {mismatches}", flush=True)
if mismatches == 0:
    print("✅ QA checksums: mismatches=0", flush=True)
else:
    print("⚠️  QA checksums: existen mismatches (verificar cambios esperados o integridad).", flush=True)

# --------------------------- Backup (ZIP) -----------------------------------------
print("-"*110, flush=True)
backup_name = f"backup_m5_{RUN_ID}.zip"
backup_path = BACKUPS_DIR / backup_name

def _zip_add_dir(zf: zipfile.ZipFile, base: Path):
    base = base.resolve()
    if not base.exists(): return 0, 0
    added, total_bytes = 0, 0
    for p in _iter_files(base):
        rel = p.resolve().relative_to(DATA_ROOT)
        zf.write(p, arcname=str(rel))
        added += 1
        total_bytes += _size_bytes(p)
    return added, total_bytes

print("Creando backup (zip)...", flush=True)
files_in_zip = 0
bytes_uncompressed = 0
with zipfile.ZipFile(backup_path, mode="w", compression=zipfile.ZIP_DEFLATED, compresslevel=6) as zf:
    _log("INFO", f"Añadiendo {source_label} ...")
    a, b = _zip_add_dir(zf, SOURCE_DIR); files_in_zip += a; bytes_uncompressed += b
    _log("INFO", "Añadiendo metadata/ ...")
    a, b = _zip_add_dir(zf, META_DIR);   files_in_zip += a; bytes_uncompressed += b
    if WIN_DIR.exists():
        _log("INFO", "Añadiendo processed_data/m5_windows/ ...")
        a, b = _zip_add_dir(zf, WIN_DIR); files_in_zip += a; bytes_uncompressed += b

zip_size = _size_bytes(backup_path)
print(f"Backup creado en: {backup_path}", flush=True)
print(f"  - Archivos incluidos: {files_in_zip} | Bytes sin comprimir (aprox): {_fmt_bytes(bytes_uncompressed)}", flush=True)
print(f"  - Tamaño ZIP: {_fmt_bytes(zip_size)}", flush=True)
if zip_size <= 0:
    print("⚠️  Backup con tamaño 0. Revisa permisos/espacio en disco.", flush=True)

# --------------------------- Cierre de MT5 -----------------------------------------
print("-"*110, flush=True)
mt5_status = "NO-OP"
if _HAS_MT5:
    try:
        mt5.shutdown()
        mt5_status = "OK"
    except Exception as e:
        mt5_status = f"ERROR: {e.__class__.__name__}"
print(f"Estado de desconexión MT5: {mt5_status}", flush=True)

# --------------------------- Resumen final -----------------------------------------
print("-"*110, flush=True)
print("Resumen:", flush=True)
print(f"  • Archivos hasheados: {checksums_written} | Bytes: {_fmt_bytes(hashed_bytes)} | Tasa: {rate_files:.1f} files/s, {rate_mib:.2f} MiB/s", flush=True)
print(f"  • Mismatches: {mismatches}", flush=True)
print(f"  • Backup ZIP: {backup_path}", flush=True)
print("✅ Cierre completo del pipeline de extracción M5: OK", flush=True)
# ==============================================================================================================
# Out:
# ==============================================================================================================
# Inicio Celda 13 — Backup, checksums y cierre | TZ local: America/Guayaquil
# Hora local: 2025-12-02T23:41:05-05:00 | Hora UTC: 2025-12-03T04:41:05+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT: C:\Quant\MT5_Data_Extraction\data
# Origen principal de backup: historical_data/m5_clean → C:\Quant\MT5_Data_Extraction\data\historical_data\m5_clean
# Ventanas (si existen): C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows
# Metadata: C:\Quant\MT5_Data_Extraction\data\metadata
# --------------------------------------------------------------------------------------------------------------
# Manifest escrito en: C:\Quant\MT5_Data_Extraction\data\metadata\manifest.json
# --------------------------------------------------------------------------------------------------------------
# Calculando checksums SHA-256 de archivos nuevos/modificados en esta corrida...
# [2025-12-02T23:41:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 50/103946 archivos | 188.0 files/s | 1.13 MiB/s
# [2025-12-02T23:41:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100/103946 archivos | 193.8 files/s | 1.16 MiB/s
# [2025-12-02T23:41:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 150/103946 archivos | 181.2 files/s | 1.08 MiB/s
# [2025-12-02T23:41:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 200/103946 archivos | 175.3 files/s | 1.05 MiB/s
# [2025-12-02T23:41:11-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 250/103946 archivos | 163.3 files/s | 0.98 MiB/s
# [2025-12-02T23:41:11-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 300/103946 archivos | 156.1 files/s | 0.93 MiB/s
# [2025-12-02T23:41:11-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 350/103946 archivos | 161.1 files/s | 0.96 MiB/s
# [2025-12-02T23:41:12-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 400/103946 archivos | 148.8 files/s | 0.89 MiB/s
# [2025-12-02T23:41:12-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 450/103946 archivos | 151.6 files/s | 0.90 MiB/s
# [2025-12-02T23:41:13-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 500/103946 archivos | 146.1 files/s | 0.87 MiB/s
# [2025-12-02T23:41:13-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 550/103946 archivos | 147.3 files/s | 0.88 MiB/s
# [2025-12-02T23:41:13-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 600/103946 archivos | 149.4 files/s | 0.89 MiB/s
# [2025-12-02T23:41:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 650/103946 archivos | 149.6 files/s | 0.89 MiB/s
# [2025-12-02T23:41:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 700/103946 archivos | 151.4 files/s | 0.90 MiB/s
# [2025-12-02T23:41:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 750/103946 archivos | 151.9 files/s | 0.90 MiB/s
# [2025-12-02T23:41:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 800/103946 archivos | 152.4 files/s | 0.91 MiB/s
# [2025-12-02T23:41:15-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 850/103946 archivos | 151.1 files/s | 0.90 MiB/s
# [2025-12-02T23:41:15-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 900/103946 archivos | 149.2 files/s | 0.89 MiB/s
# [2025-12-02T23:41:16-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 950/103946 archivos | 150.9 files/s | 0.90 MiB/s
# [2025-12-02T23:41:16-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1000/103946 archivos | 149.2 files/s | 0.89 MiB/s
# [2025-12-02T23:41:16-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1050/103946 archivos | 150.0 files/s | 0.89 MiB/s
# [2025-12-02T23:41:17-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1100/103946 archivos | 149.5 files/s | 0.88 MiB/s
# [2025-12-02T23:41:17-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1150/103946 archivos | 149.0 files/s | 0.87 MiB/s
# [2025-12-02T23:41:17-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1200/103946 archivos | 150.9 files/s | 0.87 MiB/s
# [2025-12-02T23:41:17-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1250/103946 archivos | 152.1 files/s | 0.88 MiB/s
# [2025-12-02T23:41:18-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1300/103946 archivos | 153.5 files/s | 0.91 MiB/s
# [2025-12-02T23:41:18-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1350/103946 archivos | 153.7 files/s | 0.93 MiB/s
# [2025-12-02T23:41:18-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1400/103946 archivos | 154.2 files/s | 0.95 MiB/s
# [2025-12-02T23:41:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1450/103946 archivos | 154.7 files/s | 0.97 MiB/s
# [2025-12-02T23:41:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1500/103946 archivos | 153.8 files/s | 0.98 MiB/s
# [2025-12-02T23:41:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1550/103946 archivos | 154.3 files/s | 1.00 MiB/s
# [2025-12-02T23:41:20-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1600/103946 archivos | 154.0 files/s | 1.01 MiB/s
# [2025-12-02T23:41:20-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1650/103946 archivos | 153.7 files/s | 1.02 MiB/s
# [2025-12-02T23:41:20-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1700/103946 archivos | 154.5 files/s | 1.03 MiB/s
# [2025-12-02T23:41:21-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1750/103946 archivos | 155.3 files/s | 1.05 MiB/s
# [2025-12-02T23:41:21-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1800/103946 archivos | 154.2 files/s | 1.05 MiB/s
# [2025-12-02T23:41:21-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1850/103946 archivos | 153.8 files/s | 1.06 MiB/s
# [2025-12-02T23:41:22-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1900/103946 archivos | 153.9 files/s | 1.07 MiB/s
# [2025-12-02T23:41:22-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 1950/103946 archivos | 153.7 files/s | 1.08 MiB/s
# [2025-12-02T23:41:22-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2000/103946 archivos | 153.3 files/s | 1.08 MiB/s
# [2025-12-02T23:41:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2050/103946 archivos | 152.7 files/s | 1.09 MiB/s
# [2025-12-02T23:41:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2100/103946 archivos | 153.1 files/s | 1.10 MiB/s
# [2025-12-02T23:41:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2150/103946 archivos | 152.7 files/s | 1.10 MiB/s
# [2025-12-02T23:41:24-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2200/103946 archivos | 152.2 files/s | 1.10 MiB/s
# [2025-12-02T23:41:24-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2250/103946 archivos | 152.4 files/s | 1.11 MiB/s
# [2025-12-02T23:41:24-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2300/103946 archivos | 152.9 files/s | 1.12 MiB/s
# [2025-12-02T23:41:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2350/103946 archivos | 153.2 files/s | 1.13 MiB/s
# [2025-12-02T23:41:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2400/103946 archivos | 153.0 files/s | 1.14 MiB/s
# [2025-12-02T23:41:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2450/103946 archivos | 153.6 files/s | 1.15 MiB/s
# [2025-12-02T23:41:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2500/103946 archivos | 153.6 files/s | 1.15 MiB/s
# [2025-12-02T23:41:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2550/103946 archivos | 154.1 files/s | 1.15 MiB/s
# [2025-12-02T23:41:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2600/103946 archivos | 154.6 files/s | 1.14 MiB/s
# [2025-12-02T23:41:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2650/103946 archivos | 155.3 files/s | 1.14 MiB/s
# [2025-12-02T23:41:27-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2700/103946 archivos | 154.8 files/s | 1.13 MiB/s
# [2025-12-02T23:41:27-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2750/103946 archivos | 154.9 files/s | 1.12 MiB/s
# [2025-12-02T23:41:27-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2800/103946 archivos | 155.0 files/s | 1.12 MiB/s
# [2025-12-02T23:41:28-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2850/103946 archivos | 155.5 files/s | 1.13 MiB/s
# [2025-12-02T23:41:28-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2900/103946 archivos | 156.1 files/s | 1.14 MiB/s
# [2025-12-02T23:41:28-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 2950/103946 archivos | 156.0 files/s | 1.15 MiB/s
# [2025-12-02T23:41:29-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3000/103946 archivos | 155.5 files/s | 1.15 MiB/s
# [2025-12-02T23:41:29-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3050/103946 archivos | 155.8 files/s | 1.16 MiB/s
# [2025-12-02T23:41:29-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3100/103946 archivos | 154.3 files/s | 1.15 MiB/s
# [2025-12-02T23:41:30-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3150/103946 archivos | 153.8 files/s | 1.15 MiB/s
# [2025-12-02T23:41:30-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3200/103946 archivos | 154.2 files/s | 1.16 MiB/s
# [2025-12-02T23:41:30-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3250/103946 archivos | 153.8 files/s | 1.16 MiB/s
# [2025-12-02T23:41:31-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3300/103946 archivos | 153.7 files/s | 1.16 MiB/s
# [2025-12-02T23:41:31-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3350/103946 archivos | 153.2 files/s | 1.17 MiB/s
# [2025-12-02T23:41:32-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3400/103946 archivos | 152.2 files/s | 1.17 MiB/s
# [2025-12-02T23:41:32-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3450/103946 archivos | 152.4 files/s | 1.17 MiB/s
# [2025-12-02T23:41:32-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3500/103946 archivos | 152.1 files/s | 1.18 MiB/s
# [2025-12-02T23:41:33-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3550/103946 archivos | 151.4 files/s | 1.18 MiB/s
# [2025-12-02T23:41:33-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3600/103946 archivos | 151.3 files/s | 1.18 MiB/s
# [2025-12-02T23:41:33-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3650/103946 archivos | 151.4 files/s | 1.19 MiB/s
# [2025-12-02T23:41:34-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3700/103946 archivos | 150.7 files/s | 1.19 MiB/s
# [2025-12-02T23:41:34-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3750/103946 archivos | 150.8 files/s | 1.20 MiB/s
# [2025-12-02T23:41:34-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3800/103946 archivos | 151.0 files/s | 1.21 MiB/s
# [2025-12-02T23:41:35-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3850/103946 archivos | 150.8 files/s | 1.21 MiB/s
# [2025-12-02T23:41:35-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3900/103946 archivos | 151.0 files/s | 1.22 MiB/s
# [2025-12-02T23:41:35-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 3950/103946 archivos | 151.2 files/s | 1.23 MiB/s
# [2025-12-02T23:41:36-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4000/103946 archivos | 151.6 files/s | 1.23 MiB/s
# [2025-12-02T23:41:36-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4050/103946 archivos | 152.0 files/s | 1.23 MiB/s
# [2025-12-02T23:41:36-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4100/103946 archivos | 152.1 files/s | 1.23 MiB/s
# [2025-12-02T23:41:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4150/103946 archivos | 151.9 files/s | 1.22 MiB/s
# [2025-12-02T23:41:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4200/103946 archivos | 152.4 files/s | 1.22 MiB/s
# [2025-12-02T23:41:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4250/103946 archivos | 152.2 files/s | 1.21 MiB/s
# [2025-12-02T23:41:38-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4300/103946 archivos | 152.1 files/s | 1.20 MiB/s
# [2025-12-02T23:41:38-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4350/103946 archivos | 151.4 files/s | 1.19 MiB/s
# [2025-12-02T23:41:38-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4400/103946 archivos | 151.6 files/s | 1.19 MiB/s
# [2025-12-02T23:41:39-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4450/103946 archivos | 151.2 files/s | 1.18 MiB/s
# [2025-12-02T23:41:39-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4500/103946 archivos | 151.3 files/s | 1.18 MiB/s
# [2025-12-02T23:41:40-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4550/103946 archivos | 150.0 files/s | 1.16 MiB/s
# [2025-12-02T23:41:40-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4600/103946 archivos | 150.4 files/s | 1.16 MiB/s
# [2025-12-02T23:41:40-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4650/103946 archivos | 150.3 files/s | 1.16 MiB/s
# [2025-12-02T23:41:41-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4700/103946 archivos | 149.4 files/s | 1.15 MiB/s
# [2025-12-02T23:41:41-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4750/103946 archivos | 149.4 files/s | 1.15 MiB/s
# [2025-12-02T23:41:41-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4800/103946 archivos | 149.8 files/s | 1.15 MiB/s
# [2025-12-02T23:41:42-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4850/103946 archivos | 149.4 files/s | 1.14 MiB/s
# [2025-12-02T23:41:42-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4900/103946 archivos | 149.3 files/s | 1.14 MiB/s
# [2025-12-02T23:41:42-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 4950/103946 archivos | 149.2 files/s | 1.13 MiB/s
# [2025-12-02T23:41:43-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5000/103946 archivos | 149.0 files/s | 1.13 MiB/s
# [2025-12-02T23:41:43-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5050/103946 archivos | 148.4 files/s | 1.13 MiB/s
# [2025-12-02T23:41:44-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5100/103946 archivos | 148.2 files/s | 1.13 MiB/s
# [2025-12-02T23:41:44-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5150/103946 archivos | 148.4 files/s | 1.14 MiB/s
# [2025-12-02T23:41:44-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5200/103946 archivos | 148.2 files/s | 1.14 MiB/s
# [2025-12-02T23:41:45-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5250/103946 archivos | 148.1 files/s | 1.15 MiB/s
# [2025-12-02T23:41:45-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5300/103946 archivos | 148.1 files/s | 1.15 MiB/s
# [2025-12-02T23:41:45-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5350/103946 archivos | 148.0 files/s | 1.15 MiB/s
# [2025-12-02T23:41:46-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5400/103946 archivos | 148.1 files/s | 1.16 MiB/s
# [2025-12-02T23:41:46-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5450/103946 archivos | 148.4 files/s | 1.16 MiB/s
# [2025-12-02T23:41:46-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5500/103946 archivos | 148.5 files/s | 1.16 MiB/s
# [2025-12-02T23:41:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5550/103946 archivos | 148.2 files/s | 1.16 MiB/s
# [2025-12-02T23:41:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5600/103946 archivos | 147.6 files/s | 1.16 MiB/s
# [2025-12-02T23:41:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5650/103946 archivos | 147.7 files/s | 1.16 MiB/s
# [2025-12-02T23:41:48-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5700/103946 archivos | 147.8 files/s | 1.16 MiB/s
# [2025-12-02T23:41:48-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5750/103946 archivos | 147.1 files/s | 1.15 MiB/s
# [2025-12-02T23:41:49-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5800/103946 archivos | 147.0 files/s | 1.15 MiB/s
# [2025-12-02T23:41:49-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5850/103946 archivos | 146.8 files/s | 1.15 MiB/s
# [2025-12-02T23:41:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5900/103946 archivos | 146.5 files/s | 1.15 MiB/s
# [2025-12-02T23:41:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 5950/103946 archivos | 146.5 files/s | 1.16 MiB/s
# [2025-12-02T23:41:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6000/103946 archivos | 146.5 files/s | 1.16 MiB/s
# [2025-12-02T23:41:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6050/103946 archivos | 146.8 files/s | 1.16 MiB/s
# [2025-12-02T23:41:51-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6100/103946 archivos | 147.0 files/s | 1.16 MiB/s
# [2025-12-02T23:41:51-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6150/103946 archivos | 146.8 files/s | 1.16 MiB/s
# [2025-12-02T23:41:51-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6200/103946 archivos | 146.9 files/s | 1.17 MiB/s
# [2025-12-02T23:41:52-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6250/103946 archivos | 147.0 files/s | 1.17 MiB/s
# [2025-12-02T23:41:52-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6300/103946 archivos | 147.2 files/s | 1.17 MiB/s
# [2025-12-02T23:41:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6350/103946 archivos | 146.4 files/s | 1.17 MiB/s
# [2025-12-02T23:41:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6400/103946 archivos | 146.5 files/s | 1.17 MiB/s
# [2025-12-02T23:41:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6450/103946 archivos | 146.6 files/s | 1.17 MiB/s
# [2025-12-02T23:41:54-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6500/103946 archivos | 146.5 files/s | 1.17 MiB/s
# [2025-12-02T23:41:54-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6550/103946 archivos | 146.1 files/s | 1.17 MiB/s
# [2025-12-02T23:41:54-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6600/103946 archivos | 146.2 files/s | 1.16 MiB/s
# [2025-12-02T23:41:55-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6650/103946 archivos | 145.9 files/s | 1.16 MiB/s
# [2025-12-02T23:41:55-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6700/103946 archivos | 146.0 files/s | 1.16 MiB/s
# [2025-12-02T23:41:55-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6750/103946 archivos | 146.0 files/s | 1.16 MiB/s
# [2025-12-02T23:41:56-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6800/103946 archivos | 145.8 files/s | 1.15 MiB/s
# [2025-12-02T23:41:56-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6850/103946 archivos | 145.7 files/s | 1.15 MiB/s
# [2025-12-02T23:41:57-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6900/103946 archivos | 145.0 files/s | 1.14 MiB/s
# [2025-12-02T23:41:57-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 6950/103946 archivos | 144.9 files/s | 1.14 MiB/s
# [2025-12-02T23:41:58-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7000/103946 archivos | 144.9 files/s | 1.14 MiB/s
# [2025-12-02T23:41:58-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7050/103946 archivos | 144.7 files/s | 1.13 MiB/s
# [2025-12-02T23:41:58-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7100/103946 archivos | 145.0 files/s | 1.13 MiB/s
# [2025-12-02T23:41:59-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7150/103946 archivos | 145.1 files/s | 1.13 MiB/s
# [2025-12-02T23:41:59-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7200/103946 archivos | 144.6 files/s | 1.13 MiB/s
# [2025-12-02T23:41:59-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7250/103946 archivos | 144.7 files/s | 1.13 MiB/s
# [2025-12-02T23:42:00-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7300/103946 archivos | 144.7 files/s | 1.12 MiB/s
# [2025-12-02T23:42:00-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7350/103946 archivos | 144.7 files/s | 1.12 MiB/s
# [2025-12-02T23:42:00-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7400/103946 archivos | 144.8 files/s | 1.12 MiB/s
# [2025-12-02T23:42:01-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7450/103946 archivos | 144.7 files/s | 1.12 MiB/s
# [2025-12-02T23:42:01-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7500/103946 archivos | 145.0 files/s | 1.12 MiB/s
# [2025-12-02T23:42:01-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7550/103946 archivos | 144.9 files/s | 1.12 MiB/s
# [2025-12-02T23:42:02-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7600/103946 archivos | 144.8 files/s | 1.11 MiB/s
# [2025-12-02T23:42:02-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7650/103946 archivos | 144.6 files/s | 1.11 MiB/s
# [2025-12-02T23:42:02-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7700/103946 archivos | 144.7 files/s | 1.11 MiB/s
# [2025-12-02T23:42:03-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7750/103946 archivos | 144.9 files/s | 1.11 MiB/s
# [2025-12-02T23:42:03-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7800/103946 archivos | 144.8 files/s | 1.11 MiB/s
# [2025-12-02T23:42:03-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7850/103946 archivos | 145.0 files/s | 1.11 MiB/s
# [2025-12-02T23:42:04-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7900/103946 archivos | 145.0 files/s | 1.10 MiB/s
# [2025-12-02T23:42:04-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 7950/103946 archivos | 144.9 files/s | 1.10 MiB/s
# [2025-12-02T23:42:05-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8000/103946 archivos | 144.6 files/s | 1.10 MiB/s
# [2025-12-02T23:42:05-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8050/103946 archivos | 144.7 files/s | 1.10 MiB/s
# [2025-12-02T23:42:05-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8100/103946 archivos | 144.9 files/s | 1.10 MiB/s
# [2025-12-02T23:42:05-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8150/103946 archivos | 145.0 files/s | 1.10 MiB/s
# [2025-12-02T23:42:06-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8200/103946 archivos | 144.8 files/s | 1.09 MiB/s
# [2025-12-02T23:42:06-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8250/103946 archivos | 144.9 files/s | 1.09 MiB/s
# [2025-12-02T23:42:07-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8300/103946 archivos | 145.0 files/s | 1.09 MiB/s
# [2025-12-02T23:42:07-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8350/103946 archivos | 144.7 files/s | 1.09 MiB/s
# [2025-12-02T23:42:07-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8400/103946 archivos | 144.8 files/s | 1.09 MiB/s
# [2025-12-02T23:42:08-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8450/103946 archivos | 144.7 files/s | 1.09 MiB/s
# [2025-12-02T23:42:08-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8500/103946 archivos | 144.9 files/s | 1.09 MiB/s
# [2025-12-02T23:42:08-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8550/103946 archivos | 145.0 files/s | 1.09 MiB/s
# [2025-12-02T23:42:09-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8600/103946 archivos | 145.1 files/s | 1.10 MiB/s
# [2025-12-02T23:42:09-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8650/103946 archivos | 145.0 files/s | 1.10 MiB/s
# [2025-12-02T23:42:09-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8700/103946 archivos | 144.7 files/s | 1.10 MiB/s
# [2025-12-02T23:42:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8750/103946 archivos | 144.8 files/s | 1.11 MiB/s
# [2025-12-02T23:42:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8800/103946 archivos | 144.8 files/s | 1.11 MiB/s
# [2025-12-02T23:42:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8850/103946 archivos | 144.9 files/s | 1.11 MiB/s
# [2025-12-02T23:42:11-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8900/103946 archivos | 145.1 files/s | 1.12 MiB/s
# [2025-12-02T23:42:11-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 8950/103946 archivos | 144.8 files/s | 1.12 MiB/s
# [2025-12-02T23:42:11-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9000/103946 archivos | 145.0 files/s | 1.13 MiB/s
# [2025-12-02T23:42:12-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9050/103946 archivos | 145.1 files/s | 1.13 MiB/s
# [2025-12-02T23:42:12-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9100/103946 archivos | 145.2 files/s | 1.13 MiB/s
# [2025-12-02T23:42:12-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9150/103946 archivos | 145.0 files/s | 1.14 MiB/s
# [2025-12-02T23:42:13-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9200/103946 archivos | 145.0 files/s | 1.14 MiB/s
# [2025-12-02T23:42:13-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9250/103946 archivos | 145.2 files/s | 1.14 MiB/s
# [2025-12-02T23:42:13-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9300/103946 archivos | 145.3 files/s | 1.15 MiB/s
# [2025-12-02T23:42:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9350/103946 archivos | 144.8 files/s | 1.15 MiB/s
# [2025-12-02T23:42:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9400/103946 archivos | 144.6 files/s | 1.15 MiB/s
# [2025-12-02T23:42:15-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9450/103946 archivos | 144.6 files/s | 1.15 MiB/s
# [2025-12-02T23:42:15-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9500/103946 archivos | 144.6 files/s | 1.16 MiB/s
# [2025-12-02T23:42:15-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9550/103946 archivos | 144.7 files/s | 1.16 MiB/s
# [2025-12-02T23:42:16-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9600/103946 archivos | 144.9 files/s | 1.16 MiB/s
# [2025-12-02T23:42:16-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9650/103946 archivos | 144.9 files/s | 1.17 MiB/s
# [2025-12-02T23:42:16-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9700/103946 archivos | 144.8 files/s | 1.17 MiB/s
# [2025-12-02T23:42:17-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9750/103946 archivos | 144.7 files/s | 1.17 MiB/s
# [2025-12-02T23:42:17-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9800/103946 archivos | 144.7 files/s | 1.18 MiB/s
# [2025-12-02T23:42:17-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9850/103946 archivos | 144.6 files/s | 1.18 MiB/s
# [2025-12-02T23:42:18-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9900/103946 archivos | 144.7 files/s | 1.18 MiB/s
# [2025-12-02T23:42:18-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 9950/103946 archivos | 144.8 files/s | 1.19 MiB/s
# [2025-12-02T23:42:18-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10000/103946 archivos | 144.6 files/s | 1.19 MiB/s
# [2025-12-02T23:42:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10050/103946 archivos | 144.7 files/s | 1.19 MiB/s
# [2025-12-02T23:42:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10100/103946 archivos | 144.7 files/s | 1.19 MiB/s
# [2025-12-02T23:42:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10150/103946 archivos | 144.9 files/s | 1.20 MiB/s
# [2025-12-02T23:42:20-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10200/103946 archivos | 144.3 files/s | 1.19 MiB/s
# [2025-12-02T23:42:20-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10250/103946 archivos | 144.4 files/s | 1.20 MiB/s
# [2025-12-02T23:42:21-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10300/103946 archivos | 144.4 files/s | 1.20 MiB/s
# [2025-12-02T23:42:21-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10350/103946 archivos | 144.4 files/s | 1.20 MiB/s
# [2025-12-02T23:42:21-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10400/103946 archivos | 144.0 files/s | 1.20 MiB/s
# [2025-12-02T23:42:22-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10450/103946 archivos | 144.0 files/s | 1.20 MiB/s
# [2025-12-02T23:42:22-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10500/103946 archivos | 144.3 files/s | 1.21 MiB/s
# [2025-12-02T23:42:22-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10550/103946 archivos | 144.4 files/s | 1.21 MiB/s
# [2025-12-02T23:42:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10600/103946 archivos | 144.5 files/s | 1.21 MiB/s
# [2025-12-02T23:42:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10650/103946 archivos | 144.7 files/s | 1.22 MiB/s
# [2025-12-02T23:42:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10700/103946 archivos | 144.7 files/s | 1.22 MiB/s
# [2025-12-02T23:42:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10750/103946 archivos | 144.8 files/s | 1.22 MiB/s
# [2025-12-02T23:42:24-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10800/103946 archivos | 144.7 files/s | 1.22 MiB/s
# [2025-12-02T23:42:24-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10850/103946 archivos | 144.8 files/s | 1.23 MiB/s
# [2025-12-02T23:42:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10900/103946 archivos | 144.6 files/s | 1.23 MiB/s
# [2025-12-02T23:42:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 10950/103946 archivos | 144.6 files/s | 1.23 MiB/s
# [2025-12-02T23:42:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11000/103946 archivos | 144.6 files/s | 1.23 MiB/s
# [2025-12-02T23:42:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11050/103946 archivos | 144.4 files/s | 1.23 MiB/s
# [2025-12-02T23:42:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11100/103946 archivos | 144.4 files/s | 1.23 MiB/s
# [2025-12-02T23:42:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11150/103946 archivos | 144.5 files/s | 1.23 MiB/s
# [2025-12-02T23:42:27-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11200/103946 archivos | 144.5 files/s | 1.23 MiB/s
# [2025-12-02T23:42:27-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11250/103946 archivos | 144.4 files/s | 1.23 MiB/s
# [2025-12-02T23:42:27-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11300/103946 archivos | 144.5 files/s | 1.24 MiB/s
# [2025-12-02T23:42:28-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11350/103946 archivos | 144.5 files/s | 1.24 MiB/s
# [2025-12-02T23:42:28-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11400/103946 archivos | 144.6 files/s | 1.24 MiB/s
# [2025-12-02T23:42:29-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11450/103946 archivos | 144.4 files/s | 1.24 MiB/s
# [2025-12-02T23:42:29-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11500/103946 archivos | 144.1 files/s | 1.24 MiB/s
# [2025-12-02T23:42:29-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11550/103946 archivos | 144.2 files/s | 1.24 MiB/s
# [2025-12-02T23:42:30-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11600/103946 archivos | 144.0 files/s | 1.24 MiB/s
# [2025-12-02T23:42:30-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11650/103946 archivos | 144.1 files/s | 1.24 MiB/s
# [2025-12-02T23:42:30-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11700/103946 archivos | 144.2 files/s | 1.25 MiB/s
# [2025-12-02T23:42:31-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11750/103946 archivos | 144.4 files/s | 1.25 MiB/s
# [2025-12-02T23:42:31-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11800/103946 archivos | 144.4 files/s | 1.25 MiB/s
# [2025-12-02T23:42:31-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11850/103946 archivos | 144.4 files/s | 1.25 MiB/s
# [2025-12-02T23:42:32-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11900/103946 archivos | 144.4 files/s | 1.26 MiB/s
# [2025-12-02T23:42:32-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 11950/103946 archivos | 144.2 files/s | 1.26 MiB/s
# [2025-12-02T23:42:32-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12000/103946 archivos | 144.4 files/s | 1.26 MiB/s
# [2025-12-02T23:42:33-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12050/103946 archivos | 144.3 files/s | 1.26 MiB/s
# [2025-12-02T23:42:33-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12100/103946 archivos | 144.0 files/s | 1.26 MiB/s
# [2025-12-02T23:42:34-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12150/103946 archivos | 144.1 files/s | 1.27 MiB/s
# [2025-12-02T23:42:34-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12200/103946 archivos | 144.2 files/s | 1.27 MiB/s
# [2025-12-02T23:42:34-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12250/103946 archivos | 144.4 files/s | 1.27 MiB/s
# [2025-12-02T23:42:35-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12300/103946 archivos | 144.1 files/s | 1.27 MiB/s
# [2025-12-02T23:42:35-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12350/103946 archivos | 144.3 files/s | 1.27 MiB/s
# [2025-12-02T23:42:35-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12400/103946 archivos | 144.3 files/s | 1.28 MiB/s
# [2025-12-02T23:42:36-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12450/103946 archivos | 144.3 files/s | 1.28 MiB/s
# [2025-12-02T23:42:36-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12500/103946 archivos | 144.1 files/s | 1.28 MiB/s
# [2025-12-02T23:42:36-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12550/103946 archivos | 144.3 files/s | 1.28 MiB/s
# [2025-12-02T23:42:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12600/103946 archivos | 144.3 files/s | 1.28 MiB/s
# [2025-12-02T23:42:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12650/103946 archivos | 144.2 files/s | 1.28 MiB/s
# [2025-12-02T23:42:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12700/103946 archivos | 144.2 files/s | 1.28 MiB/s
# [2025-12-02T23:42:38-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12750/103946 archivos | 144.3 files/s | 1.29 MiB/s
# [2025-12-02T23:42:38-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12800/103946 archivos | 144.2 files/s | 1.29 MiB/s
# [2025-12-02T23:42:38-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12850/103946 archivos | 144.1 files/s | 1.29 MiB/s
# [2025-12-02T23:42:39-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12900/103946 archivos | 144.1 files/s | 1.29 MiB/s
# [2025-12-02T23:42:39-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 12950/103946 archivos | 144.0 files/s | 1.29 MiB/s
# [2025-12-02T23:42:39-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13000/103946 archivos | 144.1 files/s | 1.30 MiB/s
# [2025-12-02T23:42:40-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13050/103946 archivos | 144.1 files/s | 1.30 MiB/s
# [2025-12-02T23:42:40-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13100/103946 archivos | 144.2 files/s | 1.30 MiB/s
# [2025-12-02T23:42:41-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13150/103946 archivos | 143.9 files/s | 1.30 MiB/s
# [2025-12-02T23:42:41-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13200/103946 archivos | 144.0 files/s | 1.30 MiB/s
# [2025-12-02T23:42:41-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13250/103946 archivos | 144.1 files/s | 1.30 MiB/s
# [2025-12-02T23:42:42-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13300/103946 archivos | 144.1 files/s | 1.31 MiB/s
# [2025-12-02T23:42:42-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13350/103946 archivos | 144.1 files/s | 1.31 MiB/s
# [2025-12-02T23:42:42-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13400/103946 archivos | 144.2 files/s | 1.31 MiB/s
# [2025-12-02T23:42:43-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13450/103946 archivos | 144.0 files/s | 1.31 MiB/s
# [2025-12-02T23:42:43-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13500/103946 archivos | 144.0 files/s | 1.31 MiB/s
# [2025-12-02T23:42:44-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13550/103946 archivos | 143.7 files/s | 1.31 MiB/s
# [2025-12-02T23:42:44-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13600/103946 archivos | 143.7 files/s | 1.31 MiB/s
# [2025-12-02T23:42:44-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13650/103946 archivos | 143.7 files/s | 1.31 MiB/s
# [2025-12-02T23:42:45-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13700/103946 archivos | 143.7 files/s | 1.31 MiB/s
# [2025-12-02T23:42:45-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13750/103946 archivos | 143.7 files/s | 1.32 MiB/s
# [2025-12-02T23:42:45-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13800/103946 archivos | 143.8 files/s | 1.32 MiB/s
# [2025-12-02T23:42:46-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13850/103946 archivos | 143.8 files/s | 1.32 MiB/s
# [2025-12-02T23:42:46-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13900/103946 archivos | 143.9 files/s | 1.32 MiB/s
# [2025-12-02T23:42:46-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 13950/103946 archivos | 143.9 files/s | 1.32 MiB/s
# [2025-12-02T23:42:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14000/103946 archivos | 143.9 files/s | 1.32 MiB/s
# [2025-12-02T23:42:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14050/103946 archivos | 143.9 files/s | 1.32 MiB/s
# [2025-12-02T23:42:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14100/103946 archivos | 144.0 files/s | 1.32 MiB/s
# [2025-12-02T23:42:48-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14150/103946 archivos | 144.0 files/s | 1.32 MiB/s
# [2025-12-02T23:42:48-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14200/103946 archivos | 144.0 files/s | 1.32 MiB/s
# [2025-12-02T23:42:48-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14250/103946 archivos | 144.1 files/s | 1.32 MiB/s
# [2025-12-02T23:42:48-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14300/103946 archivos | 144.1 files/s | 1.31 MiB/s
# [2025-12-02T23:42:49-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14350/103946 archivos | 144.1 files/s | 1.31 MiB/s
# [2025-12-02T23:42:49-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14400/103946 archivos | 144.2 files/s | 1.31 MiB/s
# [2025-12-02T23:42:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14450/103946 archivos | 144.0 files/s | 1.31 MiB/s
# [2025-12-02T23:42:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14500/103946 archivos | 143.9 files/s | 1.31 MiB/s
# [2025-12-02T23:42:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14550/103946 archivos | 143.8 files/s | 1.31 MiB/s
# [2025-12-02T23:42:51-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14600/103946 archivos | 143.9 files/s | 1.31 MiB/s
# [2025-12-02T23:42:51-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14650/103946 archivos | 144.0 files/s | 1.31 MiB/s
# [2025-12-02T23:42:51-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14700/103946 archivos | 143.9 files/s | 1.31 MiB/s
# [2025-12-02T23:42:52-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14750/103946 archivos | 143.9 files/s | 1.31 MiB/s
# [2025-12-02T23:42:52-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14800/103946 archivos | 144.0 files/s | 1.31 MiB/s
# [2025-12-02T23:42:52-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14850/103946 archivos | 144.1 files/s | 1.31 MiB/s
# [2025-12-02T23:42:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14900/103946 archivos | 144.2 files/s | 1.31 MiB/s
# [2025-12-02T23:42:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 14950/103946 archivos | 144.4 files/s | 1.31 MiB/s
# [2025-12-02T23:42:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15000/103946 archivos | 144.4 files/s | 1.31 MiB/s
# [2025-12-02T23:42:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15050/103946 archivos | 144.4 files/s | 1.31 MiB/s
# [2025-12-02T23:42:54-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15100/103946 archivos | 144.3 files/s | 1.31 MiB/s
# [2025-12-02T23:42:54-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15150/103946 archivos | 144.3 files/s | 1.31 MiB/s
# [2025-12-02T23:42:55-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15200/103946 archivos | 144.3 files/s | 1.31 MiB/s
# [2025-12-02T23:42:55-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15250/103946 archivos | 144.4 files/s | 1.31 MiB/s
# [2025-12-02T23:42:55-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15300/103946 archivos | 144.4 files/s | 1.31 MiB/s
# [2025-12-02T23:42:56-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15350/103946 archivos | 144.3 files/s | 1.31 MiB/s
# [2025-12-02T23:42:56-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15400/103946 archivos | 144.3 files/s | 1.31 MiB/s
# [2025-12-02T23:42:56-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15450/103946 archivos | 144.4 files/s | 1.30 MiB/s
# [2025-12-02T23:42:57-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15500/103946 archivos | 144.4 files/s | 1.30 MiB/s
# [2025-12-02T23:42:57-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15550/103946 archivos | 144.4 files/s | 1.30 MiB/s
# [2025-12-02T23:42:57-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15600/103946 archivos | 144.4 files/s | 1.30 MiB/s
# [2025-12-02T23:42:58-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15650/103946 archivos | 144.5 files/s | 1.30 MiB/s
# [2025-12-02T23:42:58-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15700/103946 archivos | 144.6 files/s | 1.30 MiB/s
# [2025-12-02T23:42:58-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15750/103946 archivos | 144.7 files/s | 1.30 MiB/s
# [2025-12-02T23:42:58-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15800/103946 archivos | 144.7 files/s | 1.30 MiB/s
# [2025-12-02T23:42:59-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15850/103946 archivos | 144.8 files/s | 1.30 MiB/s
# [2025-12-02T23:42:59-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15900/103946 archivos | 144.8 files/s | 1.30 MiB/s
# [2025-12-02T23:42:59-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 15950/103946 archivos | 144.8 files/s | 1.29 MiB/s
# [2025-12-02T23:43:00-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16000/103946 archivos | 144.8 files/s | 1.29 MiB/s
# [2025-12-02T23:43:00-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16050/103946 archivos | 144.7 files/s | 1.29 MiB/s
# [2025-12-02T23:43:01-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16100/103946 archivos | 144.6 files/s | 1.29 MiB/s
# [2025-12-02T23:43:01-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16150/103946 archivos | 144.6 files/s | 1.29 MiB/s
# [2025-12-02T23:43:01-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16200/103946 archivos | 144.6 files/s | 1.29 MiB/s
# [2025-12-02T23:43:02-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16250/103946 archivos | 144.6 files/s | 1.28 MiB/s
# [2025-12-02T23:43:02-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16300/103946 archivos | 144.6 files/s | 1.28 MiB/s
# [2025-12-02T23:43:02-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16350/103946 archivos | 144.7 files/s | 1.28 MiB/s
# [2025-12-02T23:43:03-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16400/103946 archivos | 144.7 files/s | 1.28 MiB/s
# [2025-12-02T23:43:03-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16450/103946 archivos | 144.7 files/s | 1.28 MiB/s
# [2025-12-02T23:43:03-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16500/103946 archivos | 144.8 files/s | 1.28 MiB/s
# [2025-12-02T23:43:04-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16550/103946 archivos | 144.8 files/s | 1.28 MiB/s
# [2025-12-02T23:43:04-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16600/103946 archivos | 144.8 files/s | 1.28 MiB/s
# [2025-12-02T23:43:04-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16650/103946 archivos | 144.9 files/s | 1.28 MiB/s
# [2025-12-02T23:43:05-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16700/103946 archivos | 144.7 files/s | 1.28 MiB/s
# [2025-12-02T23:43:05-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16750/103946 archivos | 144.7 files/s | 1.29 MiB/s
# [2025-12-02T23:43:05-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16800/103946 archivos | 144.6 files/s | 1.29 MiB/s
# [2025-12-02T23:43:06-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16850/103946 archivos | 144.7 files/s | 1.29 MiB/s
# [2025-12-02T23:43:06-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16900/103946 archivos | 144.7 files/s | 1.29 MiB/s
# [2025-12-02T23:43:06-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 16950/103946 archivos | 144.7 files/s | 1.29 MiB/s
# [2025-12-02T23:43:07-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17000/103946 archivos | 144.7 files/s | 1.29 MiB/s
# [2025-12-02T23:43:07-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17050/103946 archivos | 144.7 files/s | 1.29 MiB/s
# [2025-12-02T23:43:07-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17100/103946 archivos | 144.8 files/s | 1.29 MiB/s
# [2025-12-02T23:43:08-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17150/103946 archivos | 144.8 files/s | 1.29 MiB/s
# [2025-12-02T23:43:08-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17200/103946 archivos | 144.8 files/s | 1.30 MiB/s
# [2025-12-02T23:43:08-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17250/103946 archivos | 144.9 files/s | 1.30 MiB/s
# [2025-12-02T23:43:09-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17300/103946 archivos | 144.9 files/s | 1.30 MiB/s
# [2025-12-02T23:43:09-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17350/103946 archivos | 144.8 files/s | 1.30 MiB/s
# [2025-12-02T23:43:09-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17400/103946 archivos | 144.8 files/s | 1.30 MiB/s
# [2025-12-02T23:43:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17450/103946 archivos | 144.9 files/s | 1.30 MiB/s
# [2025-12-02T23:43:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17500/103946 archivos | 145.0 files/s | 1.30 MiB/s
# [2025-12-02T23:43:10-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17550/103946 archivos | 145.1 files/s | 1.31 MiB/s
# [2025-12-02T23:43:11-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17600/103946 archivos | 144.9 files/s | 1.31 MiB/s
# [2025-12-02T23:43:11-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17650/103946 archivos | 145.0 files/s | 1.31 MiB/s
# [2025-12-02T23:43:11-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17700/103946 archivos | 145.0 files/s | 1.31 MiB/s
# [2025-12-02T23:43:12-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17750/103946 archivos | 145.0 files/s | 1.31 MiB/s
# [2025-12-02T23:43:12-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17800/103946 archivos | 145.0 files/s | 1.31 MiB/s
# [2025-12-02T23:43:12-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17850/103946 archivos | 145.1 files/s | 1.31 MiB/s
# [2025-12-02T23:43:13-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17900/103946 archivos | 145.2 files/s | 1.31 MiB/s
# [2025-12-02T23:43:13-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 17950/103946 archivos | 145.2 files/s | 1.31 MiB/s
# [2025-12-02T23:43:13-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18000/103946 archivos | 145.2 files/s | 1.31 MiB/s
# [2025-12-02T23:43:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18050/103946 archivos | 145.3 files/s | 1.31 MiB/s
# [2025-12-02T23:43:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18100/103946 archivos | 145.2 files/s | 1.31 MiB/s
# [2025-12-02T23:43:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18150/103946 archivos | 145.3 files/s | 1.31 MiB/s
# [2025-12-02T23:43:14-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18200/103946 archivos | 145.3 files/s | 1.31 MiB/s
# [2025-12-02T23:43:15-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18250/103946 archivos | 145.3 files/s | 1.31 MiB/s
# [2025-12-02T23:43:15-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18300/103946 archivos | 145.3 files/s | 1.31 MiB/s
# [2025-12-02T23:43:15-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18350/103946 archivos | 145.3 files/s | 1.32 MiB/s
# [2025-12-02T23:43:16-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18400/103946 archivos | 145.2 files/s | 1.31 MiB/s
# [2025-12-02T23:43:16-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18450/103946 archivos | 145.2 files/s | 1.31 MiB/s
# [2025-12-02T23:43:17-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18500/103946 archivos | 145.1 files/s | 1.31 MiB/s
# [2025-12-02T23:43:17-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 18550/103946 archivos | 145.1 files/s | 1.31 MiB/s
# ...
# [2025-12-03T05:24:18-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98150/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:18-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98200/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98250/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98300/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98350/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:19-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98400/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:20-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98450/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:20-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98500/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:20-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98550/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:21-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98600/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:21-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98650/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:21-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98700/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:22-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98750/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:22-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98800/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:22-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98850/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98900/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 98950/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:23-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99000/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:24-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99050/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:24-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99100/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:24-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99150/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99200/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99250/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99300/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:25-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99350/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99400/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99450/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:26-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99500/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:27-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99550/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:27-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99600/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:27-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99650/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:28-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99700/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:28-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99750/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:28-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99800/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:29-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99850/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:29-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99900/103946 archivos | 4.8 files/s | 0.05 MiB/s
# [2025-12-03T05:24:29-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 99950/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:30-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100000/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:30-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100050/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:30-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100100/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:31-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100150/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:31-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100200/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:31-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100250/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:32-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100300/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:32-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100350/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:32-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100400/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:33-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100450/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:33-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100500/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:33-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100550/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:34-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100600/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:34-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100650/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:34-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100700/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:35-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100750/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:35-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100800/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:35-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100850/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:36-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100900/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:36-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 100950/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:36-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101000/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101050/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101100/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101150/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:37-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101200/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:38-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101250/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:38-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101300/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:38-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101350/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:39-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101400/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:39-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101450/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:39-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101500/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:40-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101550/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:40-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101600/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:40-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101650/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:41-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101700/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:41-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101750/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:42-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101800/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:42-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101850/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:42-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101900/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:43-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 101950/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:43-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102000/103946 archivos | 4.9 files/s | 0.05 MiB/s
# [2025-12-03T05:24:43-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102050/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:44-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102100/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:44-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102150/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:44-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102200/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:45-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102250/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:45-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102300/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:45-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102350/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:46-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102400/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:46-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102450/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:46-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102500/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102550/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102600/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102650/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:47-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102700/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:48-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102750/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:48-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102800/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:48-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102850/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:49-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102900/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:49-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 102950/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:49-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103000/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103050/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103100/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:50-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103150/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:51-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103200/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:51-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103250/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:51-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103300/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:52-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103350/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:52-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103400/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:52-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103450/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103500/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103550/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:53-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103600/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:54-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103650/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:54-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103700/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:54-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103750/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:55-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103800/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:55-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103850/103946 archivos | 5.0 files/s | 0.05 MiB/s
# [2025-12-03T05:24:55-05:00] [20251202_232253] [INFO] [13-Backup] Checksums: 103900/103946 archivos | 5.0 files/s | 0.05 MiB/s
# Checksums escritos en: C:\Quant\MT5_Data_Extraction\data\metadata\checksums.jsonl (líneas nuevas=103946)
# Hashing: archivos=103946 | bytes=1105863305 (1.03 GiB) | tasa=5.0 files/s, 0.05 MiB/s
# Mismatches detectados respecto a último registro previo: 0
# ✅ QA checksums: mismatches=0
# --------------------------------------------------------------------------------------------------------------
# Creando backup (zip)...
# [2025-12-03T05:24:56-05:00] [20251202_232253] [INFO] [13-Backup] Añadiendo historical_data/m5_clean ...
# [2025-12-03T05:25:43-05:00] [20251202_232253] [INFO] [13-Backup] Añadiendo metadata/ ...
# [2025-12-03T05:25:47-05:00] [20251202_232253] [INFO] [13-Backup] Añadiendo processed_data/m5_windows/ ...
# Backup creado en: C:\Quant\MT5_Data_Extraction\data\backups\backup_m5_20251202_232253.zip
#   - Archivos incluidos: 132007 | Bytes sin comprimir (aprox): 1.68 GiB
#   - Tamaño ZIP: 1.01 GiB
# --------------------------------------------------------------------------------------------------------------
# Estado de desconexión MT5: OK
# --------------------------------------------------------------------------------------------------------------
# Resumen:
#   • Archivos hasheados: 103946 | Bytes: 1.03 GiB | Tasa: 5.0 files/s, 0.05 MiB/s
#   • Mismatches: 0
#   • Backup ZIP: C:\Quant\MT5_Data_Extraction\data\backups\backup_m5_20251202_232253.zip
# ✅ Cierre completo del pipeline de extracción M5: OK

# %%
# ======================= Celda 14 — Restore y verificación cruzada (POLARS-only) =======================
# Propósito:
#   1) Restaurar el ZIP de backup más reciente (o por RUN_ID) en DATA_ROOT/restore/restore_<RUN_ID>/
#   2) Verificar integridad con checksums (SHA-256) usando el checksums.jsonl del backup restaurado
#   3) Verificar Parquet con Polars (columnas/orden contra schema_m5.json; filas y rangos)
#   4) Comparar recuentos de archivos/bytes y filas entre ORIGINAL (DATA_ROOT) y RESTORE (restore_<RUN_ID>)
#   5) Imprimir tasas de hashing y heartbeats de progreso
# Notas:
#   - 100% Polars (sin fallback a pandas).
#   - No borra nada en el DATA_ROOT original.
#   - Si FORCE_FULL_CHECKSUM=False, se verifica por muestra; en True, se verifican todos los archivos hashados.
# =======================================================================================================

from __future__ import annotations
import os, json, time, hashlib, zipfile, random
from pathlib import Path
from datetime import datetime, timezone
from typing import Iterable, List, Dict, Tuple, Optional

# ------------------------------------ Config ------------------------------------
CELL_LABEL = "14-Restore-Verify"
RUN_ID = globals().get("RUN_ID", None)  # si None, escogerá el backup más reciente
DATA_ROOT = Path(globals().get("DATA_ROOT", str(path_contract.data_root()))).resolve()

# Parámetros de verificación
TIMEZONE_IANA         = globals().get("TIMEZONE_IANA", "America/Guayaquil")
FORCE_FULL_CHECKSUM   = bool(globals().get("FORCE_FULL_CHECKSUM", False))
CHECKSUM_SAMPLE_FILES = int(globals().get("CHECKSUM_SAMPLE_FILES", 1500))
PARQUET_SAMPLE_FILES  = int(globals().get("PARQUET_SAMPLE_FILES", 24))
SHOW_SAMPLE_LIST      = bool(globals().get("SHOW_SAMPLE_LIST", True))
SHA256_CHUNK          = int(globals().get("SHA256_CHUNK", 8 * 1024 * 1024))  # 8 MiB
HEARTBEAT_SECS        = float(globals().get("HEARTBEAT_SECS", 2.0))

BACKUPS_DIR = DATA_ROOT / "backups"
BACKUP_PREFIX = "backup_m5_"

# Polars (requerido)
try:
    import polars as pl
except Exception as e:
    raise RuntimeError("Se requiere 'polars'. Instálalo e intenta de nuevo.") from e

# ---------------------------------- Utilidades -----------------------------------
def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return datetime.now(timezone.utc).isoformat(timespec="seconds")

def _log(level: str, msg: str):
    rid = RUN_ID or "NA"
    print(f"[{_now_local_iana()}] [{rid}] [{level}] [{CELL_LABEL}] {msg}", flush=True)

def _fmt_bytes(n: int) -> str:
    if n < 1024: return f"{n} B"
    kib = n/1024
    if kib < 1024: return f"{kib:.2f} KiB"
    mib = kib/1024
    if mib < 1024: return f"{mib:.2f} MiB"
    gib = mib/1024
    if gib < 1024: return f"{gib:.2f} GiB"
    tib = gib/1024
    return f"{tib:.2f} TiB"

def _iter_files(base: Path) -> Iterable[Path]:
    for root, _, files in os.walk(base):
        for f in files:
            p = Path(root) / f
            if p.is_file():
                yield p

def _size_bytes(p: Path) -> int:
    try: return p.stat().st_size
    except Exception: return 0

def _sha256_file(path: Path, chunk: int = SHA256_CHUNK) -> str:
    h = hashlib.sha256()
    with open(path, "rb") as f:
        while True:
            b = f.read(chunk)
            if not b: break
            h.update(b)
    return h.hexdigest()

# --------------------------- Selección del backup a usar -------------------------
def _find_backup_zip(run_id: Optional[str]) -> Tuple[Path, str]:
    BACKUPS_DIR.mkdir(parents=True, exist_ok=True)
    if run_id:
        z = BACKUPS_DIR / f"{BACKUP_PREFIX}{run_id}.zip"
        if z.exists():
            return z, run_id
        # fallback: buscar que contenga el run_id
        cands = sorted(BACKUPS_DIR.glob(f"*{run_id}*.zip"), key=lambda p: p.stat().st_mtime, reverse=True)
        if not cands:
            raise FileNotFoundError(f"No se encontró ZIP para RUN_ID={run_id} en {BACKUPS_DIR}")
        rid = cands[0].stem.replace(BACKUP_PREFIX, "")
        return cands[0], rid
    # sin run_id: más reciente
    zips = sorted(BACKUPS_DIR.glob(f"{BACKUP_PREFIX}*.zip"), key=lambda p: p.stat().st_mtime, reverse=True)
    if not zips:
        raise FileNotFoundError(f"No hay backups en {BACKUPS_DIR}")
    rid = zips[0].stem.replace(BACKUP_PREFIX, "")
    return zips[0], rid

# ------------------------------------ Restore ------------------------------------
def _restore_zip(zip_path: Path, rid: str) -> Path:
    restore_dir = DATA_ROOT / "restore" / f"restore_{rid}"
    restore_dir.mkdir(parents=True, exist_ok=True)
    _log("INFO", f"Restaurando ZIP: {zip_path.name}")
    with zipfile.ZipFile(zip_path, "r") as zf:
        infos = zf.infolist()
        total = len(infos)
        _log("INFO", f"Entradas en ZIP: {total}")
        t0 = time.monotonic()
        lastb = t0
        for i, inf in enumerate(infos, 1):
            zf.extract(inf, path=restore_dir)
            now = time.monotonic()
            if (i % 1000 == 0) or (now - lastb >= HEARTBEAT_SECS) or (i == total):
                rate = i / max(now - t0, 1e-6)
                _log("INFO", f"Restore progreso: {i}/{total} | {rate:.1f} files/s")
                lastb = now
    return restore_dir

# ---------------------- Cargar manifest/checksums del RESTORE --------------------
def _load_restored_manifest(restore_root: Path) -> dict:
    mp = restore_root / "metadata" / "manifest.json"
    if not mp.exists():
        return {}
    try:
        return json.loads(mp.read_text(encoding="utf-8"))
    except Exception:
        return {}

def _load_restored_checksums_df(restore_root: Path, filter_run_id: Optional[str]) -> pl.DataFrame:
    chk_path = restore_root / "metadata" / "checksums.jsonl"
    if not chk_path.exists():
        raise FileNotFoundError(f"No existe {chk_path} dentro del RESTORE.")
    lf = pl.scan_ndjson(str(chk_path))
    if filter_run_id:
        lf = lf.filter(pl.col("run_id") == filter_run_id)
    # si hay múltiples entradas por path, nos quedamos con la última
    df = (lf.with_row_count("rc")
            .select(pl.all())  # rc, run_id, path, size, sha256, mtime_utc...
            .sort("path", pl.col("rc"), descending=[False, True])
            .unique(subset=["path"], keep="first")
            .select(["path", "size", "sha256"]))
    return df.collect()

def _derive_rel_from_abs(abs_path: str, orig_root: str) -> str:
    p = abs_path.replace("\\", "/")
    root = orig_root.replace("\\", "/").rstrip("/")
    if p.lower().startswith(root.lower()):
        rel = p[len(root):].lstrip("/")
        return rel
    # ya sería relativo
    return p.lstrip("/")

# ---------------------------- Verificación de checksums --------------------------
def _verify_checksums_restored(restore_root: Path, df_chk: pl.DataFrame, orig_data_root: Optional[str]) -> Tuple[int,int,int,List[str],float,float]:
    """
    Devuelve: ok, total, mismatches_count, mism_list (≤20), rate_files, rate_mib
    """
    # Derivar rutas relativas para mapear a restore_root
    if orig_data_root:
        rel = df_chk.with_columns(
            pl.col("path").map_elements(lambda s: _derive_rel_from_abs(s, orig_data_root)).alias("_rel")
        )
    else:
        rel = df_chk.with_columns(pl.col("path").alias("_rel"))

    rows = rel.to_dicts()
    total = len(rows)
    ok = 0
    mism = []
    hashed_bytes = 0
    t0 = time.monotonic()
    lastb = t0

    # Modo muestra vs completo
    if not FORCE_FULL_CHECKSUM and total > CHECKSUM_SAMPLE_FILES:
        random.shuffle(rows)
        rows = rows[:CHECKSUM_SAMPLE_FILES]
        total = len(rows)

    for i, r in enumerate(rows, 1):
        target = (restore_root / r["_rel"])
        try:
            if target.exists():
                digest = _sha256_file(target, SHA256_CHUNK)
                hashed_bytes += _size_bytes(target)
                if digest == r["sha256"]:
                    ok += 1
                else:
                    if len(mism) < 20:
                        mism.append(f"{r['_rel']} (mismatch)")
            else:
                if len(mism) < 20:
                    mism.append(f"{r['_rel']} (missing)")
        except Exception as e:
            if len(mism) < 20:
                mism.append(f"{r['_rel']} (error: {e.__class__.__name__})")

        now = time.monotonic()
        if (i % 50 == 0) or (now - lastb >= HEARTBEAT_SECS) or (i == total):
            rate_files = i / max(now - t0, 1e-6)
            rate_mib   = (hashed_bytes/1048576) / max(now - t0, 1e-6)
            _log("INFO", f"Checksums: {i}/{total} | {rate_files:.1f} files/s | {rate_mib:.2f} MiB/s")
            lastb = now

    rate_files = total / max(time.monotonic() - t0, 1e-6)
    rate_mib   = (hashed_bytes/1048576) / max(time.monotonic() - t0, 1e-6)
    return ok, total, (total - ok), mism, rate_files, rate_mib

# -------------------------- Verificación Parquet (Polars) ------------------------
def _schema_columns_from_restore(restore_root: Path) -> List[str]:
    schema_path = restore_root / "metadata" / "schema_m5.json"
    if not schema_path.exists():
        # fallback: del original (por si el backup no lo contenía)
        schema_path = DATA_ROOT / "metadata" / "schema_m5.json"
    if schema_path.exists():
        try:
            d = json.loads(schema_path.read_text(encoding="utf-8"))
            cols = d.get("column_order", None)
            if isinstance(cols, list) and cols:
                return cols
        except Exception:
            pass
    # fallback razonable
    return ["timestamp_utc","symbol","open","high","low","close",
            "tick_volume","real_volume","spread_points","broker","server_tz"]

def _pick_parquet_samples(restore_root: Path, k: int) -> List[Path]:
    bases = []
    cand1 = restore_root / "historical_data" / "m5_clean"
    cand2 = restore_root / "bulk_data" / "m5_raw"
    cand3 = restore_root / "processed_data" / "m5_windows"
    for c in (cand1, cand2, cand3):
        if c.exists():
            bases.append(c)
    files = []
    for b in bases:
        files += list(b.rglob("part=*.parquet"))
    random.shuffle(files)
    return files[:min(k, len(files))]

def _verify_schema_and_rows(paths: List[Path], schema_cols: List[str]) -> Tuple[int,int,int,int,Optional[int],Optional[int]]:
    """
    Devuelve: col_mismatch, empty_parts, dupes_files, files_read, ts_min, ts_max
    """
    col_mismatch = 0
    empty_parts = 0
    dupes_files = 0
    files_read = 0
    ts_min_glob = None
    ts_max_glob = None

    t0 = time.monotonic()
    lastb = t0

    for i, p in enumerate(paths, 1):
        try:
            df = pl.read_parquet(p)
            files_read += 1

            # Orden de columnas: exigimos que el prefijo coincida con schema_cols
            cols = df.columns
            if schema_cols and cols[:len(schema_cols)] != schema_cols:
                col_mismatch += 1

            n = df.height
            if n == 0:
                empty_parts += 1
            else:
                if "timestamp_utc" in df.columns:
                    dmin = int(df.select(pl.col("timestamp_utc").min()).item())
                    dmax = int(df.select(pl.col("timestamp_utc").max()).item())
                    ts_min_glob = dmin if ts_min_glob is None else min(ts_min_glob, dmin)
                    ts_max_glob = dmax if ts_max_glob is None else max(ts_max_glob, dmax)

                # Duplicados por archivo
                if "timestamp_utc" in df.columns:
                    dups = int(n - int(df.select(pl.col("timestamp_utc").n_unique()).item()))
                    if dups > 0:
                        dupes_files += 1

        except Exception as e:
            col_mismatch += 1  # contar como problema de esquema/lectura

        now = time.monotonic()
        if (i % 6 == 0) or (now - lastb >= HEARTBEAT_SECS) or (i == len(paths)):
            rate = i / max(now - t0, 1e-6)
            _log("INFO", f"Verif Parquet (muestra): {i}/{len(paths)} | {rate:.2f} files/s")
            lastb = now

    return col_mismatch, empty_parts, dupes_files, files_read, ts_min_glob, ts_max_glob

# ---------------------- Conteos/bytes y filas (ORIG vs RESTORE) -------------------
def _count_files_bytes(base: Path) -> Tuple[int,int]:
    files = 0
    bytes_total = 0
    if base.exists():
        for p in _iter_files(base):
            files += 1
            bytes_total += _size_bytes(p)
    return files, bytes_total

def _row_count_glob(paths: List[Path]) -> int:
    if not paths:
        return 0
    # usamos scan_parquet para sumar filas sin cargar todo a memoria
    lf = pl.scan_parquet([str(p) for p in paths])
    return int(lf.select(pl.len()).collect().item())

def _gather_parquet_paths(base: Path) -> List[Path]:
    if not base.exists():
        return []
    return list(base.rglob("part=*.parquet"))

# =================================== EJECUCIÓN ===================================
# 1) Selección y cabecera
zip_path, chosen_rid = _find_backup_zip(RUN_ID)
RUN_ID = chosen_rid  # normalizamos
print("="*110)
print(f"Inicio Celda 14 — Restore y verificación cruzada | TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-"*110)
print(f"DATA_ROOT: {DATA_ROOT}")
print(f"ZIP elegido: {zip_path} | tamaño={_fmt_bytes(zip_path.stat().st_size)}")
print("-"*110)

# 2) Restore ZIP
restore_root = _restore_zip(zip_path, RUN_ID)
print("-"*110)
print(f"Restaurado en: {restore_root}")

# 3) Cargar manifest/checksums del RESTORE
manifest = _load_restored_manifest(restore_root)
backup_run_id = manifest.get("run_id", RUN_ID)
orig_data_root = manifest.get("data_root", str(DATA_ROOT))

df_chk = _load_restored_checksums_df(restore_root, backup_run_id)
print(f"Checksums encontrados (restored, run_id={backup_run_id}): {len(df_chk)}")

# 4) Verificar checksums (restored) con heartbeats
ok, total, mism_count, mism_list, rate_files, rate_mib = _verify_checksums_restored(
    restore_root, df_chk, orig_data_root
)
print("-"*110)
print(f"Checksums verificados: {total} | OK={ok} | mismatches={mism_count}")
if mism_list:
    print("Mismatches (primeros 20):")
    for x in mism_list:
        print("  -", x)
print(f"Tasa de hashing: {rate_files:.1f} files/s | {rate_mib:.2f} MiB/s")

# 5) Verificación Parquet (muestra con Polars)
schema_cols = _schema_columns_from_restore(restore_root)
samples = _pick_parquet_samples(restore_root, PARQUET_SAMPLE_FILES)
print("-"*110)
print(f"Sample Parquet para verificación: {len(samples)} archivos")
if SHOW_SAMPLE_LIST:
    for p in samples[:min(12, len(samples))]:
        print("  ·", str(p))

col_mismatch, empty_parts, dupes_files, files_read, ts_min, ts_max = _verify_schema_and_rows(samples, schema_cols)

# 6) Comparaciones ORIG vs RESTORE (files/bytes y filas)
orig_sources = [
    DATA_ROOT / "historical_data" / "m5_clean",
    DATA_ROOT / "bulk_data" / "m5_raw",
    DATA_ROOT / "processed_data" / "m5_windows",
    DATA_ROOT / "metadata",
]
rest_sources = [
    restore_root / "historical_data" / "m5_clean",
    restore_root / "bulk_data" / "m5_raw",
    restore_root / "processed_data" / "m5_windows",
    restore_root / "metadata",
]

orig_files = sum(_count_files_bytes(p)[0] for p in orig_sources)
orig_bytes = sum(_count_files_bytes(p)[1] for p in orig_sources)
rest_files = sum(_count_files_bytes(p)[0] for p in rest_sources)
rest_bytes = sum(_count_files_bytes(p)[1] for p in rest_sources)

# Filas (contamos en Parquet de capas principales)
orig_parquets = _gather_parquet_paths(DATA_ROOT / "historical_data" / "m5_clean")
if not orig_parquets:
    orig_parquets = _gather_parquet_paths(DATA_ROOT / "bulk_data" / "m5_raw")
orig_parquets += _gather_parquet_paths(DATA_ROOT / "processed_data" / "m5_windows")

rest_parquets = _gather_parquet_paths(restore_root / "historical_data" / "m5_clean")
if not rest_parquets:
    rest_parquets = _gather_parquet_paths(restore_root / "bulk_data" / "m5_raw")
rest_parquets += _gather_parquet_paths(restore_root / "processed_data" / "m5_windows")

t_rows0 = time.monotonic()
orig_rows = _row_count_glob(orig_parquets)
rest_rows = _row_count_glob(rest_parquets)
rows_rate = (len(rest_parquets) + len(orig_parquets)) / max(time.monotonic() - t_rows0, 1e-6)

# 7) Impresiones finales
print("="*110)
print("RESUMEN DE VERIFICACIÓN")
print(f"Backup usado               : {zip_path.name}")
print(f"Restaurado en              : {restore_root}")
print("-"*110)
print("Checksums:")
print(f"  • Verificados            : {total}")
print(f"  • OK                     : {ok}")
print(f"  • Mismatches             : {mism_count}")
print(f"  • Tasa de hashing        : {rate_files:.1f} files/s | {rate_mib:.2f} MiB/s")
print("-"*110)
print("Verificación Parquet (muestra):")
print(f"  • Archivos leídos        : {files_read}")
print(f"  • Column order mismatches: {col_mismatch}")
print(f"  • Partes vacías          : {empty_parts}")
print(f"  • Archivos con dups (ts) : {dupes_files}")
if ts_min is not None and ts_max is not None:
    utc_min = datetime.fromtimestamp(ts_min/1000, tz=timezone.utc).isoformat(timespec="seconds")
    utc_max = datetime.fromtimestamp(ts_max/1000, tz=timezone.utc).isoformat(timespec="seconds")
    print(f"  • Rango UTC (muestra)    : {utc_min} → {utc_max}")
print("-"*110)
print("Comparación ORIG vs RESTORE:")
print(f"  • ORIG  archivos/bytes   : {orig_files} / {_fmt_bytes(orig_bytes)}")
print(f"  • REST  archivos/bytes   : {rest_files} / {_fmt_bytes(rest_bytes)}")
print(f"  • Δ archivos/bytes       : {rest_files-orig_files} / {_fmt_bytes(rest_bytes-orig_bytes)}")
print(f"  • ORIG  filas (Parquet)  : {orig_rows:,}")
print(f"  • REST  filas (Parquet)  : {rest_rows:,}")
print(f"  • Δ filas                : {rest_rows - orig_rows:,}")
print(f"  • Tasa conteo filas      : {rows_rate:.2f} files/s (scan_parquet)")
print("-"*110)

ok_checksums = (mism_count == 0) or (not FORCE_FULL_CHECKSUM and ok > 0)
ok_schema    = (col_mismatch == 0)
ok_restore   = (rest_files > 0 and rest_bytes > 0)

if ok_checksums and ok_schema and ok_restore:
    print("✅ Restore y verificación cruzada: OK (integridad comprobada, Polars-only).")
else:
    print("⚠️  Restore/verificación con observaciones. Revisa mismatches/column order/partes vacías antes de continuar.")
# =======================================================================================================
# Out:
# ==============================================================================================================
# Inicio Celda 14 — Restore y verificación cruzada | TZ local: America/Guayaquil
# Hora local: 2025-12-03T05:26:21-05:00 | Hora UTC: 2025-12-03T10:26:21+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT: C:\Quant\MT5_Data_Extraction\data
# ZIP elegido: C:\Quant\MT5_Data_Extraction\data\backups\backup_m5_20251202_232253.zip | tamaño=1.01 GiB
# --------------------------------------------------------------------------------------------------------------
# [2025-12-03T05:26:21-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restaurando ZIP: backup_m5_20251202_232253.zip
# [2025-12-03T05:26:21-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Entradas en ZIP: 132007
# [2025-12-03T05:26:22-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 1000/132007 | 4000.0 files/s
# [2025-12-03T05:26:22-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 2000/132007 | 4000.0 files/s
# [2025-12-03T05:26:22-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 3000/132007 | 3841.2 files/s
# [2025-12-03T05:26:22-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 4000/132007 | 3710.6 files/s
# [2025-12-03T05:26:23-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 5000/132007 | 3679.2 files/s
# [2025-12-03T05:26:23-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 6000/132007 | 3656.3 files/s
# [2025-12-03T05:26:23-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 7000/132007 | 3642.0 files/s
# [2025-12-03T05:26:23-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 8000/132007 | 3631.4 files/s
# [2025-12-03T05:26:24-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 9000/132007 | 3600.0 files/s
# [2025-12-03T05:26:24-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 10000/132007 | 3554.9 files/s
# [2025-12-03T05:26:24-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 11000/132007 | 3538.1 files/s
# [2025-12-03T05:26:25-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 12000/132007 | 3475.2 files/s
# [2025-12-03T05:26:25-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 13000/132007 | 3466.7 files/s
# [2025-12-03T05:26:25-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 14000/132007 | 3445.7 files/s
# [2025-12-03T05:26:26-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 15000/132007 | 3453.0 files/s
# [2025-12-03T05:26:26-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 16000/132007 | 3459.5 files/s
# [2025-12-03T05:26:26-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 17000/132007 | 3465.1 files/s
# [2025-12-03T05:26:26-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 18000/132007 | 3459.5 files/s
# [2025-12-03T05:26:27-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 19000/132007 | 3454.5 files/s
# [2025-12-03T05:26:27-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 20000/132007 | 3459.6 files/s
# [2025-12-03T05:26:27-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 21000/132007 | 3463.6 files/s
# [2025-12-03T05:26:28-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 22000/132007 | 3459.7 files/s
# [2025-12-03T05:26:28-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 23000/132007 | 3447.2 files/s
# [2025-12-03T05:26:28-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 24000/132007 | 3428.6 files/s
# [2025-12-03T05:26:29-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 25000/132007 | 3426.1 files/s
# [2025-12-03T05:26:29-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 26000/132007 | 3431.0 files/s
# [2025-12-03T05:26:29-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 27000/132007 | 3435.6 files/s
# [2025-12-03T05:26:29-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 28000/132007 | 3426.3 files/s
# [2025-12-03T05:26:30-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 29000/132007 | 3430.7 files/s
# [2025-12-03T05:26:30-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 30000/132007 | 3422.3 files/s
# [2025-12-03T05:26:30-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 31000/132007 | 3420.5 files/s
# [2025-12-03T05:26:31-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 32000/132007 | 3424.7 files/s
# [2025-12-03T05:26:31-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 33000/132007 | 3422.9 files/s
# [2025-12-03T05:26:31-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 34000/132007 | 3416.1 files/s
# [2025-12-03T05:26:32-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 35000/132007 | 3414.6 files/s
# [2025-12-03T05:26:32-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 36000/132007 | 3408.1 files/s
# [2025-12-03T05:26:32-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 37000/132007 | 3407.3 files/s
# [2025-12-03T05:26:32-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 38000/132007 | 3406.2 files/s
# [2025-12-03T05:26:33-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 39000/132007 | 3405.2 files/s
# [2025-12-03T05:26:33-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 40000/132007 | 3404.3 files/s
# [2025-12-03T05:26:33-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 41000/132007 | 3398.8 files/s
# [2025-12-03T05:26:34-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 42000/132007 | 3398.3 files/s
# [2025-12-03T05:26:34-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 43000/132007 | 3397.6 files/s
# [2025-12-03T05:26:34-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 44000/132007 | 3384.6 files/s
# [2025-12-03T05:26:35-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 45000/132007 | 3384.2 files/s
# [2025-12-03T05:26:35-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 46000/132007 | 3383.8 files/s
# [2025-12-03T05:26:35-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 47000/132007 | 3379.8 files/s
# [2025-12-03T05:26:36-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 48000/132007 | 3364.6 files/s
# [2025-12-03T05:26:36-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 49000/132007 | 3364.7 files/s
# [2025-12-03T05:26:36-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 50000/132007 | 3357.7 files/s
# [2025-12-03T05:26:36-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 51000/132007 | 3354.6 files/s
# [2025-12-03T05:26:37-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 52000/132007 | 3348.1 files/s
# [2025-12-03T05:26:37-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 53000/132007 | 3348.5 files/s
# [2025-12-03T05:26:37-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 54000/132007 | 3352.2 files/s
# [2025-12-03T05:26:38-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 55000/132007 | 3345.9 files/s
# [2025-12-03T05:26:38-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 56000/132007 | 3321.7 files/s
# [2025-12-03T05:26:39-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 57000/132007 | 3310.3 files/s
# [2025-12-03T05:26:39-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 58000/132007 | 3311.3 files/s
# [2025-12-03T05:26:39-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 59000/132007 | 3286.4 files/s
# [2025-12-03T05:26:40-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 60000/132007 | 3287.7 files/s
# [2025-12-03T05:26:40-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 61000/132007 | 3280.6 files/s
# [2025-12-03T05:26:40-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 62000/132007 | 3273.8 files/s
# [2025-12-03T05:26:41-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 63000/132007 | 3246.4 files/s
# [2025-12-03T05:26:41-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 64000/132007 | 3250.7 files/s
# [2025-12-03T05:26:41-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 65000/132007 | 3250.0 files/s
# [2025-12-03T05:26:42-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 66000/132007 | 3239.3 files/s
# [2025-12-03T05:26:42-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 67000/132007 | 3236.2 files/s
# [2025-12-03T05:26:42-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 68000/132007 | 3230.9 files/s
# [2025-12-03T05:26:43-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 69000/132007 | 3230.5 files/s
# [2025-12-03T05:26:43-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 70000/132007 | 3225.4 files/s
# [2025-12-03T05:26:43-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 71000/132007 | 3209.0 files/s
# [2025-12-03T05:26:44-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 72000/132007 | 3197.7 files/s
# [2025-12-03T05:26:44-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 73000/132007 | 3189.0 files/s
# [2025-12-03T05:26:45-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 74000/132007 | 3178.6 files/s
# [2025-12-03T05:26:45-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 75000/132007 | 3174.6 files/s
# [2025-12-03T05:26:45-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 76000/132007 | 3168.8 files/s
# [2025-12-03T05:26:46-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 77000/132007 | 3159.0 files/s
# [2025-12-03T05:26:46-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 78000/132007 | 3151.5 files/s
# [2025-12-03T05:26:46-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 79000/132007 | 3138.4 files/s
# [2025-12-03T05:26:47-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 80000/132007 | 3133.4 files/s
# [2025-12-03T05:26:47-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 81000/132007 | 3121.0 files/s
# [2025-12-03T05:26:48-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 82000/132007 | 3114.6 files/s
# [2025-12-03T05:26:48-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 83000/132007 | 3108.3 files/s
# [2025-12-03T05:26:48-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 84000/132007 | 3100.3 files/s
# [2025-12-03T05:26:49-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 85000/132007 | 3094.4 files/s
# [2025-12-03T05:26:49-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 86000/132007 | 3088.6 files/s
# [2025-12-03T05:26:50-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 87000/132007 | 3083.0 files/s
# [2025-12-03T05:26:50-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 88000/132007 | 3074.2 files/s
# [2025-12-03T05:26:50-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 89000/132007 | 3072.2 files/s
# [2025-12-03T05:26:51-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 90000/132007 | 3068.7 files/s
# [2025-12-03T05:26:51-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 91000/132007 | 3060.5 files/s
# [2025-12-03T05:26:51-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 92000/132007 | 3055.6 files/s
# [2025-12-03T05:26:52-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 93000/132007 | 3053.9 files/s
# [2025-12-03T05:26:52-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 94000/132007 | 3041.5 files/s
# [2025-12-03T05:26:53-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 95000/132007 | 3038.4 files/s
# [2025-12-03T05:26:53-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 96000/132007 | 3034.0 files/s
# [2025-12-03T05:26:53-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 97000/132007 | 3032.8 files/s
# [2025-12-03T05:26:54-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 98000/132007 | 3032.8 files/s
# [2025-12-03T05:26:54-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 99000/132007 | 3028.6 files/s
# [2025-12-03T05:26:54-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 100000/132007 | 3031.8 files/s
# [2025-12-03T05:26:55-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 101000/132007 | 3029.0 files/s
# [2025-12-03T05:26:55-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 102000/132007 | 3026.4 files/s
# [2025-12-03T05:26:55-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 103000/132007 | 3015.6 files/s
# [2025-12-03T05:26:57-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 104000/132007 | 2925.7 files/s
# [2025-12-03T05:26:57-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 105000/132007 | 2928.1 files/s
# [2025-12-03T05:26:58-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 106000/132007 | 2926.6 files/s
# [2025-12-03T05:26:58-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 107000/132007 | 2927.7 files/s
# [2025-12-03T05:26:58-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 108000/132007 | 2926.4 files/s
# [2025-12-03T05:26:59-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 109000/132007 | 2923.7 files/s
# [2025-12-03T05:26:59-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 110000/132007 | 2921.2 files/s
# [2025-12-03T05:26:59-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 111000/132007 | 2923.4 files/s
# [2025-12-03T05:27:00-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 112000/132007 | 2918.6 files/s
# [2025-12-03T05:27:00-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 113000/132007 | 2920.8 files/s
# [2025-12-03T05:27:00-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 114000/132007 | 2924.3 files/s
# [2025-12-03T05:27:01-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 115000/132007 | 2922.9 files/s
# [2025-12-03T05:27:01-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 116000/132007 | 2920.5 files/s
# [2025-12-03T05:27:01-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 117000/132007 | 2915.9 files/s
# [2025-12-03T05:27:02-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 118000/132007 | 2911.4 files/s
# [2025-12-03T05:27:02-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 119000/132007 | 2906.8 files/s
# [2025-12-03T05:27:03-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 120000/132007 | 2908.0 files/s
# [2025-12-03T05:27:03-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 121000/132007 | 2906.9 files/s
# [2025-12-03T05:27:03-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 122000/132007 | 2906.9 files/s
# [2025-12-03T05:27:04-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 123000/132007 | 2905.9 files/s
# [2025-12-03T05:27:04-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 124000/132007 | 2905.9 files/s
# [2025-12-03T05:27:04-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 125000/132007 | 2905.9 files/s
# [2025-12-03T05:27:05-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 126000/132007 | 2906.0 files/s
# [2025-12-03T05:27:05-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 127000/132007 | 2896.6 files/s
# [2025-12-03T05:27:05-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 128000/132007 | 2899.8 files/s
# [2025-12-03T05:27:06-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 129000/132007 | 2899.9 files/s
# [2025-12-03T05:27:06-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 130000/132007 | 2902.0 files/s
# [2025-12-03T05:27:07-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 131000/132007 | 2891.0 files/s
# [2025-12-03T05:27:07-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 132000/132007 | 2889.2 files/s
# [2025-12-03T05:27:07-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Restore progreso: 132007/132007 | 2889.3 files/s
# --------------------------------------------------------------------------------------------------------------
# Restaurado en: C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253
# Checksums encontrados (restored, run_id=20251202_232253): 103946
# C:\Users\PC\AppData\Local\Temp\ipykernel_5380\3317119554.py:144: DeprecationWarning: `LazyFrame.with_row_count` is deprecated; use `LazyFrame.with_row_index` instead. Note that the default column name has changed from 'row_nr' to 'index'.
#   df = (lf.with_row_count("rc")
# [2025-12-03T05:27:08-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 50/1500 | 91.4 files/s | 0.92 MiB/s
# [2025-12-03T05:27:08-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 100/1500 | 88.9 files/s | 0.89 MiB/s
# [2025-12-03T05:27:09-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 150/1500 | 89.7 files/s | 0.90 MiB/s
# [2025-12-03T05:27:09-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 200/1500 | 92.1 files/s | 0.93 MiB/s
# [2025-12-03T05:27:10-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 250/1500 | 95.2 files/s | 0.95 MiB/s
# [2025-12-03T05:27:10-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 300/1500 | 97.0 files/s | 0.96 MiB/s
# [2025-12-03T05:27:11-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 350/1500 | 94.9 files/s | 0.94 MiB/s
# [2025-12-03T05:27:11-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 400/1500 | 95.9 files/s | 0.94 MiB/s
# [2025-12-03T05:27:12-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 450/1500 | 97.0 files/s | 0.96 MiB/s
# [2025-12-03T05:27:12-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 500/1500 | 97.9 files/s | 0.97 MiB/s
# [2025-12-03T05:27:13-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 550/1500 | 98.6 files/s | 0.98 MiB/s
# [2025-12-03T05:27:13-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 600/1500 | 97.5 files/s | 0.97 MiB/s
# [2025-12-03T05:27:14-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 650/1500 | 98.4 files/s | 0.98 MiB/s
# [2025-12-03T05:27:14-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 700/1500 | 98.9 files/s | 0.99 MiB/s
# [2025-12-03T05:27:15-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 750/1500 | 99.0 files/s | 0.99 MiB/s
# [2025-12-03T05:27:15-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 800/1500 | 99.0 files/s | 0.99 MiB/s
# [2025-12-03T05:27:16-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 850/1500 | 99.1 files/s | 0.99 MiB/s
# [2025-12-03T05:27:16-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 900/1500 | 100.0 files/s | 1.00 MiB/s
# [2025-12-03T05:27:17-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 950/1500 | 99.4 files/s | 0.99 MiB/s
# [2025-12-03T05:27:17-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1000/1500 | 99.1 files/s | 0.99 MiB/s
# [2025-12-03T05:27:18-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1050/1500 | 100.0 files/s | 1.00 MiB/s
# [2025-12-03T05:27:18-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1100/1500 | 100.4 files/s | 1.00 MiB/s
# [2025-12-03T05:27:19-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1150/1500 | 101.2 files/s | 1.01 MiB/s
# [2025-12-03T05:27:19-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1200/1500 | 100.7 files/s | 1.00 MiB/s
# [2025-12-03T05:27:20-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1250/1500 | 100.5 files/s | 1.00 MiB/s
# [2025-12-03T05:27:20-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1300/1500 | 100.6 files/s | 1.00 MiB/s
# [2025-12-03T05:27:21-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1350/1500 | 100.9 files/s | 1.00 MiB/s
# [2025-12-03T05:27:21-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1400/1500 | 99.8 files/s | 0.99 MiB/s
# [2025-12-03T05:27:22-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1450/1500 | 100.0 files/s | 0.99 MiB/s
# [2025-12-03T05:27:22-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Checksums: 1500/1500 | 99.7 files/s | 0.99 MiB/s
# --------------------------------------------------------------------------------------------------------------
# Checksums verificados: 1500 | OK=1498 | mismatches=2
# Mismatches (primeros 20):
#   - bulk_data/m5_raw/symbol=ALVG/year=2025/month=12/part=20251202.parquet (missing)
#   - bulk_data/m5_raw/symbol=IBE/year=2025/month=12/part=20251202.parquet (missing)
# Tasa de hashing: 99.7 files/s | 0.99 MiB/s
# --------------------------------------------------------------------------------------------------------------
# Sample Parquet para verificación: 24 archivos
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=SOLUSD\year=2025\month=10\part=20251021.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=USDCNH\year=2024\month=08\part=20240826.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=BTCUSD\year=2023\month=12\part=20231227.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=AUDUSD\year=2023\month=05\part=20230508.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=GBPUSD\year=2022\month=10\part=20221007.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\processed_data\m5_windows\window=last_90d\symbol=USDZAR\part=20251001.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=AAVUSD\year=2025\month=09\part=20250915.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=USDHKD\year=2022\month=11\part=20221109.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=USDPLN\year=2025\month=03\part=20250320.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=LNKUSD\year=2023\month=01\part=20230130.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=USDNOK\year=2023\month=12\part=20231219.parquet
#   · C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253\historical_data\m5_clean\symbol=XAUUSD\year=2024\month=03\part=20240322.parquet
# [2025-12-03T05:27:24-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Verif Parquet (muestra): 6/24 | 193.55 files/s
# [2025-12-03T05:27:24-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Verif Parquet (muestra): 12/24 | 153.85 files/s
# [2025-12-03T05:27:24-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Verif Parquet (muestra): 18/24 | 165.14 files/s
# [2025-12-03T05:27:24-05:00] [20251202_232253] [INFO] [14-Restore-Verify] Verif Parquet (muestra): 24/24 | 170.21 files/s
# ==============================================================================================================
# RESUMEN DE VERIFICACIÓN
# Backup usado               : backup_m5_20251202_232253.zip
# Restaurado en              : C:\Quant\MT5_Data_Extraction\data\restore\restore_20251202_232253
# --------------------------------------------------------------------------------------------------------------
# Checksums:
#   • Verificados            : 1500
#   • OK                     : 1498
#   • Mismatches             : 2
#   • Tasa de hashing        : 99.7 files/s | 0.99 MiB/s
# --------------------------------------------------------------------------------------------------------------
# Verificación Parquet (muestra):
#   • Archivos leídos        : 24
#   • Column order mismatches: 0
#   • Partes vacías          : 0
#   • Archivos con dups (ts) : 0
#   • Rango UTC (muestra)    : 2022-01-07T00:05:00+00:00 → 2025-10-21T23:50:00+00:00
# --------------------------------------------------------------------------------------------------------------
# Comparación ORIG vs RESTORE:
#   • ORIG  archivos/bytes   : 253464 / 2.85 GiB
#   • REST  archivos/bytes   : 132007 / 1.68 GiB
#   • Δ archivos/bytes       : -121457 / -1256621819 B
#   • ORIG  filas (Parquet)  : 32,434,235
#   • REST  filas (Parquet)  : 32,434,235
#   • Δ filas                : 0
#   • Tasa conteo filas      : 2360.90 files/s (scan_parquet)
# --------------------------------------------------------------------------------------------------------------
# ✅ Restore y verificación cruzada: OK (integridad comprobada, Polars-only).

# %%
# ======================= Celda 15 — Índices de lectura y catálogo (M5, POLARS-only + fallback ventanas) =======================
# Propósito:
#   - Construir índices auxiliares y catálogo de ventanas:
#       1) metadata/day_index_m5.parquet
#       2) metadata/symbol_index_m5.parquet
#       3) metadata/window_catalog_m5.parquet
#   - Orden de preferencia para day/symbol index: m5_clean > m5_raw > m5_windows (desdup por día/símbolo).
#   - Lectura con scan_parquet (proyección tardía), heartbeats y sin abortar el notebook.
# ============================================================================================================================

from __future__ import annotations
import os, time
from pathlib import Path
from datetime import datetime, timezone
from typing import List, Dict, Any, Tuple, Optional

try:
    import polars as pl
except Exception as e:
    raise RuntimeError("Se requiere 'polars'. Instálalo e inténtalo de nuevo.") from e

CELL_LABEL = "15-Index-Catalog"
RUN_ID = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))
DATA_ROOT = Path(globals().get("DATA_ROOT", str(path_contract.data_root()))).resolve()

HIST_DIR  = DATA_ROOT / "historical_data" / "m5_clean"
RAW_DIR   = DATA_ROOT / "bulk_data" / "m5_raw"
PROC_DIR  = DATA_ROOT / "processed_data" / "m5_windows"
META_DIR  = DATA_ROOT / "metadata"

DAY_INDEX_PATH    = META_DIR / "day_index_m5.parquet"
SYMBOL_INDEX_PATH = META_DIR / "symbol_index_m5.parquet"
WINDOW_CATALOG    = META_DIR / "window_catalog_m5.parquet"

TIMEZONE_IANA          = globals().get("TIMEZONE_IANA", "America/Guayaquil")
COMPUTE_DUPES          = bool(globals().get("COMPUTE_DUPES", False))
PROGRESS_EVERY_FILES   = int(globals().get("PROGRESS_EVERY_FILES", 500))
PROGRESS_EVERY_SECONDS = float(globals().get("PROGRESS_EVERY_SECONDS", 1.5))
PARQUET_COMP           = "zstd"
PARQUET_STATS          = True

def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return datetime.now(timezone.utc).isoformat(timespec="seconds")

def _log(level: str, msg: str):
    print(f"[{_now_local_iana()}] [{RUN_ID}] [{level.upper()}] [{CELL_LABEL}] {msg}", flush=True)

def _fmt_bytes(n: int) -> str:
    if n < 1024: return f"{n} B"
    kib = n/1024
    if kib < 1024: return f"{kib:.2f} KiB"
    mib = kib/1024
    if mib < 1024: return f"{mib:.2f} MiB"
    gib = mib/1024
    if gib < 1024: return f"{gib:.2f} GiB"
    tib = gib/1024
    return f"{tib:.2f} TiB"

def _schema_str(df: pl.DataFrame):
    return [f"  • {c}: {str(t)}" for c, t in zip(df.columns, df.dtypes)]

def _safe_file_size(p: Path) -> int:
    try: return p.stat().st_size
    except Exception: return 0

def _count_parts_quick(base: Path, limit: int = 1) -> int:
    if not base.exists(): return 0
    c = 0
    for _ in base.rglob("part=*.parquet"):
        c += 1
        if c >= limit: break
    return c

def _collect_hist_or_raw_parts(base: Path) -> List[Path]:
    parts: List[Path] = []
    for sdir in sorted(p for p in base.glob("symbol=*") if p.is_dir()):
        parts.extend(sorted(sdir.rglob("part=*.parquet")))
    return parts

def _collect_window_unique_parts(proc_dir: Path) -> List[Path]:
    """Devuelve partes únicas (symbol, ymd) priorizando last_180d > last_90d > last_30d."""
    win_order = ["last_180d", "last_90d", "last_30d"]
    chosen: Dict[Tuple[str,str], Path] = {}
    for w in win_order:
        base = proc_dir / f"window={w}"
        if not base.exists(): continue
        for sdir in sorted(p for p in base.glob("symbol=*") if p.is_dir()):
            sym = sdir.name.split("=",1)[-1]
            for pf in sorted(sdir.rglob("part=*.parquet")):
                ymd = pf.name.split("=")[-1].split(".")[0]
                key = (sym, ymd)
                if key not in chosen:
                    chosen[key] = pf
    return list(chosen.values())

print("="*110)
print(f"Inicio Celda 15 — Índices de lectura y catálogo (M5) | TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-"*110)
print(f"DATA_ROOT: {DATA_ROOT}")
META_DIR.mkdir(parents=True, exist_ok=True)

# ------------------------ Selección de capa para day/symbol index ------------------------
source_kind = None
part_files: List[Path] = []

if _count_parts_quick(HIST_DIR, 1) > 0:
    source_kind = "clean"
    part_files = _collect_hist_or_raw_parts(HIST_DIR)
elif _count_parts_quick(RAW_DIR, 1) > 0:
    source_kind = "raw"
    part_files = _collect_hist_or_raw_parts(RAW_DIR)
elif _count_parts_quick(PROC_DIR, 1) > 0:
    source_kind = "windows"
    part_files = _collect_window_unique_parts(PROC_DIR)

if source_kind is None:
    print("⚠️  No hay archivos en m5_clean, m5_raw ni m5_windows. Escribiendo índices vacíos.")
    pl.DataFrame({"symbol": [], "date": [], "path": [], "bytes": [], "n_rows": [],
                  "min_ts": [], "max_ts": [], "dups": []}
                ).write_parquet(DAY_INDEX_PATH, compression=PARQUET_COMP, statistics=PARQUET_STATS)
    pl.DataFrame({"symbol": [], "days": [], "rows_total": [], "bytes_total": [],
                  "first_day": [], "last_day": [], "min_ts": [], "max_ts": [], "dups_total": []}
                ).write_parquet(SYMBOL_INDEX_PATH, compression=PARQUET_COMP, statistics=PARQUET_STATS)
else:
    where = {"clean": HIST_DIR, "raw": RAW_DIR, "windows": PROC_DIR}[source_kind]
    label = {"clean": "historical_data/m5_clean",
             "raw": "bulk_data/m5_raw",
             "windows": "processed_data/m5_windows (canonicalizado)"}[source_kind]
    print(f"Origen indexado (auto): {where}  [{label}]")
    print("-"*110)

# ----------------------------- Catálogo de ventanas (siempre) -----------------------------
def _window_catalog(proc_dir: Path) -> pl.DataFrame:
    rows = []
    for wname in ("last_30d","last_90d","last_180d"):
        base = proc_dir / f"window={wname}"
        if not base.exists():
            rows.append({"window": wname, "symbols": 0, "files": 0, "bytes": 0, "from_ts": None, "to_ts": None})
            continue
        files = sorted(base.rglob("part=*.parquet"))
        nfiles = len(files)
        bytes_sum = sum(_safe_file_size(p) for p in files)
        sym_count = len([p for p in base.glob("symbol=*") if p.is_dir()])
        ts_min = None; ts_max = None
        if files:
            lf = pl.scan_parquet([str(p) for p in files], low_memory=True).select(pl.col("timestamp_utc"))
            ag = lf.select([pl.min("timestamp_utc").alias("min_ts"),
                            pl.max("timestamp_utc").alias("max_ts")]).collect()
            ts_min = None if ag["min_ts"][0] is None else int(ag["min_ts"][0])
            ts_max = None if ag["max_ts"][0] is None else int(ag["max_ts"][0])
        rows.append({"window": wname, "symbols": int(sym_count), "files": int(nfiles),
                     "bytes": int(bytes_sum), "from_ts": ts_min, "to_ts": ts_max})
    return pl.DataFrame(rows).select(["window","symbols","files","bytes","from_ts","to_ts"])

win_df = _window_catalog(PROC_DIR)
win_df.write_parquet(WINDOW_CATALOG, compression=PARQUET_COMP, statistics=PARQUET_STATS)

# ----------------------------- Cálculo índices si hay fuente -----------------------------
if source_kind is None:
    print(f"Catálogo de ventanas → {WINDOW_CATALOG} | filas={win_df.height}")
    print("✅ Índices vacíos escritos. Finaliza sin abortar.")
else:
    n_files = len(part_files)
    # derivar set de símbolos detectados
    def _sym_from_parts(path: Path) -> Optional[str]:
        for part in path.parts:
            if part.startswith("symbol="):
                return part.split("=",1)[-1]
        return None
    symbols = sorted(set(s for s in (_sym_from_parts(p) for p in part_files) if s))
    print(f"Símbolos detectados: {len(symbols)} | Archivos canónicos: {n_files}")

    def _stats_from_part(path: Path) -> Tuple[int, Optional[int], Optional[int], Optional[int]]:
        lf = pl.scan_parquet(str(path), low_memory=True).select(pl.col("timestamp_utc"))
        n_rows = int(lf.select(pl.len()).collect().item())
        if n_rows == 0:
            return 0, None, None, (0 if COMPUTE_DUPES else None)
        ag = lf.select([
            pl.min("timestamp_utc").alias("min_ts"),
            pl.max("timestamp_utc").alias("max_ts"),
            (pl.len() - pl.col("timestamp_utc").n_unique()).alias("dups") if COMPUTE_DUPES else pl.lit(None).alias("dups"),
        ]).collect()
        min_ts = ag["min_ts"][0]; max_ts = ag["max_ts"][0]
        dups   = ag["dups"][0] if COMPUTE_DUPES else None
        return int(n_rows), (None if min_ts is None else int(min_ts)), (None if max_ts is None else int(max_ts)), (None if dups is None else int(dups))

    # -------- day_index --------
    t0_day = time.monotonic()
    last_beat = t0_day
    day_rows: List[Dict[str, Any]] = []

    for i, f in enumerate(part_files, 1):
        try:
            sym = _sym_from_parts(f) or ""
            ymd = f.name.split("=")[-1].split(".")[0]
            fsize = _safe_file_size(f)
            n_rows, min_ts, max_ts, dups = _stats_from_part(f)
            day_rows.append({
                "symbol": sym, "date": ymd, "path": str(f), "bytes": int(fsize),
                "n_rows": int(n_rows),
                "min_ts": None if min_ts is None else int(min_ts),
                "max_ts": None if max_ts is None else int(max_ts),
                "dups":   None if dups   is None else int(dups),
            })
        except Exception as e:
            _log("WARNING", f"Error leyendo {f.name}: {e!r}")
        now = time.monotonic()
        if (i % PROGRESS_EVERY_FILES == 0) or (now - last_beat >= PROGRESS_EVERY_SECONDS) or (i == n_files):
            rate = i / max(now - t0_day, 1e-6)
            _log("INFO", f"day_index: {i}/{n_files} archivos | {rate:.1f} files/s")
            last_beat = now

    day_df = pl.DataFrame(day_rows).with_columns([
        pl.col("symbol").cast(pl.Utf8), pl.col("date").cast(pl.Utf8), pl.col("path").cast(pl.Utf8),
        pl.col("bytes").cast(pl.Int64), pl.col("n_rows").cast(pl.Int64),
        pl.col("min_ts").cast(pl.Int64), pl.col("max_ts").cast(pl.Int64),
        (pl.col("dups").cast(pl.Int64) if COMPUTE_DUPES else pl.lit(None).alias("dups").cast(pl.Int64)),
    ]).select(["symbol","date","path","bytes","n_rows","min_ts","max_ts","dups"])
    day_df.write_parquet(DAY_INDEX_PATH, compression=PARQUET_COMP, statistics=PARQUET_STATS)
    t_day = time.monotonic() - t0_day

    # -------- symbol_index --------
    t0_sym = time.monotonic()
    sym_agg = (
        day_df.with_columns(pl.col("date").str.slice(0,8).cast(pl.Int32).alias("date_int"))
              .group_by("symbol")
              .agg([
                  pl.len().alias("days"),
                  pl.col("n_rows").sum().alias("rows_total"),
                  pl.col("bytes").sum().alias("bytes_total"),
                  pl.col("date_int").min().alias("first_day"),
                  pl.col("date_int").max().alias("last_day"),
                  pl.col("min_ts").min().alias("min_ts"),
                  pl.col("max_ts").max().alias("max_ts"),
                  (pl.col("dups").sum().alias("dups_total") if COMPUTE_DUPES else pl.lit(None).alias("dups_total")),
              ])
              .sort("symbol")
    )
    sym_agg.write_parquet(SYMBOL_INDEX_PATH, compression=PARQUET_COMP, statistics=PARQUET_STATS)
    t_sym = time.monotonic() - t0_sym

    # -------- prints finales --------
    print("-"*110)
    print(f"Índice diario → {DAY_INDEX_PATH}")
    print(f"  - Filas: {day_df.height} | Columnas: {len(day_df.columns)}")
    print("  - Esquema:")
    for line in _schema_str(day_df): print(line)
    print(f"  - Tiempo construcción: {t_day:.2f} s")

    print("-"*110)
    print(f"Índice por símbolo → {SYMBOL_INDEX_PATH}")
    print(f"  - Filas (símbolos): {sym_agg.height} | Columnas: {len(sym_agg.columns)}")
    print("  - Esquema:")
    for line in _schema_str(sym_agg): print(line)
    print(f"  - Tiempo construcción: {t_sym:.2f} s")

# -------- Catálogo de ventanas (impresión) --------
print("-"*110)
print(f"Catálogo de ventanas → {WINDOW_CATALOG}")
print(f"  - Filas (ventanas): {win_df.height} | Columnas: {len(win_df.columns)}")
for line in _schema_str(win_df): print(line)
for r in win_df.iter_rows(named=True):
    fr, to = r["from_ts"], r["to_ts"]
    if (fr is not None) and (to is not None):
        utc_min = datetime.fromtimestamp(fr/1000, tz=timezone.utc).isoformat(timespec="seconds")
        utc_max = datetime.fromtimestamp(to/1000, tz=timezone.utc).isoformat(timespec="seconds")
        print(f"Ventana {r['window']}: symbols={r['symbols']} | files={r['files']} | bytes={_fmt_bytes(int(r['bytes']))} | rango UTC: {utc_min} → {utc_max}")
    else:
        print(f"Ventana {r['window']}: symbols={r['symbols']} | files={r['files']} | bytes={_fmt_bytes(int(r['bytes']))} | rango: (sin filas)")

print("-"*110)
print("✅ Índices y catálogo listos (incluye fallback a ventanas cuando GOLD/RAW están vacíos).")
# ============================================================================================================================
# Out:
# ==============================================================================================================
# Inicio Celda 15 — Índices de lectura y catálogo (M5) | TZ local: America/Guayaquil
# Hora local: 2025-12-03T05:29:45-05:00 | Hora UTC: 2025-12-03T10:29:45+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT: C:\Quant\MT5_Data_Extraction\data
# Origen indexado (auto): C:\Quant\MT5_Data_Extraction\data\historical_data\m5_clean  [historical_data/m5_clean]
# --------------------------------------------------------------------------------------------------------------
# Símbolos detectados: 92 | Archivos canónicos: 103917
# [2025-12-03T05:29:56-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 1090/103917 archivos | 545.0 files/s
# [2025-12-03T05:29:58-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 2000/103917 archivos | 559.0 files/s
# [2025-12-03T05:30:00-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 3164/103917 archivos | 567.2 files/s
# [2025-12-03T05:30:01-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 4000/103917 archivos | 575.3 files/s
# [2025-12-03T05:30:03-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 5194/103917 archivos | 580.1 files/s
# [2025-12-03T05:30:05-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 6000/103917 archivos | 584.5 files/s
# [2025-12-03T05:30:07-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 7194/103917 archivos | 586.5 files/s
# [2025-12-03T05:30:08-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 8000/103917 archivos | 583.1 files/s
# [2025-12-03T05:30:10-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 9204/103917 archivos | 585.5 files/s
# [2025-12-03T05:30:11-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 10000/103917 archivos | 587.2 files/s
# [2025-12-03T05:30:13-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 11180/103917 archivos | 587.5 files/s
# [2025-12-03T05:30:15-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 12000/103917 archivos | 589.4 files/s
# [2025-12-03T05:30:17-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 13128/103917 archivos | 587.1 files/s
# [2025-12-03T05:30:18-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 14000/103917 archivos | 584.1 files/s
# [2025-12-03T05:30:20-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 15128/103917 archivos | 582.5 files/s
# [2025-12-03T05:30:22-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 16000/103917 archivos | 583.5 files/s
# [2025-12-03T05:30:24-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 17191/103917 archivos | 584.3 files/s
# [2025-12-03T05:30:25-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 18000/103917 archivos | 584.5 files/s
# [2025-12-03T05:30:27-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 19198/103917 archivos | 585.4 files/s
# [2025-12-03T05:30:28-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 20000/103917 archivos | 586.4 files/s
# [2025-12-03T05:30:30-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 21135/103917 archivos | 585.3 files/s
# [2025-12-03T05:30:32-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 22000/103917 archivos | 585.4 files/s
# [2025-12-03T05:30:34-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 23212/103917 archivos | 586.5 files/s
# [2025-12-03T05:30:35-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 24000/103917 archivos | 587.2 files/s
# [2025-12-03T05:30:37-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 25222/103917 archivos | 588.3 files/s
# [2025-12-03T05:30:38-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 26000/103917 archivos | 589.2 files/s
# [2025-12-03T05:30:40-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 27196/103917 archivos | 589.6 files/s
# [2025-12-03T05:30:42-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 28000/103917 archivos | 590.4 files/s
# [2025-12-03T05:30:44-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 29227/103917 archivos | 591.4 files/s
# [2025-12-03T05:30:45-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 30000/103917 archivos | 591.7 files/s
# [2025-12-03T05:30:47-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 31218/103917 archivos | 592.3 files/s
# [2025-12-03T05:30:48-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 32000/103917 archivos | 592.9 files/s
# [2025-12-03T05:30:50-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 33200/103917 archivos | 593.2 files/s
# [2025-12-03T05:30:52-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 34000/103917 archivos | 593.6 files/s
# [2025-12-03T05:30:54-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 35219/103917 archivos | 594.1 files/s
# [2025-12-03T05:30:55-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 36000/103917 archivos | 594.3 files/s
# [2025-12-03T05:30:57-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 37155/103917 archivos | 593.7 files/s
# [2025-12-03T05:30:58-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 38000/103917 archivos | 593.3 files/s
# [2025-12-03T05:31:00-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 39186/103917 archivos | 593.3 files/s
# [2025-12-03T05:31:02-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 40000/103917 archivos | 593.6 files/s
# [2025-12-03T05:31:04-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 41171/103917 archivos | 593.3 files/s
# [2025-12-03T05:31:05-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 42000/103917 archivos | 593.0 files/s
# [2025-12-03T05:31:07-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 43151/103917 archivos | 592.5 files/s
# [2025-12-03T05:31:09-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 44000/103917 archivos | 592.6 files/s
# [2025-12-03T05:31:11-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 45182/103917 archivos | 592.6 files/s
# [2025-12-03T05:31:12-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 46000/103917 archivos | 592.5 files/s
# [2025-12-03T05:31:14-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 47174/103917 archivos | 592.3 files/s
# [2025-12-03T05:31:15-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 48000/103917 archivos | 592.4 files/s
# [2025-12-03T05:31:17-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 49138/103917 archivos | 591.8 files/s
# [2025-12-03T05:31:19-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 50000/103917 archivos | 591.1 files/s
# [2025-12-03T05:31:21-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 51137/103917 archivos | 590.5 files/s
# [2025-12-03T05:31:22-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 52000/103917 archivos | 590.7 files/s
# [2025-12-03T05:31:24-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 53199/103917 archivos | 590.9 files/s
# [2025-12-03T05:31:26-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 54000/103917 archivos | 591.1 files/s
# [2025-12-03T05:31:28-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 55157/103917 archivos | 590.8 files/s
# [2025-12-03T05:31:29-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 56000/103917 archivos | 591.0 files/s
# [2025-12-03T05:31:31-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 57173/103917 archivos | 590.9 files/s
# [2025-12-03T05:31:33-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 58000/103917 archivos | 590.9 files/s
# [2025-12-03T05:31:34-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 59169/103917 archivos | 590.8 files/s
# [2025-12-03T05:31:36-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 60000/103917 archivos | 591.0 files/s
# [2025-12-03T05:31:38-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 61148/103917 archivos | 590.7 files/s
# [2025-12-03T05:31:39-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 62000/103917 archivos | 590.9 files/s
# [2025-12-03T05:31:41-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 63180/103917 archivos | 590.9 files/s
# [2025-12-03T05:31:43-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 64000/103917 archivos | 590.6 files/s
# [2025-12-03T05:31:45-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 65155/103917 archivos | 590.4 files/s
# [2025-12-03T05:31:46-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 66000/103917 archivos | 590.0 files/s
# [2025-12-03T05:31:48-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 67163/103917 archivos | 589.9 files/s
# [2025-12-03T05:31:49-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 68000/103917 archivos | 592.3 files/s
# [2025-12-03T05:31:51-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 69887/103917 archivos | 598.3 files/s
# [2025-12-03T05:31:51-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 70000/103917 archivos | 598.7 files/s
# [2025-12-03T05:31:53-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 71864/103917 archivos | 604.3 files/s
# [2025-12-03T05:31:53-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 72000/103917 archivos | 604.8 files/s
# [2025-12-03T05:31:55-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 73989/103917 archivos | 611.2 files/s
# [2025-12-03T05:31:55-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 74000/103917 archivos | 611.3 files/s
# [2025-12-03T05:31:57-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 75954/103917 archivos | 617.3 files/s
# [2025-12-03T05:31:57-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 76000/103917 archivos | 617.4 files/s
# [2025-12-03T05:31:59-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 77783/103917 archivos | 621.8 files/s
# [2025-12-03T05:32:00-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 78000/103917 archivos | 622.3 files/s
# [2025-12-03T05:32:02-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 79553/103917 archivos | 624.7 files/s
# [2025-12-03T05:32:02-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 80000/103917 archivos | 625.4 files/s
# [2025-12-03T05:32:04-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 81693/103917 archivos | 628.8 files/s
# [2025-12-03T05:32:05-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 82000/103917 archivos | 629.6 files/s
# [2025-12-03T05:32:07-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 83624/103917 archivos | 632.3 files/s
# [2025-12-03T05:32:07-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 84000/103917 archivos | 633.2 files/s
# [2025-12-03T05:32:09-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 85607/103917 archivos | 635.7 files/s
# [2025-12-03T05:32:09-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 86000/103917 archivos | 636.3 files/s
# [2025-12-03T05:32:11-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 87657/103917 archivos | 639.1 files/s
# [2025-12-03T05:32:12-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 88000/103917 archivos | 639.9 files/s
# [2025-12-03T05:32:14-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 89676/103917 archivos | 642.7 files/s
# [2025-12-03T05:32:14-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 90000/103917 archivos | 643.3 files/s
# [2025-12-03T05:32:16-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 91749/103917 archivos | 646.5 files/s
# [2025-12-03T05:32:17-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 92000/103917 archivos | 647.1 files/s
# [2025-12-03T05:32:19-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 93737/103917 archivos | 650.2 files/s
# [2025-12-03T05:32:19-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 94000/103917 archivos | 650.6 files/s
# [2025-12-03T05:32:21-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 95775/103917 archivos | 653.8 files/s
# [2025-12-03T05:32:21-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 96000/103917 archivos | 654.2 files/s
# [2025-12-03T05:32:23-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 97711/103917 archivos | 656.9 files/s
# [2025-12-03T05:32:23-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 98000/103917 archivos | 657.2 files/s
# [2025-12-03T05:32:25-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 99718/103917 archivos | 659.9 files/s
# [2025-12-03T05:32:26-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 100000/103917 archivos | 660.3 files/s
# [2025-12-03T05:32:28-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 101755/103917 archivos | 663.2 files/s
# [2025-12-03T05:32:28-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 102000/103917 archivos | 663.5 files/s
# [2025-12-03T05:32:30-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 103748/103917 archivos | 666.3 files/s
# [2025-12-03T05:32:30-05:00] [20251202_232253] [INFO] [15-Index-Catalog] day_index: 103917/103917 archivos | 666.5 files/s
# --------------------------------------------------------------------------------------------------------------
# Índice diario → C:\Quant\MT5_Data_Extraction\data\metadata\day_index_m5.parquet
#   - Filas: 103917 | Columnas: 8
#   - Esquema:
#   • symbol: String
#   • date: String
#   • path: String
#   • bytes: Int64
#   • n_rows: Int64
#   • min_ts: Int64
#   • max_ts: Int64
#   • dups: Int64
#   - Tiempo construcción: 155.97 s
# --------------------------------------------------------------------------------------------------------------
# Índice por símbolo → C:\Quant\MT5_Data_Extraction\data\metadata\symbol_index_m5.parquet
#   - Filas (símbolos): 92 | Columnas: 9
#   - Esquema:
#   • symbol: String
#   • days: UInt32
#   • rows_total: Int64
#   • bytes_total: Int64
#   • first_day: Int32
#   • last_day: Int32
#   • min_ts: Int64
#   • max_ts: Int64
#   • dups_total: Null
#   - Tiempo construcción: 0.01 s
# --------------------------------------------------------------------------------------------------------------
# Catálogo de ventanas → C:\Quant\MT5_Data_Extraction\data\metadata\window_catalog_m5.parquet
#   - Filas (ventanas): 3 | Columnas: 6
#   • window: String
#   • symbols: Int64
#   • files: Int64
#   • bytes: Int64
#   • from_ts: Int64
#   • to_ts: Int64
# Ventana last_30d: symbols=108 | files=3496 | bytes=35.35 MiB | rango UTC: 2025-10-21T00:05:00+00:00 → 2025-12-02T23:50:00+00:00
# Ventana last_90d: symbols=108 | files=8485 | bytes=85.83 MiB | rango UTC: 2025-08-22T00:05:00+00:00 → 2025-12-02T23:50:00+00:00
# Ventana last_180d: symbols=108 | files=16073 | bytes=163.07 MiB | rango UTC: 2025-05-24T00:05:00+00:00 → 2025-12-02T23:50:00+00:00
# --------------------------------------------------------------------------------------------------------------
# ✅ Índices y catálogo listos (incluye fallback a ventanas cuando GOLD/RAW están vacíos).

# %%
# ======================= Celda 16 — QA Trading-Ready (síntesis ejecutiva) =======================
# Propósito:
#   - Construir un resumen ejecutivo de si el dataset M5 actual está "TRADING_READY" o no.
#   - Fusiona información de:
#       * filtros 3B / universe base (eligible_symbols_by_cost.*)
#       * capa GOLD (historical_data/m5_clean)
#       * ventanas recientes (processed_data/m5_windows)
#       * costes por símbolo (costs_summary.parquet, Celda 05)
#       * QA operativa por símbolo (qa_operativa_summary.parquet, Celda 10)
#       * universe_snapshot_{RUN_ID}.parquet (Celda 12B)
#   - Escribe un único artefacto JSON:
#       * metadata/qa_trading_ready_summary.json
#
# Notas de diseño:
#   - NO recalcula QA ni reconstruye datos; sólo lee artefactos existentes.
#   - Incluye métricas ricas para el siguiente notebook (research / backtests).
#   - El "gate" (TRADING_READY vs NO) es configurable:
#       * ENFORCE_TRADING_GATE = False → status="EMPTY" (informativo, no bloqueante).
#       * ENFORCE_TRADING_GATE = True  → status="PASS"/"FAIL" según criterios definidos.
#   - Por defecto, REQUIRED_WINDOW="last_30d" (modo research, no producción).
# ===============================================================================================

from __future__ import annotations
import os, json, math, time
from pathlib import Path
from datetime import datetime, timedelta, timezone, date
from typing import Any, Dict, List, Optional, Tuple

try:
    import polars as pl
except Exception as e:
    raise RuntimeError("Se requiere 'polars'. Instálalo e inténtalo de nuevo.") from e

# ----------------------------- Identidad / Config base -----------------------------
CELL_LABEL    = "16-QA-Trading-Ready"
RUN_ID        = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))
TIMEZONE_IANA = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# DATA_ROOT: preferimos el definido en Celda 02; si no, env M5_DATA_ROOT; si no, ./data
DATA_ROOT = Path(
    globals().get("DATA_ROOT", os.environ.get("M5_DATA_ROOT", "./data"))
).resolve()

META_DIR = DATA_ROOT / "metadata"
HIST_DIR = DATA_ROOT / "historical_data" / "m5_clean"
PROC_DIR = DATA_ROOT / "processed_data"  / "m5_windows"

META_DIR.mkdir(parents=True, exist_ok=True)

COSTS_SUMMARY_PATH     = META_DIR / "costs_summary.parquet"                # Celda 05
QA_OPER_SUMMARY_PATH   = META_DIR / "qa_operativa_summary.parquet"        # Celda 10
UNIVERSE_SNAPSHOT_PATH = META_DIR / f"universe_snapshot_{RUN_ID}.parquet" # Celda 12B
UNIVERSE_LATEST_PATH   = META_DIR / "universe_snapshot_latest.parquet"    # fallback
QA_TRADING_JSON        = META_DIR / "qa_trading_ready_summary.json"

# Parámetros del gate (ajustables vía globals() antes de ejecutar esta celda)
WINDOWS = {"last_30d": 30, "last_90d": 90, "last_180d": 180}
REQUIRED_WINDOW           = str(globals().get("REQUIRED_WINDOW", "last_30d"))
GATE_BASE_MIN_FLOOR       = int(globals().get("GATE_BASE_MIN_FLOOR", 50))
GATE_BASE_PCT             = float(globals().get("GATE_BASE_PCT", 0.70))    # 70% del universo base
MIN_COSTS_OK_RATIO_PCT    = float(globals().get("MIN_COSTS_OK_RATIO_PCT", 70.0))
MIN_QA_OK_RATIO_PCT       = float(globals().get("MIN_QA_OK_RATIO_PCT", 70.0))
READY_COST_FLAGS          = list(globals().get("READY_COST_FLAGS", ["OK"]))
READY_QA_FLAGS            = list(globals().get("READY_QA_FLAGS", ["OK"]))
ENFORCE_TRADING_GATE      = bool(globals().get("ENFORCE_TRADING_GATE", False))

# ----------------------------- Utils ---------------------------------------------
def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return datetime.now(timezone.utc).isoformat(timespec="seconds")

def _log(level: str, msg: str):
    """
    Si log_msg(celda, level, message) existe (Celda 03), lo usa.
    Sino, hace print() con timestamp local.
    """
    if "log_msg" in globals():
        try:
            log_msg(CELL_LABEL, level, msg)
            return
        except Exception:
            pass
    print(f"[{_now_local_iana()}] [{RUN_ID}] [{level.upper()}] [{CELL_LABEL}] {msg}", flush=True)

def _fmt_bytes(n: int) -> str:
    if n < 1024: return f"{n} B"
    kib = n/1024
    if kib < 1024: return f"{kib:.2f} KiB"
    mib = kib/1024
    if mib < 1024: return f"{mib:.2f} MiB"
    gib = mib/1024
    if gib < 1024: return f"{gib:.2f} GiB"
    tib = gib/1024
    return f"{tib:.2f} TiB"

def _hist_symbols() -> set[str]:
    """Símbolos presentes en la capa GOLD (m5_clean)."""
    if not HIST_DIR.exists():
        return set()
    out: set[str] = set()
    for d in HIST_DIR.glob("symbol=*"):
        if d.is_dir():
            out.add(d.name.split("=",1)[-1])
    return out

def _expected_ymd(d: date) -> str:
    return f"{d.year:04d}{d.month:02d}{d.day:02d}"

def _expected_ymds(n_days: int) -> set[str]:
    """
    Conjunto de fechas esperadas (YYYYMMDD) para una ventana de n_days,
    terminando en el día de ayer (UTC).
    """
    end_day = (datetime.now(timezone.utc) - timedelta(days=1)).date()
    start_day = end_day - timedelta(days=n_days-1)
    out: List[str] = []
    cur = start_day
    while cur <= end_day:
        out.append(_expected_ymd(cur))
        cur += timedelta(days=1)
    return set(out)

def _window_days_for_symbol(wname: str, sym: str) -> set[str]:
    """
    Devuelve el conjunto de YYYYMMDD disponibles en m5_windows
    para una ventana dada y símbolo concreto.
    """
    base = PROC_DIR / f"window={wname}" / f"symbol={sym}"
    if not base.exists():
        return set()
    return {
        p.name.split("=")[-1].split(".")[0]
        for p in base.glob("part=*.parquet")
    }

def _read_eligible_set() -> tuple[Optional[set[str]], str]:
    """
    Lee el universo base 3B (por costes) desde metadata/filters/,
    si existe. Fallback: None + etiqueta.
    """
    filt_dir = META_DIR / "filters"
    p_parq = filt_dir / "eligible_symbols_by_cost.parquet"
    p_txt  = filt_dir / "eligible_symbols_by_cost.txt"
    try:
        if p_parq.exists():
            df = pl.read_parquet(p_parq)
            col = "symbol" if "symbol" in df.columns else df.columns[0]
            return set(df[col].cast(pl.Utf8).to_list()), "eligible_3B(parquet)"
    except Exception:
        pass
    if p_txt.exists():
        s: set[str] = set()
        for ln in p_txt.read_text(encoding="utf-8").splitlines():
            v = ln.strip()
            if v:
                s.add(v)
        return s, "eligible_3B(txt)"
    return None, "eligible_missing"

# ----------------------------- Cabecera de ejecución -----------------------------
print("="*110)
print("Celda 16 — QA Trading-Ready (síntesis ejecutiva del Data Engine M5)")
print(f"TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-"*110)
print(f"DATA_ROOT : {DATA_ROOT}")
print(f"Metadata  : {META_DIR}")
print(f"GOLD (m5_clean)  : {HIST_DIR}")
print(f"WINDOWS (m5_win) : {PROC_DIR}")
print(f"Universe snapshot esperado: {UNIVERSE_SNAPSHOT_PATH}")
print(f"Resumen QA trading → {QA_TRADING_JSON}")
print("-"*110)
print(f"REQUIRED_WINDOW        = '{REQUIRED_WINDOW}'")
print(f"GATE_BASE_MIN_FLOOR    = {GATE_BASE_MIN_FLOOR}")
print(f"GATE_BASE_PCT          = {GATE_BASE_PCT:.2f}")
print(f"MIN_COSTS_OK_RATIO_PCT = {MIN_COSTS_OK_RATIO_PCT:.1f}")
print(f"MIN_QA_OK_RATIO_PCT    = {MIN_QA_OK_RATIO_PCT:.1f}")
print(f"READY_COST_FLAGS       = {READY_COST_FLAGS}")
print(f"READY_QA_FLAGS         = {READY_QA_FLAGS}")
print(f"ENFORCE_TRADING_GATE   = {ENFORCE_TRADING_GATE}")
print("-"*110)

issues: List[str] = []

# ----------------------------- 1) GOLD summary -----------------------------------
hist_syms  = _hist_symbols()
hist_parts = sorted(HIST_DIR.rglob("part=*.parquet")) if HIST_DIR.exists() else []
hist_files = len(hist_parts)
hist_bytes = sum(p.stat().st_size for p in hist_parts)

print(f"📦 GOLD (m5_clean): files={hist_files:,} | bytes={_fmt_bytes(hist_bytes)} | symbols={len(hist_syms)}")

# ----------------------------- 2) Universo base (3B) -----------------------------
eligible_set, elig_label = _read_eligible_set()
if eligible_set is None:
    base_universe = set(hist_syms)
    base_label = "clean_fallback"
    issues.append("eligible_symbols_by_cost.* no encontrado; se usa fallback al universo GOLD.")
else:
    base_universe = set(eligible_set)
    base_label = elig_label

print(f"🔎 Universo base (costes): {base_label} → {len(base_universe)} símbolo(s)")

intersect_base_clean = base_universe & hist_syms
missing_in_clean     = base_universe - hist_syms
outside_but_clean    = hist_syms - base_universe

print(f"    ∩ base ∩ GOLD = {len(intersect_base_clean)} | missing_in_clean={len(missing_in_clean)} | outside_but_clean={len(outside_but_clean)}")

# ----------------------------- 3) Universe snapshot (Celda 12B) ------------------
universe_syms: Optional[set[str]] = None
universe_n = 0
universe_path_used = None

if UNIVERSE_SNAPSHOT_PATH.exists():
    try:
        df_univ = pl.read_parquet(UNIVERSE_SNAPSHOT_PATH)
        if "symbol" not in df_univ.columns:
            raise ValueError("universe_snapshot no tiene columna 'symbol'.")
        universe_syms = set(df_univ.get_column("symbol").cast(pl.Utf8, strict=False).to_list())
        universe_n = len(universe_syms)
        universe_path_used = str(UNIVERSE_SNAPSHOT_PATH)
        _log("INFO", f"Universe snapshot cargado ({universe_n} símbolos) desde {UNIVERSE_SNAPSHOT_PATH}")
    except Exception as e:
        issues.append(f"universe_snapshot ilegible: {e}")
        _log("WARNING", f"universe_snapshot ilegible: {e}")
elif UNIVERSE_LATEST_PATH.exists():
    try:
        df_univ = pl.read_parquet(UNIVERSE_LATEST_PATH)
        if "symbol" not in df_univ.columns:
            raise ValueError("universe_snapshot_latest no tiene columna 'symbol'.")
        universe_syms = set(df_univ.get_column("symbol").cast(pl.Utf8, strict=False).to_list())
        universe_n = len(universe_syms)
        universe_path_used = str(UNIVERSE_LATEST_PATH)
        _log("WARNING", f"No se encontró universe_snapshot para RUN_ID={RUN_ID}; usando universe_snapshot_latest.parquet.")
    except Exception as e:
        issues.append(f"universe_snapshot_latest ilegible: {e}")
        _log("WARNING", f"universe_snapshot_latest ilegible: {e}")
else:
    issues.append("No se encontró universe_snapshot (ni por RUN_ID ni latest).")
    _log("WARNING", "Universe snapshot no encontrado; la auditoría usará sólo costes + GOLD.")

# ----------------------------- 4) Costes summary (Celda 05) ----------------------
costs_exists = COSTS_SUMMARY_PATH.exists()
syms_costs: set[str] = set()
costs_flag_dist: Optional[Dict[str, int]] = None
costs_ok_ratio_pct: Optional[float] = None

if costs_exists:
    try:
        df_costs = pl.read_parquet(COSTS_SUMMARY_PATH)
        if "symbol" not in df_costs.columns:
            raise ValueError("costs_summary.parquet no tiene columna 'symbol'.")
        syms_costs = set(df_costs.get_column("symbol").cast(pl.Utf8, strict=False).to_list())

        if "cost_flag" in df_costs.columns:
            flag_counts = (
                df_costs
                .group_by("cost_flag")
                .agg(pl.len().alias("n"))
                .to_dicts()
            )
            costs_flag_dist = {r["cost_flag"]: int(r["n"]) for r in flag_counts}
            total_flags = sum(costs_flag_dist.values())
            if total_flags > 0 and "OK" in costs_flag_dist:
                costs_ok_ratio_pct = round(100.0 * costs_flag_dist["OK"] / total_flags, 1)
        _log("INFO", f"costs_summary.parquet cargado ({len(syms_costs)} símbolos).")
    except Exception as e:
        costs_exists = False
        issues.append(f"costs_summary ilegible: {e}")
        _log("WARNING", f"costs_summary ilegible: {e}")
else:
    issues.append("costs_summary.parquet no encontrado (Celda 05 no ejecutada o en otra ruta).")
    _log("WARNING", "costs_summary.parquet no encontrado.")

# ----------------------------- 5) QA operativa summary (Celda 10) ----------------
qa_exists = QA_OPER_SUMMARY_PATH.exists()
syms_qa: set[str] = set()
qa_flag_dist: Optional[Dict[str, int]] = None
qa_ok_ratio_pct: Optional[float] = None

if qa_exists:
    try:
        df_qa = pl.read_parquet(QA_OPER_SUMMARY_PATH)
        if "symbol" not in df_qa.columns:
            raise ValueError("qa_operativa_summary.parquet no tiene columna 'symbol'.")
        syms_qa = set(df_qa.get_column("symbol").cast(pl.Utf8, strict=False).to_list())

        if "qa_operativa_flag" in df_qa.columns:
            flag_counts = (
                df_qa
                .group_by("qa_operativa_flag")
                .agg(pl.len().alias("n"))
                .to_dicts()
            )
            qa_flag_dist = {r["qa_operativa_flag"]: int(r["n"]) for r in flag_counts}
            total_flags = sum(qa_flag_dist.values())
            if total_flags > 0 and "OK" in qa_flag_dist:
                qa_ok_ratio_pct = round(100.0 * qa_flag_dist["OK"] / total_flags, 1)
        _log("INFO", f"qa_operativa_summary.parquet cargado ({len(syms_qa)} símbolos).")
    except Exception as e:
        qa_exists = False
        issues.append(f"qa_operativa_summary ilegible: {e}")
        _log("WARNING", f"qa_operativa_summary ilegible: {e}")
else:
    issues.append("qa_operativa_summary.parquet no encontrado (Celda 10 no ejecutada o en otra ruta).")
    _log("WARNING", "qa_operativa_summary.parquet no encontrado.")

# ----------------------------- 6) Cobertura por ventanas (m5_windows) ------------
# Símbolos que consideramos para ventanas: intersección entre universo base y GOLD
symbols_for_windows = sorted(intersect_base_clean)
expected_by_win: Dict[str, set[str]] = {w: _expected_ymds(n) for w, n in WINDOWS.items()}
passed_by_window: Dict[str, set[str]] = {w: set() for w in WINDOWS}

t0 = time.monotonic()
last = t0

for k, sym in enumerate(symbols_for_windows, 1):
    for wname, exp_set in expected_by_win.items():
        have = _window_days_for_symbol(wname, sym)
        if exp_set.issubset(have):
            passed_by_window[wname].add(sym)
    now = time.monotonic()
    if now - last >= 2.0:
        _log("INFO", f"Ventanas: símbolos evaluados {k}/{len(symbols_for_windows)}")
        last = now

print("-"*110)
for wname in ("last_30d", "last_90d", "last_180d"):
    if wname in passed_by_window:
        n_pass = len(passed_by_window[wname])
        base_n = len(symbols_for_windows)
        pct = (100.0 * n_pass / base_n) if base_n else 0.0
        print(f"🪟 {wname}: pasan={n_pass} / {base_n} ({pct:.1f}%)")

# ----------------------------- 7) Construcción de listas de símbolos ready -------
# Base consolidada por símbolo
symbols_all = sorted(set(symbols_for_windows))

rows_detail: List[Dict[str, Any]] = []
ready_by_window: Dict[str, List[str]] = {w: [] for w in WINDOWS}

for sym in symbols_all:
    cost_flag = None
    qa_flag   = None

    if costs_exists:
        try:
            row = df_costs.filter(pl.col("symbol") == sym)
            if row.height > 0 and "cost_flag" in row.columns:
                cost_flag = row["cost_flag"][0]
        except Exception:
            cost_flag = None

    if qa_exists:
        try:
            row = df_qa.filter(pl.col("symbol") == sym)
            if row.height > 0 and "qa_operativa_flag" in row.columns:
                qa_flag = row["qa_operativa_flag"][0]
        except Exception:
            qa_flag = None

    has_full_30  = sym in passed_by_window.get("last_30d", set())
    has_full_90  = sym in passed_by_window.get("last_90d", set())
    has_full_180 = sym in passed_by_window.get("last_180d", set())

    # Best window = la más larga que cumple, en orden 180 > 90 > 30
    best_window = None
    if has_full_180:
        best_window = "last_180d"
    elif has_full_90:
        best_window = "last_90d"
    elif has_full_30:
        best_window = "last_30d"

    # Condición de "ready" por ventana: pasa la ventana Y flags aceptables
    for wname, has_full in [("last_30d", has_full_30),
                            ("last_90d", has_full_90),
                            ("last_180d", has_full_180)]:
        if not has_full:
            continue
        if (cost_flag is not None) and (READY_COST_FLAGS and cost_flag not in READY_COST_FLAGS):
            continue
        if (qa_flag is not None) and (READY_QA_FLAGS and qa_flag not in READY_QA_FLAGS):
            continue
        ready_by_window[wname].append(sym)

    rows_detail.append({
        "symbol": sym,
        "best_window": best_window,
        "cost_flag": cost_flag,
        "qa_operativa_flag": qa_flag,
        "has_full_last_30d": has_full_30,
        "has_full_last_90d": has_full_90,
        "has_full_last_180d": has_full_180,
    })

# Eliminamos duplicados manteniendo orden
for wname, lst in ready_by_window.items():
    seen: set[str] = set()
    uniq: List[str] = []
    for s in lst:
        if s not in seen:
            seen.add(s)
            uniq.append(s)
    ready_by_window[wname] = uniq

print("-"*110)
for wname in ("last_30d", "last_90d", "last_180d"):
    lst = ready_by_window.get(wname, [])
    print(f"✅ Símbolos 'ready' para {wname} (ventana completa + flags costes/QA aceptables): {len(lst)}")

# ----------------------------- 8) Evaluación del gate global ---------------------
base_size = len(base_universe)
min_symbols_hist = max(GATE_BASE_MIN_FLOOR, math.ceil(GATE_BASE_PCT * base_size)) if base_size > 0 else 0

approved_syms_required = set(ready_by_window.get(REQUIRED_WINDOW, []))
approved_count = len(approved_syms_required)

cond_symbols = (approved_count >= min_symbols_hist)
cond_costs   = (costs_ok_ratio_pct is None) or (costs_ok_ratio_pct >= MIN_COSTS_OK_RATIO_PCT)
cond_qa      = (qa_ok_ratio_pct is None) or (qa_ok_ratio_pct >= MIN_QA_OK_RATIO_PCT)

computed_status: str
if not symbols_for_windows:
    computed_status = "EMPTY"
    issues.append("No hay símbolos en la intersección base ∩ GOLD para evaluar ventanas.")
else:
    if cond_symbols and cond_costs and cond_qa:
        computed_status = "PASS"
    else:
        computed_status = "FAIL"
        if not cond_symbols:
            issues.append(
                f"Gate de ventanas no cumplido: {approved_count} < MIN_SYMBOLS_HIST={min_symbols_hist} "
                f"para REQUIRED_WINDOW='{REQUIRED_WINDOW}'."
            )
        if not cond_costs and costs_ok_ratio_pct is not None:
            issues.append(
                f"Ratio de costes OK insuficiente: {costs_ok_ratio_pct:.1f}% < MIN_COSTS_OK_RATIO_PCT={MIN_COSTS_OK_RATIO_PCT:.1f}%."
            )
        if not cond_qa and qa_ok_ratio_pct is not None:
            issues.append(
                f"Ratio de QA operativa OK insuficiente: {qa_ok_ratio_pct:.1f}% < MIN_QA_OK_RATIO_PCT={MIN_QA_OK_RATIO_PCT:.1f}%."
            )

# Estado efectivo que verá el resto del pipeline
if ENFORCE_TRADING_GATE:
    final_status = computed_status
else:
    # Modo informativo: el Data Engine no bloquea, sólo informa.
    final_status = "EMPTY"

print("-"*110)
print(f"📏 Umbral dinámico MIN_SYMBOLS_HIST = {min_symbols_hist} (base={base_size}, regla={int(GATE_BASE_PCT*100)}%)")
print(f"🧰 Ventana requerida  : {REQUIRED_WINDOW}")
print(f"🧰 Símbolos aprobados : {approved_count}")
print(f"📊 Ratio costes OK     : {costs_ok_ratio_pct}%")
print(f"📊 Ratio QA op. OK     : {qa_ok_ratio_pct}%")
print(f"🟦 computed_status     : {computed_status}")
print(f"🟩 final status (JSON) : {final_status}  (ENFORCE_TRADING_GATE={ENFORCE_TRADING_GATE})")

# ----------------------------- 9) Construcción del JSON de salida ----------------
qa_summary: Dict[str, Any] = {
    "run_id": RUN_ID,
    "ts_utc": datetime.now(timezone.utc).isoformat(),
    "data_root": str(DATA_ROOT),
    "status": final_status,  # lo que verá Celda 18
    "gate_config": {
        "required_window": REQUIRED_WINDOW,
        "windows": WINDOWS,
        "base_min_floor": GATE_BASE_MIN_FLOOR,
        "base_pct": GATE_BASE_PCT,
        "min_costs_ok_ratio_pct": MIN_COSTS_OK_RATIO_PCT,
        "min_qa_ok_ratio_pct": MIN_QA_OK_RATIO_PCT,
        "ready_cost_flags": READY_COST_FLAGS,
        "ready_qa_flags": READY_QA_FLAGS,
        "enforce_trading_gate": ENFORCE_TRADING_GATE,
    },
    "gold": {
        "files": hist_files,
        "bytes": hist_bytes,
        "bytes_human": _fmt_bytes(hist_bytes),
        "symbols": len(hist_syms),
    },
    "universe_summary": {
        "base_label": base_label,
        "eligible_3b_symbols": len(base_universe),
        "gold_symbols": len(hist_syms),
        "intersection_base_vs_gold": len(intersect_base_clean),
        "missing_in_clean": len(missing_in_clean),
        "outside_but_clean": len(outside_but_clean),
    },
    "universe_snapshot": {
        "path_used": universe_path_used,
        "n_symbols": universe_n,
    },
    "costs_summary": {
        "path": str(COSTS_SUMMARY_PATH),
        "exists": costs_exists,
        "n_symbols_costs": len(syms_costs),
        "cost_flag_distribution": costs_flag_dist,
        "cost_flag_ok_ratio_pct": costs_ok_ratio_pct,
    },
    "qa_operativa_summary": {
        "path": str(QA_OPER_SUMMARY_PATH),
        "exists": qa_exists,
        "n_symbols_qa_operativa": len(syms_qa),
        "qa_operativa_flag_distribution": qa_flag_dist,
        "qa_operativa_flag_ok_ratio_pct": qa_ok_ratio_pct,
    },
    "windows_coverage": {
        w: {
            "symbols_passing": len(passed_by_window.get(w, set())),
            "base_intersection": len(symbols_for_windows),
            "pct_intersection_passing": (
                round(100.0 * len(passed_by_window.get(w, set())) / len(symbols_for_windows), 1)
                if symbols_for_windows else 0.0
            ),
        }
        for w in WINDOWS
    },
    "gate_result": {
        "computed_status": computed_status,
        "final_status": final_status,
        "required_window": REQUIRED_WINDOW,
        "approved_symbols_required_window": approved_count,
        "min_symbols_hist": min_symbols_hist,
    },
    "ready_symbols": ready_by_window,
    "ready_symbols_detail": rows_detail,
    "issues": issues,
}

QA_TRADING_JSON.write_text(json.dumps(qa_summary, ensure_ascii=False, indent=2), encoding="utf-8")

print("-"*110)
print(f"📄 qa_trading_ready_summary.json escrito en: {QA_TRADING_JSON}")
print(f"    status={final_status} | computed_status={computed_status} | issues={len(issues)}")
print("="*110)
print("✅ Celda 16 — QA Trading-Ready completada (resumen ejecutivo disponible para el siguiente notebook).")
# Out:
# ==============================================================================================================
# Celda 16 — QA Trading-Ready (síntesis ejecutiva del Data Engine M5)
# TZ local: America/Guayaquil
# Hora local: 2025-12-03T05:32:30-05:00 | Hora UTC: 2025-12-03T10:32:30+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT : C:\Quant\MT5_Data_Extraction\data
# Metadata  : C:\Quant\MT5_Data_Extraction\data\metadata
# GOLD (m5_clean)  : C:\Quant\MT5_Data_Extraction\data\historical_data\m5_clean
# WINDOWS (m5_win) : C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows
# Universe snapshot esperado: C:\Quant\MT5_Data_Extraction\data\metadata\universe_snapshot_20251202_232253.parquet
# Resumen QA trading → C:\Quant\MT5_Data_Extraction\data\metadata\qa_trading_ready_summary.json
# --------------------------------------------------------------------------------------------------------------
# REQUIRED_WINDOW        = 'last_30d'
# GATE_BASE_MIN_FLOOR    = 50
# GATE_BASE_PCT          = 0.70
# MIN_COSTS_OK_RATIO_PCT = 70.0
# MIN_QA_OK_RATIO_PCT    = 70.0
# READY_COST_FLAGS       = ['OK']
# READY_QA_FLAGS         = ['OK']
# ENFORCE_TRADING_GATE   = False
# --------------------------------------------------------------------------------------------------------------
# 📦 GOLD (m5_clean): files=103,917 | bytes=1.03 GiB | symbols=92
# 🔎 Universo base (costes): eligible_3B(parquet) → 107 símbolo(s)
#     ∩ base ∩ GOLD = 89 | missing_in_clean=18 | outside_but_clean=3
# [2025-12-03 05:32:33] [20251202_232253] [INFO] [16-QA-Trading-Ready] Universe snapshot cargado (107 símbolos) desde C:\Quant\MT5_Data_Extraction\data\metadata\universe_snapshot_20251202_232253.parquet
# [2025-12-03 05:32:33] [20251202_232253] [INFO] [16-QA-Trading-Ready] costs_summary.parquet cargado (131 símbolos).
# [2025-12-03 05:32:33] [20251202_232253] [INFO] [16-QA-Trading-Ready] qa_operativa_summary.parquet cargado (107 símbolos).
# --------------------------------------------------------------------------------------------------------------
# 🪟 last_30d: pasan=29 / 89 (32.6%)
# 🪟 last_90d: pasan=0 / 89 (0.0%)
# 🪟 last_180d: pasan=0 / 89 (0.0%)
# --------------------------------------------------------------------------------------------------------------
# ✅ Símbolos 'ready' para last_30d (ventana completa + flags costes/QA aceptables): 13
# ✅ Símbolos 'ready' para last_90d (ventana completa + flags costes/QA aceptables): 0
# ✅ Símbolos 'ready' para last_180d (ventana completa + flags costes/QA aceptables): 0
# --------------------------------------------------------------------------------------------------------------
# 📏 Umbral dinámico MIN_SYMBOLS_HIST = 75 (base=107, regla=70%)
# 🧰 Ventana requerida  : last_30d
# 🧰 Símbolos aprobados : 13
# 📊 Ratio costes OK     : 71.8%
# 📊 Ratio QA op. OK     : 69.2%
# 🟦 computed_status     : FAIL
# 🟩 final status (JSON) : EMPTY  (ENFORCE_TRADING_GATE=False)
# --------------------------------------------------------------------------------------------------------------
# 📄 qa_trading_ready_summary.json escrito en: C:\Quant\MT5_Data_Extraction\data\metadata\qa_trading_ready_summary.json
#     status=EMPTY | computed_status=FAIL | issues=2
# ==============================================================================================================
# ✅ Celda 16 — QA Trading-Ready completada (resumen ejecutivo disponible para el siguiente notebook).

# %%
# ======================= Celda 18 — Auditoría integral de PADs (opcional, NO reemplazo) =======================
# Propósito:
#   - Auditoría de salud del pipeline M5 leyendo artefactos existentes (Celdas 10/12/15/16/18).
#   - NO reemplaza pasos previos; NO reconstruye nada. Sólo verifica y resume estado.
#   - Sin hardcode de rutas: usa DATA_ROOT de globals() o env M5_DATA_ROOT (fallback ./data).
#   - Polars-only + scan_parquet con proyección/predicado tardío (homogéneo).
# Salidas:
#   - metadata/pipeline_health_report.json  (reporte consolidado, legible por máquinas)
# Prints:
#   - Recuentos, rangos, tasas de verificación, heartbeats suaves.
# Flags:
#   - Por defecto NO crea flags TRADING_READY/NOT_READY. Se puede habilitar con WRITE_FLAGS=True.
# ==============================================================================================================

from __future__ import annotations
import os, json, time, math, re
from pathlib import Path
from datetime import datetime, timedelta, timezone, date
from typing import Any, Dict, List, Optional, Tuple

# ----------------------------- Dependencia requerida -----------------------------
try:
    import polars as pl
except Exception as e:
    raise RuntimeError("Se requiere 'polars'. Instálalo e inténtalo de nuevo.") from e

# ----------------------------- Configuración básica ------------------------------
CELL_LABEL = "18-Health-Audit"
RUN_ID = globals().get("RUN_ID", datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S"))
TIMEZONE_IANA = globals().get("TIMEZONE_IANA", "America/Guayaquil")

# DATA_ROOT: globals() -> env M5_DATA_ROOT -> ./data
DATA_ROOT = Path(
    globals().get("DATA_ROOT", os.environ.get("M5_DATA_ROOT", "./data"))
).resolve()

HIST_DIR    = DATA_ROOT / "historical_data" / "m5_clean"         # producido por Celda 10
PROC_DIR    = DATA_ROOT / "processed_data"  / "m5_windows"       # producido por Celda 12
META_DIR    = DATA_ROOT / "metadata"                             # índices/QA de Celdas 15/16
BACKUPS_DIR = DATA_ROOT / "backups"                              # por Celda 13 (backup)

DAY_INDEX_PATH    = META_DIR / "day_index_m5.parquet"            # Celda 15
SYMBOL_INDEX_PATH = META_DIR / "symbol_index_m5.parquet"         # Celda 15
WINDOW_CATALOG    = META_DIR / "window_catalog_m5.parquet"       # Celda 15
QA_SUMMARY_JSON   = META_DIR / "qa_trading_ready_summary.json"   # Celda 16
HEALTH_JSON       = META_DIR / "pipeline_health_report.json"

# Nuevos artefactos (Celdas 05, 10, 12B)
COSTS_SUMMARY_PATH        = META_DIR / "costs_summary.parquet"                   # Celda 05
QA_OPER_SUMMARY_PATH      = META_DIR / "qa_operativa_summary.parquet"           # Celda 10
UNIVERSE_SNAPSHOT_PATH    = META_DIR / f"universe_snapshot_{RUN_ID}.parquet"    # Celda 12B

# Flags (opt-in)
WRITE_FLAGS = bool(globals().get("WRITE_FLAGS", True))
FLAG_READY  = META_DIR / "TRADING_READY.flag"
FLAG_NOT    = META_DIR / "TRADING_NOT_READY.flag"

# Ventanas y umbrales (ajustables por globals())
WINDOWS = {"last_30d": 30, "last_90d": 90, "last_180d": 180}
REQUIRED_WINDOW = str(globals().get("REQUIRED_WINDOW", "last_180d"))
BASE_MIN_FLOOR  = int(globals().get("GATE_BASE_MIN_FLOOR", 50))
BASE_PCT        = float(globals().get("GATE_BASE_PCT", 0.70))   # 70% del universo base
MIN_DAY_INDEX_ROWS  = int(globals().get("MIN_DAY_INDEX_ROWS", 50_000))
MIN_QA_MAX_AGE_DAYS = int(globals().get("MIN_QA_MAX_AGE_DAYS", 3))
MIN_BACKUP_SIZE_MB  = int(globals().get("MIN_BACKUP_SIZE_MB", 100))

# Heartbeats
HEARTBEAT_SECS = float(globals().get("HEALTH_HEARTBEAT_SECS", 2.0))

# ----------------------------- Utils --------------------------------------------
def _now_local_iana() -> str:
    try:
        from zoneinfo import ZoneInfo
        return datetime.now(timezone.utc).astimezone(ZoneInfo(TIMEZONE_IANA)).isoformat(timespec="seconds")
    except Exception:
        return datetime.now(timezone.utc).isoformat(timespec="seconds")

def _log(level: str, msg: str):
    """
    Usa log_msg(celda, level, message) si está disponible (Celda 03),
    si no, hace un print() formateado.
    """
    if "log_msg" in globals():
        try:
            log_msg(CELL_LABEL, level, msg)
            return
        except Exception:
            # Fallback a print si el logger falla
            pass
    print(f"[{_now_local_iana()}] [{RUN_ID}] [{level.upper()}] [{CELL_LABEL}] {msg}", flush=True)

def _fmt_bytes(n: int) -> str:
    if n < 1024: return f"{n} B"
    kib = n/1024
    if kib < 1024: return f"{kib:.2f} KiB"
    mib = kib/1024
    if mib < 1024: return f"{mib:.2f} MiB"
    gib = mib/1024
    if gib < 1024: return f"{gib:.2f} GiB"
    tib = gib/1024
    return f"{tib:.2f} TiB"

def _safe_size(p: Path) -> int:
    try:
        return p.stat().st_size
    except Exception:
        return 0

def _scan_len(paths: List[str]) -> int:
    if not paths:
        return 0
    return int(pl.scan_parquet(paths, low_memory=True).select(pl.len()).collect().item())

def _ymd(d: date) -> str:
    return f"{d.year:04d}{d.month:02d}{d.day:02d}"

def _expected_ymds(n_days: int) -> set[str]:
    end_day = (datetime.now(timezone.utc) - timedelta(days=1)).date()
    start_day = end_day - timedelta(days=n_days-1)
    out = []
    cur = start_day
    while cur <= end_day:
        out.append(_ymd(cur))
        cur += timedelta(days=1)
    return set(out)

def _read_eligible_set() -> tuple[Optional[set[str]], str]:
    filt_dir = META_DIR / "filters"
    p_parq = filt_dir / "eligible_symbols_by_cost.parquet"
    p_txt  = filt_dir / "eligible_symbols_by_cost.txt"
    try:
        if p_parq.exists():
            df = pl.read_parquet(p_parq)
            col = "symbol" if "symbol" in df.columns else df.columns[0]
            return set(df[col].cast(pl.Utf8).to_list()), "eligible_3B(parquet)"
    except Exception:
        pass
    if p_txt.exists():
        s = set()
        for ln in p_txt.read_text(encoding="utf-8").splitlines():
            v = ln.strip()
            if v:
                s.add(v)
        return s, "eligible_3B(txt)"
    return None, "eligible_missing"

def _hist_symbols() -> set[str]:
    if not HIST_DIR.exists():
        return set()
    out = set()
    for d in HIST_DIR.glob("symbol=*"):
        if d.is_dir():
            out.add(d.name.split("=",1)[-1])
    return out

def _window_days_for_symbol(wname: str, sym: str) -> set[str]:
    base = PROC_DIR / f"window={wname}" / f"symbol={sym}"
    if not base.exists():
        return set()
    return {p.name.split("=")[-1].split(".")[0] for p in base.glob("part=*.parquet")}

# ----------------------------- Cabecera -----------------------------------------
print("="*110)
print("Celda 18 — Auditoría integral de PADs (opcional). NO reemplaza 10/12/15.")
print(f"TZ local: {TIMEZONE_IANA}")
print(f"Hora local: {_now_local_iana()} | Hora UTC: {datetime.now(timezone.utc).isoformat(timespec='seconds')}")
print("-"*110)
print(f"DATA_ROOT: {DATA_ROOT}")
print(f"Metadata:  {META_DIR}")
print("Artefactos clave esperados:")
print(f"  - GOLD (m5_clean)        : {HIST_DIR}")
print(f"  - WINDOWS (m5_windows)   : {PROC_DIR}")
print(f"  - Índices (Celda 15)     : {DAY_INDEX_PATH}, {SYMBOL_INDEX_PATH}, {WINDOW_CATALOG}")
print(f"  - QA trading ready (16)  : {QA_SUMMARY_JSON}")
print(f"  - Costes summary (05)    : {COSTS_SUMMARY_PATH}")
print(f"  - QA operativa (10)      : {QA_OPER_SUMMARY_PATH}")
print(f"  - Universe snapshot (12B): {UNIVERSE_SNAPSHOT_PATH}")
print("-"*110)
META_DIR.mkdir(parents=True, exist_ok=True)

issues: List[str] = []

# ----------------------------- 1) Estado general de GOLD ------------------------
hist_parts = sorted(HIST_DIR.rglob("part=*.parquet")) if HIST_DIR.exists() else []
hist_files = len(hist_parts)
hist_bytes = sum(_safe_size(p) for p in hist_parts)
hist_syms  = _hist_symbols()

print(f"📦 GOLD (m5_clean): files={hist_files:,} | bytes={_fmt_bytes(hist_bytes)} | symbols={len(hist_syms)}")

# ----------------------------- 2) Índices (Celda 15) ----------------------------
def _rows_or_none(p: Path) -> Optional[int]:
    if not p.exists():
        return None
    try:
        return int(pl.scan_parquet(str(p), low_memory=True).select(pl.len()).collect().item())
    except Exception:
        return None

rows_day   = _rows_or_none(DAY_INDEX_PATH)
rows_sym   = _rows_or_none(SYMBOL_INDEX_PATH)
rows_win   = _rows_or_none(WINDOW_CATALOG)

print(f"🧭 day_index_m5.parquet       : filas={rows_day}")
print(f"🧭 symbol_index_m5.parquet    : filas={rows_sym}")
print(f"🧭 window_catalog_m5.parquet  : filas={rows_win}")

if rows_day is None or rows_day < MIN_DAY_INDEX_ROWS:
    issues.append(f"day_index_m5.parquet inválido o con pocas filas ({rows_day}).")
if rows_sym is None or rows_sym == 0:
    issues.append("symbol_index_m5.parquet inexistente o vacío.")
if rows_win is None or rows_win == 0:
    issues.append("window_catalog_m5.parquet inexistente o vacío.")

# ----------------------------- 3) QA resumen (Celda 16) -------------------------
qa_status = "MISSING"
qa_age_days = None
if QA_SUMMARY_JSON.exists():
    try:
        obj = json.loads(QA_SUMMARY_JSON.read_text(encoding="utf-8"))
        qa_status = str(obj.get("status", "UNKNOWN"))
        mtime = QA_SUMMARY_JSON.stat().st_mtime
        qa_age_days = (datetime.now() - datetime.fromtimestamp(mtime)).days
    except Exception:
        qa_status = "UNREADABLE"

print(f"🧪 QA summary: status={qa_status} | age_days={qa_age_days} | path={QA_SUMMARY_JSON}")
if qa_status not in ("PASS", "EMPTY"):
    issues.append("Último QA no es PASS/EMPTY.")
if qa_age_days is not None and qa_age_days > MIN_QA_MAX_AGE_DAYS:
    issues.append(f"QA summary demasiado antiguo ({qa_age_days} días).")

# ----------------------------- 4) Backup reciente (Celda 13) --------------------
zips = sorted(
    BACKUPS_DIR.glob("*.zip"),
    key=lambda p: p.stat().st_mtime if p.exists() else 0,
    reverse=True
) if BACKUPS_DIR.exists() else []
if zips:
    latest_zip = zips[0]
    size_mb = latest_zip.stat().st_size / (1024 * 1024)
    print(f"💾 Backup más reciente: {latest_zip.name} | ~{size_mb:.2f} MiB")
    if size_mb < MIN_BACKUP_SIZE_MB:
        issues.append(f"Backup más reciente demasiado pequeño ({size_mb:.2f} MiB).")
else:
    latest_zip = None
    print("💾 Backup más reciente: (no encontrado)")
    issues.append("No hay ZIP de backup en backups/.")

# ----------------------------- 5) Gate opcional por ventanas --------------------
eligible_set, elig_label = _read_eligible_set()
base_universe = eligible_set if eligible_set is not None else set(hist_syms)
base_label = elig_label if eligible_set is not None else "clean_fallback"

intersect = base_universe & hist_syms
missing_clean = base_universe - hist_syms
outside_base  = hist_syms - base_universe

print("-"*110)
print(f"🔎 Universo base: {base_label} → {len(base_universe)} símbolo(s)")
print(f"∩ Intersección (base ∩ clean): {len(intersect)} | missing_in_clean={len(missing_clean)} | outside_but_clean={len(outside_base)}")

if REQUIRED_WINDOW not in WINDOWS:
    print(f"⚠️  REQUIRED_WINDOW='{REQUIRED_WINDOW}' inválida. Usando 'last_180d'.")
    REQUIRED_WINDOW = "last_180d"

expected_by_win = {w: _expected_ymds(n) for w, n in WINDOWS.items()}
passed_by_window: Dict[str, set[str]] = {w: set() for w in WINDOWS}
t0 = time.monotonic()
last = t0

for k, sym in enumerate(sorted(intersect), 1):
    for wname, exp_set in expected_by_win.items():
        have = _window_days_for_symbol(wname, sym)
        if exp_set.issubset(have):
            passed_by_window[wname].add(sym)
    if (time.monotonic() - last) >= HEARTBEAT_SECS:
        _log("INFO", f"Ventanas: símbolos evaluados {k}/{len(intersect)}")
        last = time.monotonic()

print("-"*110)
for wname in ("last_30d", "last_90d", "last_180d"):
    if wname in passed_by_window:
        print(f"🪟 {wname}: pasan={len(passed_by_window[wname])} / {len(intersect)}")

min_symbols_hist = max(BASE_MIN_FLOOR, math.ceil(BASE_PCT * max(len(base_universe), 0)))
approved_syms = passed_by_window.get(REQUIRED_WINDOW, set())
approved_count = len(approved_syms)

print(f"📏 Umbral dinámico MIN_SYMBOLS_HIST={min_symbols_hist} (base={len(base_universe)}, regla={int(BASE_PCT*100)}%)")
print(f"🧰 Ventana requerida: {REQUIRED_WINDOW} → aprobados={approved_count}/{len(intersect)}")

# ----------------------------- 6) Universe snapshot + costes + QA operativa -----
print("-"*110)
print("📊 Verificando universe_snapshot, costs_summary y qa_operativa_summary...")

# Universe snapshot (Celda 12B)
universe_syms: Optional[set[str]] = None
universe_exists = False
universe_n = 0

if UNIVERSE_SNAPSHOT_PATH.exists():
    try:
        df_univ = pl.read_parquet(UNIVERSE_SNAPSHOT_PATH)
        if "symbol" not in df_univ.columns:
            raise ValueError("universe_snapshot no tiene columna 'symbol'.")
        universe_syms = set(
            df_univ.get_column("symbol").cast(pl.Utf8, strict=False).to_list()
        )
        universe_n = len(universe_syms)
        universe_exists = True
        _log("INFO", f"Universe snapshot cargado ({universe_n} símbolos) desde {UNIVERSE_SNAPSHOT_PATH}")
    except Exception as e:
        _log("WARNING", f"No se pudo leer universe snapshot {UNIVERSE_SNAPSHOT_PATH}: {e}")
        issues.append("universe_snapshot ilegible o sin columna 'symbol'.")
else:
    _log("WARNING", f"Universe snapshot no encontrado para RUN_ID={RUN_ID}: {UNIVERSE_SNAPSHOT_PATH}")
    issues.append("universe_snapshot inexistente (ejecuta Celda 12B).")

# Costes summary (Celda 05)
costs_exists = COSTS_SUMMARY_PATH.exists()
costs_n_syms = None
costs_n_universe = None
costs_pct_universe = None
costs_flag_dist: Optional[Dict[str, int]] = None
costs_ok_ratio = None

if costs_exists:
    try:
        df_costs = pl.read_parquet(COSTS_SUMMARY_PATH)
        if "symbol" not in df_costs.columns:
            raise ValueError("costs_summary.parquet no tiene columna 'symbol'.")
        syms_costs = set(
            df_costs.get_column("symbol").cast(pl.Utf8, strict=False).to_list()
        )
        costs_n_syms = len(syms_costs)
        _log("INFO", f"costs_summary.parquet cargado ({costs_n_syms} símbolos)")

        if universe_syms is not None and len(universe_syms) > 0:
            inter_costs_univ = syms_costs & universe_syms
            costs_n_universe = len(inter_costs_univ)
            costs_pct_universe = round(
                100.0 * costs_n_universe / len(universe_syms), 1
            )

        if "cost_flag" in df_costs.columns:
            flag_counts = (
                df_costs
                .group_by("cost_flag")
                .agg(pl.len().alias("n"))
                .to_dicts()
            )
            costs_flag_dist = {
                r["cost_flag"]: int(r["n"]) for r in flag_counts
            }
            total_flags = sum(costs_flag_dist.values())
            if total_flags > 0 and "OK" in costs_flag_dist:
                costs_ok_ratio = round(
                    100.0 * costs_flag_dist["OK"] / total_flags, 1
                )
    except Exception as e:
        _log("WARNING", f"No se pudo leer costs_summary.parquet: {e}")
        issues.append("costs_summary ilegible o sin columna 'symbol'.")
        costs_exists = False
else:
    _log("WARNING", f"costs_summary.parquet no encontrado en {COSTS_SUMMARY_PATH}")

# QA operativa summary (Celda 10)
qa_oper_exists = QA_OPER_SUMMARY_PATH.exists()
qa_n_syms = None
qa_n_universe = None
qa_pct_universe = None
qa_flag_dist: Optional[Dict[str, int]] = None
qa_ok_ratio = None

if qa_oper_exists:
    try:
        df_qa = pl.read_parquet(QA_OPER_SUMMARY_PATH)
        if "symbol" not in df_qa.columns:
            raise ValueError("qa_operativa_summary.parquet no tiene columna 'symbol'.")
        syms_qa = set(
            df_qa.get_column("symbol").cast(pl.Utf8, strict=False).to_list()
        )
        qa_n_syms = len(syms_qa)
        _log("INFO", f"qa_operativa_summary.parquet cargado ({qa_n_syms} símbolos)")

        if universe_syms is not None and len(universe_syms) > 0:
            inter_qa_univ = syms_qa & universe_syms
            qa_n_universe = len(inter_qa_univ)
            qa_pct_universe = round(
                100.0 * qa_n_universe / len(universe_syms), 1
            )

        if "qa_operativa_flag" in df_qa.columns:
            flag_counts = (
                df_qa
                .group_by("qa_operativa_flag")
                .agg(pl.len().alias("n"))
                .to_dicts()
            )
            qa_flag_dist = {
                r["qa_operativa_flag"]: int(r["n"]) for r in flag_counts
            }
            total_flags_qa = sum(qa_flag_dist.values())
            if total_flags_qa > 0 and "OK" in qa_flag_dist:
                qa_ok_ratio = round(
                    100.0 * qa_flag_dist["OK"] / total_flags_qa, 1
                )
    except Exception as e:
        _log("WARNING", f"No se pudo leer qa_operativa_summary.parquet: {e}")
        issues.append("qa_operativa_summary ilegible o sin columna 'symbol'.")
        qa_oper_exists = False
else:
    _log("WARNING", f"qa_operativa_summary.parquet no encontrado en {QA_OPER_SUMMARY_PATH}")

print("Resumen costes / QA operativa:")
print(f"  - Universe snapshot: exists={universe_exists} | n_symbols={universe_n}")
print(f"  - costs_summary.parquet: exists={costs_exists} | n_symbols={costs_n_syms}")
print(f"  - qa_operativa_summary.parquet: exists={qa_oper_exists} | n_symbols={qa_n_syms}")
if universe_syms is not None and len(universe_syms) > 0:
    print(
        f"  - Universo con costes: {costs_n_universe}/{len(universe_syms)} "
        f"({costs_pct_universe}%)"
        if costs_n_universe is not None else
        "  - Universo con costes: (no disponible)"
    )
    print(
        f"  - Universo con QA op.: {qa_n_universe}/{len(universe_syms)} "
        f"({qa_pct_universe}%)"
        if qa_n_universe is not None else
        "  - Universo con QA op.: (no disponible)"
    )

# ----------------------------- 7) Resultado & persistencia ----------------------
health = {
    "run_id": RUN_ID,
    "ts_utc": datetime.now(timezone.utc).isoformat(),
    "data_root": str(DATA_ROOT),
    "gold": {
        "files": hist_files,
        "bytes": hist_bytes,
        "symbols": len(hist_syms),
    },
    "indices": {
        "day_rows": rows_day,
        "symbol_rows": rows_sym,
        "window_rows": rows_win,
    },
    "qa": {
        "status": qa_status,
        "age_days": qa_age_days,
        "path": str(QA_SUMMARY_JSON),
    },
    "backup": {
        "latest": (latest_zip.name if latest_zip else None),
        "size_mb": (
            round(latest_zip.stat().st_size / 1024 / 1024, 2)
            if latest_zip else None
        ),
    },
    "universe": {
        "label": base_label,
        "size": len(base_universe),
    },
    "intersection": {
        "size": len(intersect),
    },
    "windows": {
        w: len(passed_by_window.get(w, set())) for w in WINDOWS
    },
    "required_window": {
        "name": REQUIRED_WINDOW,
        "approved": approved_count,
        "min_symbols_hist": min_symbols_hist,
    },
    "universe_snapshot": {
        "path": str(UNIVERSE_SNAPSHOT_PATH),
        "exists": universe_exists,
        "n_symbols": universe_n,
    },
    "costs": {
        "path": str(COSTS_SUMMARY_PATH),
        "has_costs_summary": costs_exists,
        "exists": costs_exists,
        "n_symbols_costs": costs_n_syms,
        "n_symbols_universe_with_costs": costs_n_universe,
        "pct_universe_with_costs": costs_pct_universe,
        "cost_flag_distribution": costs_flag_dist,
        "cost_flag_ok_ratio_pct": costs_ok_ratio,
    },
    "qa_operativa": {
        "path": str(QA_OPER_SUMMARY_PATH),
        "has_qa_operativa_summary": qa_oper_exists,
        "exists": qa_oper_exists,
        "n_symbols_qa_operativa": qa_n_syms,
        "n_symbols_universe_with_qa_operativa": qa_n_universe,
        "pct_universe_with_qa_operativa": qa_pct_universe,
        "qa_operativa_flag_distribution": qa_flag_dist,
        "qa_operativa_flag_ok_ratio_pct": qa_ok_ratio,
    },
    "issues": issues,
}

HEALTH_JSON.write_text(json.dumps(health, ensure_ascii=False, indent=2), encoding="utf-8")

print("-"*110)
print(f"📄 Reporte de salud escrito en: {HEALTH_JSON}")

# Flags opcionales (no obligatorio; desactivado por defecto)
if WRITE_FLAGS:
    gate_ok = (approved_count >= min_symbols_hist) and (len(issues) == 0)
    if gate_ok:
        FLAG_READY.write_text(f"[{RUN_ID}] TRADING_READY\n", encoding="utf-8")
        if FLAG_NOT.exists():
            try:
                FLAG_NOT.unlink()
            except Exception:
                pass
        print("✅ Gate OK → TRADING_READY.flag escrito (WRITE_FLAGS=True).")
    else:
        FLAG_NOT.write_text(
            f"[{RUN_ID}] TRADING_NOT_READY\n" + "\n".join(issues),
            encoding="utf-8"
        )
        if FLAG_READY.exists():
            try:
                FLAG_READY.unlink()
            except Exception:
                pass
        print("❌ Gate NO-OK → TRADING_NOT_READY.flag escrito (WRITE_FLAGS=True).")
else:
    print("ℹ️  WRITE_FLAGS=False (no se escriben flags). Usa WRITE_FLAGS=True para emitir banderas.")

print("="*110)
print("✅ Auditoría integral completada (lectura-only, sin reemplazar pasos del pipeline).")
_log("INFO", "Auditoría integral completada y pipeline_health_report.json actualizado")
# ==============================================================================================================
# Out:
# ==============================================================================================================
# Celda 18 — Auditoría integral de PADs (opcional). NO reemplaza 10/12/15.
# TZ local: America/Guayaquil
# Hora local: 2025-12-03T05:32:33-05:00 | Hora UTC: 2025-12-03T10:32:33+00:00
# --------------------------------------------------------------------------------------------------------------
# DATA_ROOT: C:\Quant\MT5_Data_Extraction\data
# Metadata:  C:\Quant\MT5_Data_Extraction\data\metadata
# Artefactos clave esperados:
#   - GOLD (m5_clean)        : C:\Quant\MT5_Data_Extraction\data\historical_data\m5_clean
#   - WINDOWS (m5_windows)   : C:\Quant\MT5_Data_Extraction\data\processed_data\m5_windows
#   - Índices (Celda 15)     : C:\Quant\MT5_Data_Extraction\data\metadata\day_index_m5.parquet, C:\Quant\MT5_Data_Extraction\data\metadata\symbol_index_m5.parquet, C:\Quant\MT5_Data_Extraction\data\metadata\window_catalog_m5.parquet
#   - QA trading ready (16)  : C:\Quant\MT5_Data_Extraction\data\metadata\qa_trading_ready_summary.json
#   - Costes summary (05)    : C:\Quant\MT5_Data_Extraction\data\metadata\costs_summary.parquet
#   - QA operativa (10)      : C:\Quant\MT5_Data_Extraction\data\metadata\qa_operativa_summary.parquet
#   - Universe snapshot (12B): C:\Quant\MT5_Data_Extraction\data\metadata\universe_snapshot_20251202_232253.parquet
# --------------------------------------------------------------------------------------------------------------
# 📦 GOLD (m5_clean): files=103,917 | bytes=1.03 GiB | symbols=92
# 🧭 day_index_m5.parquet       : filas=103917
# 🧭 symbol_index_m5.parquet    : filas=92
# 🧭 window_catalog_m5.parquet  : filas=3
# 🧪 QA summary: status=EMPTY | age_days=0 | path=C:\Quant\MT5_Data_Extraction\data\metadata\qa_trading_ready_summary.json
# 💾 Backup más reciente: backup_m5_20251202_232253.zip | ~1035.76 MiB
# --------------------------------------------------------------------------------------------------------------
# 🔎 Universo base: eligible_3B(parquet) → 107 símbolo(s)
# ∩ Intersección (base ∩ clean): 89 | missing_in_clean=18 | outside_but_clean=3
# --------------------------------------------------------------------------------------------------------------
# 🪟 last_30d: pasan=29 / 89
# 🪟 last_90d: pasan=0 / 89
# 🪟 last_180d: pasan=0 / 89
# 📏 Umbral dinámico MIN_SYMBOLS_HIST=75 (base=107, regla=70%)
# 🧰 Ventana requerida: last_30d → aprobados=29/89
# --------------------------------------------------------------------------------------------------------------
# 📊 Verificando universe_snapshot, costs_summary y qa_operativa_summary...
# [2025-12-03 05:32:36] [20251202_232253] [INFO] [18-Health-Audit] Universe snapshot cargado (107 símbolos) desde C:\Quant\MT5_Data_Extraction\data\metadata\universe_snapshot_20251202_232253.parquet
# [2025-12-03 05:32:36] [20251202_232253] [INFO] [18-Health-Audit] costs_summary.parquet cargado (131 símbolos)
# [2025-12-03 05:32:36] [20251202_232253] [INFO] [18-Health-Audit] qa_operativa_summary.parquet cargado (107 símbolos)
# Resumen costes / QA operativa:
#   - Universe snapshot: exists=True | n_symbols=107
#   - costs_summary.parquet: exists=True | n_symbols=131
#   - qa_operativa_summary.parquet: exists=True | n_symbols=107
#   - Universo con costes: 89/107 (83.2%)
#   - Universo con QA op.: 89/107 (83.2%)
# --------------------------------------------------------------------------------------------------------------
# 📄 Reporte de salud escrito en: C:\Quant\MT5_Data_Extraction\data\metadata\pipeline_health_report.json
# ❌ Gate NO-OK → TRADING_NOT_READY.flag escrito (WRITE_FLAGS=True).
# ==============================================================================================================
# ✅ Auditoría integral completada (lectura-only, sin reemplazar pasos del pipeline).
# [2025-12-03 05:32:36] [20251202_232253] [INFO] [18-Health-Audit] Auditoría integral completada y pipeline_health_report.json actualizado

# %%
# Out:
# ====================================================================================================
# Muestreo ligero de archivos PARQUET
# DATA_ROOT : C:\Quant\MT5_Data_Extraction\data
# LOG_PATH  : C:\Quant\MT5_Data_Extraction\data\logs\parquet_sample_20251203_231541.txt
# ====================================================================================================
# Total de archivos .parquet encontrados: 1326898
# ----------------------------------------------------------------------------------------------------
# Resumen por carpeta raíz:
#   - bulk_data           : 121457 parquets
#   - historical_data     : 103917 parquets
#   - metadata            :     22 parquets
#   - processed_data      :  28054 parquets
#   - restore             : 1073448 parquets
# ----------------------------------------------------------------------------------------------------
# Archivos 'interesantes' por nombre (cost/param/fee/...): 40
#   → costs_summary.parquet encontrado : True
#   → ea_params.parquet encontrado     : False
#   → ea_params.csv encontrado         : False
# Muestras seleccionadas para el log: 40 archivos
# [1/40] metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [2/40] metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [3/40] metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'days_price_ok', 'days_price_warn', 'days_price_bad', 'days_price_empty', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'price_ok_ratio', 'price_bad_ratio', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag', 'qa_operativa_flag', 'qa_price_flag']
# [4/40] metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [5/40] restore\restore_20251119_203858\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [6/40] restore\restore_20251119_203858\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [7/40] restore\restore_20251119_203858\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'qa_operativa_flag']
# [8/40] restore\restore_20251119_203858\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [9/40] restore\restore_20251120_052600\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [10/40] restore\restore_20251120_052600\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [11/40] restore\restore_20251120_052600\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'qa_operativa_flag', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag']
# [12/40] restore\restore_20251120_052600\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [13/40] restore\restore_20251120_114220\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [14/40] restore\restore_20251120_114220\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [15/40] restore\restore_20251120_114220\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'qa_operativa_flag', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag']
# [16/40] restore\restore_20251120_114220\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [17/40] restore\restore_20251120_181107\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [18/40] restore\restore_20251120_181107\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [19/40] restore\restore_20251120_181107\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'qa_operativa_flag', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag']
# [20/40] restore\restore_20251120_181107\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [21/40] restore\restore_20251120_224711\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [22/40] restore\restore_20251120_224711\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [23/40] restore\restore_20251120_224711\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag', 'qa_operativa_flag']
# [24/40] restore\restore_20251120_224711\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [25/40] restore\restore_20251121_103142\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [26/40] restore\restore_20251121_103142\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [27/40] restore\restore_20251121_103142\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag', 'qa_operativa_flag']
# [28/40] restore\restore_20251121_103142\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [29/40] restore\restore_20251121_161336\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [30/40] restore\restore_20251121_161336\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [31/40] bulk_data\m5_raw\symbol=AAPL\year=2021\month=11\part=20211119.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [32/40] bulk_data\m5_raw\symbol=AAPL\year=2021\month=11\part=20211122.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [33/40] historical_data\m5_clean\symbol=AAPL\year=2021\month=11\part=20211119.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [34/40] historical_data\m5_clean\symbol=AAPL\year=2021\month=11\part=20211122.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [35/40] metadata\dataset_catalog.parquet
#    columnas: ['symbol', 'first_ts_utc', 'last_ts_utc', 'n_files', 'n_days', 'n_months', 'n_years', 'bytes', 'last_update_ts_utc', 'notes']
# [36/40] metadata\day_index_m5.parquet
#    columnas: ['symbol', 'date', 'path', 'bytes', 'n_rows', 'min_ts', 'max_ts', 'dups']
# [37/40] processed_data\m5_windows\window=last_180d\symbol=AAPL\part=20250527.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [38/40] processed_data\m5_windows\window=last_180d\symbol=AAPL\part=20250528.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [39/40] restore\restore_20251119_203858\bulk_data\m5_raw\symbol=AAPL\year=2021\month=11\part=20211119.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [40/40] restore\restore_20251119_203858\bulk_data\m5_raw\symbol=AAPL\year=2021\month=11\part=20211122.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# ----------------------------------------------------------------------------------------------------
# ✅ Muestreo completado.
# Log (ligero) generado en: C:\Quant\MT5_Data_Extraction\data\logs\parquet_sample_20251203_231541.txt
# Sube ese TXT si quieres que lo revisemos aquí.
# ====================================================================================================
#
# CONCLUSIÓN RÁPIDA SOBRE COSTES / PARAMS
#   ✔ Existe un costs_summary.parquet (costes por símbolo).
#   ✖ No hay ea_params.parquet ni ea_params.csv → el ER_FILTER_5M seguirá en AUTOGEN.
# ====================================================================================================

# %%
# ========== Celda — Construir ea_params.parquet con comisión rellena (valores típicos) ==========
from pathlib import Path
import polars as pl

# -----------------------------------------------------------------------------------
# 0) Parámetros de comisión por defecto (en bps de notional)
#    Ajusta estos números a algo razonable para tu broker.
# -----------------------------------------------------------------------------------
GLOBAL_DEFAULT_COMMISSION_BPS = 0.5  # fallback global si no hay nada mejor

ASSET_CLASS_DEFAULTS = {
    "FX_MAJOR":   0.2,
    "FX_MINOR":   0.3,
    "FX_EXOTIC":  0.5,
    "INDEX":      0.2,
    "STOCK_US":   0.5,
    "STOCK_EU":   0.5,
    "STOCK":      0.5,
    "CRYPTO":     1.0,
    "COMMODITY":  0.4,
}

# 1) Rutas
DATA_ROOT   = Path(globals().get("DATA_ROOT", str(path_contract.data_root()))).resolve()
META_DIR    = DATA_ROOT / "metadata"
FILTERS_DIR = META_DIR / "filters"

COSTS_PATH    = META_DIR / "costs_summary.parquet"
ELIGIBLE_PATH = FILTERS_DIR / "eligible_symbols_by_cost.parquet"
EA_PARAMS_OUT = DATA_ROOT / "ea_params.parquet"

print("=" * 90)
print("Construyendo ea_params.parquet a partir de costs_summary (rellenando comisión)...")
print(f"DATA_ROOT        : {DATA_ROOT}")
print(f"COSTS_PATH       : {COSTS_PATH}")
print(f"ELIGIBLE_PATH    : {ELIGIBLE_PATH}")
print(f"EA_PARAMS_OUT    : {EA_PARAMS_OUT}")
print(f"GLOBAL_DEFAULT_COMMISSION_BPS = {GLOBAL_DEFAULT_COMMISSION_BPS}")
print("=" * 90)

# 2) Cargar tabla de costes principal
if not COSTS_PATH.exists():
    raise FileNotFoundError(f"No existe {COSTS_PATH}. Ejecuta antes la celda de costes (Celda 05).")

costs = pl.read_parquet(str(COSTS_PATH))
costs = costs.rename({c: c.lower() for c in costs.columns})

required_cols = {"symbol", "asset_class", "spread_bps", "commission_bps", "cost_bps"}
missing = required_cols - set(costs.columns)
if missing:
    raise RuntimeError(f"costs_summary.parquet NO tiene columnas requeridas: {missing}")

print(f"costs_summary: {costs.height} filas, columnas = {costs.columns}")

# 3) (Opcional) cruzar con lista de símbolos elegibles por coste
if ELIGIBLE_PATH.exists():
    elig = pl.read_parquet(str(ELIGIBLE_PATH))
    elig = elig.rename({c: c.lower() for c in elig.columns})
else:
    elig = None  # hook para futuro

if "eligible" in costs.columns:
    costs_valid = costs.filter(pl.col("eligible") == True)
    print(f"  -> usando solo símbolos elegibles de costs_summary: {costs_valid.height} filas.")
else:
    costs_valid = costs
    print("  -> columna 'eligible' no encontrada, se usan todos los símbolos.")

# 4) Calcular comisión típica por asset_class a partir de valores > 0
print("-" * 90)
print("Calculando comisión típica por asset_class (solo commission_bps > 0)...")

non_zero = costs_valid.filter(pl.col("commission_bps") > 0)

if non_zero.height > 0:
    typical_by_class = (
        non_zero
        .group_by("asset_class")
        .agg(
            pl.col("commission_bps")
            .median()
            .alias("typical_commission_bps")
        )
    )
else:
    print("⚠ No hay ninguna commission_bps > 0. No se puede calcular mediana por asset_class.")
    # Creamos una tabla vacía pero con el esquema correcto para que el join no explote
    typical_by_class = (
        costs_valid
        .select("asset_class")
        .unique()
        .with_columns(
            pl.lit(None)
            .cast(pl.Float64)
            .alias("typical_commission_bps")
        )
    )

print("Tabla de comisiones típicas por asset_class:")
print(typical_by_class)

# 5) Rellenar commission_bps = 0 con típicos o default por asset_class / global
costs_filled = (
    costs_valid
    .join(typical_by_class, on="asset_class", how="left")
    .with_columns(
        # Comisión por defecto según asset_class (o GLOBAL_DEFAULT si no está en el diccionario)
        pl.col("asset_class")
        .replace(ASSET_CLASS_DEFAULTS, default=GLOBAL_DEFAULT_COMMISSION_BPS)
        .alias("asset_class_default_commission")
    )
    .with_columns(
        pl.when(pl.col("commission_bps") > 0)
          .then(pl.col("commission_bps"))
          .when(pl.col("typical_commission_bps").is_not_null())
          .then(pl.col("typical_commission_bps"))
          .otherwise(pl.col("asset_class_default_commission"))
          .alias("commission_eff_bps")
    )
)

# Pequeño resumen antes/después (solo diagnóstico)
n_zero_before = costs_valid.filter(pl.col("commission_bps") == 0).height
n_zero_after  = costs_filled.filter(pl.col("commission_eff_bps") == 0).height

print("-" * 90)
print(f"Filas con commission_bps == 0 ANTES del relleno : {n_zero_before}")
print(f"Filas con commission_eff_bps == 0 DESPUÉS      : {n_zero_after}")
print("Ejemplo de commission_eff_bps por símbolo:")
print(
    costs_filled
    .select(["symbol", "asset_class", "commission_bps",
             "typical_commission_bps", "asset_class_default_commission",
             "commission_eff_bps"])
    .head(10)
)

# 6) Construir tabla de parámetros para ER_FILTER_5M
params_df = (
    costs_filled
    .select(
        pl.col("symbol").cast(pl.Utf8),
        pl.col("commission_eff_bps").cast(pl.Float64).alias("commission"),
        pl.lit("from_costs_summary_bps_filled").alias("spread_rule"),
        pl.col("spread_bps").cast(pl.Float64).alias("spread_est"),
    )
    .unique(subset=["symbol"])
)

print("-" * 90)
print(f"ea_params a escribir: {params_df.height} símbolos únicos.")
print(params_df.head(5))

# 7) Guardar en data/ea_params.parquet
params_df.write_parquet(str(EA_PARAMS_OUT))
print("=" * 90)
print(f"✅ ea_params.parquet generado en: {EA_PARAMS_OUT}")
print("   Columnas: ", params_df.columns)
print("=" * 90)
# Out:
# ==========================================================================================
# Construyendo ea_params.parquet a partir de costs_summary (rellenando comisión)...
# DATA_ROOT        : C:\Quant\MT5_Data_Extraction\data
# COSTS_PATH       : C:\Quant\MT5_Data_Extraction\data\metadata\costs_summary.parquet
# ELIGIBLE_PATH    : C:\Quant\MT5_Data_Extraction\data\metadata\filters\eligible_symbols_by_cost.parquet
# EA_PARAMS_OUT    : C:\Quant\MT5_Data_Extraction\data\ea_params.parquet
# GLOBAL_DEFAULT_COMMISSION_BPS = 0.5
# ==========================================================================================
# costs_summary: 131 filas, columnas = ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
#   -> usando solo símbolos elegibles de costs_summary: 107 filas.
# ------------------------------------------------------------------------------------------
# Calculando comisión típica por asset_class (solo commission_bps > 0)...
# ⚠ No hay ninguna commission_bps > 0. No se puede calcular mediana por asset_class.
# Tabla de comisiones típicas por asset_class:
# shape: (5, 2)
# ┌─────────────┬────────────────────────┐
# │ asset_class ┆ typical_commission_bps │
# │ ---         ┆ ---                    │
# │ str         ┆ f64                    │
# ╞═════════════╪════════════════════════╡
# │ METAL       ┆ null                   │
# │ OTHER       ┆ null                   │
# │ CRYPTO      ┆ null                   │
# │ INDEX       ┆ null                   │
# │ FX_MAJOR    ┆ null                   │
# └─────────────┴────────────────────────┘
# ------------------------------------------------------------------------------------------
# Filas con commission_bps == 0 ANTES del relleno : 107
# Filas con commission_eff_bps == 0 DESPUÉS      : 0
# Ejemplo de commission_eff_bps por símbolo:
# shape: (10, 6)
# ┌────────┬─────────────┬────────────────┬───────────────────┬───────────────────┬──────────────────┐
# │ symbol ┆ asset_class ┆ commission_bps ┆ typical_commissio ┆ asset_class_defau ┆ commission_eff_b │
# │ ---    ┆ ---         ┆ ---            ┆ n_bps             ┆ lt_commission     ┆ ps               │
# │ str    ┆ str         ┆ f64            ┆ ---               ┆ ---               ┆ ---              │
# │        ┆             ┆                ┆ f64               ┆ f64               ┆ f64              │
# ╞════════╪═════════════╪════════════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ EURUSD ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# │ GBPUSD ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# │ USDCHF ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# │ USDJPY ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# │ USDCAD ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# │ AUDUSD ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# │ AUDNZD ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# │ AUDCAD ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# │ AUDCHF ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# │ AUDJPY ┆ FX_MAJOR    ┆ 0.0            ┆ null              ┆ 0.2               ┆ 0.2              │
# └────────┴─────────────┴────────────────┴───────────────────┴───────────────────┴──────────────────┘
# ------------------------------------------------------------------------------------------
# ea_params a escribir: 107 símbolos únicos.
# shape: (5, 4)
# ┌──────────┬────────────┬───────────────────────────────┬────────────┐
# │ symbol   ┆ commission ┆ spread_rule                   ┆ spread_est │
# │ ---      ┆ ---        ┆ ---                           ┆ ---        │
# │ str      ┆ f64        ┆ str                           ┆ f64        │
# ╞══════════╪════════════╪═══════════════════════════════╪════════════╡
# │ MANUSD   ┆ 1.0        ┆ from_costs_summary_bps_filled ┆ 6.691201   │
# │ DXY.cash ┆ 0.2        ┆ from_costs_summary_bps_filled ┆ 1.607604   │
# │ DOGEUSD  ┆ 1.0        ┆ from_costs_summary_bps_filled ┆ 6.613514   │
# │ ALGUSD   ┆ 1.0        ┆ from_costs_summary_bps_filled ┆ 23.068051  │
# │ XAUEUR   ┆ 0.5        ┆ from_costs_summary_bps_filled ┆ 1.080588   │
# └──────────┴────────────┴───────────────────────────────┴────────────┘
# ==========================================================================================
# ✅ ea_params.parquet generado en: C:\Quant\MT5_Data_Extraction\data\ea_params.parquet
#    Columnas:  ['symbol', 'commission', 'spread_rule', 'spread_est']
# ==========================================================================================
# C:\Users\PC\AppData\Local\Temp\ipykernel_5380\3890395035.py:109: DeprecationWarning: the `default` parameter for `replace` is deprecated. Use `replace_strict` instead to set a default while replacing values.
# (Deprecated in version 1.0.0)
#   .replace(ASSET_CLASS_DEFAULTS, default=GLOBAL_DEFAULT_COMMISSION_BPS)

# %%
 # ===================== Celda — Muestreo ligero de PARQUET + Conclusiones =====================
# - Resume cuántos parquets hay por carpeta de primer nivel.
# - Busca archivos "interesantes" por nombre: cost, fee, param, summary, ea_, watchlist.
# - Toma SOLO unas pocas muestras y genera un log pequeño con esquemas y 3 filas de ejemplo.
# =============================================================================================

from __future__ import annotations

from pathlib import Path
from datetime import datetime
import polars as pl

# ---------------------------- Configuración ----------------------------------

DATA_ROOT = Path(globals().get("DATA_ROOT", str(path_contract.data_root()))).resolve()

MAX_ROWS_PER_FILE       = 3   # filas de ejemplo por archivo
MAX_SAMPLES_PER_FOLDER  = 2   # máximo de parquets muestreados por carpeta raíz
MAX_RANDOM_SAMPLES      = 10  # número máximo de parquets "random" extra (por si no hay interesantes)

INTERESTING_KEYWORDS = ["cost", "fee", "param", "summary", "ea_", "watchlist"]

LOGS_DIR = DATA_ROOT / "logs"
LOGS_DIR.mkdir(parents=True, exist_ok=True)
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
LOG_PATH = LOGS_DIR / f"parquet_sample_{timestamp}.txt"

print("=" * 100)
print("Muestreo ligero de archivos PARQUET")
print(f"DATA_ROOT : {DATA_ROOT}")
print(f"LOG_PATH  : {LOG_PATH}")
print("=" * 100)

# ---------------------------- Localizar parquets ------------------------------

all_parquets = list(DATA_ROOT.rglob("*.parquet"))
total_files  = len(all_parquets)

print(f"Total de archivos .parquet encontrados: {total_files}")
if total_files == 0:
    print("⚠️  No hay parquets bajo DATA_ROOT, paro aquí.")
    raise SystemExit

# Agrupar por carpeta de primer nivel (bulk_data, metadata, etc.)
from collections import defaultdict
by_root = defaultdict(list)

for p in all_parquets:
    rel = p.relative_to(DATA_ROOT)
    parts = rel.parts
    root = parts[0] if len(parts) > 1 else "."
    by_root[root].append(p)

print("-" * 100)
print("Resumen por carpeta raíz:")
for root, files in sorted(by_root.items(), key=lambda kv: kv[0]):
    print(f"  - {root:<20s}: {len(files):6d} parquets")

print("-" * 100)

# ---------------------------- Buscar archivos "interesantes" ------------------

interesting = []
for p in all_parquets:
    name = p.name.lower()
    if any(k in name for k in INTERESTING_KEYWORDS):
        interesting.append(p)

# quitar duplicados manteniendo orden
seen = set()
interesting_unique = []
for p in interesting:
    if p not in seen:
        seen.add(p)
        interesting_unique.append(p)

print(f"Archivos 'interesantes' por nombre (cost/param/fee/...): {len(interesting_unique)}")

# Marcar si vemos alguno clave
found_costs_summary = any(p.name.lower() == "costs_summary.parquet" for p in interesting_unique)
found_ea_params_parquet = any(p.name.lower() == "ea_params.parquet" for p in interesting_unique)
found_ea_params_csv     = any(p.name.lower() == "ea_params.csv" for p in all_parquets)

print(f"  → costs_summary.parquet encontrado : {found_costs_summary}")
print(f"  → ea_params.parquet encontrado     : {found_ea_params_parquet}")
print(f"  → ea_params.csv encontrado         : {found_ea_params_csv}")

# ---------------------------- Seleccionar muestras ----------------------------

samples = []

# 1) Primero, todos los interesantes (pero limitando a 30 máximo)
MAX_INTERESTING = 30
for p in interesting_unique[:MAX_INTERESTING]:
    samples.append(p)

# 2) Luego, hasta N por carpeta raíz, si aún no llenamos
for root, files in sorted(by_root.items(), key=lambda kv: kv[0]):
    # ya tenemos suficientes muestras → salimos
    if len(samples) >= MAX_INTERESTING + MAX_RANDOM_SAMPLES:
        break
    # coger los primeros MAX_SAMPLES_PER_FOLDER de esa carpeta que no estén ya
    count_for_root = 0
    for p in sorted(files):
        if p in samples:
            continue
        samples.append(p)
        count_for_root += 1
        if count_for_root >= MAX_SAMPLES_PER_FOLDER:
            break

print(f"Muestras seleccionadas para el log: {len(samples)} archivos")

# ---------------------------- Volcar esquemas al log -------------------------

with open(LOG_PATH, "w", encoding="utf-8") as logf:
    logf.write(f"PARQUET SAMPLE - {datetime.now().isoformat(timespec='seconds')}\n")
    logf.write(f"DATA_ROOT = {DATA_ROOT}\n")
    logf.write(f"TOTAL PARQUETS  = {total_files}\n")
    logf.write(f"SAMPLED PARQUETS= {len(samples)}\n")
    logf.write("=" * 100 + "\n\n")

    for idx, path in enumerate(samples, start=1):
        rel = path.relative_to(DATA_ROOT)
        hdr = f"[{idx}/{len(samples)}] {rel}"
        print(hdr)  # resumen en pantalla
        logf.write("=" * 100 + "\n")
        logf.write(hdr + "\n")

        try:
            df_head = pl.read_parquet(str(path), n_rows=MAX_ROWS_PER_FILE)
            schema = df_head.schema
            logf.write(f"Columns ({len(schema)}): {list(schema.keys())}\n")
            logf.write(f"DTypes : {list(schema.values())}\n\n")
            logf.write("Sample rows:\n")
            logf.write(df_head.__repr__() + "\n\n")

            # pequeña impresión en notebook para que veas algo
            print(f"   columnas: {list(schema.keys())}")
        except Exception as e:
            msg = f"ERROR leyendo parquet: {repr(e)}"
            logf.write(msg + "\n\n")
            print("   ❌ " + msg)

print("-" * 100)
print("✅ Muestreo completado.")
print(f"Log (ligero) generado en: {LOG_PATH}")
print("Sube ese TXT si quieres que lo revisemos aquí.")
print("=" * 100)

# ---------------------------- Conclusión rápida --------------------------------

print("\nCONCLUSIÓN RÁPIDA SOBRE COSTES / PARAMS")
if found_costs_summary:
    print("  ✔ Existe un costs_summary.parquet (costes por símbolo).")
else:
    print("  ✖ NO se encontró costs_summary.parquet por nombre. Puede estar con otro nombre.")

if found_ea_params_parquet or found_ea_params_csv:
    print("  ✔ Existe algún ea_params.* → el ER_FILTER_5M debería usarlo en vez de autogen.")
else:
    print("  ✖ No hay ea_params.parquet ni ea_params.csv → el ER_FILTER_5M seguirá en AUTOGEN.")
print("=" * 100)
# Out:
# ====================================================================================================
# Muestreo ligero de archivos PARQUET
# DATA_ROOT : C:\Quant\MT5_Data_Extraction\data
# LOG_PATH  : C:\Quant\MT5_Data_Extraction\data\logs\parquet_sample_20251203_235118.txt
# ====================================================================================================
# Total de archivos .parquet encontrados: 1326899
# ----------------------------------------------------------------------------------------------------
# Resumen por carpeta raíz:
#   - .                   :      1 parquets
#   - bulk_data           : 121457 parquets
#   - historical_data     : 103917 parquets
#   - metadata            :     22 parquets
#   - processed_data      :  28054 parquets
#   - restore             : 1073448 parquets
# ----------------------------------------------------------------------------------------------------
# Archivos 'interesantes' por nombre (cost/param/fee/...): 41
#   → costs_summary.parquet encontrado : True
#   → ea_params.parquet encontrado     : True
#   → ea_params.csv encontrado         : False
# Muestras seleccionadas para el log: 40 archivos
# [1/40] ea_params.parquet
#    columnas: ['symbol', 'commission', 'spread_rule', 'spread_est']
# [2/40] metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [3/40] metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [4/40] metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'days_price_ok', 'days_price_warn', 'days_price_bad', 'days_price_empty', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'price_ok_ratio', 'price_bad_ratio', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag', 'qa_operativa_flag', 'qa_price_flag']
# [5/40] metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [6/40] restore\restore_20251119_203858\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [7/40] restore\restore_20251119_203858\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [8/40] restore\restore_20251119_203858\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'qa_operativa_flag']
# [9/40] restore\restore_20251119_203858\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [10/40] restore\restore_20251120_052600\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [11/40] restore\restore_20251120_052600\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [12/40] restore\restore_20251120_052600\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'qa_operativa_flag', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag']
# [13/40] restore\restore_20251120_052600\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [14/40] restore\restore_20251120_114220\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [15/40] restore\restore_20251120_114220\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [16/40] restore\restore_20251120_114220\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'qa_operativa_flag', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag']
# [17/40] restore\restore_20251120_114220\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [18/40] restore\restore_20251120_181107\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [19/40] restore\restore_20251120_181107\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [20/40] restore\restore_20251120_181107\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'qa_operativa_flag', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag']
# [21/40] restore\restore_20251120_181107\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [22/40] restore\restore_20251120_224711\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [23/40] restore\restore_20251120_224711\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [24/40] restore\restore_20251120_224711\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag', 'qa_operativa_flag']
# [25/40] restore\restore_20251120_224711\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [26/40] restore\restore_20251121_103142\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [27/40] restore\restore_20251121_103142\metadata\data_quality_summary.parquet
#    columnas: ['symbol', 'first_date', 'last_date', 'days_with_data', 'days_expected', 'coverage_days', 'total_candles', 'days_with_large_gaps', 'missing_candles_pct', 'bad_days_ratio', 'data_quality_score', 'data_quality_flag', 'comentario']
# [28/40] restore\restore_20251121_103142\metadata\qa_operativa_summary.parquet
#    columnas: ['symbol', 'n_days', 'days_ok', 'days_warn', 'days_fail', 'days_empty', 'n_bars_mean', 'n_bars_p50', 'rejilla_pct_mean', 'days_rejilla_ge_warn', 'days_low_gt_high', 'p50_spread_bps_mean', 'p90_spread_bps_mean', 'p99_spread_bps_mean', 'ok_ratio', 'warn_ratio', 'fail_ratio', 'empty_ratio', 'rejilla_ge_warn_ratio', 'low_gt_high_ratio', 'expected_bars_per_day_symbol', 'session_type', 'qa_struct_flag', 'qa_operativa_flag']
# [29/40] restore\restore_20251121_103142\metadata\filters\eligible_symbols_by_cost.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'reason']
# [30/40] restore\restore_20251121_161336\metadata\costs_summary.parquet
#    columnas: ['symbol', 'asset_class', 'spread_bps', 'commission_bps', 'slippage_bps', 'cost_bps', 'threshold_bps', 'eligible', 'reason', 'cost_flag']
# [31/40] bulk_data\m5_raw\symbol=AAPL\year=2021\month=11\part=20211119.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [32/40] bulk_data\m5_raw\symbol=AAPL\year=2021\month=11\part=20211122.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [33/40] historical_data\m5_clean\symbol=AAPL\year=2021\month=11\part=20211119.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [34/40] historical_data\m5_clean\symbol=AAPL\year=2021\month=11\part=20211122.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [35/40] metadata\dataset_catalog.parquet
#    columnas: ['symbol', 'first_ts_utc', 'last_ts_utc', 'n_files', 'n_days', 'n_months', 'n_years', 'bytes', 'last_update_ts_utc', 'notes']
# [36/40] metadata\day_index_m5.parquet
#    columnas: ['symbol', 'date', 'path', 'bytes', 'n_rows', 'min_ts', 'max_ts', 'dups']
# [37/40] processed_data\m5_windows\window=last_180d\symbol=AAPL\part=20250527.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [38/40] processed_data\m5_windows\window=last_180d\symbol=AAPL\part=20250528.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [39/40] restore\restore_20251119_203858\bulk_data\m5_raw\symbol=AAPL\year=2021\month=11\part=20211119.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# [40/40] restore\restore_20251119_203858\bulk_data\m5_raw\symbol=AAPL\year=2021\month=11\part=20211122.parquet
#    columnas: ['timestamp_utc', 'timestamp_gye', 'symbol', 'open', 'high', 'low', 'close', 'tick_volume', 'real_volume', 'spread_points', 'broker', 'server_tz']
# ----------------------------------------------------------------------------------------------------
# ✅ Muestreo completado.
# Log (ligero) generado en: C:\Quant\MT5_Data_Extraction\data\logs\parquet_sample_20251203_235118.txt
# Sube ese TXT si quieres que lo revisemos aquí.
# ====================================================================================================
#
# CONCLUSIÓN RÁPIDA SOBRE COSTES / PARAMS
#   ✔ Existe un costs_summary.parquet (costes por símbolo).
#   ✔ Existe algún ea_params.* → el ER_FILTER_5M debería usarlo en vez de autogen.
# ====================================================================================================
